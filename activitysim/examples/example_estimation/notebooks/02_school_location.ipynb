# %% [markdown]
# # Estimating School Location Choice
#
# This notebook illustrates how to re-estimate a single model component for ActivitySim.  This process
# includes running ActivitySim in estimation mode to read household travel survey files and write out
# the estimation data bundles used in this notebook.  To review how to do so, please visit the other
# notebooks in this directory.

# %% [markdown]
# # Load libraries

# %%
import larch  # !conda install larch #for estimation
import pandas as pd
import numpy as np
import yaml 
import larch.util.excel
import os

# %% [markdown]
# We'll work in our `test` directory, where ActivitySim has saved the estimation data bundles.

# %%
os.chdir('test')

# %% [markdown]
# # Load data and prep model for estimation

# %%
modelname="school_location"

# %%
from activitysim.estimation.larch import component_model
model, data = component_model(modelname, return_data=True)

# %% [markdown]
# # Review data loaded from EDB
#
# Next we can review what was read the EDB, including the coefficients, model settings, utilities specification, and chooser and alternative data.

# %% [markdown]
# ## coefficients

# %%
data.coefficients
# Out:
#                            value constrain
# coefficient_name
# coef_univ_dist_0_1       -3.2451         F
# coef_univ_dist_1_2       -2.7011         F
# coef_univ_dist_2_5       -0.5707         F
# coef_univ_dist_5_15      -0.5002         F
# coef_univ_dist_15_up     -0.0730         F
# coef_high_dist_0_1       -0.9523         F
# coef_high_grade_dist_1_2 -0.5700         F
# coef_high_grade_dist_2_5 -0.5700         F
# coef_high_dist_5_15      -0.1930         F
# coef_high_dist_15_up     -0.1882         F
# coef_grade_dist_0_1      -1.6419         F
# coef_grade_dist_5_15     -0.2031         F
# coef_grade_dist_15_up    -0.0460         F
# coef_mode_logsum          0.5358         F

# %% [markdown]
# ## alt_values

# %%
data.alt_values
# Out:
#        person_id                           variable                      5  \
# 0            629                 mode_choice_logsum    -1.2112310566711697
# 1            629                         pick_count                    1.0
# 2            629                               prob  3.964160543594042e-05
# 3            629  shadow_price_size_term_adjustment                    1.0
# 4            629    shadow_price_utility_adjustment                    0.0
# ...          ...                                ...                    ...
# 15739    7541072            util_mode_choice_logsum    0.40135279939989227
# 15740    7541072                util_no_attractions                  False
# 15741    7541072  util_sample_of_corrections_factor      7.389915782617758
# 15742    7541072                 util_size_variable     3.7775981687727715
# 15743    7541072            util_utility_adjustment                      0
#
#                            9                     10                   12  \
# 0         -0.932235390015777    -0.9960110406421955  -1.2780595287661722
# 1                        1.0                    1.0                  1.0
# 2      0.0016781637363059928  0.0006643895574387415  0.00279311489869619
# 3                        1.0                    1.0                  1.0
# 4                        0.0                    0.0                  0.0
# ...                      ...                    ...                  ...
# 15739     0.6886076440937283   -0.19687426761567137   0.2984571875113106
# 15740                  False                  False                False
# 15741       3.63171689160651      4.086567141458603   3.0685803316958498
# 15742      7.102065086612786     6.0156825253211785    8.007621568875283
# 15743                      0                      0                    0
#
#                           13                    14                     37  \
# 0        -1.4547553701284834   -1.4573412829661365    -3.8602604963599583
# 1                        1.0                   1.0                    1.0
# 2      0.0021809528368544094  0.000462535262887269  0.0001419935499379287
# 3                        1.0                   1.0                    1.0
# 4                        0.0                   0.0                    0.0
# ...                      ...                   ...                    ...
# 15739    0.12893352536731956   0.11661882054650644    -0.6296937346519611
# 15740                  False                 False                  False
# 15741      3.329370934699213     4.894970267088966      6.157455562658895
# 15742      7.855264033670534     6.409511700926014      5.523688361666357
# 15743                      0                     0                      0
#
#                            39  ...  178  179  180  181  182  184  186  187  \
# 0         -3.8673170163655084  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1                         1.0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      0.00020956937572710045  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3                         1.0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                         0.0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 15739     -1.8050089284615745  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 15740                   False  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 15741       5.794602181057687  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 15742       5.897955675114184  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 15743                       0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        189  190
# 0      NaN  NaN
# 1      NaN  NaN
# 2      NaN  NaN
# 3      NaN  NaN
# 4      NaN  NaN
# ...    ...  ...
# 15739  NaN  NaN
# 15740  NaN  NaN
# 15741  NaN  NaN
# 15742  NaN  NaN
# 15743  NaN  NaN
#
# [15744 rows x 192 columns]

# %% [markdown]
# ## chooser_data

# %%
data.chooser_data
# Out:
#      person_id  model_choice  override_choice  home_zone_id  school_segment  \
# 0          629            13               12           131               3
# 1         1274            10               10           166               3
# 2        27266            10               12             9               3
# 3        28012             5                5            10               3
# 4        29368           185              185            16               3
# ..         ...           ...              ...           ...             ...
# 979    7514214           185              185            56               3
# 980    7514777           185              185           106               3
# 981    7515185           188              188           142               3
# 982    7527597            69               13           188               3
# 983    7541072           112              107           117               3
#
#      household_id
# 0             629
# 1            1274
# 2           27266
# 3           28012
# 4           29368
# ..            ...
# 979       2822879
# 980       2823442
# 981       2823850
# 982       2836262
# 983       2849737
#
# [984 rows x 6 columns]

# %% [markdown]
# ## landuse

# %%
data.landuse
# Out:
#          DISTRICT  SD  county_id  TOTHH  TOTPOP  TOTACRE  RESACRE     CIACRE  \
# zone_id
# 1               1   1          1     46      82     20.3      1.0   15.00000
# 2               1   1          1    134     240     31.1      1.0   24.79297
# 3               1   1          1    267     476     14.7      1.0    2.31799
# 4               1   1          1    151     253     19.3      1.0   18.00000
# 5               1   1          1    611    1069     52.7      1.0   15.00000
# ...           ...  ..        ...    ...     ...      ...      ...        ...
# 186             4   4          1   2779    8062    376.0    172.0   15.00000
# 187             4   4          1   1492    4139    214.0    116.0   10.00000
# 188             4   4          1    753    4072    232.0     11.0  178.00000
# 189             4   4          1   3546    8476    201.0     72.0    6.00000
# 190             4   4          1    968    1647   1381.0     14.0   28.00000
#
#          TOTEMP  AGE0519  ...  area_type    HSENROLL      COLLFTE  \
# zone_id                   ...
# 1         27318        7  ...          0     0.00000      0.00000
# 2         42078       19  ...          0     0.00000      0.00000
# 3          2445       38  ...          0     0.00000      0.00000
# 4         22434       20  ...          0     0.00000      0.00000
# 5         15662       86  ...          0     0.00000     72.14684
# ...         ...      ...  ...        ...         ...          ...
# 186        1760     1178  ...          3     0.00000      0.00000
# 187         808      603  ...          3     0.00000      0.00000
# 188        4502     1117  ...          2  3961.04761  17397.79102
# 189         226     1057  ...          2     0.00000      0.00000
# 190        1010      114  ...          3     0.00000      0.00000
#
#              COLLPTE  TOPOLOGY  TERMINAL  household_density  \
# zone_id
# 1            0.00000         3   5.89564           2.875000
# 2            0.00000         1   5.84871           5.195214
# 3            0.00000         1   5.53231          80.470405
# 4            0.00000         2   5.64330           7.947368
# 5            0.00000         1   5.52555          38.187500
# ...              ...       ...       ...                ...
# 186          0.00000         1   2.04173          14.860963
# 187          0.00000         2   1.73676          11.841270
# 188      11152.93652         1   2.28992           3.984127
# 189          0.00000         1   2.88773          45.461538
# 190          0.00000         1   2.60309          23.047619
#
#          employment_density  density_index  is_cbd
# zone_id
# 1               1707.375000       2.870167   False
# 2               1631.374751       5.178722   False
# 3                736.891913      72.547987   False
# 4               1180.736842       7.894233   False
# 5                978.875000      36.753679   False
# ...                     ...            ...     ...
# 186                9.411765       5.762347   False
# 187                6.412698       4.159890   False
# 188               23.820106       3.413233   False
# 189                2.897436       2.723836   False
# 190               24.047619      11.768501   False
#
# [190 rows x 28 columns]

# %% [markdown]
# ## spec

# %%
data.spec
# Out:
#                                Label  \
# 0                      util_dist_0_1
# 1                      util_dist_1_2
# 2                      util_dist_2_5
# 3                     util_dist_5_15
# 4                    util_dist_15_up
# 5                util_no_attractions
# 6            util_mode_choice_logsum
# 7  util_sample_of_corrections_factor
#
#                                      Description  \
# 0   Distance, piecewise linear from 0 to 1 miles
# 1   Distance, piecewise linear from 1 to 2 miles
# 2   Distance, piecewise linear from 2 to 5 miles
# 3  Distance, piecewise linear from 5 to 15 miles
# 4       Distance, piecewise linear for 15+ miles
# 5                                 No attractions
# 6                             Mode choice logsum
# 7       Sample of alternatives correction factor
#
#                                        Expression            university  \
# 0                                @_DIST.clip(0,1)    coef_univ_dist_0_1
# 1                            @(_DIST-1).clip(0,1)    coef_univ_dist_1_2
# 2                            @(_DIST-2).clip(0,3)    coef_univ_dist_2_5
# 3                           @(_DIST-5).clip(0,10)   coef_univ_dist_5_15
# 4                           @(_DIST-15.0).clip(0)  coef_univ_dist_15_up
# 5                             @df['size_term']==0                  -999
# 6                              mode_choice_logsum      coef_mode_logsum
# 7  @np.minimum(np.log(df.pick_count/df.prob), 60)                     1
#
#                  highschool               gradeschool
# 0        coef_high_dist_0_1       coef_grade_dist_0_1
# 1  coef_high_grade_dist_1_2  coef_high_grade_dist_1_2
# 2  coef_high_grade_dist_2_5  coef_high_grade_dist_2_5
# 3       coef_high_dist_5_15      coef_grade_dist_5_15
# 4      coef_high_dist_15_up     coef_grade_dist_15_up
# 5                      -999                      -999
# 6          coef_mode_logsum          coef_mode_logsum
# 7                         1                         1

# %% [markdown]
# ## size_spec

# %%
data.size_spec
# Out:
#              AGE0519  HSENROLL  COLLFTE  COLLPTE
# segment
# university       0.0       0.0    0.592    0.408
# gradeschool      1.0       0.0    0.000    0.000
# highschool       0.0       1.0    0.000    0.000

# %% [markdown]
# # Estimate
#
# With the model setup for estimation, the next step is to estimate the model coefficients.  Make sure to use a sufficiently large enough household sample and set of zones to avoid an over-specified model, which does not have a numerically stable likelihood maximizing solution.  Larch has a built-in estimation methods including BHHH, and also offers access to more advanced general purpose non-linear optimizers in the `scipy` package, including SLSQP, which allows for bounds and constraints on parameters.  BHHH is the default and typically runs faster, but does not follow constraints on parameters.

# %%
model.estimate(method='BHHH', options={'maxiter':1000})
# Out:
# req_data does not request avail_ca or avail_co but it is set and being provided
# <h3>Iteration 006 [Optimization terminated successfully.] </h3>
# <p>Best LL = -4058.719620832402</p>
#                                value   initvalue  nullvalue  minimum  maximum  \
# -999                     -999.000000 -999.000000     -999.0   -999.0   -999.0
# 1                           1.000000    1.000000        1.0      1.0      1.0
# coef_grade_dist_0_1        -1.824840   -1.641900        0.0      NaN      NaN
# coef_grade_dist_15_up      -0.046000   -0.046000        0.0      NaN      NaN
# coef_grade_dist_5_15       -0.144663   -0.203100        0.0      NaN      NaN
# coef_high_dist_0_1         -2.106211   -0.952300        0.0      NaN      NaN
# coef_high_dist_15_up       -0.188200   -0.188200        0.0      NaN      NaN
# coef_high_dist_5_15        -0.101747   -0.193000        0.0      NaN      NaN
# coef_high_grade_dist_1_2   -0.751852   -0.570000        0.0      NaN      NaN
# coef_high_grade_dist_2_5   -0.667119   -0.570000        0.0      NaN      NaN
# coef_mode_logsum            0.372245    0.535800        0.0      NaN      NaN
# coef_univ_dist_0_1         -3.311744   -3.245100        0.0      NaN      NaN
# coef_univ_dist_15_up       -0.073000   -0.073000        0.0      NaN      NaN
# coef_univ_dist_1_2         -2.878224   -2.701100        0.0      NaN      NaN
# coef_univ_dist_2_5         -0.456009   -0.570700        0.0      NaN      NaN
# coef_univ_dist_5_15        -0.572553   -0.500200        0.0      NaN      NaN
# gradeschool_AGE0519         0.000000    0.000000        0.0     -6.0      6.0
# highschool_HSENROLL         0.000000    0.000000        0.0     -6.0      6.0
# university_COLLFTE         -0.524249   -0.524249        0.0     -6.0      6.0
# university_COLLPTE         -1.208828   -0.896488        0.0     -6.0      6.0
#
#                           holdfast note        best
# -999                             1      -999.000000
# 1                                1         1.000000
# coef_grade_dist_0_1              0        -1.824840
# coef_grade_dist_15_up            0        -0.046000
# coef_grade_dist_5_15             0        -0.144663
# coef_high_dist_0_1               0        -2.106211
# coef_high_dist_15_up             0        -0.188200
# coef_high_dist_5_15              0        -0.101747
# coef_high_grade_dist_1_2         0        -0.751852
# coef_high_grade_dist_2_5         0        -0.667119
# coef_mode_logsum                 0         0.372245
# coef_univ_dist_0_1               0        -3.311744
# coef_univ_dist_15_up             0        -0.073000
# coef_univ_dist_1_2               0        -2.878224
# coef_univ_dist_2_5               0        -0.456009
# coef_univ_dist_5_15              0        -0.572553
# gradeschool_AGE0519              1         0.000000
# highschool_HSENROLL              1         0.000000
# university_COLLFTE               1        -0.524249
# university_COLLPTE               0        -1.208828
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 1.702173976472811e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 7.452131216396507e-16 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 1.6859854144555066e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 1.0694117400754151e-16 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 7.262790059748344e-16 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 1.6292481359929981e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 1.818811050478879e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 1.2608013734918816e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# ┣          loglike: -4058.719620832402
# ┣                x: -999                       -999.000000
# ┃                   1                             1.000000
# ┃                   coef_grade_dist_0_1          -1.824840
# ┃                   coef_grade_dist_15_up        -0.046000
# ┃                   coef_grade_dist_5_15         -0.144663
# ┃                   coef_high_dist_0_1           -2.106211
# ┃                   coef_high_dist_15_up         -0.188200
# ┃                   coef_high_dist_5_15          -0.101747
# ┃                   coef_high_grade_dist_1_2     -0.751852
# ┃                   coef_high_grade_dist_2_5     -0.667119
# ┃                   coef_mode_logsum              0.372245
# ┃                   coef_univ_dist_0_1           -3.311744
# ┃                   coef_univ_dist_15_up         -0.073000
# ┃                   coef_univ_dist_1_2           -2.878224
# ┃                   coef_univ_dist_2_5           -0.456009
# ┃                   coef_univ_dist_5_15          -0.572553
# ┃                   gradeschool_AGE0519           0.000000
# ┃                   highschool_HSENROLL           0.000000
# ┃                   university_COLLFTE           -0.524249
# ┃                   university_COLLPTE           -1.208828
# ┃                   dtype: float64
# ┣        tolerance: 7.272237631812952e-06
# ┣            steps: array([1., 1., 1., 1., 1., 1.])
# ┣          message: 'Optimization terminated successfully.'
# ┣     elapsed_time: datetime.timedelta(microseconds=218468)
# ┣           method: 'BHHH'
# ┣          n_cases: 984
# ┣ iteration_number: 6
# ┣          logloss: 4.124715061821547

# %% [markdown]
# ### Estimated coefficients

# %%
model.parameter_summary()
# Out:
# <style  type="text/css" >
#     #T_3d7b2_ th {
#           vertical-align: top;
#           text-align: left;
#     }    #T_3d7b2_ td {
#           vertical-align: top;
#           text-align: left;
#     }#T_3d7b2_row0_col0,#T_3d7b2_row0_col1,#T_3d7b2_row0_col2,#T_3d7b2_row0_col3,#T_3d7b2_row0_col4,#T_3d7b2_row1_col0,#T_3d7b2_row1_col1,#T_3d7b2_row1_col2,#T_3d7b2_row1_col3,#T_3d7b2_row1_col4,#T_3d7b2_row2_col0,#T_3d7b2_row2_col1,#T_3d7b2_row2_col2,#T_3d7b2_row2_col3,#T_3d7b2_row2_col4,#T_3d7b2_row3_col0,#T_3d7b2_row3_col1,#T_3d7b2_row3_col2,#T_3d7b2_row3_col3,#T_3d7b2_row3_col4,#T_3d7b2_row4_col0,#T_3d7b2_row4_col1,#T_3d7b2_row4_col2,#T_3d7b2_row4_col3,#T_3d7b2_row4_col4,#T_3d7b2_row5_col0,#T_3d7b2_row5_col1,#T_3d7b2_row5_col2,#T_3d7b2_row5_col3,#T_3d7b2_row5_col4,#T_3d7b2_row6_col0,#T_3d7b2_row6_col1,#T_3d7b2_row6_col2,#T_3d7b2_row6_col3,#T_3d7b2_row6_col4,#T_3d7b2_row7_col0,#T_3d7b2_row7_col1,#T_3d7b2_row7_col2,#T_3d7b2_row7_col3,#T_3d7b2_row7_col4,#T_3d7b2_row8_col0,#T_3d7b2_row8_col1,#T_3d7b2_row8_col2,#T_3d7b2_row8_col3,#T_3d7b2_row8_col4,#T_3d7b2_row9_col0,#T_3d7b2_row9_col1,#T_3d7b2_row9_col2,#T_3d7b2_row9_col3,#T_3d7b2_row9_col4,#T_3d7b2_row10_col0,#T_3d7b2_row10_col1,#T_3d7b2_row10_col2,#T_3d7b2_row10_col3,#T_3d7b2_row10_col4,#T_3d7b2_row11_col0,#T_3d7b2_row11_col1,#T_3d7b2_row11_col2,#T_3d7b2_row11_col3,#T_3d7b2_row11_col4,#T_3d7b2_row12_col0,#T_3d7b2_row12_col1,#T_3d7b2_row12_col2,#T_3d7b2_row12_col3,#T_3d7b2_row12_col4,#T_3d7b2_row13_col0,#T_3d7b2_row13_col1,#T_3d7b2_row13_col2,#T_3d7b2_row13_col3,#T_3d7b2_row13_col4,#T_3d7b2_row14_col0,#T_3d7b2_row14_col1,#T_3d7b2_row14_col2,#T_3d7b2_row14_col3,#T_3d7b2_row14_col4,#T_3d7b2_row15_col0,#T_3d7b2_row15_col1,#T_3d7b2_row15_col2,#T_3d7b2_row15_col3,#T_3d7b2_row15_col4,#T_3d7b2_row16_col0,#T_3d7b2_row16_col1,#T_3d7b2_row16_col2,#T_3d7b2_row16_col3,#T_3d7b2_row16_col4,#T_3d7b2_row17_col0,#T_3d7b2_row17_col1,#T_3d7b2_row17_col2,#T_3d7b2_row17_col3,#T_3d7b2_row17_col4,#T_3d7b2_row18_col0,#T_3d7b2_row18_col1,#T_3d7b2_row18_col2,#T_3d7b2_row18_col3,#T_3d7b2_row18_col4,#T_3d7b2_row19_col0,#T_3d7b2_row19_col1,#T_3d7b2_row19_col2,#T_3d7b2_row19_col3,#T_3d7b2_row19_col4{
#             font-family: monospace;
#         }</style><table id="T_3d7b2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Value</th>        <th class="col_heading level0 col1" >Std Err</th>        <th class="col_heading level0 col2" >t Stat</th>        <th class="col_heading level0 col3" >Signif</th>        <th class="col_heading level0 col4" >Null Value</th>        <th class="col_heading level0 col5" >Constrained</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3d7b2_level0_row0" class="row_heading level0 row0" >-999</th>
#                         <td id="T_3d7b2_row0_col0" class="data row0 col0" >-999.</td>
#                         <td id="T_3d7b2_row0_col1" class="data row0 col1" > NA</td>
#                         <td id="T_3d7b2_row0_col2" class="data row0 col2" > NA</td>
#                         <td id="T_3d7b2_row0_col3" class="data row0 col3" ></td>
#                         <td id="T_3d7b2_row0_col4" class="data row0 col4" >-999.00</td>
#                         <td id="T_3d7b2_row0_col5" class="data row0 col5" >fixed value</td>
#             </tr>
#             <tr>
#                         <th id="T_3d7b2_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3d7b2_row1_col0" class="data row1 col0" > 1.00</td>
#                         <td id="T_3d7b2_row1_col1" class="data row1 col1" > NA</td>
#                         <td id="T_3d7b2_row1_col2" class="data row1 col2" > NA</td>
#                         <td id="T_3d7b2_row1_col3" class="data row1 col3" ></td>
#                         <td id="T_3d7b2_row1_col4" class="data row1 col4" > 1.00</td>
#                         <td id="T_3d7b2_row1_col5" class="data row1 col5" >fixed value</td>
#             </tr>
#             <tr>
#                         <th id="T_3d7b2_level0_row2" class="row_heading level0 row2" >coef_grade_dist_0_1</th>
#                         <td id="T_3d7b2_row2_col0" class="data row2 col0" >-1.82</td>
#                         <td id="T_3d7b2_row2_col1" class="data row2 col1" > 0.435</td>
#                         <td id="T_3d7b2_row2_col2" class="data row2 col2" >-4.19</td>
#                         <td id="T_3d7b2_row2_col3" class="data row2 col3" >***</td>
#                         <td id="T_3d7b2_row2_col4" class="data row2 col4" > 0.00</td>
#                         <td id="T_3d7b2_row2_col5" class="data row2 col5" ></td>
#             </tr>
#             <tr>
#                         <th id="T_3d7b2_level0_row3" class="row_heading level0 row3" >coef_grade_dist_15_up</th>
#                         <td id="T_3d7b2_row3_col0" class="data row3 col0" >-0.0460</td>
#                         <td id="T_3d7b2_row3_col1" class="data row3 col1" > 4.66e-15</td>
#                         <td id="T_3d7b2_row3_col2" class="data row3 col2" >-BIG</td>
#                         <td id="T_3d7b2_row3_col3" class="data row3 col3" >***</td>
#                         <td id="T_3d7b2_row3_col4" class="data row3 col4" > 0.00</td>
#                         <td id="T_3d7b2_row3_col5" class="data row3 col5" ></td>
#             </tr>
#             <tr>
#                         <th id="T_3d7b2_level0_row4" class="row_heading level0 row4" >coef_grade_dist_5_15</th>
#                         <td id="T_3d7b2_row4_col0" class="data row4 col0" >-0.145</td>
#                         <td id="T_3d7b2_row4_col1" class="data row4 col1" > 0.0638</td>
#                         <td id="T_3d7b2_row4_col2" class="data row4 col2" >-2.27</td>
#                         <td id="T_3d7b2_row4_col3" class="data row4 col3" >*</td>
#                         <td id="T_3d7b2_row4_col4" class="data row4 col4" > 0.00</td>
#                         <td id="T_3d7b2_row4_col5" class="data row4 col5" ></td>
#             </tr>
#             <tr>
#                         <th id="T_3d7b2_level0_row5" class="row_heading level0 row5" >coef_high_dist_0_1</th>
#                         <td id="T_3d7b2_row5_col0" class="data row5 col0" >-2.11</td>
#                         <td id="T_3d7b2_row5_col1" class="data row5 col1" > 0.801</td>
#                         <td id="T_3d7b2_row5_col2" class="data row5 col2" >-2.63</td>
#                         <td id="T_3d7b2_row5_col3" class="data row5 col3" >**</td>
#                         <td id="T_3d7b2_row5_col4" class="data row5 col4" > 0.00</td>
#                         <td id="T_3d7b2_row5_col5" class="data row5 col5" ></td>
#             </tr>
#             <tr>
#                         <th id="T_3d7b2_level0_row6" class="row_heading level0 row6" >coef_high_dist_15_up</th>
#                         <td id="T_3d7b2_row6_col0" class="data row6 col0" >-0.188</td>
#                         <td id="T_3d7b2_row6_col1" class="data row6 col1" > 3.34e-15</td>
#                         <td id="T_3d7b2_row6_col2" class="data row6 col2" >-BIG</td>
#                         <td id="T_3d7b2_row6_col3" class="data row6 col3" >***</td>
#                         <td id="T_3d7b2_row6_col4" class="data row6 col4" > 0.00</td>
#                         <td id="T_3d7b2_row6_col5" class="data row6 col5" ></td>
#             </tr>
#             <tr>
#                         <th id="T_3d7b2_level0_row7" class="row_heading level0 row7" >coef_high_dist_5_15</th>
#                         <td id="T_3d7b2_row7_col0" class="data row7 col0" >-0.102</td>
#                         <td id="T_3d7b2_row7_col1" class="data row7 col1" > 0.143</td>
#                         <td id="T_3d7b2_row7_col2" class="data row7 col2" >-0.71</td>
#                         <td id="T_3d7b2_row7_col3" class="data row7 col3" ></td>
#                         <td id="T_3d7b2_row7_col4" class="data row7 col4" > 0.00</td>
#                         <td id="T_3d7b2_row7_col5" class="data row7 col5" ></td>
#             </tr>
#             <tr>
#                         <th id="T_3d7b2_level0_row8" class="row_heading level0 row8" >coef_high_grade_dist_

# %% [markdown]
# # Output Estimation Results

# %%
from activitysim.estimation.larch import update_coefficients, update_size_spec
result_dir = data.edb_directory/"estimated"

# %% [markdown]
# ## Write updated utility coefficients

# %%
update_coefficients(
    model, data, result_dir,
    output_file=f"{modelname}_coefficients_revised.csv",
);

# %% [markdown]
# ## Write updated size coefficients

# %%
update_size_spec(
    model, data, result_dir, 
    output_file=f"{modelname}_size_terms.csv",
)
# Out:
#           segment model_selector     TOTHH   RETEMPN   FPSEMPN   HEREMPN  \
# 0        work_low      workplace  0.000000  0.129129  0.193193  0.383383
# 1        work_med      workplace  0.000000  0.120120  0.197197  0.325325
# 2       work_high      workplace  0.000000  0.110000  0.207000  0.284000
# 3   work_veryhigh      workplace  0.000000  0.093000  0.270000  0.241000
# 4      university         school  0.000000  0.000000  0.000000  0.000000
# 5     gradeschool         school  0.000000  0.000000  0.000000  0.000000
# 6      highschool         school  0.000000  0.000000  0.000000  0.000000
# 7          escort  non_mandatory  0.000000  0.225000  0.000000  0.144000
# 8        shopping  non_mandatory  0.000000  1.000000  0.000000  0.000000
# 9          eatout  non_mandatory  0.000000  0.742000  0.000000  0.258000
# 10       othmaint  non_mandatory  0.000000  0.482000  0.000000  0.518000
# 11         social  non_mandatory  0.000000  0.522000  0.000000  0.478000
# 12       othdiscr  non_mandatory  0.252252  0.212212  0.000000  0.272272
# 13         atwork         atwork  0.000000  0.742000  0.000000  0.258000
# 14           work           trip  0.000000  0.166667  0.166667  0.166667
# 15         escort           trip  0.001000  0.225000  0.000000  0.144000
# 16       shopping           trip  0.001000  0.999000  0.000000  0.000000
# 17         eatout           trip  0.000000  0.742000  0.000000  0.258000
# 18       othmaint           trip  0.001000  0.481000  0.000000  0.518000
# 19         social           trip  0.001000  0.521000  0.000000  0.478000
# 20       othdiscr           trip  0.252252  0.212212  0.000000  0.272272
# 21           univ           trip  0.000999  0.000000  0.000000  0.000000
#
#      OTHEMPN   AGREMPN   MWTEMPN  AGE0519  HSENROLL   COLLFTE   COLLPTE
# 0   0.120120  0.010010  0.164164    0.000  0.000000  0.000000  0.000000
# 1   0.139139  0.008008  0.210210    0.000  0.000000  0.000000  0.000000
# 2   0.154000  0.006000  0.239000    0.000  0.000000  0.000000  0.000000
# 3   0.146000  0.004000  0.246000    0.000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000    0.000  0.000000  0.664760  0.335240
# 5   0.000000  0.000000  0.000000    1.000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000    0.000  1.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000    0.465  0.166000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000    0.000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000    0.000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000    0.000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000    0.000  0.000000  0.000000  0.000000
# 12  0.165165  0.000000  0.000000    0.000  0.098098  0.000000  0.000000
# 13  0.000000  0.000000  0.000000    0.000  0.000000  0.000000  0.000000
# 14  0.166667  0.166667  0.166667    0.000  0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000    0.464  0.166000  0.000000  0.000000
# 16  0.000000  0.000000  0.000000    0.000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000    0.000  0.000000  0.000000  0.000000
# 18  0.000000  0.000000  0.000000    0.000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000    0.000  0.000000  0.000000  0.000000
# 20  0.165165  0.000000  0.000000    0.000  0.098098  0.000000  0.000000
# 21  0.000000  0.000000  0.000000    0.000  0.000000  0.591409  0.407592

# %% [markdown]
# ## Write the model estimation report, including coefficient t-statistic and log likelihood

# %%
model.to_xlsx(
    result_dir/f"{modelname}_model_estimation.xlsx", 
    data_statistics=False,
);

# %% [markdown]
# # Next Steps
#
# The final step is to either manually or automatically copy the `*_coefficients_revised.csv` file and `*_size_terms.csv` file to the configs folder, rename them to `*_coefficients.csv` and `destination_choice_size_terms.csv`, and run ActivitySim in simulation mode.  Note that all the location
# and desintation choice models share the same `destination_choice_size_terms.csv` input file, so if you
# are updating all these models, you'll need to ensure that updated sections of this file for each model
# are joined together correctly.

# %%
pd.read_csv(result_dir/f"{modelname}_coefficients_revised.csv")
# Out:
#             coefficient_name     value constrain
# 0         coef_univ_dist_0_1 -3.311744         F
# 1         coef_univ_dist_1_2 -2.878224         F
# 2         coef_univ_dist_2_5 -0.456009         F
# 3        coef_univ_dist_5_15 -0.572553         F
# 4       coef_univ_dist_15_up -0.073000         F
# 5         coef_high_dist_0_1 -2.106211         F
# 6   coef_high_grade_dist_1_2 -0.751852         F
# 7   coef_high_grade_dist_2_5 -0.667119         F
# 8        coef_high_dist_5_15 -0.101747         F
# 9       coef_high_dist_15_up -0.188200         F
# 10       coef_grade_dist_0_1 -1.824840         F
# 11      coef_grade_dist_5_15 -0.144663         F
# 12     coef_grade_dist_15_up -0.046000         F
# 13          coef_mode_logsum  0.372245         F

# %%
pd.read_csv(result_dir/f"{modelname}_size_terms.csv")
# Out:
#     index        segment model_selector     TOTHH   RETEMPN   FPSEMPN  \
# 0       0       work_low      workplace  0.000000  0.129129  0.193193
# 1       1       work_med      workplace  0.000000  0.120120  0.197197
# 2       2      work_high      workplace  0.000000  0.110000  0.207000
# 3       3  work_veryhigh      workplace  0.000000  0.093000  0.270000
# 4       4     university         school  0.000000  0.000000  0.000000
# 5       5    gradeschool         school  0.000000  0.000000  0.000000
# 6       6     highschool         school  0.000000  0.000000  0.000000
# 7       7         escort  non_mandatory  0.000000  0.225000  0.000000
# 8       8       shopping  non_mandatory  0.000000  1.000000  0.000000
# 9       9         eatout  non_mandatory  0.000000  0.742000  0.000000
# 10     10       othmaint  non_mandatory  0.000000  0.482000  0.000000
# 11     11         social  non_mandatory  0.000000  0.522000  0.000000
# 12     12       othdiscr  non_mandatory  0.252252  0.212212  0.000000
# 13     13         atwork         atwork  0.000000  0.742000  0.000000
# 14     14           work           trip  0.000000  0.166667  0.166667
# 15     15         escort           trip  0.001000  0.225000  0.000000
# 16     16       shopping           trip  0.001000  0.999000  0.000000
# 17     17         eatout           trip  0.000000  0.742000  0.000000
# 18     18       othmaint           trip  0.001000  0.481000  0.000000
# 19     19         social           trip  0.001000  0.521000  0.000000
# 20     20       othdiscr           trip  0.252252  0.212212  0.000000
# 21     21           univ           trip  0.000999  0.000000  0.000000
#
#      HEREMPN   OTHEMPN   AGREMPN   MWTEMPN  AGE0519  HSENROLL   COLLFTE  \
# 0   0.383383  0.120120  0.010010  0.164164    0.000  0.000000  0.000000
# 1   0.325325  0.139139  0.008008  0.210210    0.000  0.000000  0.000000
# 2   0.284000  0.154000  0.006000  0.239000    0.000  0.000000  0.000000
# 3   0.241000  0.146000  0.004000  0.246000    0.000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000    0.000  0.000000  0.664760
# 5   0.000000  0.000000  0.000000  0.000000    1.000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  0.000000    0.000  1.000000  0.000000
# 7   0.144000  0.000000  0.000000  0.000000    0.465  0.166000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000    0.000  0.000000  0.000000
# 9   0.258000  0.000000  0.000000  0.000000    0.000  0.000000  0.000000
# 10  0.518000  0.000000  0.000000  0.000000    0.000  0.000000  0.000000
# 11  0.478000  0.000000  0.000000  0.000000    0.000  0.000000  0.000000
# 12  0.272272  0.165165  0.000000  0.000000    0.000  0.098098  0.000000
# 13  0.258000  0.000000  0.000000  0.000000    0.000  0.000000  0.000000
# 14  0.166667  0.166667  0.166667  0.166667    0.000  0.000000  0.000000
# 15  0.144000  0.000000  0.000000  0.000000    0.464  0.166000  0.000000
# 16  0.000000  0.000000  0.000000  0.000000    0.000  0.000000  0.000000
# 17  0.258000  0.000000  0.000000  0.000000    0.000  0.000000  0.000000
# 18  0.518000  0.000000  0.000000  0.000000    0.000  0.000000  0.000000
# 19  0.478000  0.000000  0.000000  0.000000    0.000  0.000000  0.000000
# 20  0.272272  0.165165  0.000000  0.000000    0.000  0.098098  0.000000
# 21  0.000000  0.000000  0.000000  0.000000    0.000  0.000000  0.591409
#
#      COLLPTE
# 0   0.000000
# 1   0.000000
# 2   0.000000
# 3   0.000000
# 4   0.335240
# 5   0.000000
# 6   0.000000
# 7   0.000000
# 8   0.000000
# 9   0.000000
# 10  0.000000
# 11  0.000000
# 12  0.000000
# 13  0.000000
# 14  0.000000
# 15  0.000000
# 16  0.000000
# 17  0.000000
# 18  0.000000
# 19  0.000000
# 20  0.000000
# 21  0.407592
