# %% [markdown]
# # Estimating Auto Ownership
#
# This notebook illustrates how to re-estimate a single model component for ActivitySim.  This process
# includes running ActivitySim in estimation mode to read household travel survey files and write out
# the estimation data bundles used in this notebook.  To review how to do so, please visit the other
# notebooks in this directory.

# %% [markdown]
# # Load libraries

# %%
import os
import larch  # !conda install larch -c conda-forge # for estimation
import pandas as pd

# %% [markdown]
# We'll work in our `test` directory, where ActivitySim has saved the estimation data bundles.

# %%
os.chdir('test')

# %% [markdown]
# # Load data and prep model for estimation

# %%
modelname = "auto_ownership"

from activitysim.estimation.larch import component_model
model, data = component_model(modelname, return_data=True)

# %% [markdown]
# # Review data loaded from the EDB
#
# The next step is to read the EDB, including the coefficients, model settings, utilities specification, and chooser and alternative data.

# %% [markdown]
# ### Coefficients

# %%
data.coefficients
# Out:
#                            value constrain
# coefficient_name
# coef_cars1_drivers_2      0.0000         T
# coef_cars1_drivers_3      0.0000         T
# coef_cars1_persons_16_17  0.0000         T
# coef_cars234_asc_marin    0.0000         T
# coef_cars1_persons_25_34  0.0000         T
# ...                          ...       ...
# coef_cars4_drivers_3      5.2080         F
# coef_cars3_drivers_3      5.5131         F
# coef_cars2_drivers_4_up   6.3662         F
# coef_cars3_drivers_4_up   8.5148         F
# coef_cars4_drivers_4_up   9.5807         F
#
# [67 rows x 2 columns]

# %% [markdown]
# #### Utility specification

# %%
data.spec
# Out:
#                                Label  \
# 0                     util_drivers_2
# 1                     util_drivers_3
# 2                  util_drivers_4_up
# 3                 util_persons_16_17
# 4                 util_persons_18_24
# 5                 util_persons_25_34
# 6         util_presence_children_0_4
# 7        util_presence_children_5_17
# 8            util_num_workers_clip_3
# 9               util_hh_income_0_30k
# 10             util_hh_income_30_75k
# 11             util_hh_income_75k_up
# 12      util_density_0_10_no_workers
# 13     util_density_10_up_no_workers
# 14         util_density_0_10_workers
# 15        util_density_10_up_workers
# 16                          util_asc
# 17            util_asc_san_francisco
# 18                   util_asc_solano
# 19                     util_asc_napa
# 20                   util_asc_sonoma
# 21                    util_asc_marin
# 22       util_retail_auto_no_workers
# 23          util_retail_auto_workers
# 24    util_retail_transit_no_workers
# 25       util_retail_transit_workers
# 26  util_retail_non_motor_no_workers
# 27     util_retail_non_motor_workers
# 28  util_auto_time_saving_per_worker
#
#                                           Description  \
# 0                                  2 Adults (age 16+)
# 1                                  3 Adults (age 16+)
# 2                                 4+ Adults (age 16+)
# 3                                   Persons age 16-17
# 4                                   Persons age 18-24
# 5                                   Persons age 35-34
# 6                        Presence of children age 0-4
# 7                       Presence of children age 5-17
# 8                      Number of workers, capped at 3
# 9           Piecewise Linear household income, $0-30k
# 10         Piecewise Linear household income, $30-75k
# 11  Piecewise Linear household income, $75k+, capp...
# 12               Density index up to 10, if 0 workers
# 13        Density index in excess of 10, if 0 workers
# 14              Density index up to 10, if 1+ workers
# 15       Density index in excess of 10, if 1+ workers
# 16                                          Constants
# 17                               San Francisco county
# 18                                      Solano county
# 19                                        Napa county
# 20                                      Sonoma county
# 21                                       Marin county
# 22  Retail accessibility (0.66*PK + 0.34*OP) by au...
# 23  Retail accessibility (0.66*PK + 0.34*OP) by au...
# 24  Retail accessibility (0.66*PK + 0.34*OP) by tr...
# 25  Retail accessibility (0.66*PK + 0.34*OP) by tr...
# 26  Retail accessibility by non-motorized, if 0 wo...
# 27  Retail accessibility by non-motorized, if 1+ w...
# 28               Auto time savings per worker to work
#
#                                            Expression  cars0  \
# 0                                      num_drivers==2    NaN
# 1                                      num_drivers==3    NaN
# 2                                       num_drivers>3    NaN
# 3                               num_children_16_to_17    NaN
# 4                                     num_college_age    NaN
# 5                                    num_young_adults    NaN
# 6                                num_young_children>0    NaN
# 7      (num_children_5_to_15+num_children_16_to_17)>0    NaN
# 8                       @df.num_workers.clip(upper=3)    NaN
# 9                 @df.income_in_thousands.clip(0, 30)    NaN
# 10           @(df.income_in_thousands-30).clip(0, 45)    NaN
# 11           @(df.income_in_thousands-75).clip(0, 50)    NaN
# 12  @(df.num_workers==0)*df.density_index.clip(0, 10)    NaN
# 13  @(df.num_workers==0)*(df.density_index-10).cli...    NaN
# 14   @(df.num_workers>0)*df.density_index.clip(0, 10)    NaN
# 15  @(df.num_workers>0)*(df.density_index-10).clip(0)    NaN
# 16                                                  1    NaN
# 17                  @df.county_id == ID_SAN_FRANCISCO    NaN
# 18                         @df.county_id == ID_SOLANO    NaN
# 19                           @df.county_id == ID_NAPA    NaN
# 20                         @df.county_id == ID_SONOMA    NaN
# 21                          @df.county_id == ID_MARIN    NaN
# 22  (num_workers==0)*(0.66*auPkRetail+0.34*auOpRet...    NaN
# 23  (num_workers>0)*(0.66*auPkRetail+0.34*auOpRetail)    NaN
# 24  (num_workers==0)*(0.66*trPkRetail+0.34*trOpRet...    NaN
# 25  (num_workers>0)*(0.66*trPkRetail+0.34*trOpRetail)    NaN
# 26                          (num_workers==0)*nmRetail    NaN
# 27                           (num_workers>0)*nmRetail    NaN
# 28  @np.where(df.num_workers > 0, df.hh_work_auto_...    NaN
#
#                                      cars1  \
# 0                     coef_cars1_drivers_2
# 1                     coef_cars1_drivers_3
# 2                  coef_cars1_drivers_4_up
# 3                 coef_cars1_persons_16_17
# 4                 coef_cars1_persons_18_24
# 5                 coef_cars1_persons_25_34
# 6         coef_cars1_presence_children_0_4
# 7        coef_cars1_presence_children_5_17
# 8            coef_cars1_num_workers_clip_3
# 9               coef_cars1_hh_income_0_30k
# 10              coef_cars1_hh_income_30_up
# 11              coef_cars1_hh_income_30_up
# 12      coef_cars1_density_0_10_no_workers
# 13     coef_cars1_density_10_up_no_workers
# 14      coef_cars1_density_0_10_no_workers
# 15        coef_cars1_density_10_up_workers
# 16                          coef_cars1_asc
# 17            coef_cars1_asc_san_francisco
# 18                   coef_cars1_asc_county
# 19                   coef_cars1_asc_county
# 20                   coef_cars1_asc_county
# 21                    coef_cars1_asc_marin
# 22             coef_retail_auto_no_workers
# 23                coef_retail_auto_workers
# 24          coef_retail_transit_no_workers
# 25             coef_retail_transit_workers
# 26                   coef_retail_non_motor
# 27                   coef_retail_non_motor
# 28  coef_cars1_auto_time_saving_per_worker
#
#                                      cars2  \
# 0                     coef_cars2_drivers_2
# 1                     coef_cars2_drivers_3
# 2                  coef_cars2_drivers_4_up
# 3                 coef_cars2_persons_16_17
# 4                 coef_cars2_persons_18_24
# 5                 coef_cars2_persons_25_34
# 6       coef_cars234_presence_children_0_4
# 7        coef_cars2_presence_children_5_17
# 8            coef_cars2_num_workers_clip_3
# 9               coef_cars2_hh_income_0_30k
# 10              coef_cars2_hh_income_30_up
# 11              coef_cars2_hh_income_30_up
# 12      coef_cars2_density_0_10_no_workers
# 13     coef_cars2_density_10_up_no_workers
# 14      coef_cars2_density_0_10_no_workers
# 15     coef_cars2_density_10_up_no_workers
# 16                          coef_cars2_asc
# 17            coef_cars2_asc_san_francisco
# 18                   coef_cars2_asc_county
# 19                   coef_cars2_asc_county
# 20                   coef_cars2_asc_county
# 21                  coef_cars234_asc_marin
# 22             coef_retail_auto_no_workers
# 23                coef_retail_auto_workers
# 24          coef_retail_transit_no_workers
# 25             coef_retail_transit_workers
# 26                   coef_retail_non_motor
# 27                   coef_retail_non_motor
# 28  coef_cars2_auto_time_saving_per_worker
#
#                                      cars3  \
# 0                     coef_cars3_drivers_2
# 1                     coef_cars3_drivers_3
# 2                  coef_cars3_drivers_4_up
# 3                coef_cars34_persons_16_17
# 4                coef_cars34_persons_18_24
# 5                coef_cars34_persons_25_34
# 6       coef_cars234_presence_children_0_4
# 7       coef_cars34_presence_children_5_17
# 8            coef_cars3_num_workers_clip_3
# 9               coef_cars3_hh_income_0_30k
# 10              coef_cars3_hh_income_30_up
# 11              coef_cars3_hh_income_30_up
# 12     coef_cars34_density_0_10_no_workers
# 13    coef_cars34_density_10_up_no_workers
# 14     coef_cars34_density_0_10_no_workers
# 15    coef_cars34_density_10_up_no_workers
# 16                          coef_cars3_asc
# 17           coef_cars34_asc_san_francisco
# 18                  coef_cars34_asc_county
# 19                  coef_cars34_asc_county
# 20                  coef_cars34_asc_county
# 21                  coef_cars234_asc_marin
# 22             coef_retail_auto_no_workers
# 23                coef_retail_auto_workers
# 24          coef_retail_transit_no_workers
# 25             coef_retail_transit_workers
# 26                   coef_retail_non_motor
# 27                   coef_retail_non_motor
# 28  coef_cars3_auto_time_saving_per_worker
#
#                                      cars4
# 0                     coef_cars4_drivers_2
# 1                     coef_cars4_drivers_3
# 2                  coef_cars4_drivers_4_up
# 3                coef_cars34_persons_16_17
# 4                coef_cars34_persons_18_24
# 5                coef_cars34_persons_25_34
# 6       coef_cars234_presence_children_0_4
# 7       coef_cars34_presence_children_5_17
# 8            coef_cars4_num_workers_clip_3
# 9               coef_cars4_hh_income_0_30k
# 10              coef_cars4_hh_income_30_up
# 11              coef_cars4_hh_income_30_up
# 12     coef_cars34_density_0_10_no_workers
# 13    coef_cars34_density_10_up_no_workers
# 14     coef_cars34_density_0_10_no_workers
# 15    coef_cars34_density_10_up_no_workers
# 16                          coef_cars4_asc
# 17           coef_cars34_asc_san_francisco
# 18                  coef_cars34_asc_county
# 19                  coef_cars34_asc_county
# 20                  coef_cars34_asc_county
# 21                  coef_cars234_asc_marin
# 22             coef_retail_auto_no_workers
# 23                coef_retail_auto_workers
# 24          coef_retail_transit_no_workers
# 25             coef_retail_transit_workers
# 26                   coef_retail_non_motor
# 27                   coef_retail_non_motor
# 28  coef_cars4_auto_time_saving_per_worker

# %% [markdown]
# ### Chooser data

# %%
data.chooser_data
# Out:
#               model_choice  override_choice  util_drivers_2  util_drivers_3  \
# household_id
# 166                      0                0             0.0             0.0
# 197                      0                0             0.0             0.0
# 268                      1                1             0.0             0.0
# 375                      1                1             0.0             0.0
# 387                      1                1             0.0             0.0
# ...                    ...              ...             ...             ...
# 2863464                  1                1             0.0             0.0
# 2863483                  1                1             0.0             0.0
# 2863806                  1                1             0.0             0.0
# 2864518                  1                1             0.0             0.0
# 2864688                  1                1             0.0             0.0
#
#               util_drivers_4_up  util_persons_16_17  util_persons_18_24  \
# household_id
# 166                         0.0                 0.0                 0.0
# 197                         0.0                 0.0                 0.0
# 268                         0.0                 0.0                 0.0
# 375                         0.0                 0.0                 0.0
# 387                         0.0                 0.0                 0.0
# ...                         ...                 ...                 ...
# 2863464                     0.0                 0.0                 0.0
# 2863483                     0.0                 0.0                 0.0
# 2863806                     0.0                 0.0                 0.0
# 2864518                     0.0                 0.0                 0.0
# 2864688                     0.0                 0.0                 0.0
#
#               util_persons_25_34  util_presence_children_0_4  \
# household_id
# 166                          0.0                         0.0
# 197                          0.0                         0.0
# 268                          0.0                         0.0
# 375                          0.0                         0.0
# 387                          0.0                         0.0
# ...                          ...                         ...
# 2863464                      0.0                         0.0
# 2863483                      0.0                         0.0
# 2863806                      0.0                         0.0
# 2864518                      0.0                         0.0
# 2864688                      0.0                         0.0
#
#               util_presence_children_5_17  ...  HSENROLL     COLLFTE  \
# household_id                               ...
# 166                                   0.0  ...       0.0     0.00000
# 197                                   0.0  ...       0.0     0.00000
# 268                                   0.0  ...       0.0  3598.08521
# 375                                   0.0  ...       0.0     0.00000
# 387                                   0.0  ...       0.0   227.78223
# ...                                   ...  ...       ...         ...
# 2863464                               0.0  ...       0.0    72.14684
# 2863483                               0.0  ...       0.0     0.00000
# 2863806                               0.0  ...       0.0     0.00000
# 2864518                               0.0  ...       0.0     0.00000
# 2864688                               0.0  ...       0.0     0.00000
#
#                COLLPTE  TOPOLOGY  TERMINAL  household_density  \
# household_id
# 166            0.00000         1   3.21263          24.783133
# 197            0.00000         1   3.68156          56.783784
# 268            0.00000         1   3.29100          11.947644
# 375            0.00000         1   4.11499          73.040169
# 387           41.22827         1   3.83527          26.631579
# ...                ...       ...       ...                ...
# 2863464        0.00000         1   5.52555          38.187500
# 2863483        0.00000         3   3.99027          39.838272
# 2863806        0.00000         1   4.27539          51.675676
# 2864518        0.00000         1  25.52083          15.938148
# 2864688        0.00000         1   3.29134          16.000000
#
#               employment_density  density_index  is_cbd  override_choice_code
# household_id
# 166                    31.566265      13.883217   False                     1
# 197                    10.459459       8.832526   False                     1
# 268                    45.167539       9.448375    True                     2
# 375                    28.028350      20.255520    True                     2
# 387                    45.868421      16.848945   False                     2
# ...                          ...            ...     ...                   ...
# 2863464               978.875000      36.753679   False                     2
# 2863483                71.693001      25.608291    True                     2
# 2863806                47.216216      24.672699   False                     2
# 2864518               551.353820      15.490363    True                     2
# 2864688                31.644068      10.626823   False                     2
#
# [2000 rows x 95 columns]

# %% [markdown]
# # Estimate
#
# With the model setup for estimation, the next step is to estimate the model coefficients.  Make sure to use a sufficiently large enough household sample and set of zones to avoid an over-specified model, which does not have a numerically stable likelihood maximizing solution.  Larch has a built-in estimation methods including BHHH, and also offers access to more advanced general purpose non-linear optimizers in the `scipy` package, including SLSQP, which allows for bounds and constraints on parameters.  BHHH is the default and typically runs faster, but does not follow constraints on parameters.

# %%
model.estimate()
# Out:
# req_data does not request avail_ca or avail_co but it is set and being provided
# <h3>Iteration 015 [Optimization terminated successfully.] </h3>
# <p>Best LL = -1732.441809546802</p>
#                                            value  initvalue  nullvalue  \
# coef_cars1_asc                          4.744711     1.1865        0.0
# coef_cars1_asc_county                  -0.566000    -0.5660        0.0
# coef_cars1_asc_marin                   -0.243396    -0.2434        0.0
# coef_cars1_asc_san_francisco            3.984111     0.4259        0.0
# coef_cars1_auto_time_saving_per_worker -0.039384     0.4707        0.0
# ...                                          ...        ...        ...
# coef_retail_auto_no_workers            -0.637704     0.0626        0.0
# coef_retail_auto_workers               -0.531112     0.1646        0.0
# coef_retail_non_motor                  -0.030000    -0.0300        0.0
# coef_retail_transit_no_workers         -0.333447    -0.3053        0.0
# coef_retail_transit_workers            -0.464382    -0.5117        0.0
#
#                                         minimum  maximum  holdfast note  \
# coef_cars1_asc                              NaN      NaN         0
# coef_cars1_asc_county                       NaN      NaN         0
# coef_cars1_asc_marin                        NaN      NaN         0
# coef_cars1_asc_san_francisco                NaN      NaN         0
# coef_cars1_auto_time_saving_per_worker      NaN      NaN         0
# ...                                         ...      ...       ...  ...
# coef_retail_auto_no_workers                 NaN      NaN         0
# coef_retail_auto_workers                    NaN      NaN         0
# coef_retail_non_motor                       NaN      NaN         1
# coef_retail_transit_no_workers              NaN      NaN         0
# coef_retail_transit_workers                 NaN      NaN         0
#
#                                             best
# coef_cars1_asc                          4.744711
# coef_cars1_asc_county                  -0.566000
# coef_cars1_asc_marin                   -0.243396
# coef_cars1_asc_san_francisco            3.984111
# coef_cars1_auto_time_saving_per_worker -0.039384
# ...                                          ...
# coef_retail_auto_no_workers            -0.637704
# coef_retail_auto_workers               -0.531112
# coef_retail_non_motor                  -0.030000
# coef_retail_transit_no_workers         -0.333447
# coef_retail_transit_workers            -0.464382
#
# [66 rows x 8 columns]
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 9.359944885353407e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 8.107476782860855e-16 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 7.627843595130013e-16 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 2.990378290025734e-16 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 2.0563705701904108e-16 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 3.1225524327726755e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 1.2258577937616875e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 2.935415350933392e-18 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 1.2182226767165389e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 2.440720135351098e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 6.0219186659143e-16 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 1.124994084916672e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 3.288651679141822e-16 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 1.1653818878831003e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 2.1310833938776723e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 1.7070817993508089e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# <ipython-input-7-5091d419e17b>:1: PossibleOverspecification: WARNING: Model is possibly over-specified (hessian is nearly singular).
#   model.estimate()
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 1.3099078937960036e-15 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# <ipython-input-7-5091d419e17b>:1: RuntimeWarning: invalid value encountered in sqrt
#   model.estimate()
# ┣          loglike: -1732.441809546802
# ┣                x: coef_cars1_asc                            4.744711
# ┃                   coef_cars1_asc_county                    -0.566000
# ┃                   coef_cars1_asc_marin                     -0.243396
# ┃                   coef_cars1_asc_san_francisco              3.984111
# ┃                   coef_cars1_auto_time_saving_per_worker   -0.039384
# ┃                                                               ...
# ┃                   coef_retail_auto_no_workers              -0.637704
# ┃                   coef_retail_auto_workers                 -0.531112
# ┃                   coef_retail_non_motor                    -0.030000
# ┃                   coef_retail_transit_no_workers           -0.333447
# ┃                   coef_retail_transit_workers              -0.464382
# ┃                   Length: 66, dtype: float64
# ┣        tolerance: 4.356665489100602e-06
# ┣            steps: array([1. , 1. , 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
# ┃                          0.5, 0.5])
# ┣          message: 'Optimization terminated successfully.'
# ┣     elapsed_time: datetime.timedelta(microseconds=484879)
# ┣           method: 'bhhh'
# ┣          n_cases: 2000
# ┣ iteration_number: 15
# ┣          logloss: 0.866220904773401

# %% [markdown]
# ### Estimated coefficients

# %%
model.parameter_summary()
# Out:
# <style  type="text/css" >
#     #T_431bd_ th {
#           vertical-align: top;
#           text-align: left;
#     }    #T_431bd_ td {
#           vertical-align: top;
#           text-align: left;
#     }#T_431bd_row0_col0,#T_431bd_row0_col1,#T_431bd_row0_col2,#T_431bd_row0_col3,#T_431bd_row0_col4,#T_431bd_row0_col5,#T_431bd_row1_col0,#T_431bd_row1_col1,#T_431bd_row1_col2,#T_431bd_row1_col3,#T_431bd_row1_col4,#T_431bd_row1_col5,#T_431bd_row2_col0,#T_431bd_row2_col1,#T_431bd_row2_col2,#T_431bd_row2_col3,#T_431bd_row2_col4,#T_431bd_row2_col5,#T_431bd_row3_col0,#T_431bd_row3_col1,#T_431bd_row3_col2,#T_431bd_row3_col3,#T_431bd_row3_col4,#T_431bd_row3_col5,#T_431bd_row4_col0,#T_431bd_row4_col1,#T_431bd_row4_col2,#T_431bd_row4_col3,#T_431bd_row4_col4,#T_431bd_row4_col5,#T_431bd_row5_col0,#T_431bd_row5_col1,#T_431bd_row5_col2,#T_431bd_row5_col3,#T_431bd_row5_col4,#T_431bd_row5_col5,#T_431bd_row6_col0,#T_431bd_row6_col1,#T_431bd_row6_col2,#T_431bd_row6_col3,#T_431bd_row6_col4,#T_431bd_row6_col5,#T_431bd_row7_col0,#T_431bd_row7_col1,#T_431bd_row7_col2,#T_431bd_row7_col3,#T_431bd_row7_col4,#T_431bd_row7_col5,#T_431bd_row8_col0,#T_431bd_row8_col1,#T_431bd_row8_col2,#T_431bd_row8_col3,#T_431bd_row8_col4,#T_431bd_row8_col5,#T_431bd_row9_col0,#T_431bd_row9_col1,#T_431bd_row9_col2,#T_431bd_row9_col3,#T_431bd_row9_col4,#T_431bd_row9_col5,#T_431bd_row10_col0,#T_431bd_row10_col1,#T_431bd_row10_col2,#T_431bd_row10_col3,#T_431bd_row10_col4,#T_431bd_row10_col5,#T_431bd_row11_col0,#T_431bd_row11_col1,#T_431bd_row11_col2,#T_431bd_row11_col3,#T_431bd_row11_col4,#T_431bd_row11_col5,#T_431bd_row12_col0,#T_431bd_row12_col1,#T_431bd_row12_col2,#T_431bd_row12_col3,#T_431bd_row12_col4,#T_431bd_row12_col5,#T_431bd_row13_col0,#T_431bd_row13_col1,#T_431bd_row13_col2,#T_431bd_row13_col3,#T_431bd_row13_col4,#T_431bd_row13_col5,#T_431bd_row14_col0,#T_431bd_row14_col1,#T_431bd_row14_col2,#T_431bd_row14_col3,#T_431bd_row14_col4,#T_431bd_row14_col5,#T_431bd_row15_col0,#T_431bd_row15_col1,#T_431bd_row15_col2,#T_431bd_row15_col3,#T_431bd_row15_col4,#T_431bd_row15_col5,#T_431bd_row16_col0,#T_431bd_row16_col1,#T_431bd_row16_col2,#T_431bd_row16_col3,#T_431bd_row16_col4,#T_431bd_row16_col5,#T_431bd_row17_col0,#T_431bd_row17_col1,#T_431bd_row17_col2,#T_431bd_row17_col3,#T_431bd_row17_col4,#T_431bd_row17_col5,#T_431bd_row18_col0,#T_431bd_row18_col1,#T_431bd_row18_col2,#T_431bd_row18_col3,#T_431bd_row18_col4,#T_431bd_row18_col5,#T_431bd_row19_col0,#T_431bd_row19_col1,#T_431bd_row19_col2,#T_431bd_row19_col3,#T_431bd_row19_col4,#T_431bd_row19_col5,#T_431bd_row20_col0,#T_431bd_row20_col1,#T_431bd_row20_col2,#T_431bd_row20_col3,#T_431bd_row20_col4,#T_431bd_row20_col5,#T_431bd_row21_col0,#T_431bd_row21_col1,#T_431bd_row21_col2,#T_431bd_row21_col3,#T_431bd_row21_col4,#T_431bd_row21_col5,#T_431bd_row22_col0,#T_431bd_row22_col1,#T_431bd_row22_col2,#T_431bd_row22_col3,#T_431bd_row22_col4,#T_431bd_row22_col5,#T_431bd_row23_col0,#T_431bd_row23_col1,#T_431bd_row23_col2,#T_431bd_row23_col3,#T_431bd_row23_col4,#T_431bd_row23_col5,#T_431bd_row24_col0,#T_431bd_row24_col1,#T_431bd_row24_col2,#T_431bd_row24_col3,#T_431bd_row24_col4,#T_431bd_row24_col5,#T_431bd_row25_col0,#T_431bd_row25_col1,#T_431bd_row25_col2,#T_431bd_row25_col3,#T_431bd_row25_col4,#T_431bd_row25_col5,#T_431bd_row26_col0,#T_431bd_row26_col1,#T_431bd_row26_col2,#T_431bd_row26_col3,#T_431bd_row26_col4,#T_431bd_row26_col5,#T_431bd_row27_col0,#T_431bd_row27_col1,#T_431bd_row27_col2,#T_431bd_row27_col3,#T_431bd_row27_col4,#T_431bd_row27_col5,#T_431bd_row28_col0,#T_431bd_row28_col1,#T_431bd_row28_col2,#T_431bd_row28_col3,#T_431bd_row28_col4,#T_431bd_row28_col5,#T_431bd_row29_col0,#T_431bd_row29_col1,#T_431bd_row29_col2,#T_431bd_row29_col3,#T_431bd_row29_col4,#T_431bd_row29_col5,#T_431bd_row30_col0,#T_431bd_row30_col1,#T_431bd_row30_col2,#T_431bd_row30_col3,#T_431bd_row30_col4,#T_431bd_row30_col5,#T_431bd_row31_col0,#T_431bd_row31_col1,#T_431bd_row31_col2,#T_431bd_row31_col3,#T_431bd_row31_col4,#T_431bd_row31_col5,#T_431bd_row32_col0,#T_431bd_row32_col1,#T_431bd_row32_col2,#T_431bd_row32_col3,#T_431bd_row32_col4,#T_431bd_row32_col5,#T_431bd_row33_col0,#T_431bd_row33_col1,#T_431bd_row33_col2,#T_431bd_row33_col3,#T_431bd_row33_ ...

# %% [markdown]
# # Output Estimation Results

# %%
from activitysim.estimation.larch import update_coefficients
result_dir = data.edb_directory/"estimated"
update_coefficients(
    model, data, result_dir,
    output_file=f"{modelname}_coefficients_revised.csv",
);

# %% [markdown]
# ### Write the model estimation report, including coefficient t-statistic and log likelihood

# %%
model.to_xlsx(
    result_dir/f"{modelname}_model_estimation.xlsx", 
    data_statistics=False,
)

# %% [markdown]
# # Next Steps
#
# The final step is to either manually or automatically copy the `*_coefficients_revised.csv` file to the configs folder, rename it to `*_coefficients.csv`, and run ActivitySim in simulation mode.

# %%
pd.read_csv(result_dir/f"{modelname}_coefficients_revised.csv")
# Out:
#             coefficient_name       value constrain
# 0       coef_cars1_drivers_2    0.000000         T
# 1       coef_cars1_drivers_3    0.000000         T
# 2   coef_cars1_persons_16_17    0.000000         T
# 3     coef_cars234_asc_marin    0.000000         T
# 4   coef_cars1_persons_25_34    0.000000         T
# ..                       ...         ...       ...
# 62      coef_cars4_drivers_3  564.490158         F
# 63      coef_cars3_drivers_3    5.048488         F
# 64   coef_cars2_drivers_4_up    6.856405         F
# 65   coef_cars3_drivers_4_up    8.317950         F
# 66   coef_cars4_drivers_4_up  568.272514         F
#
# [67 rows x 3 columns]
