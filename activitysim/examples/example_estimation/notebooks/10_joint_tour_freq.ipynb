# %% [markdown]
# # Estimating Joint Tour Frequency
#
# This notebook illustrates how to re-estimate a single model component for ActivitySim.  This process
# includes running ActivitySim in estimation mode to read household travel survey files and write out
# the estimation data bundles used in this notebook.  To review how to do so, please visit the other
# notebooks in this directory.

# %% [markdown]
# # Load libraries

# %%
import os
import larch  # !conda install larch -c conda-forge # for estimation
import pandas as pd

# %% [markdown]
# We'll work in our `test` directory, where ActivitySim has saved the estimation data bundles.

# %%
os.chdir('test')

# %% [markdown]
# # Load data and prep model for estimation

# %%
modelname = "joint_tour_frequency"

from activitysim.estimation.larch import component_model
model, data = component_model(modelname, return_data=True)

# %% [markdown]
# # Review data loaded from the EDB
#
# The next step is to read the EDB, including the coefficients, model settings, utilities specification, and chooser and alternative data.

# %% [markdown]
# ## Coefficients

# %%
data.coefficients
# Out:
#                                             value constrain
# coefficient_name
# coef_asc_0_tours                           0.0000         T
# coef_asc_1_Shop                           -6.0149         F
# coef_asc_1_Main                           -5.7389         F
# coef_asc_1_Eat                            -6.3757         F
# coef_asc_1_Visit                          -5.8818         F
# ...                                           ...       ...
# coef_logTimeWindowOverlapAdultChild_disc   0.2212         F
# coef_incomeBetween50And100_disc            0.3167         F
# coef_incomeGreaterThan100_disc             0.4860         F
# coef_incomeMissing_dummy_always_zero_disc  0.3723         F
# coef_zeroAutomobiles_disc                 -0.9090         F
#
# [76 rows x 2 columns]

# %% [markdown]
# ## Utility specification

# %%
data.spec
# Out:
#                                         Label  \
# 0         util_alternative_specific_constants
# 1        util_fullTimeHomeMaxThree_zero_tours
# 2        util_partTimeHomeMaxThree_zero_tours
# 3       util_nonWorkerHomeMaxThree_zero_tours
# 4         util_retireeHomeMaxThree_zero_tours
# ..                                        ...
# 65   util_logTimeWindowOverlapAdultChild_disc
# 66            util_incomeBetween50And100_disc
# 67             util_incomeGreaterThan100_disc
# 68  util_incomeMissing_dummy_always_zero_disc
# 69                   util_zeroAutomobiles_dis
#
#                              Description                           Expression  \
# 0         alternative_specific_constants                                    1
# 1        fullTimeHomeMaxThree_zero_tours                  cdap_home_full_max3
# 2        partTimeHomeMaxThree_zero_tours                  cdap_home_part_max3
# 3       nonWorkerHomeMaxThree_zero_tours               cdap_home_nonwork_max3
# 4         retireeHomeMaxThree_zero_tours               cdap_home_retired_max3
# ..                                   ...                                  ...
# 65   logTimeWindowOverlapAdultChild_disc  log_time_window_overlap_adult_child
# 66            incomeBetween50And100_disc            income_between_50_and_100
# 67             incomeGreaterThan100_disc              income_greater_than_100
# 68  incomeMissing_dummy_always_zero_disc                       income_missing
# 69                  zeroAutomobiles_disc                  auto_ownership == 0
#
#                                   0_tours           1_Shop           1_Main  \
# 0                        coef_asc_0_tours  coef_asc_1_Shop  coef_asc_1_Main
# 1    coef_fullTimeHomeMaxThree_zero_tours              NaN              NaN
# 2    coef_partTimeHomeMaxThree_zero_tours              NaN              NaN
# 3   coef_nonWorkerHomeMaxThree_zero_tours              NaN              NaN
# 4     coef_retireeHomeMaxThree_zero_tours              NaN              NaN
# ..                                    ...              ...              ...
# 65                                    NaN              NaN              NaN
# 66                                    NaN              NaN              NaN
# 67                                    NaN              NaN              NaN
# 68                                    NaN              NaN              NaN
# 69                                    NaN              NaN              NaN
#
#              1_Eat           1_Visit  \
# 0   coef_asc_1_Eat  coef_asc_1_Visit
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN
# ..             ...               ...
# 65             NaN               NaN
# 66             NaN               NaN
# 67             NaN               NaN
# 68             NaN               NaN
# 69             NaN               NaN
#
#                                        1_Disc              2_SS  ...  \
# 0                             coef_asc_1_Disc  coef_asc_2_tours  ...
# 1                                         NaN               NaN  ...
# 2                                         NaN               NaN  ...
# 3                                         NaN               NaN  ...
# 4                                         NaN               NaN  ...
# ..                                        ...               ...  ...
# 65   coef_logTimeWindowOverlapAdultChild_disc               NaN  ...
# 66            coef_incomeBetween50And100_disc               NaN  ...
# 67             coef_incomeGreaterThan100_disc               NaN  ...
# 68  coef_incomeMissing_dummy_always_zero_disc               NaN  ...
# 69                  coef_zeroAutomobiles_disc               NaN  ...
#
#                 2_MM              2_ME              2_MV  \
# 0   coef_asc_2_tours  coef_asc_2_tours  coef_asc_2_tours
# 1                NaN               NaN               NaN
# 2                NaN               NaN               NaN
# 3                NaN               NaN               NaN
# 4                NaN               NaN               NaN
# ..               ...               ...               ...
# 65               NaN               NaN               NaN
# 66               NaN               NaN               NaN
# 67               NaN               NaN               NaN
# 68               NaN               NaN               NaN
# 69               NaN               NaN               NaN
#
#                                          2_MD              2_EE  \
# 0                            coef_asc_2_tours  coef_asc_2_tours
# 1                                         NaN               NaN
# 2                                         NaN               NaN
# 3                                         NaN               NaN
# 4                                         NaN               NaN
# ..                                        ...               ...
# 65   coef_logTimeWindowOverlapAdultChild_disc               NaN
# 66            coef_incomeBetween50And100_disc               NaN
# 67             coef_incomeGreaterThan100_disc               NaN
# 68  coef_incomeMissing_dummy_always_zero_disc               NaN
# 69                  coef_zeroAutomobiles_disc               NaN
#
#                 2_EV                                       2_ED  \
# 0   coef_asc_2_tours                           coef_asc_2_tours
# 1                NaN                                        NaN
# 2                NaN                                        NaN
# 3                NaN                                        NaN
# 4                NaN                                        NaN
# ..               ...                                        ...
# 65               NaN   coef_logTimeWindowOverlapAdultChild_disc
# 66               NaN            coef_incomeBetween50And100_disc
# 67               NaN             coef_incomeGreaterThan100_disc
# 68               NaN  coef_incomeMissing_dummy_always_zero_disc
# 69               NaN                  coef_zeroAutomobiles_disc
#
#                 2_VV                                       2_VD  \
# 0   coef_asc_2_tours                           coef_asc_2_tours
# 1                NaN                                        NaN
# 2                NaN                                        NaN
# 3                NaN                                        NaN
# 4                NaN                                        NaN
# ..               ...                                        ...
# 65               NaN   coef_logTimeWindowOverlapAdultChild_disc
# 66               NaN            coef_incomeBetween50And100_disc
# 67               NaN             coef_incomeGreaterThan100_disc
# 68               NaN  coef_incomeMissing_dummy_always_zero_disc
# 69               NaN                  coef_zeroAutomobiles_disc
#
#                                              2_DD
# 0                                coef_asc_2_tours
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 65   2 * coef_logTimeWindowOverlapAdultChild_disc
# 66            2 * coef_incomeBetween50And100_disc
# 67             2 * coef_incomeGreaterThan100_disc
# 68  2 * coef_incomeMissing_dummy_always_zero_disc
# 69                  2 * coef_zeroAutomobiles_disc
#
# [70 rows x 24 columns]

# %% [markdown]
# ## Chooser data

# %%
data.chooser_data
# Out:
#              model_choice override_choice  \
# household_id
# 189748            0_tours         0_tours
# 189758              1_Eat           1_Eat
# 189833            0_tours         0_tours
# 190134            0_tours         0_tours
# 190153            0_tours         0_tours
# ...                   ...             ...
# 2749929           0_tours         0_tours
# 2749970           0_tours         0_tours
# 2750003           0_tours         0_tours
# 2758909           0_tours         0_tours
# 2759348           0_tours         0_tours
#
#               util_alternative_specific_constants  \
# household_id
# 189748                                        1.0
# 189758                                        1.0
# 189833                                        1.0
# 190134                                        1.0
# 190153                                        1.0
# ...                                           ...
# 2749929                                       1.0
# 2749970                                       1.0
# 2750003                                       1.0
# 2758909                                       1.0
# 2759348                                       1.0
#
#               util_fullTimeHomeMaxThree_zero_tours  \
# household_id
# 189748                                         0.0
# 189758                                         0.0
# 189833                                         0.0
# 190134                                         0.0
# 190153                                         0.0
# ...                                            ...
# 2749929                                        0.0
# 2749970                                        0.0
# 2750003                                        0.0
# 2758909                                        0.0
# 2759348                                        0.0
#
#               util_partTimeHomeMaxThree_zero_tours  \
# household_id
# 189748                                         0.0
# 189758                                         0.0
# 189833                                         0.0
# 190134                                         0.0
# 190153                                         0.0
# ...                                            ...
# 2749929                                        0.0
# 2749970                                        0.0
# 2750003                                        0.0
# 2758909                                        0.0
# 2759348                                        0.0
#
#               util_nonWorkerHomeMaxThree_zero_tours  \
# household_id
# 189748                                          0.0
# 189758                                          0.0
# 189833                                          0.0
# 190134                                          0.0
# 190153                                          0.0
# ...                                             ...
# 2749929                                         0.0
# 2749970                                         0.0
# 2750003                                         0.0
# 2758909                                         0.0
# 2759348                                         0.0
#
#               util_retireeHomeMaxThree_zero_tours  \
# household_id
# 189748                                        0.0
# 189758                                        0.0
# 189833                                        0.0
# 190134                                        0.0
# 190153                                        0.0
# ...                                           ...
# 2749929                                       0.0
# 2749970                                       1.0
# 2750003                                       0.0
# 2758909                                       0.0
# 2759348                                       0.0
#
#               util_universityHomeMaxThree_univ_and_driving_zero_tours  \
# household_id
# 189748                                                      0.0
# 189758                                                      0.0
# 189833                                                      0.0
# 190134                                                      0.0
# 190153                                                      0.0
# ...                                                         ...
# 2749929                                                     0.0
# 2749970                                                     0.0
# 2750003                                                     0.0
# 2758909                                                     0.0
# 2759348                                                     0.0
#
#               util_preDrivingHomeMaxThree_preschool_and_school_zero_tours  \
# household_id
# 189748                                                      0.0
# 189758                                                      0.0
# 189833                                                      0.0
# 190134                                                      0.0
# 190153                                                      0.0
# ...                                                         ...
# 2749929                                                     0.0
# 2749970                                                     0.0
# 2750003                                                     0.0
# 2758909                                                     0.0
# 2759348                                                     0.0
#
#               util_fullTimeNonMandMaxThree_shopping  ...  \
# household_id                                         ...
# 189748                                          0.0  ...
# 189758                                          0.0  ...
# 189833                                          0.0  ...
# 190134                                          0.0  ...
# 190153                                          0.0  ...
# ...                                             ...  ...
# 2749929                                         0.0  ...
# 2749970                                         0.0  ...
# 2750003                                         0.0  ...
# 2758909                                         0.0  ...
# 2759348                                         0.0  ...
#
#               cdap_mand_univ_driving_max3  cdap_mand_nondriving_child_max3  \
# household_id
# 189748                                0.0                              0.0
# 189758                                2.0                              0.0
# 189833                                0.0                              0.0
# 190134                                0.0                              0.0
# 190153                                0.0                              0.0
# ...                                   ...                              ...
# 2749929                               0.0                              1.0
# 2749970                               0.0                              0.0
# 2750003                               0.0                              0.0
# 2758909                               0.0                              0.0
# 2759348                               0.0                              0.0
#
#               income_between_50_and_100  income_greater_than_100  \
# household_id
# 189748                            False                    False
# 189758                            False                    False
# 189833                            False                    False
# 190134                            False                    False
# 190153                            False                    False
# ...                                 ...                      ...
# 2749929                           False                     True
# 2749970                           False                     True
# 2750003                           False                     True
# 2758909                           False                     True
# 2759348                           False                     True
#
#               income_missing  log_time_window_overlap_adult  \
# household_id
# 189748                     0                          2.996
# 189758                     0                          2.303
# 189833                     0                          2.996
# 190134                     0                          2.996
# 190153                     0                          2.996
# ...                      ...                            ...
# 2749929                    0                          2.303
# 2749970                    0                          2.996
# 2750003                    0                          2.080
# 2758909                    0                          2.484
# 2759348                    0                          2.996
#
#               log_time_window_overlap_child  \
# household_id
# 189748                                  0.0
# 189758                                  0.0
# 189833                                  0.0
# 190134                                  0.0
# 190153                                  0.0
# ...                                     ...
# 2749929                                 0.0
# 2749970                                 0.0
# 2750003                                 0.0
# 2758909                                 0.0
# 2759348                                 0.0
#
#               log_time_window_overlap_adult_child  \
# household_id
# 189748                                      0.000
# 189758                                      0.000
# 189833                                      0.000
# 190134                                      0.000
# 190153                                      0.000
# ...                                           ...
# 2749929                                     2.484
# 2749970                                     0.000
# 2750003                                     0.000
# 2758909                                     0.000
# 2759348                                     0.000
#
#               non_motorized_retail_accessibility  override_choice_code
# household_id
# 189748                                  6.041458                     1
# 189758                                  6.035642                     4
# 189833                                  5.601202                     1
# 190134                                  5.941369                     1
# 190153                                  5.876868                     1
# ...                                          ...                   ...
# 2749929                                 3.937425                     1
# 2749970                                 5.523326                     1
# 2750003                                 6.289115                     1
# 2758909                                 6.677761                     1
# 2759348                                 5.760961                     1
#
# [1028 rows x 130 columns]

# %% [markdown]
# # Estimate
#
# With the model setup for estimation, the next step is to estimate the model coefficients.  Make sure to use a sufficiently large enough household sample and set of zones to avoid an over-specified model, which does not have a numerically stable likelihood maximizing solution.  Larch has a built-in estimation methods including BHHH, and also offers access to more advanced general purpose non-linear optimizers in the `scipy` package, including SLSQP, which allows for bounds and constraints on parameters.  BHHH is the default and typically runs faster, but does not follow constraints on parameters.

# %%
model.estimate(method='SLSQP')
# Out:
# req_data does not request avail_ca or avail_co but it is set and being provided
# <h3>Iteration 067 [Optimization terminated successfully] </h3>
# <p>Best LL = -391.31509615209995</p>
#                                              value  initvalue  nullvalue  \
# coef_asc_0_tours                          0.000000     0.0000        0.0
# coef_asc_1_Disc                          -5.857843    -5.4806        0.0
# coef_asc_1_Eat                           -5.140469    -6.3757        0.0
# coef_asc_1_Main                          -4.843654    -5.7389        0.0
# coef_asc_1_Shop                          -7.244895    -6.0149        0.0
# ...                                            ...        ...        ...
# coef_universityNonMandMaxThree_shopping   1.134054     0.7648        0.0
# coef_universityNonMandMaxThree_visiting -18.048773     0.2809        0.0
# coef_walkRetailAccessibility_eatout      -0.027363     0.0620        0.0
# coef_zeroAutomobiles_disc                -0.539939    -0.9090        0.0
# coef_zeroAutomobiles_visiting           -18.311268    -0.9800        0.0
#
#                                          minimum  maximum  holdfast note  \
# coef_asc_0_tours                             NaN      NaN         1
# coef_asc_1_Disc                              NaN      NaN         0
# coef_asc_1_Eat                               NaN      NaN         0
# coef_asc_1_Main                              NaN      NaN         0
# coef_asc_1_Shop                              NaN      NaN         0
# ...                                          ...      ...       ...  ...
# coef_universityNonMandMaxThree_shopping      NaN      NaN         0
# coef_universityNonMandMaxThree_visiting      NaN      NaN         0
# coef_walkRetailAccessibility_eatout          NaN      NaN         0
# coef_zeroAutomobiles_disc                    NaN      NaN         0
# coef_zeroAutomobiles_visiting                NaN      NaN         0
#
#                                               best
# coef_asc_0_tours                          0.000000
# coef_asc_1_Disc                          -5.857843
# coef_asc_1_Eat                           -5.140469
# coef_asc_1_Main                          -4.843654
# coef_asc_1_Shop                          -7.244895
# ...                                            ...
# coef_universityNonMandMaxThree_shopping   1.134054
# coef_universityNonMandMaxThree_visiting -18.048773
# coef_walkRetailAccessibility_eatout      -0.027363
# coef_zeroAutomobiles_disc                -0.539939
# coef_zeroAutomobiles_visiting           -18.311268
#
# [76 rows x 8 columns]
# <ipython-input-7-12921b4967da>:1: PossibleOverspecification: WARNING: Model is possibly over-specified (hessian is nearly singular).
#   model.estimate(method='SLSQP')
# /Users/jeffnewman/OneDrive - Cambridge Systematics/Git/larch/larch/linalg/__init__.py:18: UserWarning: minimum eig 1.4504151870310519e-16 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# ┣                x: coef_asc_0_tours                           4.128662e-14
# ┃                   coef_asc_1_Disc                           -5.857843e+00
# ┃                   coef_asc_1_Eat                            -5.140469e+00
# ┃                   coef_asc_1_Main                           -4.843654e+00
# ┃                   coef_asc_1_Shop                           -7.244895e+00
# ┃                                                                  ...
# ┃                   coef_universityNonMandMaxThree_shopping    1.134054e+00
# ┃                   coef_universityNonMandMaxThree_visiting   -1.804877e+01
# ┃                   coef_walkRetailAccessibility_eatout       -2.736284e-02
# ┃                   coef_zeroAutomobiles_disc                 -5.399391e-01
# ┃                   coef_zeroAutomobiles_visiting             -1.831127e+01
# ┃                   Length: 76, dtype: float64
# ┣          loglike: -391.31509615209995
# ┣        d_loglike: coef_asc_0_tours                           0.000000e+00
# ┃                   coef_asc_1_Disc                            1.523003e-04
# ┃                   coef_asc_1_Eat                             6.759891e-05
# ┃                   coef_asc_1_Main                           -2.935726e-04
# ┃                   coef_asc_1_Shop                           -2.605190e-04
# ┃                                                                  ...
# ┃                   coef_universityNonMandMaxThree_shopping   -1.669075e-04
# ┃                   coef_universityNonMandMaxThree_visiting   -3.279064e-08
# ┃                   coef_walkRetailAccessibility_eatout       -3.988777e-04
# ┃                   coef_zeroAutomobiles_disc                 -5.720641e-05
# ┃                   coef_zeroAutomobiles_visiting             -5.437687e-08
# ┃                   Length: 76, dtype: float64
# ┣              nit: 67
# ┣             nfev: 131
# ┣             njev: 67
# ┣           status: 0
# ┣          message: 'Optimization terminated successfully'
# ┣          success: True
# ┣     elapsed_time: datetime.timedelta(seconds=3, microseconds=730310)
# ┣           method: 'SLSQP'
# ┣          n_cases: 1028
# ┣ iteration_number: 67
# ┣          logloss: 0.3806567083191634

# %% [markdown]
# ### Estimated coefficients

# %%
model.parameter_summary()
# Out:
# <style  type="text/css" >
#     #T_8f18b_ th {
#           vertical-align: top;
#           text-align: left;
#     }    #T_8f18b_ td {
#           vertical-align: top;
#           text-align: left;
#     }#T_8f18b_row0_col0,#T_8f18b_row0_col1,#T_8f18b_row0_col2,#T_8f18b_row0_col3,#T_8f18b_row0_col4,#T_8f18b_row1_col0,#T_8f18b_row1_col1,#T_8f18b_row1_col2,#T_8f18b_row1_col3,#T_8f18b_row1_col4,#T_8f18b_row2_col0,#T_8f18b_row2_col1,#T_8f18b_row2_col2,#T_8f18b_row2_col3,#T_8f18b_row2_col4,#T_8f18b_row3_col0,#T_8f18b_row3_col1,#T_8f18b_row3_col2,#T_8f18b_row3_col3,#T_8f18b_row3_col4,#T_8f18b_row4_col0,#T_8f18b_row4_col1,#T_8f18b_row4_col2,#T_8f18b_row4_col3,#T_8f18b_row4_col4,#T_8f18b_row5_col0,#T_8f18b_row5_col1,#T_8f18b_row5_col2,#T_8f18b_row5_col3,#T_8f18b_row5_col4,#T_8f18b_row6_col0,#T_8f18b_row6_col1,#T_8f18b_row6_col2,#T_8f18b_row6_col3,#T_8f18b_row6_col4,#T_8f18b_row7_col0,#T_8f18b_row7_col1,#T_8f18b_row7_col2,#T_8f18b_row7_col3,#T_8f18b_row7_col4,#T_8f18b_row8_col0,#T_8f18b_row8_col1,#T_8f18b_row8_col2,#T_8f18b_row8_col3,#T_8f18b_row8_col4,#T_8f18b_row9_col0,#T_8f18b_row9_col1,#T_8f18b_row9_col2,#T_8f18b_row9_col3,#T_8f18b_row9_col4,#T_8f18b_row10_col0,#T_8f18b_row10_col1,#T_8f18b_row10_col2,#T_8f18b_row10_col3,#T_8f18b_row10_col4,#T_8f18b_row11_col0,#T_8f18b_row11_col1,#T_8f18b_row11_col2,#T_8f18b_row11_col3,#T_8f18b_row11_col4,#T_8f18b_row12_col0,#T_8f18b_row12_col1,#T_8f18b_row12_col2,#T_8f18b_row12_col3,#T_8f18b_row12_col4,#T_8f18b_row13_col0,#T_8f18b_row13_col1,#T_8f18b_row13_col2,#T_8f18b_row13_col3,#T_8f18b_row13_col4,#T_8f18b_row14_col0,#T_8f18b_row14_col1,#T_8f18b_row14_col2,#T_8f18b_row14_col3,#T_8f18b_row14_col4,#T_8f18b_row15_col0,#T_8f18b_row15_col1,#T_8f18b_row15_col2,#T_8f18b_row15_col3,#T_8f18b_row15_col4,#T_8f18b_row16_col0,#T_8f18b_row16_col1,#T_8f18b_row16_col2,#T_8f18b_row16_col3,#T_8f18b_row16_col4,#T_8f18b_row17_col0,#T_8f18b_row17_col1,#T_8f18b_row17_col2,#T_8f18b_row17_col3,#T_8f18b_row17_col4,#T_8f18b_row18_col0,#T_8f18b_row18_col1,#T_8f18b_row18_col2,#T_8f18b_row18_col3,#T_8f18b_row18_col4,#T_8f18b_row19_col0,#T_8f18b_row19_col1,#T_8f18b_row19_col2,#T_8f18b_row19_col3,#T_8f18b_row19_col4,#T_8f18b_row20_col0,#T_8f18b_row20_col1,#T_8f18b_row20_col2,#T_8f18b_row20_col3,#T_8f18b_row20_col4,#T_8f18b_row21_col0,#T_8f18b_row21_col1,#T_8f18b_row21_col2,#T_8f18b_row21_col3,#T_8f18b_row21_col4,#T_8f18b_row22_col0,#T_8f18b_row22_col1,#T_8f18b_row22_col2,#T_8f18b_row22_col3,#T_8f18b_row22_col4,#T_8f18b_row23_col0,#T_8f18b_row23_col1,#T_8f18b_row23_col2,#T_8f18b_row23_col3,#T_8f18b_row23_col4,#T_8f18b_row24_col0,#T_8f18b_row24_col1,#T_8f18b_row24_col2,#T_8f18b_row24_col3,#T_8f18b_row24_col4,#T_8f18b_row25_col0,#T_8f18b_row25_col1,#T_8f18b_row25_col2,#T_8f18b_row25_col3,#T_8f18b_row25_col4,#T_8f18b_row26_col0,#T_8f18b_row26_col1,#T_8f18b_row26_col2,#T_8f18b_row26_col3,#T_8f18b_row26_col4,#T_8f18b_row27_col0,#T_8f18b_row27_col1,#T_8f18b_row27_col2,#T_8f18b_row27_col3,#T_8f18b_row27_col4,#T_8f18b_row28_col0,#T_8f18b_row28_col1,#T_8f18b_row28_col2,#T_8f18b_row28_col3,#T_8f18b_row28_col4,#T_8f18b_row29_col0,#T_8f18b_row29_col1,#T_8f18b_row29_col2,#T_8f18b_row29_col3,#T_8f18b_row29_col4,#T_8f18b_row30_col0,#T_8f18b_row30_col1,#T_8f18b_row30_col2,#T_8f18b_row30_col3,#T_8f18b_row30_col4,#T_8f18b_row31_col0,#T_8f18b_row31_col1,#T_8f18b_row31_col2,#T_8f18b_row31_col3,#T_8f18b_row31_col4,#T_8f18b_row32_col0,#T_8f18b_row32_col1,#T_8f18b_row32_col2,#T_8f18b_row32_col3,#T_8f18b_row32_col4,#T_8f18b_row33_col0,#T_8f18b_row33_col1,#T_8f18b_row33_col2,#T_8f18b_row33_col3,#T_8f18b_row33_col4,#T_8f18b_row34_col0,#T_8f18b_row34_col1,#T_8f18b_row34_col2,#T_8f18b_row34_col3,#T_8f18b_row34_col4,#T_8f18b_row35_col0,#T_8f18b_row35_col1,#T_8f18b_row35_col2,#T_8f18b_row35_col3,#T_8f18b_row35_col4,#T_8f18b_row36_col0,#T_8f18b_row36_col1,#T_8f18b_row36_col2,#T_8f18b_row36_col3,#T_8f18b_row36_col4,#T_8f18b_row37_col0,#T_8f18b_row37_col1,#T_8f18b_row37_col2,#T_8f18b_row37_col3,#T_8f18b_row37_col4,#T_8f18b_row38_col0,#T_8f18b_row38_col1,#T_8f18b_row38_col2,#T_8f18b_row38_col3,#T_8f18b_row38_col4,#T_8f18b_row39_col0,#T_8f18b_row39_col1,#T_8f18b_row39_col2,#T_8f18b_row39_col3,#T_8f18b_row39_col4,#T_8f18b_row40_col0,#T_8f18b_row40_col1,#T_8f ...
#             font-family: monospace;
#         }</style><table id="T_8f18b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Value</th>        <th class="col_heading level0 col1" >Std Err</th>        <th clas

# %% [markdown]
# # Output Estimation Results

# %%
from activitysim.estimation.larch import update_coefficients
result_dir = data.edb_directory/"estimated"
update_coefficients(
    model, data, result_dir,
    output_file=f"{modelname}_coefficients_revised.csv",
);

# %% [markdown]
# ### Write the model estimation report, including coefficient t-statistic and log likelihood

# %%
model.to_xlsx(
    result_dir/f"{modelname}_model_estimation.xlsx", 
    data_statistics=False,
)

# %% [markdown]
# # Next Steps
#
# The final step is to either manually or automatically copy the `*_coefficients_revised.csv` file to the configs folder, rename it to `*_coefficients.csv`, and run ActivitySim in simulation mode.

# %%
pd.read_csv(result_dir/f"{modelname}_coefficients_revised.csv")
# Out:
#                              coefficient_name     value constrain
# 0                            coef_asc_0_tours  0.000000         T
# 1                             coef_asc_1_Shop -7.244895         F
# 2                             coef_asc_1_Main -4.843654         F
# 3                              coef_asc_1_Eat -5.140469         F
# 4                            coef_asc_1_Visit -5.962149         F
# ..                                        ...       ...       ...
# 71   coef_logTimeWindowOverlapAdultChild_disc  0.150256         F
# 72            coef_incomeBetween50And100_disc  0.008353         F
# 73             coef_incomeGreaterThan100_disc  0.624935         F
# 74  coef_incomeMissing_dummy_always_zero_disc  0.372300         F
# 75                  coef_zeroAutomobiles_disc -0.539939         F
#
# [76 rows x 3 columns]
