# %% [markdown]
# # Estimating Joint Tour Frequency
#
# This notebook illustrates how to re-estimate a single model component for ActivitySim.  This process
# includes running ActivitySim in estimation mode to read household travel survey files and write out
# the estimation data bundles used in this notebook.  To review how to do so, please visit the other
# notebooks in this directory.

# %% [markdown]
# # Load libraries

# %%
import larch as lx
import pandas as pd

lx.versions()
# Out:
# JAX not found. Some functionality will be unavailable.
# {'larch': '6.0.32',
#  'sharrow': '2.13.0',
#  'numpy': '1.26.4',
#  'pandas': '1.5.3',
#  'xarray': '2024.3.0',
#  'numba': '0.60.0'}

# %% [markdown]
# For this demo, we will assume that you have already run ActivitySim in estimation
# mode, and saved the required estimation data bundles (EDB's) to disk.  See
# the [first notebook](./01_estimation_mode.ipynb) for details.  The following module
# will run a script to set everything up if the example data is not already available.

# %%
from est_mode_setup import prepare

prepare()
# Out:
# EDB directory already populated.
# PosixPath('test-estimation-data/activitysim-prototype-mtc-extended')

# %% [markdown]
# # Load data and prep model for estimation

# %%
modelname = "joint_tour_frequency"

from activitysim.estimation.larch import component_model

model, data = component_model(
    modelname,
    edb_directory=f"output-est-mode/estimation_data_bundle/{modelname}/",
    return_data=True,
)
# Out:
# loading from output-est-mode/estimation_data_bundle/joint_tour_frequency/joint_tour_frequency_coefficients.csv
# loading spec from output-est-mode/estimation_data_bundle/joint_tour_frequency/joint_tour_frequency_SPEC.csv
# loading from output-est-mode/estimation_data_bundle/joint_tour_frequency/joint_tour_frequency_values_combined.parquet

# %% [markdown]
# # Review data loaded from the EDB
#
# The next step is to read the EDB, including the coefficients, model settings, utilities specification, and chooser and alternative data.

# %% [markdown]
# ## Coefficients

# %%
data.coefficients
# Out:
#                                             value constrain
# coefficient_name
# coef_asc_0_tours                           0.0000         T
# coef_asc_1_Shop                           -6.0149         F
# coef_asc_1_Main                           -5.7389         F
# coef_asc_1_Eat                            -6.3757         F
# coef_asc_1_Visit                          -5.8818         F
# ...                                           ...       ...
# coef_logTimeWindowOverlapAdultChild_disc   0.2212         F
# coef_incomeBetween50And100_disc            0.3167         F
# coef_incomeGreaterThan100_disc             0.4860         F
# coef_incomeMissing_dummy_always_zero_disc  0.3723         F
# coef_zeroAutomobiles_disc                 -0.9090         F
#
# [76 rows x 2 columns]

# %% [markdown]
# ## Utility specification

# %%
data.spec
# Out:
#                                         Label  \
# 0         util_alternative_specific_constants
# 1        util_fullTimeHomeMaxThree_zero_tours
# 2        util_partTimeHomeMaxThree_zero_tours
# 3       util_nonWorkerHomeMaxThree_zero_tours
# 4         util_retireeHomeMaxThree_zero_tours
# ..                                        ...
# 65   util_logTimeWindowOverlapAdultChild_disc
# 66            util_incomeBetween50And100_disc
# 67             util_incomeGreaterThan100_disc
# 68  util_incomeMissing_dummy_always_zero_disc
# 69                   util_zeroAutomobiles_dis
#
#                              Description                           Expression  \
# 0         alternative_specific_constants                                    1
# 1        fullTimeHomeMaxThree_zero_tours                  cdap_home_full_max3
# 2        partTimeHomeMaxThree_zero_tours                  cdap_home_part_max3
# 3       nonWorkerHomeMaxThree_zero_tours               cdap_home_nonwork_max3
# 4         retireeHomeMaxThree_zero_tours               cdap_home_retired_max3
# ..                                   ...                                  ...
# 65   logTimeWindowOverlapAdultChild_disc  log_time_window_overlap_adult_child
# 66            incomeBetween50And100_disc            income_between_50_and_100
# 67             incomeGreaterThan100_disc              income_greater_than_100
# 68  incomeMissing_dummy_always_zero_disc                       income_missing
# 69                  zeroAutomobiles_disc                  auto_ownership == 0
#
#                                   0_tours           1_Shop           1_Main  \
# 0                        coef_asc_0_tours  coef_asc_1_Shop  coef_asc_1_Main
# 1    coef_fullTimeHomeMaxThree_zero_tours              NaN              NaN
# 2    coef_partTimeHomeMaxThree_zero_tours              NaN              NaN
# 3   coef_nonWorkerHomeMaxThree_zero_tours              NaN              NaN
# 4     coef_retireeHomeMaxThree_zero_tours              NaN              NaN
# ..                                    ...              ...              ...
# 65                                    NaN              NaN              NaN
# 66                                    NaN              NaN              NaN
# 67                                    NaN              NaN              NaN
# 68                                    NaN              NaN              NaN
# 69                                    NaN              NaN              NaN
#
#              1_Eat           1_Visit  \
# 0   coef_asc_1_Eat  coef_asc_1_Visit
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN
# ..             ...               ...
# 65             NaN               NaN
# 66             NaN               NaN
# 67             NaN               NaN
# 68             NaN               NaN
# 69             NaN               NaN
#
#                                        1_Disc              2_SS  ...  \
# 0                             coef_asc_1_Disc  coef_asc_2_tours  ...
# 1                                         NaN               NaN  ...
# 2                                         NaN               NaN  ...
# 3                                         NaN               NaN  ...
# 4                                         NaN               NaN  ...
# ..                                        ...               ...  ...
# 65   coef_logTimeWindowOverlapAdultChild_disc               NaN  ...
# 66            coef_incomeBetween50And100_disc               NaN  ...
# 67             coef_incomeGreaterThan100_disc               NaN  ...
# 68  coef_incomeMissing_dummy_always_zero_disc               NaN  ...
# 69                  coef_zeroAutomobiles_disc               NaN  ...
#
#                 2_MM              2_ME              2_MV  \
# 0   coef_asc_2_tours  coef_asc_2_tours  coef_asc_2_tours
# 1                NaN               NaN               NaN
# 2                NaN               NaN               NaN
# 3                NaN               NaN               NaN
# 4                NaN               NaN               NaN
# ..               ...               ...               ...
# 65               NaN               NaN               NaN
# 66               NaN               NaN               NaN
# 67               NaN               NaN               NaN
# 68               NaN               NaN               NaN
# 69               NaN               NaN               NaN
#
#                                          2_MD              2_EE  \
# 0                            coef_asc_2_tours  coef_asc_2_tours
# 1                                         NaN               NaN
# 2                                         NaN               NaN
# 3                                         NaN               NaN
# 4                                         NaN               NaN
# ..                                        ...               ...
# 65   coef_logTimeWindowOverlapAdultChild_disc               NaN
# 66            coef_incomeBetween50And100_disc               NaN
# 67             coef_incomeGreaterThan100_disc               NaN
# 68  coef_incomeMissing_dummy_always_zero_disc               NaN
# 69                  coef_zeroAutomobiles_disc               NaN
#
#                 2_EV                                       2_ED  \
# 0   coef_asc_2_tours                           coef_asc_2_tours
# 1                NaN                                        NaN
# 2                NaN                                        NaN
# 3                NaN                                        NaN
# 4                NaN                                        NaN
# ..               ...                                        ...
# 65               NaN   coef_logTimeWindowOverlapAdultChild_disc
# 66               NaN            coef_incomeBetween50And100_disc
# 67               NaN             coef_incomeGreaterThan100_disc
# 68               NaN  coef_incomeMissing_dummy_always_zero_disc
# 69               NaN                  coef_zeroAutomobiles_disc
#
#                 2_VV                                       2_VD  \
# 0   coef_asc_2_tours                           coef_asc_2_tours
# 1                NaN                                        NaN
# 2                NaN                                        NaN
# 3                NaN                                        NaN
# 4                NaN                                        NaN
# ..               ...                                        ...
# 65               NaN   coef_logTimeWindowOverlapAdultChild_disc
# 66               NaN            coef_incomeBetween50And100_disc
# 67               NaN             coef_incomeGreaterThan100_disc
# 68               NaN  coef_incomeMissing_dummy_always_zero_disc
# 69               NaN                  coef_zeroAutomobiles_disc
#
#                                              2_DD
# 0                                coef_asc_2_tours
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 65   2 * coef_logTimeWindowOverlapAdultChild_disc
# 66            2 * coef_incomeBetween50And100_disc
# 67             2 * coef_incomeGreaterThan100_disc
# 68  2 * coef_incomeMissing_dummy_always_zero_disc
# 69                  2 * coef_zeroAutomobiles_disc
#
# [70 rows x 24 columns]

# %% [markdown]
# ## Chooser data

# %%
data.chooser_data
# Out:
#              model_choice override_choice  \
# household_id
# 190236            0_tours         0_tours
# 190592             1_Disc           1_Eat
# 190998            0_tours         0_tours
# 191185            0_tours          1_Shop
# 191276            0_tours          1_Disc
# ...                   ...             ...
# 2759076           0_tours         0_tours
# 2759264           0_tours         0_tours
# 2759425           0_tours          1_Disc
# 2760422            1_Shop         0_tours
# 2760425           0_tours         0_tours
#
#               util_alternative_specific_constants  \
# household_id
# 190236                                        1.0
# 190592                                        1.0
# 190998                                        1.0
# 191185                                        1.0
# 191276                                        1.0
# ...                                           ...
# 2759076                                       1.0
# 2759264                                       1.0
# 2759425                                       1.0
# 2760422                                       1.0
# 2760425                                       1.0
#
#               util_fullTimeHomeMaxThree_zero_tours  \
# household_id
# 190236                                         0.0
# 190592                                         0.0
# 190998                                         0.0
# 191185                                         0.0
# 191276                                         0.0
# ...                                            ...
# 2759076                                        2.0
# 2759264                                        1.0
# 2759425                                        0.0
# 2760422                                        0.0
# 2760425                                        0.0
#
#               util_partTimeHomeMaxThree_zero_tours  \
# household_id
# 190236                                         0.0
# 190592                                         0.0
# 190998                                         0.0
# 191185                                         0.0
# 191276                                         0.0
# ...                                            ...
# 2759076                                        0.0
# 2759264                                        0.0
# 2759425                                        0.0
# 2760422                                        0.0
# 2760425                                        0.0
#
#               util_nonWorkerHomeMaxThree_zero_tours  \
# household_id
# 190236                                          0.0
# 190592                                          0.0
# 190998                                          0.0
# 191185                                          0.0
# 191276                                          0.0
# ...                                             ...
# 2759076                                         0.0
# 2759264                                         0.0
# 2759425                                         0.0
# 2760422                                         0.0
# 2760425                                         0.0
#
#               util_retireeHomeMaxThree_zero_tours  \
# household_id
# 190236                                        0.0
# 190592                                        0.0
# 190998                                        0.0
# 191185                                        0.0
# 191276                                        0.0
# ...                                           ...
# 2759076                                       1.0
# 2759264                                       0.0
# 2759425                                       0.0
# 2760422                                       0.0
# 2760425                                       0.0
#
#               util_universityHomeMaxThree_univ_and_driving_zero_tours  \
# household_id
# 190236                                                      0.0
# 190592                                                      0.0
# 190998                                                      0.0
# 191185                                                      0.0
# 191276                                                      0.0
# ...                                                         ...
# 2759076                                                     0.0
# 2759264                                                     0.0
# 2759425                                                     0.0
# 2760422                                                     0.0
# 2760425                                                     0.0
#
#               util_preDrivingHomeMaxThree_preschool_and_school_zero_tours  \
# household_id
# 190236                                                      0.0
# 190592                                                      0.0
# 190998                                                      0.0
# 191185                                                      0.0
# 191276                                                      0.0
# ...                                                         ...
# 2759076                                                     0.0
# 2759264                                                     0.0
# 2759425                                                     0.0
# 2760422                                                     0.0
# 2760425                                                     0.0
#
#               util_fullTimeNonMandMaxThree_shopping  ...  \
# household_id                                         ...
# 190236                                          0.0  ...
# 190592                                          0.0  ...
# 190998                                          0.0  ...
# 191185                                          0.0  ...
# 191276                                          0.0  ...
# ...                                             ...  ...
# 2759076                                         0.0  ...
# 2759264                                         0.0  ...
# 2759425                                         0.0  ...
# 2760422                                         0.0  ...
# 2760425                                         0.0  ...
#
#               cdap_mand_univ_driving_max3  cdap_mand_nondriving_child_max3  \
# household_id
# 190236                                1.0                              0.0
# 190592                                0.0                              0.0
# 190998                                1.0                              0.0
# 191185                                0.0                              0.0
# 191276                                0.0                              0.0
# ...                                   ...                              ...
# 2759076                               1.0                              2.0
# 2759264                               0.0                              0.0
# 2759425                               1.0                              0.0
# 2760422                               0.0                              0.0
# 2760425                               0.0                              0.0
#
#               income_between_50_and_100  income_greater_than_100  \
# household_id
# 190236                            False                    False
# 190592                            False                    False
# 190998                            False                    False
# 191185                            False                    False
# 191276                            False                    False
# ...                                 ...                      ...
# 2759076                           False                     True
# 2759264                           False                     True
# 2759425                           False                     True
# 2760422                           False                     True
# 2760425                           False                     True
#
#               income_missing  log_time_window_overlap_adult  \
# household_id
# 190236                     0                       2.996094
# 190592                     0                       2.996094
# 190998                     0                       2.564453
# 191185                     0                       2.996094
# 191276                     0                       2.996094
# ...                      ...                            ...
# 2759076                    0                       2.996094
# 2759264                    0                       2.996094
# 2759425                    0                       2.996094
# 2760422                    0                       2.197266
# 2760425                    0                       2.080078
#
#               log_time_window_overlap_child  \
# household_id
# 190236                             0.000000
# 190592                             0.000000
# 190998                             0.000000
# 191185                             0.000000
# 191276                             0.000000
# ...                                     ...
# 2759076                            1.946289
# 2759264                            0.000000
# 2759425                            0.000000
# 2760422                            0.000000
# 2760425                            0.000000
#
#               log_time_window_overlap_adult_child  \
# household_id
# 190236                                   0.000000
# 190592                                   0.000000
# 190998                                   0.000000
# 191185                                   0.000000
# 191276                                   0.000000
# ...                                           ...
# 2759076                                  2.564453
# 2759264                                  0.000000
# 2759425                                  2.996094
# 2760422                                  0.000000
# 2760425                                  0.000000
#
#               non_motorized_retail_accessibility  override_choice_code
# household_id
# 190236                                  5.661266                     1
# 190592                                  5.384032                     4
# 190998                                  4.529309                     1
# 191185                                  4.015752                     2
# 191276                                  4.422027                     6
# ...                                          ...                   ...
# 2759076                                 6.481015                     1
# 2759264                                 6.343830                     1
# 2759425                                 4.507081                     6
# 2760422                                 4.345421                     1
# 2760425                                 3.586974                     1
#
# [13210 rows x 130 columns]

# %% [markdown]
# # Estimate
#
# With the model setup for estimation, the next step is to estimate the model coefficients.  Make sure to use a sufficiently large enough household sample and set of zones to avoid an over-specified model, which does not have a numerically stable likelihood maximizing solution.  Larch has a built-in estimation methods including BHHH, and also offers access to more advanced general purpose non-linear optimizers in the `scipy` package, including SLSQP, which allows for bounds and constraints on parameters.  BHHH is the default and typically runs faster, but does not follow constraints on parameters.

# %%
model.estimate(method='SLSQP')
# Out:
# <h3>Iteration 061 [Optimization terminated successfully] </h3>
# <p>Best LL = -5583.026333343983</p>
#                                             value      best  initvalue  \
# param_name
# coef_asc_0_tours                         0.000000  0.000000     0.0000
# coef_asc_1_Disc                         -5.351766 -5.351766    -5.4806
# coef_asc_1_Eat                          -6.074061 -6.074061    -6.3757
# coef_asc_1_Main                         -5.816690 -5.816690    -5.7389
# coef_asc_1_Shop                         -6.045190 -6.045190    -6.0149
# ...                                           ...       ...        ...
# coef_universityNonMandMaxThree_shopping  0.857729  0.857729     0.7648
# coef_universityNonMandMaxThree_visiting  0.282416  0.282416     0.2809
# coef_walkRetailAccessibility_eatout      0.042572  0.042572     0.0620
# coef_zeroAutomobiles_disc               -0.953758 -0.953758    -0.9090
# coef_zeroAutomobiles_visiting           -0.900518 -0.900518    -0.9800
#
#                                          minimum  maximum  nullvalue  holdfast
# param_name
# coef_asc_0_tours                             0.0      0.0        0.0         1
# coef_asc_1_Disc                            -50.0     50.0        0.0         0
# coef_asc_1_Eat                             -50.0     50.0        0.0         0
# coef_asc_1_Main                            -50.0     50.0        0.0         0
# coef_asc_1_Shop                            -50.0     50.0        0.0         0
# ...                                          ...      ...        ...       ...
# coef_universityNonMandMaxThree_shopping    -50.0     50.0        0.0         0
# coef_universityNonMandMaxThree_visiting    -50.0     50.0        0.0         0
# coef_walkRetailAccessibility_eatout        -50.0     50.0        0.0         0
# coef_zeroAutomobiles_disc                  -50.0     50.0        0.0         0
# coef_zeroAutomobiles_visiting              -50.0     50.0        0.0         0
#
# [76 rows x 7 columns]
# ┣                x: coef_asc_0_tours                           0.000000
# ┃                   coef_asc_1_Disc                           -5.351766
# ┃                   coef_asc_1_Eat                            -6.074061
# ┃                   coef_asc_1_Main                           -5.816690
# ┃                   coef_asc_1_Shop                           -6.045190
# ┃                                                                ...
# ┃                   coef_universityNonMandMaxThree_shopping    0.857729
# ┃                   coef_universityNonMandMaxThree_visiting    0.282416
# ┃                   coef_walkRetailAccessibility_eatout        0.042572
# ┃                   coef_zeroAutomobiles_disc                 -0.953758
# ┃                   coef_zeroAutomobiles_visiting             -0.900518
# ┃                   Length: 76, dtype: float64
# ┣          logloss: 0.4226363613432236
# ┣        d_logloss: coef_asc_0_tours                           0.000000
# ┃                   coef_asc_1_Disc                            0.000127
# ┃                   coef_asc_1_Eat                             0.000172
# ┃                   coef_asc_1_Main                           -0.000055
# ┃                   coef_asc_1_Shop                           -0.000097
# ┃                                                                ...
# ┃                   coef_universityNonMandMaxThree_shopping    0.000013
# ┃                   coef_universityNonMandMaxThree_visiting   -0.000090
# ┃                   coef_walkRetailAccessibility_eatout        0.000218
# ┃                   coef_zeroAutomobiles_disc                 -0.000027
# ┃                   coef_zeroAutomobiles_visiting              0.000058
# ┃                   Length: 76, dtype: float64
# ┣              nit: 61
# ┣             nfev: 63
# ┣             njev: 61
# ┣           status: 0
# ┣          message: 'Optimization terminated successfully'
# ┣          success: True
# ┣     elapsed_time: datetime.timedelta(seconds=2, microseconds=374665)
# ┣           method: 'SLSQP'
# ┣          n_cases: 13210
# ┣ iteration_number: 61
# ┣          loglike: -5583.026333343983

# %% [markdown]
# ### Estimated coefficients

# %%
model.parameter_summary()
# Out:
# <style type="text/css">
# #T_adde2 th {
#   vertical-align: top;
#   text-align: left;
# }
# #T_adde2 td {
#   vertical-align: top;
#   text-align: left;
# }
# #T_adde2_row0_col0, #T_adde2_row0_col1, #T_adde2_row0_col2, #T_adde2_row0_col3, #T_adde2_row0_col4, #T_adde2_row1_col0, #T_adde2_row1_col1, #T_adde2_row1_col2, #T_adde2_row1_col3, #T_adde2_row1_col4, #T_adde2_row2_col0, #T_adde2_row2_col1, #T_adde2_row2_col2, #T_adde2_row2_col3, #T_adde2_row2_col4, #T_adde2_row3_col0, #T_adde2_row3_col1, #T_adde2_row3_col2, #T_adde2_row3_col3, #T_adde2_row3_col4, #T_adde2_row4_col0, #T_adde2_row4_col1, #T_adde2_row4_col2, #T_adde2_row4_col3, #T_adde2_row4_col4, #T_adde2_row5_col0, #T_adde2_row5_col1, #T_adde2_row5_col2, #T_adde2_row5_col3, #T_adde2_row5_col4, #T_adde2_row6_col0, #T_adde2_row6_col1, #T_adde2_row6_col2, #T_adde2_row6_col3, #T_adde2_row6_col4, #T_adde2_row7_col0, #T_adde2_row7_col1, #T_adde2_row7_col2, #T_adde2_row7_col3, #T_adde2_row7_col4, #T_adde2_row8_col0, #T_adde2_row8_col1, #T_adde2_row8_col2, #T_adde2_row8_col3, #T_adde2_row8_col4, #T_adde2_row9_col0, #T_adde2_row9_col1, #T_adde2_row9_col2, #T_adde2_row9_col3, #T_adde2_row9_col4, #T_adde2_row10_col0, #T_adde2_row10_col1, #T_adde2_row10_col2, #T_adde2_row10_col3, #T_adde2_row10_col4, #T_adde2_row11_col0, #T_adde2_row11_col1, #T_adde2_row11_col2, #T_adde2_row11_col3, #T_adde2_row11_col4, #T_adde2_row12_col0, #T_adde2_row12_col1, #T_adde2_row12_col2, #T_adde2_row12_col3, #T_adde2_row12_col4, #T_adde2_row13_col0, #T_adde2_row13_col1, #T_adde2_row13_col2, #T_adde2_row13_col3, #T_adde2_row13_col4, #T_adde2_row14_col0, #T_adde2_row14_col1, #T_adde2_row14_col2, #T_adde2_row14_col3, #T_adde2_row14_col4, #T_adde2_row15_col0, #T_adde2_row15_col1, #T_adde2_row15_col2, #T_adde2_row15_col3, #T_adde2_row15_col4, #T_adde2_row16_col0, #T_adde2_row16_col1, #T_adde2_row16_col2, #T_adde2_row16_col3, #T_adde2_row16_col4, #T_adde2_row17_col0, #T_adde2_row17_col1, #T_adde2_row17_col2, #T_adde2_row17_col3, #T_adde2_row17_col4, #T_adde2_row18_col0, #T_adde2_row18_col1, #T_adde2_row18_col2, #T_adde2_row18_col3, #T_adde2_row18_col4, #T_adde2_row19_col0, #T_adde2_row19_col1, #T_adde2_row19_col2, #T_adde2_row19_col3, #T_adde2_row19_col4, #T_adde2_row20_col0, #T_adde2_row20_col1, #T_adde2_row20_col2, #T_adde2_row20_col3, #T_adde2_row20_col4, #T_adde2_row21_col0, #T_adde2_row21_col1, #T_adde2_row21_col2, #T_adde2_row21_col3, #T_adde2_row21_col4, #T_adde2_row22_col0, #T_adde2_row22_col1, #T_adde2_row22_col2, #T_adde2_row22_col3, #T_adde2_row22_col4, #T_adde2_row23_col0, #T_adde2_row23_col1, #T_adde2_row23_col2, #T_adde2_row23_col3, #T_adde2_row23_col4, #T_adde2_row24_col0, #T_adde2_row24_col1, #T_adde2_row24_col2, #T_adde2_row24_col3, #T_adde2_row24_col4, #T_adde2_row25_col0, #T_adde2_row25_col1, #T_adde2_row25_col2, #T_adde2_row25_col3, #T_adde2_row25_col4, #T_adde2_row26_col0, #T_adde2_row26_col1, #T_adde2_row26_col2, #T_adde2_row26_col3, #T_adde2_row26_col4, #T_adde2_row27_col0, #T_adde2_row27_col1, #T_adde2_row27_col2, #T_adde2_row27_col3, #T_adde2_row27_col4, #T_adde2_row28_col0, #T_adde2_row28_col1, #T_adde2_row28_col2, #T_adde2_row28_col3, #T_adde2_row28_col4, #T_adde2_row29_col0, #T_adde2_row29_col1, #T_adde2_row29_col2, #T_adde2_row29_col3, #T_adde2_row29_col4, #T_adde2_row30_col0, #T_adde2_row30_col1, #T_adde2_row30_col2, #T_adde2_row30_col3, #T_adde2_row30_col4, #T_adde2_row31_col0, #T_adde2_row31_col1, #T_adde2_row31_col2, #T_adde2_row31_col3, #T_adde2_row31_col4, #T_adde2_row32_col0, #T_adde2_row32_col1, #T_adde2_row32_col2, #T_adde2_row32_col3, #T_adde2_row32_col4, #T_adde2_row33_col0, #T_adde2_row33_col1, #T_adde2_row33_col2, #T_adde2_row33_col3, #T_adde2_row33_col4, #T_adde2_row34_col0, #T_adde2_row34_col1, #T_adde2_row34_col2, #T_adde2_row34_col3, #T_adde2_row34_col4, #T_adde2_row35_col0, #T_adde2_row35_col1, #T_adde2_row35_col2, #T_adde2_row35_col3, #T_adde2_row35_col4, #T_adde2_row36_col0, #T_adde2_row36_col1, #T_adde2_row36_col2, #T_adde2_row36_col3, #T_adde2_row36_col4, #T_adde2_row37_col0, #T_adde2_row37_col1, #T_adde2_row37_col2, #T_adde2_row37_col3, #T_adde2_row37_col4, #T_adde2_row38_col0, #T_adde2_row38_col1, #T_adde2_row38_col ...

# %% [markdown]
# # Output Estimation Results

# %%
from activitysim.estimation.larch import update_coefficients
result_dir = data.edb_directory/"estimated"
update_coefficients(
    model, data, result_dir,
    output_file=f"{modelname}_coefficients_revised.csv",
);

# %% [markdown]
# ### Write the model estimation report, including coefficient t-statistic and log likelihood

# %%
model.to_xlsx(
    result_dir/f"{modelname}_model_estimation.xlsx", 
    data_statistics=False,
)

# %% [markdown]
# # Next Steps
#
# The final step is to either manually or automatically copy the `*_coefficients_revised.csv` file to the configs folder, rename it to `*_coefficients.csv`, and run ActivitySim in simulation mode.

# %%
pd.read_csv(result_dir/f"{modelname}_coefficients_revised.csv")
# Out:
#                              coefficient_name     value constrain
# 0                            coef_asc_0_tours  0.000000         T
# 1                             coef_asc_1_Shop -6.045190         F
# 2                             coef_asc_1_Main -5.816690         F
# 3                              coef_asc_1_Eat -6.074061         F
# 4                            coef_asc_1_Visit -5.839951         F
# ..                                        ...       ...       ...
# 71   coef_logTimeWindowOverlapAdultChild_disc  0.303504         F
# 72            coef_incomeBetween50And100_disc  0.132487         F
# 73             coef_incomeGreaterThan100_disc  0.366581         F
# 74  coef_incomeMissing_dummy_always_zero_disc  0.372300         F
# 75                  coef_zeroAutomobiles_disc -0.953758         F
#
# [76 rows x 3 columns]
