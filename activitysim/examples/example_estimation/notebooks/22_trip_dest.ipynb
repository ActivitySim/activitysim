# %% [markdown]
# # Estimating Trip Destination Choice
#
# This notebook illustrates how to re-estimate a single model component for ActivitySim.  This process
# includes running ActivitySim in estimation mode to read household travel survey files and write out
# the estimation data bundles used in this notebook.  To review how to do so, please visit the other
# notebooks in this directory.

# %% [markdown]
# # Load libraries

# %%
import larch as lx
import pandas as pd

lx.versions()
# Out:
# JAX not found. Some functionality will be unavailable.
# {'larch': '6.0.32',
#  'sharrow': '2.13.0',
#  'numpy': '1.26.4',
#  'pandas': '1.5.3',
#  'xarray': '2024.3.0',
#  'numba': '0.60.0'}

# %% [markdown]
# For this demo, we will assume that you have already run ActivitySim in estimation
# mode, and saved the required estimation data bundles (EDB's) to disk.  See
# the [first notebook](./01_estimation_mode.ipynb) for details.  The following module
# will run a script to set everything up if the example data is not already available.

# %%
from est_mode_setup import prepare

prepare()
# Out:
# EDB directory already populated.
# PosixPath('test-estimation-data/activitysim-prototype-mtc-extended')

# %% [markdown]
# # Load data and prep model for estimation

# %%
modelname="trip_destination"

# %%
from activitysim.estimation.larch import component_model
model, data = component_model(
    modelname,
    edb_directory=f"output-est-mode/estimation_data_bundle/{modelname}/",
    return_data=True,
)
# Out:
# loading from output-est-mode/estimation_data_bundle/trip_destination/trip_destination_coefficients.csv
# loading from output-est-mode/estimation_data_bundle/trip_destination/trip_destination_SPEC.csv
# loading from output-est-mode/estimation_data_bundle/trip_destination/trip_destination_alternatives_combined.parquet
# loading from output-est-mode/estimation_data_bundle/trip_destination/trip_destination_choosers_combined.parquet
# loading from output-est-mode/estimation_data_bundle/trip_destination/trip_destination_landuse.csv
# loading from output-est-mode/estimation_data_bundle/trip_destination/trip_destination_size_terms.csv
# /Users/jpn/Git/est-mode/activitysim/activitysim/estimation/larch/location_choice.py:548: UserWarning: Removed 5419 choosers with invalid (zero-sized) observed choice
#   return location_choice_model(

# %% [markdown]
# # Review data loaded from EDB
#
# Next we can review what was read the EDB, including the coefficients, model settings, utilities specification, and chooser and alternative data.

# %% [markdown]
# ## coefficients

# %%
data.coefficients
# Out:
#                                        value constrain
# coefficient_name
# coef_UNAVAILABLE                 -999.000000         T
# coef_one                            1.000000         T
# coef_mode_choice_logsum             1.821000         F
# coef_distance_joint                -0.123800         F
# coef_util_distance_work_outbound   -0.049726         F
# coef_util_distance_work_inbound     0.147813         F
# coef_util_distance_univ            -0.061300         F
# coef_util_distance_school          -0.105600         F
# coef_util_distance_escort          -0.149100         F
# coef_util_distance_shopping        -0.119200         F
# coef_util_distance_eatout          -0.102900         F
# coef_util_distance_othmaint        -0.096200         F
# coef_util_distance_social          -0.132900         F
# coef_util_distance_othdiscr        -0.126172         F
# coef_util_distance_atwork          -0.122335         F
# coef_prox_home_outbound_work       -0.380000         F
# coef_prox_home_inbound_work        -0.150000         F
# coef_prox_dest_outbound_work       -0.260000         F

# %% [markdown]
# ## alt_values

# %%
data.alt_values
# Out:
#            trip_id  dest_taz  util_size_term  util_no_attractions  \
# 0           439241         2        6.117394                False
# 1           439241        11        7.726934                False
# 2           439241        16        7.935721                False
# 3           439241        21        5.953480                False
# 4           439241        82        5.890218                False
# ...            ...       ...             ...                  ...
# 854498  2481262477      1314        6.565007                False
# 854499  2481262477      1315        5.491167                False
# 854500  2481262477      1318        4.109496                False
# 854501  2481262477      1324        5.586113                False
# 854502  2481262477      1361        7.160701                False
#
#         util_distance_inbound  util_distance_outbound  util_distance_joint  \
# 0                    0.000000               14.110000                  0.0
# 1                    0.000000               12.280001                  0.0
# 2                    0.000000               14.280000                  0.0
# 3                    0.000000               12.920000                  0.0
# 4                    0.000000                9.790000                  0.0
# ...                       ...                     ...                  ...
# 854498              21.299999                0.000000                  0.0
# 854499              14.500000                0.000000                  0.0
# 854500              35.799999                0.000000                  0.0
# 854501              40.349998                0.000000                  0.0
# 854502              60.360001                0.000000                  0.0
#
#         util_prox_home_outbound  util_prox_home_inbound  \
# 0                          6.89                0.000000
# 1                          5.90                0.000000
# 2                          6.81                0.000000
# 3                          6.13                0.000000
# 4                          4.83                0.000000
# ...                         ...                     ...
# 854498                     0.00               10.650000
# 854499                     0.00                7.250000
# 854500                     0.00               17.900000
# 854501                     0.00               19.950001
# 854502                     0.00               30.180000
#
#         util_prox_dest_outbound  util_prox_dest_inbound  \
# 0                          7.22                    0.00
# 1                          6.38                    0.00
# 2                          7.47                    0.00
# 3                          6.79                    0.00
# 4                          4.96                    0.00
# ...                         ...                     ...
# 854498                     0.00                   10.65
# 854499                     0.00                    7.25
# 854500                     0.00                   17.90
# 854501                     0.00                   20.40
# 854502                     0.00                   30.18
#
#         util_sample_of_alternatives_correction_factor  \
# 0                                            6.128602
# 1                                            3.637608
# 2                                            3.634621
# 3                                            5.476918
# 4                                            5.218103
# ...                                               ...
# 854498                                       3.869640
# 854499                                       2.986897
# 854500                                       7.056036
# 854501                                       6.153502
# 854502                                       7.103621
#
#         util_mode_choice_logsum_os  \
# 0                        -0.847005
# 1                        -0.558405
# 2                        -0.681632
# 3                        -0.536647
# 4                        -0.383122
# ...                            ...
# 854498                   -3.466365
# 854499                   -2.475631
# 854500                   -6.066198
# 854501                   -6.458255
# 854502                   -9.888594
#
#         util_stop_not_accessible_by_this_tour_mode  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 854498                                       False
# 854499                                       False
# 854500                                       False
# 854501                                       False
# 854502                                       False
#
#         util_mode_choice_logsum_sd  util_dest_not_accessible_by_this_tour_mode
# 0                        -0.633253                                       False
# 1                        -0.497479                                       False
# 2                        -0.639591                                       False
# 3                        -0.524008                                       False
# 4                        -0.265333                                       False
# ...                            ...                                         ...
# 854498                   -3.466365                                       False
# 854499                   -2.476182                                       False
# 854500                   -6.054759                                       False
# 854501                   -6.443607                                       False
# 854502                   -9.902823                                       False
#
# [854503 rows x 16 columns]

# %% [markdown]
# ## chooser_data

# %%
data.chooser_data
# Out:
#           trip_id  model_choice  override_choice  person_id  household_id  \
# 0          439241            93              178       1339          1339
# 1          497189           169               99       1515          1515
# 2          536181           184              177       1634          1634
# 3          593909           183              136       1810          1810
# 4          593910            89              188       1810          1810
# ...           ...           ...              ...        ...           ...
# 36442  2480879045          1304             1306    7563655       2872320
# 36443  2480879069          1298             1299    7563655       2872320
# 36444  2480879070          1291             1293    7563655       2872320
# 36445  2480879071          1293             1293    7563655       2872320
# 36446  2481262477          1309             1302    7564824       2873489
#
#       primary_purpose  trip_num  outbound  trip_count  destination  ...  \
# 0              eatout         1      True           2          187  ...
# 1            shopping         1     False           2          170  ...
# 2            othmaint         1     False           2          178  ...
# 3            othmaint         1     False           3          183  ...
# 4            othmaint         2     False           3          183  ...
# ...               ...       ...       ...         ...          ...  ...
# 36442        othdiscr         1     False           2         1293  ...
# 36443        othmaint         1     False           4         1293  ...
# 36444        othmaint         2     False           4         1293  ...
# 36445        othmaint         3     False           4         1293  ...
# 36446        othdiscr         1     False           2         1310  ...
#
#         purpose  next_trip_id       tour_mode trip_period  is_joint  \
# 0      shopping        439242  DRIVEALONEFREE          PM     False
# 1      othdiscr        497190  DRIVEALONEFREE          EV     False
# 2      othmaint        536182  DRIVEALONEFREE          PM     False
# 3        escort        593910     SHARED2FREE          AM     False
# 4      othmaint        593911     SHARED2FREE          AM     False
# ...         ...           ...             ...         ...       ...
# 36442  othdiscr    2480879046  DRIVEALONEFREE          MD     False
# 36443  shopping    2480879070  DRIVEALONEFREE          PM     False
# 36444    eatout    2480879071  DRIVEALONEFREE          PM     False
# 36445  othdiscr    2480879072  DRIVEALONEFREE          PM     False
# 36446  shopping    2481262478  DRIVEALONEFREE          PM     False
#
#       tour_leg_dest purpose_index_num  tour_mode_is_walk  tour_mode_is_bike  \
# 0             187.0                 2              False              False
# 1             170.0                 6              False              False
# 2             178.0                 4              False              False
# 3             183.0                 1              False              False
# 4             183.0                 4              False              False
# ...             ...               ...                ...                ...
# 36442        1293.0                 6              False              False
# 36443        1293.0                 2              False              False
# 36444        1293.0                 3              False              False
# 36445        1293.0                 6              False              False
# 36446        1310.0                 2              False              False
#
#        destination_logsum
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 36442                 NaN
# 36443                 NaN
# 36444                 NaN
# 36445                 NaN
# 36446                 NaN
#
# [36447 rows x 23 columns]

# %% [markdown]
# ## landuse

# %%
data.landuse
# Out:
#          DISTRICT  SD  county_id  TOTHH  TOTPOP  TOTACRE  RESACRE    CIACRE  \
# zone_id
# 1               1   1          1     46      82     20.3      1.0  15.00000
# 2               1   1          1    134     240     31.1      1.0  24.79297
# 3               1   1          1    267     476     14.7      1.0   2.31799
# 4               1   1          1    151     253     19.3      1.0  18.00000
# 5               1   1          1    611    1069     52.7      1.0  15.00000
# ...           ...  ..        ...    ...     ...      ...      ...       ...
# 1450           34  34          9   2724    6493   1320.0    630.0  69.00000
# 1451           34  34          9   2016    4835    664.0    379.0  43.00000
# 1452           34  34          9   2178    5055   1068.0    602.0  35.00000
# 1453           34  34          9    298     779  14195.0    429.0   4.00000
# 1454           34  34          9   1068    2337  10469.0   1114.0  27.00000
#
#          TOTEMP  AGE0519  ...  area_type  HSENROLL   COLLFTE  COLLPTE  \
# zone_id                   ...
# 1         27318        7  ...          0       0.0   0.00000      0.0
# 2         42078       19  ...          0       0.0   0.00000      0.0
# 3          2445       38  ...          0       0.0   0.00000      0.0
# 4         22434       20  ...          0       0.0   0.00000      0.0
# 5         15662       86  ...          0       0.0  72.14684      0.0
# ...         ...      ...  ...        ...       ...       ...      ...
# 1450       1046     1013  ...          4       0.0   0.00000      0.0
# 1451        757      757  ...          4       0.0   0.00000      0.0
# 1452       2110      789  ...          4       0.0   0.00000      0.0
# 1453        922       88  ...          5       0.0   0.00000      0.0
# 1454        607      418  ...          5       0.0   0.00000      0.0
#
#          TOPOLOGY  TERMINAL  household_density  employment_density  \
# zone_id
# 1               3   5.89564           2.875000         1707.375000
# 2               1   5.84871           5.195214         1631.374751
# 3               1   5.53231          80.470405          736.891913
# 4               2   5.64330           7.947368         1180.736842
# 5               1   5.52555          38.187500          978.875000
# ...           ...       ...                ...                 ...
# 1450            1   1.12116           3.896996            1.496423
# 1451            1   1.17116           4.777251            1.793839
# 1452            1   1.17587           3.419152            3.312402
# 1453            1   1.01972           0.688222            2.129330
# 1454            1   0.95542           0.936021            0.531989
#
#          density_index  is_cbd
# zone_id
# 1             2.870167   False
# 2             5.178722   False
# 3            72.547987   False
# 4             7.894233   False
# 5            36.753679   False
# ...                ...     ...
# 1450          1.081235   False
# 1451          1.304140   False
# 1452          1.682465   False
# 1453          0.520115   False
# 1454          0.339203   False
#
# [1454 rows x 28 columns]

# %% [markdown]
# ## spec

# %%
data.spec
# Out:
#                                             Label  \
# 0                                  util_size_term
# 1                             util_no_attractions
# 2                           util_distance_inbound
# 3                          util_distance_outbound
# 4                             util_distance_joint
# 5                         util_prox_home_outbound
# 6                          util_prox_home_inbound
# 7                         util_prox_dest_outbound
# 8                          util_prox_dest_inbound
# 9   util_sample_of_alternatives_correction_factor
# 10                     util_mode_choice_logsum_os
# 11     util_stop_not_accessible_by_this_tour_mode
# 12                     util_mode_choice_logsum_sd
# 13     util_dest_not_accessible_by_this_tour_mode
#
#                                           Description  \
# 0                                           size term
# 1                                      no attractions
# 2   distance (calibration adjustment individual - ...
# 3   distance (calibration adjustment individual - ...
# 4             distance (calibration adjustment joint)
# 5                   stop proximity to home (outbound)
# 6                    stop proximity to home (inbound)
# 7       stop proximity to main destination (outbound)
# 8        stop proximity to main destination (inbound)
# 9            Sample of alternatives correction factor
# 10             Mode choice logsum from origin to stop
# 11           Can't access stop zone by this tour mode
# 12        Mode choice logsum from stop to destination
# 13    Can't access destination zone by this tour mode
#
#                                            Expression  \
# 0   @np.log1p(size_terms.get(df.dest_taz, df.purpo...
# 1   @size_terms.get(df.dest_taz, df.purpose) == 0 ...
# 2   @(~df.is_joint & ~df.outbound) * (_od_DIST + _...
# 3   @(~df.is_joint & df.outbound) * (_od_DIST + _d...
# 4                @df.is_joint * (_od_DIST + _dp_DIST)
# 5                             @df.outbound * _od_DIST
# 6                            @~df.outbound * _dp_DIST
# 7                             @df.outbound * _dp_DIST
# 8                            @~df.outbound * _od_DIST
# 9      @np.minimum(np.log(df.pick_count/df.prob), 60)
# 10                                          od_logsum
# 11                                 (od_logsum < -100)
# 12                                          dp_logsum
# 13                                 (dp_logsum < -100)
#
#                                 work                     univ  \
# 0                           coef_one                 coef_one
# 1                   coef_UNAVAILABLE         coef_UNAVAILABLE
# 2   coef_util_distance_work_outbound  coef_util_distance_univ
# 3    coef_util_distance_work_inbound  coef_util_distance_univ
# 4                                NaN                      NaN
# 5       coef_prox_home_outbound_work                      NaN
# 6        coef_prox_home_inbound_work                      NaN
# 7       coef_prox_dest_outbound_work                      NaN
# 8                                NaN                      NaN
# 9                           coef_one                 coef_one
# 10           coef_mode_choice_logsum  coef_mode_choice_logsum
# 11                  coef_UNAVAILABLE         coef_UNAVAILABLE
# 12           coef_mode_choice_logsum  coef_mode_choice_logsum
# 13                  coef_UNAVAILABLE         coef_UNAVAILABLE
#
#                        school                     escort  \
# 0                    coef_one                   coef_one
# 1            coef_UNAVAILABLE           coef_UNAVAILABLE
# 2   coef_util_distance_school  coef_util_distance_escort
# 3   coef_util_distance_school  coef_util_distance_escort
# 4                         NaN        coef_distance_joint
# 5                         NaN                        NaN
# 6                         NaN                        NaN
# 7                         NaN                        NaN
# 8                         NaN                        NaN
# 9                    coef_one                   coef_one
# 10    coef_mode_choice_logsum    coef_mode_choice_logsum
# 11           coef_UNAVAILABLE           coef_UNAVAILABLE
# 12    coef_mode_choice_logsum    coef_mode_choice_logsum
# 13           coef_UNAVAILABLE           coef_UNAVAILABLE
#
#                        shopping                     eatout  \
# 0                      coef_one                   coef_one
# 1              coef_UNAVAILABLE           coef_UNAVAILABLE
# 2   coef_util_distance_shopping  coef_util_distance_eatout
# 3   coef_util_distance_shopping  coef_util_distance_eatout
# 4           coef_distance_joint        coef_distance_joint
# 5                           NaN                        NaN
# 6                           NaN                        NaN
# 7                           NaN                        NaN
# 8                           NaN                        NaN
# 9                      coef_one                   coef_one
# 10      coef_mode_choice_logsum    coef_mode_choice_logsum
# 11             coef_UNAVAILABLE           coef_UNAVAILABLE
# 12      coef_mode_choice_logsum    coef_mode_choice_logsum
# 13             coef_UNAVAILABLE           coef_UNAVAILABLE
#
#                        othmaint                     social  \
# 0                      coef_one                   coef_one
# 1              coef_UNAVAILABLE           coef_UNAVAILABLE
# 2   coef_util_distance_othmaint  coef_util_distance_social
# 3   coef_util_distance_othmaint  coef_util_distance_social
# 4           coef_distance_joint        coef_distance_joint
# 5                           NaN                        NaN
# 6                           NaN                        NaN
# 7                           NaN                        NaN
# 8                           NaN                        NaN
# 9                      coef_one                   coef_one
# 10      coef_mode_choice_logsum    coef_mode_choice_logsum
# 11             coef_UNAVAILABLE           coef_UNAVAILABLE
# 12      coef_mode_choice_logsum    coef_mode_choice_logsum
# 13             coef_UNAVAILABLE           coef_UNAVAILABLE
#
#                        othdiscr                     atwork
# 0                      coef_one                   coef_one
# 1              coef_UNAVAILABLE           coef_UNAVAILABLE
# 2   coef_util_distance_othdiscr  coef_util_distance_atwork
# 3   coef_util_distance_othdiscr  coef_util_distance_atwork
# 4           coef_distance_joint                        NaN
# 5                           NaN                        NaN
# 6                           NaN                        NaN
# 7                           NaN                        NaN
# 8                           NaN                        NaN
# 9                      coef_one                   coef_one
# 10      coef_mode_choice_logsum    coef_mode_choice_logsum
# 11             coef_UNAVAILABLE           coef_UNAVAILABLE
# 12      coef_mode_choice_logsum    coef_mode_choice_logsum
# 13             coef_UNAVAILABLE           coef_UNAVAILABLE

# %% [markdown]
# ## size_spec

# %%
data.size_spec
# Out:
#           TOTHH  RETEMPN  FPSEMPN  HEREMPN  OTHEMPN  AGREMPN  MWTEMPN  \
# segment
# work      0.000    1.000      1.0    1.000    1.000      1.0      1.0
# escort    0.001    0.225      0.0    0.144    0.000      0.0      0.0
# shopping  0.001    0.999      0.0    0.000    0.000      0.0      0.0
# eatout    0.000    0.742      0.0    0.258    0.000      0.0      0.0
# othmaint  0.001    0.481      0.0    0.518    0.000      0.0      0.0
# social    0.001    0.521      0.0    0.478    0.000      0.0      0.0
# othdiscr  0.252    0.212      0.0    0.272    0.165      0.0      0.0
# univ      0.001    0.000      0.0    0.000    0.000      0.0      0.0
#
#           AGE0519  HSENROLL  COLLFTE  COLLPTE
# segment
# work        0.000     0.000    0.000    0.000
# escort      0.464     0.166    0.000    0.000
# shopping    0.000     0.000    0.000    0.000
# eatout      0.000     0.000    0.000    0.000
# othmaint    0.000     0.000    0.000    0.000
# social      0.000     0.000    0.000    0.000
# othdiscr    0.000     0.098    0.000    0.000
# univ        0.000     0.000    0.592    0.408

# %% [markdown]
# # Estimate
#
# With the model setup for estimation, the next step is to estimate the model coefficients.  Make sure to use a sufficiently large enough household sample and set of zones to avoid an over-specified model, which does not have a numerically stable likelihood maximizing solution.  Larch has a built-in estimation methods including BHHH, and also offers access to more advanced general purpose non-linear optimizers in the `scipy` package, including SLSQP, which allows for bounds and constraints on parameters.  BHHH is the default and typically runs faster, but does not follow constraints on parameters.

# %%
model.estimate(method='SLSQP', options={'maxiter':1000})
# Out:
# <h3>Iteration 087 [Optimization terminated successfully] </h3>
# <p>Best LL = -78919.86749443343</p>
#                                        value        best   initvalue  \
# param_name
# coef_UNAVAILABLE                 -999.000000 -999.000000 -999.000000
# coef_distance_joint                -0.222590   -0.222590   -0.123800
# coef_mode_choice_logsum             0.908189    0.908189    1.821000
# coef_one                            1.000000    1.000000    1.000000
# coef_prox_dest_outbound_work       -0.278949   -0.278949   -0.260000
# coef_prox_home_inbound_work        -0.121975   -0.121975   -0.150000
# coef_prox_home_outbound_work       -0.419012   -0.419012   -0.380000
# coef_util_distance_atwork          -0.122335   -0.122335   -0.122335
# coef_util_distance_eatout          -0.219723   -0.219723   -0.102900
# coef_util_distance_escort          -0.235858   -0.235858   -0.149100
# coef_util_distance_othdiscr        -0.241573   -0.241573   -0.126172
# coef_util_distance_othmaint        -0.177610   -0.177610   -0.096200
# coef_util_distance_school          -0.105600   -0.105600   -0.105600
# coef_util_distance_shopping        -0.227090   -0.227090   -0.119200
# coef_util_distance_social          -0.227558   -0.227558   -0.132900
# coef_util_distance_univ            -0.139388   -0.139388   -0.061300
# coef_util_distance_work_inbound     0.089849    0.089849    0.147813
# coef_util_distance_work_outbound   -0.138174   -0.138174   -0.049726
# eatout_HEREMPN                     -2.550718   -2.550718   -1.354796
# eatout_RETEMPN                     -0.298406   -0.298406   -0.298406
# escort_AGE0519                     -0.039579   -0.039579   -0.767871
# escort_HEREMPN                     -2.848681   -2.848681   -1.937942
# escort_HSENROLL                    -2.260284   -2.260284   -1.795768
# escort_RETEMPN                     -0.886457   -0.886457   -1.491655
# escort_TOTHH                       -6.907755   -6.907755   -6.907755
# othdiscr_HEREMPN                   -4.394168   -4.394168   -1.301953
# othdiscr_HSENROLL                  -3.310820   -3.310820   -2.322788
# othdiscr_OTHEMPN                   -2.825965   -2.825965   -1.801810
# othdiscr_RETEMPN                   -2.884521   -2.884521   -1.551169
# othdiscr_TOTHH                     -1.378326   -1.378326   -1.378326
# othmaint_HEREMPN                   -1.693356   -1.693356   -0.657780
# othmaint_RETEMPN                   -0.351270   -0.351270   -0.731888
# othmaint_TOTHH                     -6.907755   -6.907755   -6.907755
# shopping_RETEMPN                   -6.000000   -6.000000   -0.001001
# shopping_TOTHH                     -6.907755   -6.907755   -6.907755
# social_HEREMPN                     -1.516222   -1.516222   -0.738145
# social_RETEMPN                     -0.098839   -0.098839   -0.652005
# social_TOTHH                       -6.907755   -6.907755   -6.907755
# univ_COLLFTE                       -6.000000   -6.000000   -0.524249
# univ_COLLPTE                       -6.000000   -6.000000   -0.896488
# univ_TOTHH                         -6.907755   -6.907755   -6.907755
# work_AGREMPN                        0.122431    0.122431    0.000000
# work_FPSEMPN                       -6.000000   -6.000000    0.000000
# work_HEREMPN                       -1.959508   -1.959508    0.000000
# work_MWTEMPN                       -5.322959   -5.322959    0.000000
# work_OTHEMPN                       -2.512682   -2.512682    0.000000
# work_RETEMPN                        0.000000    0.000000    0.000000
#
#                                      minimum     maximum  nullvalue  holdfast
# param_name
# coef_UNAVAILABLE                 -999.000000 -999.000000        0.0         1
# coef_distance_joint               -25.000000   25.000000        0.0         0
# coef_mode_choice_logsum           -25.000000   25.000000        0.0         0
# coef_one                            1.000000    1.000000        0.0         1
# coef_prox_dest_outbound_work      -25.000000   25.000000        0.0         0
# coef_prox_home_inbound_work       -25.000000   25.000000        0.0         0
# coef_prox_home_outbound_work      -25.000000   25.000000        0.0         0
# coef_util_distance_atwork         -25.000000   25.000000        0.0         0
# coef_util_distance_eatout         -25.000000   25.000000        0.0         0
# coef_util_distance_escort         -25.000000   25.000000        0.0         0
# coef_util_distance_othdiscr       -25.000000   25.000000        0.0         0
# coef_util_distance_othmaint       -25.000000   25.000000        0.0         0
# coef_util_distance_school         -25.000000   25.000000        0.0         0
# coef_util_distance_shopping       -25.000000   25.000000        0.0         0
# coef_util_distance_social         -25.000000   25.000000        0.0         0
# coef_util_distance_univ           -25.000000   25.000000        0.0         0
# coef_util_distance_work_inbound   -25.000000   25.000000        0.0         0
# coef_util_distance_work_outbound  -25.000000   25.000000        0.0         0
# eatout_HEREMPN                     -6.000000    6.000000        0.0         0
# eatout_RETEMPN                     -0.298406   -0.298406        0.0         1
# escort_AGE0519                     -6.000000    6.000000        0.0         0
# escort_HEREMPN                     -6.000000    6.000000        0.0         0
# escort_HSENROLL                    -6.000000    6.000000        0.0         0
# escort_RETEMPN                     -6.000000    6.000000        0.0         0
# escort_TOTHH                       -6.907755   -6.907755        0.0         1
# othdiscr_HEREMPN                   -6.000000    6.000000        0.0         0
# othdiscr_HSENROLL                  -6.000000    6.000000        0.0         0
# othdiscr_OTHEMPN                   -6.000000    6.000000        0.0         0
# othdiscr_RETEMPN                   -6.000000    6.000000        0.0         0
# othdiscr_TOTHH                     -1.378326   -1.378326        0.0         1
# othmaint_HEREMPN                   -6.000000    6.000000        0.0         0
# othmaint_RETEMPN                   -6.000000    6.000000        0.0         0
# othmaint_TOTHH                     -6.907755   -6.907755        0.0         1
# shopping_RETEMPN                   -6.000000    6.000000        0.0         0
# shopping_TOTHH                     -6.907755   -6.907755        0.0         1
# social_HEREMPN                     -6.000000    6.000000        0.0         0
# social_RETEMPN                     -6.000000    6.000000        0.0         0
# social_TOTHH                       -6.907755   -6.907755        0.0         1
# univ_COLLFTE                       -6.000000    6.000000        0.0         0
# univ_COLLPTE                       -6.000000    6.000000        0.0         0
# univ_TOTHH                         -6.907755   -6.907755        0.0         1
# work_AGREMPN                       -6.000000    6.000000        0.0         0
# work_FPSEMPN                       -6.000000    6.000000        0.0         0
# work_HEREMPN                       -6.000000    6.000000        0.0         0
# work_MWTEMPN                       -6.000000    6.000000        0.0         0
# work_OTHEMPN                       -6.000000    6.000000        0.0         0
# work_RETEMPN                        0.000000    0.000000        0.0         1
# /Users/jpn/Git/est-mode/larch/src/larch/model/jaxmodel.py:1156: PossibleOverspecification: Model is possibly over-specified (hessian is nearly singular).
#   self.calculate_parameter_covariance()
# ┣                x: coef_UNAVAILABLE                   -999.000000
# ┃                   coef_distance_joint                  -0.222590
# ┃                   coef_mode_choice_logsum               0.908189
# ┃                   coef_one                              1.000000
# ┃                   coef_prox_dest_outbound_work         -0.278949
# ┃                   coef_prox_home_inbound_work          -0.121975
# ┃                   coef_prox_home_outbound_work         -0.419012
# ┃                   coef_util_distance_atwork            -0.122335
# ┃                   coef_util_distance_eatout            -0.219723
# ┃                   coef_util_distance_escort            -0.235858
# ┃                   coef_util_distance_othdiscr          -0.241573
# ┃                   coef_util_distance_othmaint          -0.177610
# ┃                   coef_util_distance_school            -0.105600
# ┃                   coef_util_distance_shopping          -0.227090
# ┃                   coef_util_distance_social            -0.227558
# ┃                   coef_util_distance_univ              -0.139388
# ┃                   coef_util_distance_work_inbound       0.089849
# ┃                   coef_util_distance_work_outbound     -0.138174
# ┃                   eatout_HEREMPN                       -2.550718
# ┃                   eatout_RETEMPN                       -0.298406
# ┃                   escort_AGE0519                       -0.039579
# ┃                   escort_HEREMPN                       -2.848681
# ┃                   escort_HSENROLL                      -2.260284
# ┃                   escort_RETEMPN                       -0.886457
# ┃                   escort_TOTHH                         -6.907755
# ┃                   othdiscr_HEREMPN                     -4.394168
# ┃                   othdiscr_HSENROLL                    -3.310820
# ┃                   othdiscr_OTHEMPN                     -2.825965
# ┃                   othdiscr_RETEMPN                     -2.884521
# ┃                   othdiscr_TOTHH                       -1.378326
# ┃                   othmaint_HEREMPN                     -1.693356
# ┃                   othmaint_RETEMPN                     -0.351270
# ┃                   othmaint_TOTHH                       -6.907755
# ┃                   shopping_RETEMPN                     -6.000000
# ┃                   shopping_TOTHH                       -6.907755
# ┃                   social_HEREMPN                       -1.516222
# ┃                   social_RETEMPN                       -0.098839
# ┃                   social_TOTHH                         -6.907755
# ┃                   univ_COLLFTE                         -6.000000
# ┃                   univ_COLLPTE                         -6.000000
# ┃                   univ_TOTHH                           -6.907755
# ┃                   work_AGREMPN                          0.122431
# ┃                   work_FPSEMPN                         -6.000000
# ┃                   work_HEREMPN                         -1.959508
# ┃                   work_MWTEMPN                         -5.322959
# ┃                   work_OTHEMPN                         -2.512682
# ┃                   work_RETEMPN                          0.000000
# ┃                   dtype: float64
# ┣          logloss: 2.543504818049292
# ┣        d_logloss: coef_UNAVAILABLE                    0.000000
# ┃                   coef_distance_joint                 0.000054
# ┃                   coef_mode_choice_logsum             0.000028
# ┃                   coef_one                            0.000000
# ┃                   coef_prox_dest_outbound_work       -0.000016
# ┃                   coef_prox_home_inbound_work         0.000044
# ┃                   coef_prox_home_outbound_work       -0.000010
# ┃                   coef_util_distance_atwork           0.000000
# ┃                   coef_util_distance_eatout           0.000017
# ┃                   coef_util_distance_escort           0.000004
# ┃                   coef_util_distance_othdiscr        -0.000030
# ┃                   coef_util_distance_othmaint        -0.000009
# ┃                   coef_util_distance_school           0.000000
# ┃                   coef_util_distance_shopping         0.000006
# ┃                   coef_util_distance_social          -0.000076
# ┃                   coef_util_distance_univ             0.000026
# ┃                   coef_util_distance_work_inbound    -0.000026
# ┃                   coef_util_distance_work_outbound    0.000069
# ┃                   eatout_HEREMPN                     -0.000049
# ┃                   eatout_RETEMPN                      0.000000
# ┃                   escort_AGE0519                     -0.000144
# ┃                   escort_HEREMPN                      0.000048
# ┃                   escort_HSENROLL                     0.000044
# ┃                   escort_RETEMPN                      0.000042
# ┃                   escort_TOTHH                        0.000000
# ┃                   othdiscr_HEREMPN                    0.000056
# ┃                   othdiscr_HSENROLL                  -0.000088
# ┃                   othdiscr_OTHEMPN                    0.000216
# ┃                   othdiscr_RETEMPN                   -0.000059
# ┃                   othdiscr_TOTHH                      0.000000
# ┃                   othmaint_HEREMPN                   -0.000220
# ┃                   othmaint_RETEMPN                   -0.000006
# ┃                   othmaint_TOTHH                      0.000000
# ┃                   shopping_RETEMPN                   -0.005801
# ┃                   shopping_TOTHH                      0.000000
# ┃                   social_HEREMPN                      0.000007
# ┃                   social_RETEMPN                     -0.000072
# ┃                   social_TOTHH                        0.000000
# ┃                   univ_COLLFTE                       -0.003131
# ┃                   univ_COLLPTE                       -0.002441
# ┃                   univ_TOTHH                          0.000000
# ┃                   work_AGREMPN                       -0.000051
# ┃                   work_FPSEMPN                       -0.000190
# ┃                   work_HEREMPN                        0.000081
# ┃                   work_MWTEMPN                       -0.000196
# ┃                   work_OTHEMPN                       -0.000045
# ┃                   work_RETEMPN                        0.000000
# ┃                   dtype: float64
# ┣              nit: 87
# ┣             nfev: 92
# ┣             njev: 87
# ┣           status: 0
# ┣          message: 'Optimization terminated successfully'
# ┣          success: True
# ┣     elapsed_time: datetime.timedelta(seconds=19, microseconds=360953)
# ┣           method: 'SLSQP'
# ┣          n_cases: 31028
# ┣ iteration_number: 87
# ┣          loglike: -78919.86749443343

# %% [markdown]
# ### Estimated coefficients

# %%
model.parameter_summary()
# Out:
# <style type="text/css">
# #T_ba5b8 th {
#   vertical-align: top;
#   text-align: left;
# }
# #T_ba5b8 td {
#   vertical-align: top;
#   text-align: left;
# }
# #T_ba5b8_row0_col0, #T_ba5b8_row0_col1, #T_ba5b8_row0_col2, #T_ba5b8_row0_col3, #T_ba5b8_row0_col4, #T_ba5b8_row1_col0, #T_ba5b8_row1_col1, #T_ba5b8_row1_col2, #T_ba5b8_row1_col3, #T_ba5b8_row1_col4, #T_ba5b8_row2_col0, #T_ba5b8_row2_col1, #T_ba5b8_row2_col2, #T_ba5b8_row2_col3, #T_ba5b8_row2_col4, #T_ba5b8_row3_col0, #T_ba5b8_row3_col1, #T_ba5b8_row3_col2, #T_ba5b8_row3_col3, #T_ba5b8_row3_col4, #T_ba5b8_row4_col0, #T_ba5b8_row4_col1, #T_ba5b8_row4_col2, #T_ba5b8_row4_col3, #T_ba5b8_row4_col4, #T_ba5b8_row5_col0, #T_ba5b8_row5_col1, #T_ba5b8_row5_col2, #T_ba5b8_row5_col3, #T_ba5b8_row5_col4, #T_ba5b8_row6_col0, #T_ba5b8_row6_col1, #T_ba5b8_row6_col2, #T_ba5b8_row6_col3, #T_ba5b8_row6_col4, #T_ba5b8_row7_col0, #T_ba5b8_row7_col1, #T_ba5b8_row7_col2, #T_ba5b8_row7_col3, #T_ba5b8_row7_col4, #T_ba5b8_row8_col0, #T_ba5b8_row8_col1, #T_ba5b8_row8_col2, #T_ba5b8_row8_col3, #T_ba5b8_row8_col4, #T_ba5b8_row9_col0, #T_ba5b8_row9_col1, #T_ba5b8_row9_col2, #T_ba5b8_row9_col3, #T_ba5b8_row9_col4, #T_ba5b8_row10_col0, #T_ba5b8_row10_col1, #T_ba5b8_row10_col2, #T_ba5b8_row10_col3, #T_ba5b8_row10_col4, #T_ba5b8_row11_col0, #T_ba5b8_row11_col1, #T_ba5b8_row11_col2, #T_ba5b8_row11_col3, #T_ba5b8_row11_col4, #T_ba5b8_row12_col0, #T_ba5b8_row12_col1, #T_ba5b8_row12_col2, #T_ba5b8_row12_col3, #T_ba5b8_row12_col4, #T_ba5b8_row13_col0, #T_ba5b8_row13_col1, #T_ba5b8_row13_col2, #T_ba5b8_row13_col3, #T_ba5b8_row13_col4, #T_ba5b8_row14_col0, #T_ba5b8_row14_col1, #T_ba5b8_row14_col2, #T_ba5b8_row14_col3, #T_ba5b8_row14_col4, #T_ba5b8_row15_col0, #T_ba5b8_row15_col1, #T_ba5b8_row15_col2, #T_ba5b8_row15_col3, #T_ba5b8_row15_col4, #T_ba5b8_row16_col0, #T_ba5b8_row16_col1, #T_ba5b8_row16_col2, #T_ba5b8_row16_col3, #T_ba5b8_row16_col4, #T_ba5b8_row17_col0, #T_ba5b8_row17_col1, #T_ba5b8_row17_col2, #T_ba5b8_row17_col3, #T_ba5b8_row17_col4, #T_ba5b8_row18_col0, #T_ba5b8_row18_col1, #T_ba5b8_row18_col2, #T_ba5b8_row18_col3, #T_ba5b8_row18_col4, #T_ba5b8_row19_col0, #T_ba5b8_row19_col1, #T_ba5b8_row19_col2, #T_ba5b8_row19_col3, #T_ba5b8_row19_col4, #T_ba5b8_row20_col0, #T_ba5b8_row20_col1, #T_ba5b8_row20_col2, #T_ba5b8_row20_col3, #T_ba5b8_row20_col4, #T_ba5b8_row21_col0, #T_ba5b8_row21_col1, #T_ba5b8_row21_col2, #T_ba5b8_row21_col3, #T_ba5b8_row21_col4, #T_ba5b8_row22_col0, #T_ba5b8_row22_col1, #T_ba5b8_row22_col2, #T_ba5b8_row22_col3, #T_ba5b8_row22_col4, #T_ba5b8_row23_col0, #T_ba5b8_row23_col1, #T_ba5b8_row23_col2, #T_ba5b8_row23_col3, #T_ba5b8_row23_col4, #T_ba5b8_row24_col0, #T_ba5b8_row24_col1, #T_ba5b8_row24_col2, #T_ba5b8_row24_col3, #T_ba5b8_row24_col4, #T_ba5b8_row25_col0, #T_ba5b8_row25_col1, #T_ba5b8_row25_col2, #T_ba5b8_row25_col3, #T_ba5b8_row25_col4, #T_ba5b8_row26_col0, #T_ba5b8_row26_col1, #T_ba5b8_row26_col2, #T_ba5b8_row26_col3, #T_ba5b8_row26_col4, #T_ba5b8_row27_col0, #T_ba5b8_row27_col1, #T_ba5b8_row27_col2, #T_ba5b8_row27_col3, #T_ba5b8_row27_col4, #T_ba5b8_row28_col0, #T_ba5b8_row28_col1, #T_ba5b8_row28_col2, #T_ba5b8_row28_col3, #T_ba5b8_row28_col4, #T_ba5b8_row29_col0, #T_ba5b8_row29_col1, #T_ba5b8_row29_col2, #T_ba5b8_row29_col3, #T_ba5b8_row29_col4, #T_ba5b8_row30_col0, #T_ba5b8_row30_col1, #T_ba5b8_row30_col2, #T_ba5b8_row30_col3, #T_ba5b8_row30_col4, #T_ba5b8_row31_col0, #T_ba5b8_row31_col1, #T_ba5b8_row31_col2, #T_ba5b8_row31_col3, #T_ba5b8_row31_col4, #T_ba5b8_row32_col0, #T_ba5b8_row32_col1, #T_ba5b8_row32_col2, #T_ba5b8_row32_col3, #T_ba5b8_row32_col4, #T_ba5b8_row33_col0, #T_ba5b8_row33_col1, #T_ba5b8_row33_col2, #T_ba5b8_row33_col3, #T_ba5b8_row33_col4, #T_ba5b8_row34_col0, #T_ba5b8_row34_col1, #T_ba5b8_row34_col2, #T_ba5b8_row34_col3, #T_ba5b8_row34_col4, #T_ba5b8_row35_col0, #T_ba5b8_row35_col1, #T_ba5b8_row35_col2, #T_ba5b8_row35_col3, #T_ba5b8_row35_col4, #T_ba5b8_row36_col0, #T_ba5b8_row36_col1, #T_ba5b8_row36_col2, #T_ba5b8_row36_col3, #T_ba5b8_row36_col4, #T_ba5b8_row37_col0, #T_ba5b8_row37_col1, #T_ba5b8_row37_col2, #T_ba5b8_row37_col3, #T_ba5b8_row37_col4, #T_ba5b8_row38_col0, #T_ba5b8_row38_col1, #T_ba5b8_row38_col ...
#   font-family: monospace;
# }
# </style>
# <table id="T_ba5b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba5b8_level0_col0" class="col_heading level0 col0" >Value</th>
#       <th id="T_ba5b8_level0_col1" class="col_heading level0 col1" >Std Err</th>
#       <th id="T_ba5b8_level0_col2" class="col_heading level0 col2" >t Stat</th>
#       <th id="T_ba5b8_level0_col3" class="col_heading level0 col3" >Signif</th>
#       <th id="T_ba5b8_level0_col4" class="col_heading level0 col4" >Null Value</th>
#       <th id="T_ba5b8_level0_col5" class="col_heading level0 col5" >Constrained</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Parameter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba5b8_level0_row0" class="row_heading level0 row0" >coef_UNAVAILABLE</th>
#       <td id="T_ba5b8_row0_col0" class="data row0 col0" >-999.</td>
#       <td id="T_ba5b8_row0_col1" class="data row0 col1" > 0.00</td>
#       <td id="T_ba5b8_row0_col2" class="data row0 col2" > NA</td>
#       <td id="T_ba5b8_row0_col3" class="data row0 col3" ></td>
#       <td id="T_ba5b8_row0_col4" class="data row0 col4" > 0.00</td>
#       <td id="T_ba5b8_row0_col5" class="data row0 col5" >fixed value</td>
#     </tr>
#     <tr>
#       <th id="T_ba5b8_level0_row1" class="row_heading level0 row1" >coef_distance_joint</th>
#       <td id="T_ba5b8_row1_col0" class="data row1 col0" >-0.223</td>
#       <td id="T_ba5b8_row1_col1" class="data row1 col1" > 0.0134</td>
#       <td id="T_ba5b8_row1_col2" class="data row1 col2" >-16.56</td>
#       <td id="T_ba5b8_row1_col3" class="data row1 col3" >***</td>
#       <td id="T_ba5b8_row1_col4" class="data row1 col4" > 0.00</td>
#       <td id="T_ba5b8_row1_col5" class="data row1 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_ba5b8_level0_row2" class="row_heading level0 row2" >coef_mode_choice_logsum</th>
#       <td id="T_ba5b8_row2_col0" class="data row2 col0" > 0.908</td>
#       <td id="T_ba5b8_row2_col1" class="data row2 col1" > 0.0111</td>
#       <td id="T_ba5b8_row2_col2" class="data row2 col2" > 82.17</td>
#       <td id="T_ba5b8_row2_col3" class="data row2 col3" >***</td>
#       <td id="T_ba5b8_row2_col4" class="data row2 col4" > 0.00</td>
#       <td id="T_ba5b8_row2_col5" class="data row2 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_ba5b8_level0_row3" class="row_heading level0 row3" >coef_one</th>
#       <td id="T_ba5b8_row3_col0" class="data row3 col0" > 1.00</td>
#       <td id="T_ba5b8_row3_col1" class="data row3 col1" > 0.00</td>
#       <td id="T_ba5b8_row3_col2" class="data row3 col2" > NA</td>
#       <td id="T_ba5b8_row3_col3" class="data row3 col3" ></td>
#       <td id="T_ba5b8_row3_col4" class="data row3 col4" > 0.00</td>
#       <td id="T_ba5b8_row3_col

# %% [markdown]
# # Output Estimation Results

# %%
from activitysim.estimation.larch import update_coefficients, update_size_spec
result_dir = data.edb_directory/"estimated"

# %% [markdown]
# ## Write updated utility coefficients

# %%
update_coefficients(
    model, data, result_dir,
    output_file=f"{modelname}_coefficients_revised.csv",
);

# %% [markdown]
# ## Write updated size coefficients

# %%
update_size_spec(
    model, data, result_dir, 
    output_file=f"{modelname}_size_terms.csv",
)
# Out:
#           segment model_selector     TOTHH   RETEMPN   FPSEMPN   HEREMPN  \
# 0        work_low      workplace  0.000000  0.129129  0.193193  0.383383
# 1        work_med      workplace  0.000000  0.120120  0.197197  0.325325
# 2       work_high      workplace  0.000000  0.110000  0.207000  0.284000
# 3   work_veryhigh      workplace  0.000000  0.093000  0.270000  0.241000
# 4      university         school  0.000000  0.000000  0.000000  0.000000
# 5     gradeschool         school  0.000000  0.000000  0.000000  0.000000
# 6      highschool         school  0.000000  0.000000  0.000000  0.000000
# 7          escort  non_mandatory  0.000000  0.225000  0.000000  0.144000
# 8        shopping  non_mandatory  0.000000  1.000000  0.000000  0.000000
# 9          eatout  non_mandatory  0.000000  0.742000  0.000000  0.258000
# 10       othmaint  non_mandatory  0.000000  0.482000  0.000000  0.518000
# 11         social  non_mandatory  0.000000  0.522000  0.000000  0.478000
# 12       othdiscr  non_mandatory  0.252252  0.212212  0.000000  0.272272
# 13         atwork         atwork  0.000000  0.742000  0.000000  0.258000
# 14           work           trip  0.000000  0.423805  0.001051  0.059726
# 15         escort           trip  0.000651  0.268207  0.000000  0.037695
# 16       shopping           trip  0.287459  0.712541  0.000000  0.000000
# 17         eatout           trip  0.000000  0.904850  0.000000  0.095150
# 18       othmaint           trip  0.001125  0.791941  0.000000  0.206934
# 19         social           trip  0.000888  0.804213  0.000000  0.194899
# 20       othdiscr           trip  0.605815  0.134341  0.000000  0.029688
# 21           univ           trip  0.167856  0.000000  0.000000  0.000000
#
#      OTHEMPN   AGREMPN   MWTEMPN   AGE0519  HSENROLL   COLLFTE   COLLPTE
# 0   0.120120  0.010010  0.164164  0.000000  0.000000  0.000000  0.000000
# 1   0.139139  0.008008  0.210210  0.000000  0.000000  0.000000  0.000000
# 2   0.154000  0.006000  0.239000  0.000000  0.000000  0.000000  0.000000
# 3   0.146000  0.004000  0.246000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000  0.592000  0.408000
# 5   0.000000  0.000000  0.000000  1.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  0.000000  1.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  0.465000  0.166000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 12  0.165165  0.000000  0.000000  0.000000  0.098098  0.000000  0.000000
# 13  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 14  0.034350  0.479002  0.002067  0.000000  0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000  0.625554  0.067893  0.000000  0.000000
# 16  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 18  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 20  0.142442  0.000000  0.000000  0.000000  0.087714  0.000000  0.000000
# 21  0.000000  0.000000  0.000000  0.000000  0.000000  0.416072  0.416072

# %% [markdown]
# ## Write the model estimation report, including coefficient t-statistic and log likelihood

# %%
model.to_xlsx(
    result_dir/f"{modelname}_model_estimation.xlsx", 
    data_statistics=False,
);

# %% [markdown]
# # Next Steps
#
# The final step is to either manually or automatically copy the `*_coefficients_revised.csv` file and `*_size_terms.csv` file to the configs folder, rename them to `*_coefficients.csv` and `destination_choice_size_terms.csv`, and run ActivitySim in simulation mode.  Note that all the location
# and desintation choice models share the same `destination_choice_size_terms.csv` input file, so if you
# are updating all these models, you'll need to ensure that updated sections of this file for each model
# are joined together correctly.

# %%
pd.read_csv(result_dir/f"{modelname}_coefficients_revised.csv")
# Out:
#                     coefficient_name       value constrain
# 0                   coef_UNAVAILABLE -999.000000         T
# 1                           coef_one    1.000000         T
# 2            coef_mode_choice_logsum    0.908189         F
# 3                coef_distance_joint   -0.222590         F
# 4   coef_util_distance_work_outbound   -0.138174         F
# 5    coef_util_distance_work_inbound    0.089849         F
# 6            coef_util_distance_univ   -0.139388         F
# 7          coef_util_distance_school   -0.105600         F
# 8          coef_util_distance_escort   -0.235858         F
# 9        coef_util_distance_shopping   -0.227090         F
# 10         coef_util_distance_eatout   -0.219723         F
# 11       coef_util_distance_othmaint   -0.177610         F
# 12         coef_util_distance_social   -0.227558         F
# 13       coef_util_distance_othdiscr   -0.241573         F
# 14         coef_util_distance_atwork   -0.122335         F
# 15      coef_prox_home_outbound_work   -0.419012         F
# 16       coef_prox_home_inbound_work   -0.121975         F
# 17      coef_prox_dest_outbound_work   -0.278949         F

# %%
pd.read_csv(result_dir/f"{modelname}_size_terms.csv")
# Out:
#     index        segment model_selector     TOTHH   RETEMPN   FPSEMPN  \
# 0       0       work_low      workplace  0.000000  0.129129  0.193193
# 1       1       work_med      workplace  0.000000  0.120120  0.197197
# 2       2      work_high      workplace  0.000000  0.110000  0.207000
# 3       3  work_veryhigh      workplace  0.000000  0.093000  0.270000
# 4       4     university         school  0.000000  0.000000  0.000000
# 5       5    gradeschool         school  0.000000  0.000000  0.000000
# 6       6     highschool         school  0.000000  0.000000  0.000000
# 7       7         escort  non_mandatory  0.000000  0.225000  0.000000
# 8       8       shopping  non_mandatory  0.000000  1.000000  0.000000
# 9       9         eatout  non_mandatory  0.000000  0.742000  0.000000
# 10     10       othmaint  non_mandatory  0.000000  0.482000  0.000000
# 11     11         social  non_mandatory  0.000000  0.522000  0.000000
# 12     12       othdiscr  non_mandatory  0.252252  0.212212  0.000000
# 13     13         atwork         atwork  0.000000  0.742000  0.000000
# 14     14           work           trip  0.000000  0.423805  0.001051
# 15     15         escort           trip  0.000651  0.268207  0.000000
# 16     16       shopping           trip  0.287459  0.712541  0.000000
# 17     17         eatout           trip  0.000000  0.904850  0.000000
# 18     18       othmaint           trip  0.001125  0.791941  0.000000
# 19     19         social           trip  0.000888  0.804213  0.000000
# 20     20       othdiscr           trip  0.605815  0.134341  0.000000
# 21     21           univ           trip  0.167856  0.000000  0.000000
#
#      HEREMPN   OTHEMPN   AGREMPN   MWTEMPN   AGE0519  HSENROLL   COLLFTE  \
# 0   0.383383  0.120120  0.010010  0.164164  0.000000  0.000000  0.000000
# 1   0.325325  0.139139  0.008008  0.210210  0.000000  0.000000  0.000000
# 2   0.284000  0.154000  0.006000  0.239000  0.000000  0.000000  0.000000
# 3   0.241000  0.146000  0.004000  0.246000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.592000
# 5   0.000000  0.000000  0.000000  0.000000  1.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  0.000000  0.000000  1.000000  0.000000
# 7   0.144000  0.000000  0.000000  0.000000  0.465000  0.166000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.258000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.518000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.478000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 12  0.272272  0.165165  0.000000  0.000000  0.000000  0.098098  0.000000
# 13  0.258000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 14  0.059726  0.034350  0.479002  0.002067  0.000000  0.000000  0.000000
# 15  0.037695  0.000000  0.000000  0.000000  0.625554  0.067893  0.000000
# 16  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 17  0.095150  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 18  0.206934  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 19  0.194899  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 20  0.029688  0.142442  0.000000  0.000000  0.000000  0.087714  0.000000
# 21  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.416072
#
#      COLLPTE
# 0   0.000000
# 1   0.000000
# 2   0.000000
# 3   0.000000
# 4   0.408000
# 5   0.000000
# 6   0.000000
# 7   0.000000
# 8   0.000000
# 9   0.000000
# 10  0.000000
# 11  0.000000
# 12  0.000000
# 13  0.000000
# 14  0.000000
# 15  0.000000
# 16  0.000000
# 17  0.000000
# 18  0.000000
# 19  0.000000
# 20  0.000000
# 21  0.416072
