# %% [markdown]
# # Creating the Three Zone Example Data
#
# Transform the TM1 TAZ-based model 25 zone inputs to a three-zone (MAZ, TAZ, TAP) set of inputs for software development.
#
# The 25 zones are downtown San Francisco and they are converted to 25 MAZs. Each TAZ is also converted to a TAP numbered 10000+. MAZs 1,2,3,4 are small and adjacent and assigned TAZ 2 and TAP 10002. MAZs 13,14,15 are small and adjacent and assigned TAZ 14 and TAP 10014. TAZs 1,3,4,13,15 are removed from the final data set. TAPs 10001,10003,10004,10013,10015 are removed from the final data set.
#
# This script should work for the full TM1 example as well.

# %% [markdown]
# # Load libraries

# %%
import os
import shutil

import pandas as pd
import numpy as np
import openmatrix as omx
from activitysim.cli.create import copy_example

# %% [markdown]
# # Create example directory

# %%
example_dir = 'example'

input_data = os.path.join(example_dir, 'data')
output_data = os.path.join(example_dir, 'data_3')

if not os.path.exists(example_dir):
    copy_example(example='example_mtc', destination=example_dir)

assert os.path.exists(input_data)

os.makedirs(os.path.join(example_dir, 'configs_1'), exist_ok=True)

# copy confits_1 to configs_2
if not os.path.exists(os.path.join(example_dir, 'configs_3')):
    shutil.copytree(os.path.join(example_dir, 'configs_1'), os.path.join(example_dir, 'configs_3'))

# %% [markdown]
# # initialize output data directory

# %%
# new empty output_dir
if os.path.exists(output_data):
    # shutil.rmtree(output_data)
    # os.makedirs(output_data)
    file_type = ('csv', 'omx')
    for file_name in os.listdir(output_data):
        if file_name.endswith(file_type):
            os.unlink(os.path.join(output_data, file_name))
else:
    os.makedirs(output_data)

# copy omx file to output_dir
shutil.copy(os.path.join(input_data, 'skims.omx'), os.path.join(output_data, 'skims.omx'))
# Out:
# 'example/data_3/skims.omx'

# %% [markdown]
# ### Convert tazs to mazs and add transit access distance by mode

# %%
land_use = pd.read_csv(os.path.join(input_data, 'land_use.csv'))

land_use.insert(loc=0, column='MAZ', value=land_use.ZONE)
land_use.insert(loc=1, column='TAZ', value=land_use.ZONE)
land_use.drop(columns=['ZONE'], inplace=True)

land_use.TAZ = land_use.TAZ.replace([1, 2, 3, 4], 2)
land_use.TAZ = land_use.TAZ.replace([13, 14, 15], 14)

land_use.to_csv(os.path.join(output_data, 'land_use.csv'), index=False)

land_use  # jupyter
# Out:
#     MAZ  TAZ  DISTRICT  SD  COUNTY  TOTHH  HHPOP  TOTPOP  EMPRES  SFDU  ...  \
# 0     1    2         1   1       1     46     74      82      37     1  ...
# 1     2    2         1   1       1    134    214     240     107     5  ...
# 2     3    2         1   1       1    267    427     476     214     9  ...
# 3     4    2         1   1       1    151    239     253     117     6  ...
# 4     5    5         1   1       1    611    974    1069     476    22  ...
# 5     6    6         1   1       1   2240   3311    3963    2052     0  ...
# 6     7    7         1   1       1   3762   5561    6032    3375     0  ...
# 7     8    8         1   1       1   4582   7565    9907    3594    19  ...
# 8     9    9         1   1       1   5545   9494   10171    4672    35  ...
# 9    10   10         1   1       1   5344   9205    9308    5137     5  ...
# 10   11   11         1   1       1   2902   4998    5163    2865    10  ...
# 11   12   12         1   1       1    793   1197    1207     897     0  ...
# 12   13   14         1   1       1    102    156     166      60     0  ...
# 13   14   14         1   1       1    476    722     728     523     0  ...
# 14   15   14         1   1       1    279    422     470     330     0  ...
# 15   16   16         1   1       1   6164  10143   10272    8094    15  ...
# 16   17   17         1   1       1   4075   6702    7119    5422    25  ...
# 17   18   18         1   1       1   1034   1705    2069    1266    56  ...
# 18   19   19         1   1       1    843   1387    1608    1023    22  ...
# 19   20   20         1   1       1   2006   3346    3691    1668    97  ...
# 20   21   21         1   1       1   3472   5793    6203    2782   117  ...
# 21   22   22         1   1       1   1195   1906    1925    1137    98  ...
# 22   23   23         1   1       1    565    900     906     543    43  ...
# 23   24   24         1   1       1    604    972     979     355     0  ...
# 24   25   25         1   1       1   1551   3410    3416    1239   131  ...
#
#     area_type   HSENROLL     COLLFTE     COLLPTE  TOPOLOGY  TERMINAL  ZERO  \
# 0           0    0.00000     0.00000     0.00000         3   5.89564     0
# 1           0    0.00000     0.00000     0.00000         1   5.84871     0
# 2           0    0.00000     0.00000     0.00000         1   5.53231     0
# 3           0    0.00000     0.00000     0.00000         2   5.64330     0
# 4           0    0.00000    72.14684     0.00000         1   5.52555     0
# 5           0    0.00000     0.00000     0.00000         1   5.00004     0
# 6           0    0.00000     0.00000     0.00000         1   5.35435     0
# 7           0    0.00000     0.00000     0.00000         2   4.64648     0
# 8           0   26.92893  2035.58118    20.60887         2   5.22542     0
# 9           0    0.00000   690.54974     0.00000         3   4.73802     0
# 10          0    0.00000     0.00000     0.00000         3   4.64739     0
# 11          0    0.00000  3434.21460  2376.73853         3   5.46202     0
# 12          0  348.71741  1719.16077  3824.83545         3   5.51319     0
# 13          0    0.00000   851.33472   251.48717         3   5.52147     0
# 14          0    0.00000     0.00000     0.00000         3   5.59024     0
# 15          0    0.00000     0.00000     0.00000         2   4.75017     0
# 16          1    0.00000     0.00000     0.00000         1   4.58156     0
# 17          1    0.00000     0.00000     0.00000         3   4.17010     0
# 18          1    0.00000     0.00000     0.00000         3   4.18480     0
# 19          1    0.00000     0.00000     0.00000         3   3.99027     0
# 20          1    0.00000     0.00000     0.00000         3   4.29617     0
# 21          0    0.00000     0.00000     0.00000         3   4.93813     0
# 22          1    0.00000     0.00000     0.00000         1   5.11702     0
# 23          0    0.00000     0.00000     0.00000         1   5.35851     0
# 24          0    0.00000     0.00000     0.00000         1   4.89113     0
#
#     hhlds  sftaz  gqpop
# 0      46      1      8
# 1     134      2     26
# 2     267      3     49
# 3     151      4     14
# 4     611      5     95
# 5    2240      6    652
# 6    3762      7    471
# 7    4582      8   2342
# 8    5545      9    677
# 9    5344     10    103
# 10   2902     11    165
# 11    793     12     10
# 12    102     13     10
# 13    476     14      6
# 14    279     15     48
# 15   6164     16    129
# 16   4075     17    417
# 17   1034     18    364
# 18    843     19    221
# 19   2006     20    345
# 20   3472     21    410
# 21   1195     22     19
# 22    565     23      6
# 23    604     24      7
# 24   1551     25      6
#
# [25 rows x 43 columns]

# %% [markdown]
# ### Put households in mazs instead of tazs

# %%
households = pd.read_csv(os.path.join(input_data, 'households.csv'))
households.rename(columns={'TAZ': 'MAZ'}, inplace=True)
households.to_csv(os.path.join(output_data, 'households.csv'), index=False)

households  # jupyter
# Out:
#          HHID  MAZ  SERIALNO  PUMA5  income  PERSONS  HHT  UNITTYPE  NOC  \
# 0     2717868   25   2715386   2202  361000        2    1         0    0
# 1      763899    6   5360279   2203   59220        1    4         0    0
# 2     2222791    9     77132   2203  197000        2    2         0    0
# 3      112477   17   3286812   2203    2200        1    6         0    0
# 4      370491   21   6887183   2203   16500        3    1         0    1
# ...       ...  ...       ...    ...     ...      ...  ...       ...  ...
# 4995   109218   10   3592966   2203   15000        1    4         0    0
# 4996   570708   23   2418140   2202   13100        1    6         0    0
# 4997  2762199   21   4016973   2203       0        1    0         2    0
# 4998  2049372   18    965334   2203  103000        1    4         0    0
# 4999   702559   13   1415973   2203   14800        2    1         0    0
#
#       BLDGSZ  ...  hschpred  hschdriv  htypdwel  hownrent  hadnwst  hadwpst  \
# 0          9  ...         0         0         2         1        0        0
# 1          9  ...         0         0         2         2        0        0
# 2          9  ...         0         0         2         1        0        0
# 3          8  ...         0         0         2         2        0        0
# 4          8  ...         1         0         2         2        0        0
# ...      ...  ...       ...       ...       ...       ...      ...      ...
# 4995       8  ...         0         0         2         2        0        0
# 4996       9  ...         0         0         2         2        0        0
# 4997       0  ...         0         0         2         2        0        0
# 4998       9  ...         0         0         2         2        0        0
# 4999       9  ...         0         0         2         2        0        0
#
#       hadkids  bucketBin  originalPUMA  hmultiunit
# 0           0          3          2202           1
# 1           0          4          2203           1
# 2           1          5          2203           1
# 3           0          7          2203           1
# 4           0          7          2203           1
# ...       ...        ...           ...         ...
# 4995        0          7          2203           1
# 4996        0          6          2202           1
# 4997        0          2          2203           1
# 4998        0          9          2203           1
# 4999        0          3          2203           1
#
# [5000 rows x 47 columns]

# %% [markdown]
# ### Create tazs and taps files

# %%
maz_to_taz_df = land_use[['MAZ', 'TAZ']]
maz_to_taz_df.to_csv(os.path.join(output_data, 'maz_to_taz_df.csv'), index=False)
print("maz_to_taz_df\n%s" % (maz_to_taz_df.head(15), ) )

new_zone_labels = np.unique(land_use.TAZ)
new_zone_indexes = (new_zone_labels-1)
tazs_df = pd.DataFrame({'TAZ': new_zone_labels}, index=new_zone_indexes)
tazs_df.to_csv(os.path.join(output_data, 'tazs.csv'), index=False)
print("tazs_df\n%s" % (tazs_df.head(10), ) )

tap_zone_labels = new_zone_labels + 10000

#create taps file
taz_to_taps_df = pd.DataFrame({"taz": new_zone_labels, "tap":tap_zone_labels})
taz_to_taps_df.to_csv(os.path.join(output_data, 'taz_to_taps.csv'), index=False)
print("taz_to_taps_df\n", taz_to_taps_df.head(10))
# Out:
# maz_to_taz_df
#     MAZ  TAZ
# 0     1    2
# 1     2    2
# 2     3    2
# 3     4    2
# 4     5    5
# 5     6    6
# 6     7    7
# 7     8    8
# 8     9    9
# 9    10   10
# 10   11   11
# 11   12   12
# 12   13   14
# 13   14   14
# 14   15   14
# tazs_df
#     TAZ
# 1     2
# 4     5
# 5     6
# 6     7
# 7     8
# 8     9
# 9    10
# 10   11
# 11   12
# 13   14
# taz_to_taps_df
#     taz    tap
# 0    2  10002
# 1    5  10005
# 2    6  10006
# 3    7  10007
# 4    8  10008
# 5    9  10009
# 6   10  10010
# 7   11  10011
# 8   12  10012
# 9   14  10014

# %% [markdown]
# ### Create taz skims

# %%
# create skims

with \
    omx.open_file(os.path.join(output_data, 'skims.omx')) as skims_file, \
    omx.open_file(os.path.join(output_data, 'taz_skims.omx'), "w") as output_taz_skims_file, \
    omx.open_file(os.path.join(output_data, 'tap_skims.omx'), "w") as output_tap_skims_file:

    for skim_name in skims_file.list_matrices():

        if skim_name not in ['DISTBIKE', 'DISTWALK']:  # omit these since using MAZ to MAZ distances

            mode_code = skim_name[0:3]
            is_tap_mode = (mode_code == "DRV" or mode_code == "WLK")

            if is_tap_mode:
                output_tap_skims_file[skim_name] = skims_file[skim_name][:][new_zone_indexes,:][:,new_zone_indexes]
                print("tap skim:", skim_name, ": shape", str(output_tap_skims_file.shape()))
            else:
                output_taz_skims_file[skim_name] = skims_file[skim_name][:][new_zone_indexes,:][:,new_zone_indexes]
                print("taz skim:", skim_name, ": shape", str(output_taz_skims_file.shape()))

    output_taz_skims_file.create_mapping("taz", new_zone_labels)
    output_tap_skims_file.create_mapping("tap", tap_zone_labels)
# Out:
# taz skim: DIST : shape (20, 20)
# tap skim: DRV_COM_WLK_BOARDS__AM : shape (20, 20)
# tap skim: DRV_COM_WLK_BOARDS__EA : shape (20, 20)
# tap skim: DRV_COM_WLK_BOARDS__EV : shape (20, 20)
# tap skim: DRV_COM_WLK_BOARDS__MD : shape (20, 20)
# tap skim: DRV_COM_WLK_BOARDS__PM : shape (20, 20)
# tap skim: DRV_COM_WLK_DDIST__AM : shape (20, 20)
# tap skim: DRV_COM_WLK_DDIST__EA : shape (20, 20)
# tap skim: DRV_COM_WLK_DDIST__EV : shape (20, 20)
# tap skim: DRV_COM_WLK_DDIST__MD : shape (20, 20)
# tap skim: DRV_COM_WLK_DDIST__PM : shape (20, 20)
# tap skim: DRV_COM_WLK_DTIM__AM : shape (20, 20)
# tap skim: DRV_COM_WLK_DTIM__EA : shape (20, 20)
# tap skim: DRV_COM_WLK_DTIM__EV : shape (20, 20)
# tap skim: DRV_COM_WLK_DTIM__MD : shape (20, 20)
# tap skim: DRV_COM_WLK_DTIM__PM : shape (20, 20)
# tap skim: DRV_COM_WLK_FAR__AM : shape (20, 20)
# tap skim: DRV_COM_WLK_FAR__EA : shape (20, 20)
# tap skim: DRV_COM_WLK_FAR__EV : shape (20, 20)
# tap skim: DRV_COM_WLK_FAR__MD : shape (20, 20)
# tap skim: DRV_COM_WLK_FAR__PM : shape (20, 20)
# tap skim: DRV_COM_WLK_IWAIT__AM : shape (20, 20)
# tap skim: DRV_COM_WLK_IWAIT__EA : shape (20, 20)
# tap skim: DRV_COM_WLK_IWAIT__EV : shape (20, 20)
# tap skim: DRV_COM_WLK_IWAIT__MD : shape (20, 20)
# tap skim: DRV_COM_WLK_IWAIT__PM : shape (20, 20)
# tap skim: DRV_COM_WLK_KEYIVT__AM : shape (20, 20)
# tap skim: DRV_COM_WLK_KEYIVT__EA : shape (20, 20)
# tap skim: DRV_COM_WLK_KEYIVT__EV : shape (20, 20)
# tap skim: DRV_COM_WLK_KEYIVT__MD : shape (20, 20)
# tap skim: DRV_COM_WLK_KEYIVT__PM : shape (20, 20)
# tap skim: DRV_COM_WLK_TOTIVT__AM : shape (20, 20)
# tap skim: DRV_COM_WLK_TOTIVT__EA : shape (20, 20)
# tap skim: DRV_COM_WLK_TOTIVT__EV : shape (20, 20)
# tap skim: DRV_COM_WLK_TOTIVT__MD : shape (20, 20)
# tap skim: DRV_COM_WLK_TOTIVT__PM : shape (20, 20)
# tap skim: DRV_COM_WLK_WAIT__AM : shape (20, 20)
# tap skim: DRV_COM_WLK_WAIT__EA : shape (20, 20)
# tap skim: DRV_COM_WLK_WAIT__EV : shape (20, 20)
# tap skim: DRV_COM_WLK_WAIT__MD : shape (20, 20)
# tap skim: DRV_COM_WLK_WAIT__PM : shape (20, 20)
# tap skim: DRV_COM_WLK_WAUX__AM : shape (20, 20)
# tap skim: DRV_COM_WLK_WAUX__EA : shape (20, 20)
# tap skim: DRV_COM_WLK_WAUX__EV : shape (20, 20)
# tap skim: DRV_COM_WLK_WAUX__MD : shape (20, 20)
# tap skim: DRV_COM_WLK_WAUX__PM : shape (20, 20)
# tap skim: DRV_COM_WLK_XWAIT__AM : shape (20, 20)
# tap skim: DRV_COM_WLK_XWAIT__EA : shape (20, 20)
# tap skim: DRV_COM_WLK_XWAIT__EV : shape (20, 20)
# tap skim: DRV_COM_WLK_XWAIT__MD : shape (20, 20)
# tap skim: DRV_COM_WLK_XWAIT__PM : shape (20, 20)
# tap skim: DRV_EXP_WLK_BOARDS__AM : shape (20, 20)
# tap skim: DRV_EXP_WLK_BOARDS__EA : shape (20, 20)
# tap skim: DRV_EXP_WLK_BOARDS__EV : shape (20, 20)
# tap skim: DRV_EXP_WLK_BOARDS__MD : shape (20, 20)
# tap skim: DRV_EXP_WLK_BOARDS__PM : shape (20, 20)
# tap skim: DRV_EXP_WLK_DDIST__AM : shape (20, 20)
# tap skim: DRV_EXP_WLK_DDIST__EA : shape (20, 20)
# tap skim: DRV_EXP_WLK_DDIST__EV : shape (20, 20)
# tap skim: DRV_EXP_WLK_DDIST__MD : shape (20, 20)
# tap skim: DRV_EXP_WLK_DDIST__PM : shape (20, 20)
# tap skim: DRV_EXP_WLK_DTIM__AM : shape (20, 20)
# tap skim: DRV_EXP_WLK_DTIM__EA : shape (20, 20)
# tap skim: DRV_EXP_WLK_DTIM__EV : shape (20, 20)
# tap skim: DRV_EXP_WLK_DTIM__MD : shape (20, 20)
# tap skim: DRV_EXP_WLK_DTIM__PM : shape (20, 20)
# tap skim: DRV_EXP_WLK_FAR__AM : shape (20, 20)
# tap skim: DRV_EXP_WLK_FAR__EA : shape (20, 20)
# tap skim: DRV_EXP_WLK_FAR__EV : shape (20, 20)
# tap skim: DRV_EXP_WLK_FAR__MD : shape (20, 20)
# tap skim: DRV_EXP_WLK_FAR__PM : shape (20, 20)
# tap skim: DRV_EXP_WLK_IWAIT__AM : shape (20, 20)
# tap skim: DRV_EXP_WLK_IWAIT__EA : shape (20, 20)
# tap skim: DRV_EXP_WLK_IWAIT__EV : shape (20, 20)
# tap skim: DRV_EXP_WLK_IWAIT__MD : shape (20, 20)
# tap skim: DRV_EXP_WLK_IWAIT__PM : shape (20, 20)
# tap skim: DRV_EXP_WLK_KEYIVT__AM : shape (20, 20)
# tap skim: DRV_EXP_WLK_KEYIVT__EA : shape (20, 20)
# tap skim: DRV_EXP_WLK_KEYIVT__EV : shape (20, 20)
# tap skim: DRV_EXP_WLK_KEYIVT__MD : shape (20, 20)
# tap skim: DRV_EXP_WLK_KEYIVT__PM : shape (20, 20)
# tap skim: DRV_EXP_WLK_TOTIVT__AM : shape (20, 20)
# tap skim: DRV_EXP_WLK_TOTIVT__EA : shape (20, 20)
# tap skim: DRV_EXP_WLK_TOTIVT__EV : shape (20, 20)
# tap skim: DRV_EXP_WLK_TOTIVT__MD : shape (20, 20)
# tap skim: DRV_EXP_WLK_TOTIVT__PM : shape (20, 20)
# tap skim: DRV_EXP_WLK_WAIT__AM : shape (20, 20)
# tap skim: DRV_EXP_WLK_WAIT__EA : shape (20, 20)
# tap skim: DRV_EXP_WLK_WAIT__EV : shape (20, 20)
# tap skim: DRV_EXP_WLK_WAIT__MD : shape (20, 20)
# tap skim: DRV_EXP_WLK_WAIT__PM : shape (20, 20)
# tap skim: DRV_EXP_WLK_WAUX__AM : shape (20, 20)
# tap skim: DRV_EXP_WLK_WAUX__EA : shape (20, 20)
# tap skim: DRV_EXP_WLK_WAUX__EV : shape (20, 20)
# tap skim: DRV_EXP_WLK_WAUX__MD : shape (20, 20)
# tap skim: DRV_EXP_WLK_WAUX__PM : shape (20, 20)
# tap skim: DRV_EXP_WLK_XWAIT__AM : shape (20, 20)
# tap skim: DRV_EXP_WLK_XWAIT__EA : shape (20, 20)
# tap skim: DRV_EXP_WLK_XWAIT__EV : shape (20, 20)
# tap skim: DRV_EXP_WLK_XWAIT__MD : shape (20, 20)
# tap skim: DRV_EXP_WLK_XWAIT__PM : shape (20, 20)
# tap skim: DRV_HVY_WLK_BOARDS__AM : shape (20, 20)
# tap skim: DRV_HVY_WLK_BOARDS__EA : shape (20, 20)
# tap skim: DRV_HVY_WLK_BOARDS__EV : shape (20, 20)
# tap skim: DRV_HVY_WLK_BOARDS__MD : shape (20, 20)
# tap skim: DRV_HVY_WLK_BOARDS__PM : shape (20, 20)
# tap skim: DRV_HVY_WLK_DDIST__AM : shape (20, 20)
# tap skim: DRV_HVY_WLK_DDIST__EA : shape (20, 20)
# tap skim: DRV_HVY_WLK_DDIST__EV : shape (20, 20)
# tap skim: DRV_HVY_WLK_DDIST__MD : shape (20, 20)
# tap skim: DRV_HVY_WLK_DDIST__PM : shape (20, 20)
# tap skim: DRV_HVY_WLK_DTIM__AM : shape (20, 20)
# tap skim: DRV_HVY_WLK_DTIM__EA : shape (20, 20)
# tap skim: DRV_HVY_WLK_DTIM__EV : shape (20, 20)
# tap skim: DRV_HVY_WLK_DTIM__MD : shape (20, 20)
# tap skim: DRV_HVY_WLK_DTIM__PM : shape (20, 20)
# tap skim: DRV_HVY_WLK_FAR__AM : shape (20, 20)
# tap skim: DRV_HVY_WLK_FAR__EA : shape (20, 20)
# tap skim: DRV_HVY_WLK_FAR__EV : shape (20, 20)
# tap skim: DRV_HVY_WLK_FAR__MD : shape (20, 20)
# tap skim: DRV_HVY_WLK_FAR__PM : shape (20, 20)
# tap skim: DRV_HVY_WLK_IWAIT__AM : shape (20, 20)
# tap skim: DRV_HVY_WLK_IWAIT__EA : shape (20, 20)
# tap skim: DRV_HVY_WLK_IWAIT__EV : shape (20, 20)
# tap skim: DRV_HVY_WLK_IWAIT__MD : shape (20, 20)
# tap skim: DRV_HVY_WLK_IWAIT__PM : shape (20, 20)
# tap skim: DRV_HVY_WLK_KEYIVT__AM : shape (20, 20)
# tap skim: DRV_HVY_WLK_KEYIVT__EA : shape (20, 20)
# tap skim: DRV_HVY_WLK_KEYIVT__EV : shape (20, 20)
# tap skim: DRV_HVY_WLK_KEYIVT__MD : shape (20, 20)
# tap skim: DRV_HVY_WLK_KEYIVT__PM : shape (20, 20)
# tap skim: DRV_HVY_WLK_TOTIVT__AM : shape (20, 20)
# tap skim: DRV_HVY_WLK_TOTIVT__EA : shape (20, 20)
# tap skim: DRV_HVY_WLK_TOTIVT__EV : shape (20, 20)
# tap skim: DRV_HVY_WLK_TOTIVT__MD : shape (20, 20)
# tap skim: DRV_HVY_WLK_TOTIVT__PM : shape (20, 20)
# tap skim: DRV_HVY_WLK_WAIT__AM : shape (20, 20)
# tap skim: DRV_HVY_WLK_WAIT__EA : shape (20, 20)
# tap skim: DRV_HVY_WLK_WAIT__EV : shape (20, 20)
# tap skim: DRV_HVY_WLK_WAIT__MD : shape (20, 20)
# tap skim: DRV_HVY_WLK_WAIT__PM : shape (20, 20)
# tap skim: DRV_HVY_WLK_WAUX__AM : shape (20, 20)
# tap skim: DRV_HVY_WLK_WAUX__EA : shape (20, 20)
# tap skim: DRV_HVY_WLK_WAUX__EV : shape (20, 20)
# tap skim: DRV_HVY_WLK_WAUX__MD : shape (20, 20)
# tap skim: DRV_HVY_WLK_WAUX__PM : shape (20, 20)
# tap skim: DRV_HVY_WLK_XWAIT__AM : shape (20, 20)
# tap skim: DRV_HVY_WLK_XWAIT__EA : shape (20, 20)
# tap skim: DRV_HVY_WLK_XWAIT__EV : shape (20, 20)
# tap skim: DRV_HVY_WLK_XWAIT__MD : shape (20, 20)
# tap skim: DRV_HVY_WLK_XWAIT__PM : shape (20, 20)
# tap skim: DRV_LOC_WLK_BOARDS__AM : shape (20, 20)
# tap skim: DRV_LOC_WLK_BOARDS__EA : shape (20, 20)
# tap skim: DRV_LOC_WLK_BOARDS__EV : shape (20, 20)
# tap skim: DRV_LOC_WLK_BOARDS__MD : shape (20, 20)
# tap skim: DRV_LOC_WLK_BOARDS__PM : shape (20, 20)
# tap skim: DRV_LOC_WLK_DDIST__AM : shape (20, 20)
# tap skim: DRV_LOC_WLK_DDIST__EA : shape (20, 20)
# tap skim: DRV_LOC_WLK_DDIST__EV : shape (20, 20)
# tap skim: DRV_LOC_WLK_DDIST__MD : shape (20, 20)
# tap skim: DRV_LOC_WLK_DDIST__PM : shape (20, 20)
# tap skim: DRV_LOC_WLK_DTIM__AM : shape (20, 20)
# tap skim: DRV_LOC_WLK_DTIM__EA : shape (20, 20)
# tap skim: DRV_LOC_WLK_DTIM__EV : shape (20, 20)
# tap skim: DRV_LOC_WLK_DTIM__MD : shape (20, 20)
# tap skim: DRV_LOC_WLK_DTIM__PM : shape (20, 20)
# tap skim: DRV_LOC_WLK_FAR__AM : shape (20, 20)
# tap skim: DRV_LOC_WLK_FAR__EA : shape (20, 20)
# tap skim: DRV_LOC_WLK_FAR__EV : shape (20, 20)
# tap skim: DRV_LOC_WLK_FAR__MD : shape (20, 20)
# tap skim: DRV_LOC_WLK_FAR__PM : shape (20, 20)
# tap skim: DRV_LOC_WLK_IWAIT__AM : shape (20, 20)
# tap skim: DRV_LOC_WLK_IWAIT__EA : shape (20, 20)
# tap skim: DRV_LOC_WLK_IWAIT__EV : shape (20, 20)
# tap skim: DRV_LOC_WLK_IWAIT__MD : shape (20, 20)
# tap skim: DRV_LOC_WLK_IWAIT__PM : shape (20, 20)
# tap skim: DRV_LOC_WLK_TOTIVT__AM : shape (20, 20)
# tap skim: DRV_LOC_WLK_TOTIVT__EA : shape (20, 20)
# tap skim: DRV_LOC_WLK_TOTIVT__EV : shape (20, 20)
# tap skim: DRV_LOC_WLK_TOTIVT__MD : shape (20, 20)
# tap skim: DRV_LOC_WLK_TOTIVT__PM : shape (20, 20)
# tap skim: DRV_LOC_WLK_WAIT__AM : shape (20, 20)
# tap skim: DRV_LOC_WLK_WAIT__EA : shape (20, 20)
# tap skim: DRV_LOC_WLK_WAIT__EV : shape (20, 20)
# tap skim: DRV_LOC_WLK_WAIT__MD : shape (20, 20)
# tap skim: DRV_LOC_WLK_WAIT__PM : shape (20, 20)
# tap skim: DRV_LOC_WLK_WAUX__AM : shape (20, 20)
# tap skim: DRV_LOC_WLK_WAUX__EA : shape (20, 20)
# tap skim: DRV_LOC_WLK_WAUX__EV : shape (20, 20)
# tap skim: DRV_LOC_WLK_WAUX__MD : shape (20, 20)
# tap skim: DRV_LOC_WLK_WAUX__PM : shape (20, 20)
# tap skim: DRV_LOC_WLK_XWAIT__AM : shape (20, 20)
# tap skim: DRV_LOC_WLK_XWAIT__EA : shape (20, 20)
# tap skim: DRV_LOC_WLK_XWAIT__EV : shape (20, 20)
# tap skim: DRV_LOC_WLK_XWAIT__MD : shape (20, 20)
# tap skim: DRV_LOC_WLK_XWAIT__PM : shape (20, 20)
# tap skim: DRV_LRF_WLK_BOARDS__AM : shape (20, 20)
# tap skim: DRV_LRF_WLK_BOARDS__EA : shape (20, 20)
# tap skim: DRV_LRF_WLK_BOARDS__EV : shape (20, 20)
# tap skim: DRV_LRF_WLK_BOARDS__MD : shape (20, 20)
# tap skim: DRV_LRF_WLK_BOARDS__PM : shape (20, 20)
# tap skim: DRV_LRF_WLK_DDIST__AM : shape (20, 20)
# tap skim: DRV_LRF_WLK_DDIST__EA : shape (20, 20)
# tap skim: DRV_LRF_WLK_DDIST__EV : shape (20, 20)
# tap skim: DRV_LRF_WLK_DDIST__MD : shape (20, 20)
# tap skim: DRV_LRF_WLK_DDIST__PM : shape (20, 20)
# tap skim: DRV_LRF_WLK_DTIM__AM : shape (20, 20)
# tap skim: DRV_LRF_WLK_DTIM__EA : shape (20, 20)
# tap skim: DRV_LRF_WLK_DTIM__EV : shape (20, 20)
# tap skim: DRV_LRF_WLK_DTIM__MD : shape (20, 20)
# tap skim: DRV_LRF_WLK_DTIM__PM : shape (20, 20)
# tap skim: DRV_LRF_WLK_FAR__AM : shape (20, 20)
# tap skim: DRV_LRF_WLK_FAR__EA : shape (20, 20)
# tap skim: DRV_LRF_WLK_FAR__EV : shape (20, 20)
# tap skim: DRV_LRF_WLK_FAR__MD : shape (20, 20)
# tap skim: DRV_LRF_WLK_FAR__PM : shape (20, 20)
# tap skim: DRV_LRF_WLK_FERRYIVT__AM : shape (20, 20)
# tap skim: DRV_LRF_WLK_FERRYIVT__EA : shape (20, 20)
# tap skim: DRV_LRF_WLK_FERRYIVT__EV : shape (20, 20)
# tap skim: DRV_LRF_WLK_FERRYIVT__MD : shape (20, 20)
# tap skim: DRV_LRF_WLK_FERRYIVT__PM : shape (20, 20)
# tap skim: DRV_LRF_WLK_IWAIT__AM : shape (20, 20)
# tap skim: DRV_LRF_WLK_IWAIT__EA : shape (20, 20)
# tap skim: DRV_LRF_WLK_IWAIT__EV : shape (20, 20)
# tap skim: DRV_LRF_WLK_IWAIT__MD : shape (20, 20)
# tap skim: DRV_LRF_WLK_IWAIT__PM : shape (20, 20)
# tap skim: DRV_LRF_WLK_KEYIVT__AM : shape (20, 20)
# tap skim: DRV_LRF_WLK_KEYIVT__EA : shape (20, 20)
# tap skim: DRV_LRF_WLK_KEYIVT__EV : shape (20, 20)
# tap skim: DRV_LRF_WLK_KEYIVT__MD : shape (20, 20)
# tap skim: DRV_LRF_WLK_KEYIVT__PM : shape (20, 20)
# tap skim: DRV_LRF_WLK_TOTIVT__AM : shape (20, 20)
# tap skim: DRV_LRF_WLK_TOTIVT__EA : shape (20, 20)
# tap skim: DRV_LRF_WLK_TOTIVT__EV : shape (20, 20)
# tap skim: DRV_LRF_WLK_TOTIVT__MD : shape (20, 20)
# tap skim: DRV_LRF_WLK_TOTIVT__PM : shape (20, 20)
# tap skim: DRV_LRF_WLK_WAIT__AM : shape (20, 20)
# tap skim: DRV_LRF_WLK_WAIT__EA : shape (20, 20)
# tap skim: DRV_LRF_WLK_WAIT__EV : shape (20, 20)
# tap skim: DRV_LRF_WLK_WAIT__MD : shape (20, 20)
# tap skim: DRV_LRF_WLK_WAIT__PM : shape (20, 20)
# tap skim: DRV_LRF_WLK_WAUX__AM : shape (20, 20)
# tap skim: DRV_LRF_WLK_WAUX__EA : shape (20, 20)
# tap skim: DRV_LRF_WLK_WAUX__EV : shape (20, 20)
# tap skim: DRV_LRF_WLK_WAUX__MD : shape (20, 20)
# tap skim: DRV_LRF_WLK_WAUX__PM : shape (20, 20)
# tap skim: DRV_LRF_WLK_XWAIT__AM : shape (20, 20)
# tap skim: DRV_LRF_WLK_XWAIT__EA : shape (20, 20)
# tap skim: DRV_LRF_WLK_XWAIT__EV : shape (20, 20)
# tap skim: DRV_LRF_WLK_XWAIT__MD : shape (20, 20)
# tap skim: DRV_LRF_WLK_XWAIT__PM : shape (20, 20)
# taz skim: HOV2TOLL_BTOLL__AM : shape (20, 20)
# taz skim: HOV2TOLL_BTOLL__EA : shape (20, 20)
# taz skim: HOV2TOLL_BTOLL__EV : shape (20, 20)
# taz skim: HOV2TOLL_BTOLL__MD : shape (20, 20)
# taz skim: HOV2TOLL_BTOLL__PM : shape (20, 20)
# taz skim: HOV2TOLL_DIST__AM : shape (20, 20)
# taz skim: HOV2TOLL_DIST__EA : shape (20, 20)
# taz skim: HOV2TOLL_DIST__EV : shape (20, 20)
# taz skim: HOV2TOLL_DIST__MD : shape (20, 20)
# taz skim: HOV2TOLL_DIST__PM : shape (20, 20)
# taz skim: HOV2TOLL_TIME__AM : shape (20, 20)
# taz skim: HOV2TOLL_TIME__EA : shape (20, 20)
# taz skim: HOV2TOLL_TIME__EV : shape (20, 20)
# taz skim: HOV2TOLL_TIME__MD : shape (20, 20)
# taz skim: HOV2TOLL_TIME__PM : shape (20, 20)
# taz skim: HOV2TOLL_VTOLL__AM : shape (20, 20)
# taz skim: HOV2TOLL_VTOLL__EA : shape (20, 20)
# taz skim: HOV2TOLL_VTOLL__EV : shape (20, 20)
# taz skim: HOV2TOLL_VTOLL__MD : shape (20, 20)
# taz skim: HOV2TOLL_VTOLL__PM : shape (20, 20)
# taz skim: HOV2_BTOLL__AM : shape (20, 20)
# taz skim: HOV2_BTOLL__EA : shape (20, 20)
# taz skim: HOV2_BTOLL__EV : shape (20, 20)
# taz skim: HOV2_BTOLL__MD : shape (20, 20)
# taz skim: HOV2_BTOLL__PM : shape (20, 20)
# taz skim: HOV2_DIST__AM : shape (20, 20)
# taz skim: HOV2_DIST__EA : shape (20, 20)
# taz skim: HOV2_DIST__EV : shape (20, 20)
# taz skim: HOV2_DIST__MD : shape (20, 20)
# taz skim: HOV2_DIST__PM : shape (20, 20)
# taz skim: HOV2_TIME__AM : shape (20, 20)
# taz skim: HOV2_TIME__EA : shape (20, 20)
# taz skim: HOV2_TIME__EV : shape (20, 20)
# taz skim: HOV2_TIME__MD : shape (20, 20)
# taz skim: HOV2_TIME__PM : shape (20, 20)
# taz skim: HOV3TOLL_BTOLL__AM : shape (20, 20)
# taz skim: HOV3TOLL_BTOLL__EA : shape (20, 20)
# taz skim: HOV3TOLL_BTOLL__EV : shape (20, 20)
# taz skim: HOV3TOLL_BTOLL__MD : shape (20, 20)
# taz skim: HOV3TOLL_BTOLL__PM : shape (20, 20)
# taz skim: HOV3TOLL_DIST__AM : shape (20, 20)
# taz skim: HOV3TOLL_DIST__EA : shape (20, 20)
# taz skim: HOV3TOLL_DIST__EV : shape (20, 20)
# taz skim: HOV3TOLL_DIST__MD : shape (20, 20)
# taz skim: HOV3TOLL_DIST__PM : shape (20, 20)
# taz skim: HOV3TOLL_TIME__AM : shape (20, 20)
# taz skim: HOV3TOLL_TIME__EA : shape (20, 20)
# taz skim: HOV3TOLL_TIME__EV : shape (20, 20)
# taz skim: HOV3TOLL_TIME__MD : shape (20, 20)
# taz skim: HOV3TOLL_TIME__PM : shape (20, 20)
# taz skim: HOV3TOLL_VTOLL__AM : shape (20, 20)
# taz skim: HOV3TOLL_VTOLL__EA : shape (20, 20)
# taz skim: HOV3TOLL_VTOLL__EV : shape (20, 20)
# taz skim: HOV3TOLL_VTOLL__MD : shape (20, 20)
# taz skim: HOV3TOLL_VTOLL__PM : shape (20, 20)
# taz skim: HOV3_BTOLL__AM : shape (20, 20)
# taz skim: HOV3_BTOLL__EA : shape (20, 20)
# taz skim: HOV3_BTOLL__EV : shape (20, 20)
# taz skim: HOV3_BTOLL__MD : shape (20, 20)
# taz skim: HOV3_BTOLL__PM : shape (20, 20)
# taz skim: HOV3_DIST__AM : shape (20, 20)
# taz skim: HOV3_DIST__EA : shape (20, 20)
# taz skim: HOV3_DIST__EV : shape (20, 20)
# taz skim: HOV3_DIST__MD : shape (20, 20)
# taz skim: HOV3_DIST__PM : shape (20, 20)
# taz skim: HOV3_TIME__AM : shape (20, 20)
# taz skim: HOV3_TIME__EA : shape (20, 20)
# taz skim: HOV3_TIME__EV : shape (20, 20)
# taz skim: HOV3_TIME__MD : shape (20, 20)
# taz skim: HOV3_TIME__PM : shape (20, 20)
# taz skim: SOVTOLL_BTOLL__AM : shape (20, 20)
# taz skim: SOVTOLL_BTOLL__EA : shape (20, 20)
# taz skim: SOVTOLL_BTOLL__EV : shape (20, 20)
# taz skim: SOVTOLL_BTOLL__MD : shape (20, 20)
# taz skim: SOVTOLL_BTOLL__PM : shape (20, 20)
# taz skim: SOVTOLL_DIST__AM : shape (20, 20)
# taz skim: SOVTOLL_DIST__EA : shape (20, 20)
# taz skim: SOVTOLL_DIST__EV : shape (20, 20)
# taz skim: SOVTOLL_DIST__MD : shape (20, 20)
# taz skim: SOVTOLL_DIST__PM : shape (20, 20)
# taz skim: SOVTOLL_TIME__AM : shape (20, 20)
# taz skim: SOVTOLL_TIME__EA : shape (20, 20)
# taz skim: SOVTOLL_TIME__EV : shape (20, 20)
# taz skim: SOVTOLL_TIME__MD : shape (20, 20)
# taz skim: SOVTOLL_TIME__PM : shape (20, 20)
# taz skim: SOVTOLL_VTOLL__AM : shape (20, 20)
# taz skim: SOVTOLL_VTOLL__EA : shape (20, 20)
# taz skim: SOVTOLL_VTOLL__EV : shape (20, 20)
# taz skim: SOVTOLL_VTOLL__MD : shape (20, 20)
# taz skim: SOVTOLL_VTOLL__PM : shape (20, 20)
# taz skim: SOV_BTOLL__AM : shape (20, 20)
# taz skim: SOV_BTOLL__EA : shape (20, 20)
# taz skim: SOV_BTOLL__EV : shape (20, 20)
# taz skim: SOV_BTOLL__MD : shape (20, 20)
# taz skim: SOV_BTOLL__PM : shape (20, 20)
# taz skim: SOV_DIST__AM : shape (20, 20)
# taz skim: SOV_DIST__EA : shape (20, 20)
# taz skim: SOV_DIST__EV : shape (20, 20)
# taz skim: SOV_DIST__MD : shape (20, 20)
# taz skim: SOV_DIST__PM : shape (20, 20)
# taz skim: SOV_TIME__AM : shape (20, 20)
# taz skim: SOV_TIME__EA : shape (20, 20)
# taz skim: SOV_TIME__EV : shape (20, 20)
# taz skim: SOV_TIME__MD : shape (20, 20)
# taz skim: SOV_TIME__PM : shape (20, 20)
# tap skim: WLK_COM_DRV_BOARDS__AM : shape (20, 20)
# tap skim: WLK_COM_DRV_BOARDS__EA : shape (20, 20)
# tap skim: WLK_COM_DRV_BOARDS__EV : shape (20, 20)
# tap skim: WLK_COM_DRV_BOARDS__MD : shape (20, 20)
# tap skim: WLK_COM_DRV_BOARDS__PM : shape (20, 20)
# tap skim: WLK_COM_DRV_DDIST__AM : shape (20, 20)
# tap skim: WLK_COM_DRV_DDIST__EA : shape (20, 20)
# tap skim: WLK_COM_DRV_DDIST__EV : shape (20, 20)
# tap skim: WLK_COM_DRV_DDIST__MD : shape (20, 20)
# tap skim: WLK_COM_DRV_DDIST__PM : shape (20, 20)
# tap skim: WLK_COM_DRV_DTIM__AM : shape (20, 20)
# tap skim: WLK_COM_DRV_DTIM__EA : shape (20, 20)
# tap skim: WLK_COM_DRV_DTIM__EV : shape (20, 20)
# tap skim: WLK_COM_DRV_DTIM__MD : shape (20, 20)
# tap skim: WLK_COM_DRV_DTIM__PM : shape (20, 20)
# tap skim: WLK_COM_DRV_FAR__AM : shape (20, 20)
# tap skim: WLK_COM_DRV_FAR__EA : shape (20, 20)
# tap skim: WLK_COM_DRV_FAR__EV : shape (20, 20)
# tap skim: WLK_COM_DRV_FAR__MD : shape (20, 20)
# tap skim: WLK_COM_DRV_FAR__PM : shape (20, 20)
# tap skim: WLK_COM_DRV_IWAIT__AM : shape (20, 20)
# tap skim: WLK_COM_DRV_IWAIT__EA : shape (20, 20)
# tap skim: WLK_COM_DRV_IWAIT__EV : shape (20, 20)
# tap skim: WLK_COM_DRV_IWAIT__MD : shape (20, 20)
# tap skim: WLK_COM_DRV_IWAIT__PM : shape (20, 20)
# tap skim: WLK_COM_DRV_KEYIVT__AM : shape (20, 20)
# tap skim: WLK_COM_DRV_KEYIVT__EA : shape (20, 20)
# tap skim: WLK_COM_DRV_KEYIVT__EV : shape (20, 20)
# tap skim: WLK_COM_DRV_KEYIVT__MD : shape (20, 20)
# tap skim: WLK_COM_DRV_KEYIVT__PM : shape (20, 20)
# tap skim: WLK_COM_DRV_TOTIVT__AM : shape (20, 20)
# tap skim: WLK_COM_DRV_TOTIVT__EA : shape (20, 20)
# tap skim: WLK_COM_DRV_TOTIVT__EV : shape (20, 20)
# tap skim: WLK_COM_DRV_TOTIVT__MD : shape (20, 20)
# tap skim: WLK_COM_DRV_TOTIVT__PM : shape (20, 20)
# tap skim: WLK_COM_DRV_WAIT__AM : shape (20, 20)
# tap skim: WLK_COM_DRV_WAIT__EA : shape (20, 20)
# tap skim: WLK_COM_DRV_WAIT__EV : shape (20, 20)
# tap skim: WLK_COM_DRV_WAIT__MD : shape (20, 20)
# tap skim: WLK_COM_DRV_WAIT__PM : shape (20, 20)
# tap skim: WLK_COM_DRV_WAUX__AM : shape (20, 20)
# tap skim: WLK_COM_DRV_WAUX__EA : shape (20, 20)
# tap skim: WLK_COM_DRV_WAUX__EV : shape (20, 20)
# tap skim: WLK_COM_DRV_WAUX__MD : shape (20, 20)
# tap skim: WLK_COM_DRV_WAUX__PM : shape (20, 20)
# tap skim: WLK_COM_DRV_XWAIT__AM : shape (20, 20)
# tap skim: WLK_COM_DRV_XWAIT__EA : shape (20, 20)
# tap skim: WLK_COM_DRV_XWAIT__EV : shape (20, 20)
# tap skim: WLK_COM_DRV_XWAIT__MD : shape (20, 20)
# tap skim: WLK_COM_DRV_XWAIT__PM : shape (20, 20)
# tap skim: WLK_COM_WLK_BOARDS__AM : shape (20, 20)
# tap skim: WLK_COM_WLK_BOARDS__EA : shape (20, 20)
# tap skim: WLK_COM_WLK_BOARDS__EV : shape (20, 20)
# tap skim: WLK_COM_WLK_BOARDS__MD : shape (20, 20)
# tap skim: WLK_COM_WLK_BOARDS__PM : shape (20, 20)
# tap skim: WLK_COM_WLK_FAR__AM : shape (20, 20)
# tap skim: WLK_COM_WLK_FAR__EA : shape (20, 20)
# tap skim: WLK_COM_WLK_FAR__EV : shape (20, 20)
# tap skim: WLK_COM_WLK_FAR__MD : shape (20, 20)
# tap skim: WLK_COM_WLK_FAR__PM : shape (20, 20)
# tap skim: WLK_COM_WLK_IWAIT__AM : shape (20, 20)
# tap skim: WLK_COM_WLK_IWAIT__EA : shape (20, 20)
# tap skim: WLK_COM_WLK_IWAIT__EV : shape (20, 20)
# tap skim: WLK_COM_WLK_IWAIT__MD : shape (20, 20)
# tap skim: WLK_COM_WLK_IWAIT__PM : shape (20, 20)
# tap skim: WLK_COM_WLK_KEYIVT__AM : shape (20, 20)
# tap skim: WLK_COM_WLK_KEYIVT__EA : shape (20, 20)
# tap skim: WLK_COM_WLK_KEYIVT__EV : shape (20, 20)
# tap skim: WLK_COM_WLK_KEYIVT__MD : shape (20, 20)
# tap skim: WLK_COM_WLK_KEYIVT__PM : shape (20, 20)
# tap skim: WLK_COM_WLK_TOTIVT__AM : shape (20, 20)
# tap skim: WLK_COM_WLK_TOTIVT__EA : shape (20, 20)
# tap skim: WLK_COM_WLK_TOTIVT__EV : shape (20, 20)
# tap skim: WLK_COM_WLK_TOTIVT__MD : shape (20, 20)
# tap skim: WLK_COM_WLK_TOTIVT__PM : shape (20, 20)
# tap skim: WLK_COM_WLK_WAIT__AM : shape (20, 20)
# tap skim: WLK_COM_WLK_WAIT__EA : shape (20, 20)
# tap skim: WLK_COM_WLK_WAIT__EV : shape (20, 20)
# tap skim: WLK_COM_WLK_WAIT__MD : shape (20, 20)
# tap skim: WLK_COM_WLK_WAIT__PM : shape (20, 20)
# tap skim: WLK_COM_WLK_WAUX__AM : shape (20, 20)
# tap skim: WLK_COM_WLK_WAUX__EA : shape (20, 20)
# tap skim: WLK_COM_WLK_WAUX__EV : shape (20, 20)
# tap skim: WLK_COM_WLK_WAUX__MD : shape (20, 20)
# tap skim: WLK_COM_WLK_WAUX__PM : shape (20, 20)
# tap skim: WLK_COM_WLK_XWAIT__AM : shape (20, 20)
# tap skim: WLK_COM_WLK_XWAIT__EA : shape (20, 20)
# tap skim: WLK_COM_WLK_XWAIT__EV : shape (20, 20)
# tap skim: WLK_COM_WLK_XWAIT__MD : shape (20, 20)
# tap skim: WLK_COM_WLK_XWAIT__PM : shape (20, 20)
# tap skim: WLK_EXP_DRV_BOARDS__AM : shape (20, 20)
# tap skim: WLK_EXP_DRV_BOARDS__EA : shape (20, 20)
# tap skim: WLK_EXP_DRV_BOARDS__EV : shape (20, 20)
# tap skim: WLK_EXP_DRV_BOARDS__MD : shape (20, 20)
# tap skim: WLK_EXP_DRV_BOARDS__PM : shape (20, 20)
# tap skim: WLK_EXP_DRV_DDIST__AM : shape (20, 20)
# tap skim: WLK_EXP_DRV_DDIST__EA : shape (20, 20)
# tap skim: WLK_EXP_DRV_DDIST__EV : shape (20, 20)
# tap skim: WLK_EXP_DRV_DDIST__MD : shape (20, 20)
# tap skim: WLK_EXP_DRV_DDIST__PM : shape (20, 20)
# tap skim: WLK_EXP_DRV_DTIM__AM : shape (20, 20)
# tap skim: WLK_EXP_DRV_DTIM__EA : shape (20, 20)
# tap skim: WLK_EXP_DRV_DTIM__EV : shape (20, 20)
# tap skim: WLK_EXP_DRV_DTIM__MD : shape (20, 20)
# tap skim: WLK_EXP_DRV_DTIM__PM : shape (20, 20)
# tap skim: WLK_EXP_DRV_FAR__AM : shape (20, 20)
# tap skim: WLK_EXP_DRV_FAR__EA : shape (20, 20)
# tap skim: WLK_EXP_DRV_FAR__EV : shape (20, 20)
# tap skim: WLK_EXP_DRV_FAR__MD : shape (20, 20)
# tap skim: WLK_EXP_DRV_FAR__PM : shape (20, 20)
# tap skim: WLK_EXP_DRV_IWAIT__AM : shape (20, 20)
# tap skim: WLK_EXP_DRV_IWAIT__EA : shape (20, 20)
# tap skim: WLK_EXP_DRV_IWAIT__EV : shape (20, 20)
# tap skim: WLK_EXP_DRV_IWAIT__MD : shape (20, 20)
# tap skim: WLK_EXP_DRV_IWAIT__PM : shape (20, 20)
# tap skim: WLK_EXP_DRV_KEYIVT__AM : shape (20, 20)
# tap skim: WLK_EXP_DRV_KEYIVT__EA : shape (20, 20)
# tap skim: WLK_EXP_DRV_KEYIVT__EV : shape (20, 20)
# tap skim: WLK_EXP_DRV_KEYIVT__MD : shape (20, 20)
# tap skim: WLK_EXP_DRV_KEYIVT__PM : shape (20, 20)
# tap skim: WLK_EXP_DRV_TOTIVT__AM : shape (20, 20)
# tap skim: WLK_EXP_DRV_TOTIVT__EA : shape (20, 20)
# tap skim: WLK_EXP_DRV_TOTIVT__EV : shape (20, 20)
# tap skim: WLK_EXP_DRV_TOTIVT__MD : shape (20, 20)
# tap skim: WLK_EXP_DRV_TOTIVT__PM : shape (20, 20)
# tap skim: WLK_EXP_DRV_WAIT__AM : shape (20, 20)
# tap skim: WLK_EXP_DRV_WAIT__EA : shape (20, 20)
# tap skim: WLK_EXP_DRV_WAIT__EV : shape (20, 20)
# tap skim: WLK_EXP_DRV_WAIT__MD : shape (20, 20)
# tap skim: WLK_EXP_DRV_WAIT__PM : shape (20, 20)
# tap skim: WLK_EXP_DRV_WAUX__AM : shape (20, 20)
# tap skim: WLK_EXP_DRV_WAUX__EA : shape (20, 20)
# tap skim: WLK_EXP_DRV_WAUX__EV : shape (20, 20)
# tap skim: WLK_EXP_DRV_WAUX__MD : shape (20, 20)
# tap skim: WLK_EXP_DRV_WAUX__PM : shape (20, 20)
# tap skim: WLK_EXP_DRV_XWAIT__AM : shape (20, 20)
# tap skim: WLK_EXP_DRV_XWAIT__EA : shape (20, 20)
# tap skim: WLK_EXP_DRV_XWAIT__EV : shape (20, 20)
# tap skim: WLK_EXP_DRV_XWAIT__MD : shape (20, 20)
# tap skim: WLK_EXP_DRV_XWAIT__PM : shape (20, 20)
# tap skim: WLK_EXP_WLK_BOARDS__AM : shape (20, 20)
# tap skim: WLK_EXP_WLK_BOARDS__EA : shape (20, 20)
# tap skim: WLK_EXP_WLK_BOARDS__EV : shape (20, 20)
# tap skim: WLK_EXP_WLK_BOARDS__MD : shape (20, 20)
# tap skim: WLK_EXP_WLK_BOARDS__PM : shape (20, 20)
# tap skim: WLK_EXP_WLK_FAR__AM : shape (20, 20)
# tap skim: WLK_EXP_WLK_FAR__EA : shape (20, 20)
# tap skim: WLK_EXP_WLK_FAR__EV : shape (20, 20)
# tap skim: WLK_EXP_WLK_FAR__MD : shape (20, 20)
# tap skim: WLK_EXP_WLK_FAR__PM : shape (20, 20)
# tap skim: WLK_EXP_WLK_IWAIT__AM : shape (20, 20)
# tap skim: WLK_EXP_WLK_IWAIT__EA : shape (20, 20)
# tap skim: WLK_EXP_WLK_IWAIT__EV : shape (20, 20)
# tap skim: WLK_EXP_WLK_IWAIT__MD : shape (20, 20)
# tap skim: WLK_EXP_WLK_IWAIT__PM : shape (20, 20)
# tap skim: WLK_EXP_WLK_KEYIVT__AM : shape (20, 20)
# tap skim: WLK_EXP_WLK_KEYIVT__EA : shape (20, 20)
# tap skim: WLK_EXP_WLK_KEYIVT__EV : shape (20, 20)
# tap skim: WLK_EXP_WLK_KEYIVT__MD : shape (20, 20)
# tap skim: WLK_EXP_WLK_KEYIVT__PM : shape (20, 20)
# tap skim: WLK_EXP_WLK_TOTIVT__AM : shape (20, 20)
# tap skim: WLK_EXP_WLK_TOTIVT__EA : shape (20, 20)
# tap skim: WLK_EXP_WLK_TOTIVT__EV : shape (20, 20)
# tap skim: WLK_EXP_WLK_TOTIVT__MD : shape (20, 20)
# tap skim: WLK_EXP_WLK_TOTIVT__PM : shape (20, 20)
# tap skim: WLK_EXP_WLK_WAIT__AM : shape (20, 20)
# tap skim: WLK_EXP_WLK_WAIT__EA : shape (20, 20)
# tap skim: WLK_EXP_WLK_WAIT__EV : shape (20, 20)
# tap skim: WLK_EXP_WLK_WAIT__MD : shape (20, 20)
# tap skim: WLK_EXP_WLK_WAIT__PM : shape (20, 20)
# tap skim: WLK_EXP_WLK_WAUX__AM : shape (20, 20)
# tap skim: WLK_EXP_WLK_WAUX__EA : shape (20, 20)
# tap skim: WLK_EXP_WLK_WAUX__EV : shape (20, 20)
# tap skim: WLK_EXP_WLK_WAUX__MD : shape (20, 20)
# tap skim: WLK_EXP_WLK_WAUX__PM : shape (20, 20)
# tap skim: WLK_EXP_WLK_XWAIT__AM : shape (20, 20)
# tap skim: WLK_EXP_WLK_XWAIT__EA : shape (20, 20)
# tap skim: WLK_EXP_WLK_XWAIT__EV : shape (20, 20)
# tap skim: WLK_EXP_WLK_XWAIT__MD : shape (20, 20)
# tap skim: WLK_EXP_WLK_XWAIT__PM : shape (20, 20)
# tap skim: WLK_HVY_DRV_BOARDS__AM : shape (20, 20)
# tap skim: WLK_HVY_DRV_BOARDS__EA : shape (20, 20)
# tap skim: WLK_HVY_DRV_BOARDS__EV : shape (20, 20)
# tap skim: WLK_HVY_DRV_BOARDS__MD : shape (20, 20)
# tap skim: WLK_HVY_DRV_BOARDS__PM : shape (20, 20)
# tap skim: WLK_HVY_DRV_DDIST__AM : shape (20, 20)
# tap skim: WLK_HVY_DRV_DDIST__EA : shape (20, 20)
# tap skim: WLK_HVY_DRV_DDIST__EV : shape (20, 20)
# tap skim: WLK_HVY_DRV_DDIST__MD : shape (20, 20)
# tap skim: WLK_HVY_DRV_DDIST__PM : shape (20, 20)
# tap skim: WLK_HVY_DRV_DTIM__AM : shape (20, 20)
# tap skim: WLK_HVY_DRV_DTIM__EA : shape (20, 20)
# tap skim: WLK_HVY_DRV_DTIM__EV : shape (20, 20)
# tap skim: WLK_HVY_DRV_DTIM__MD : shape (20, 20)
# tap skim: WLK_HVY_DRV_DTIM__PM : shape (20, 20)
# tap skim: WLK_HVY_DRV_FAR__AM : shape (20, 20)
# tap skim: WLK_HVY_DRV_FAR__EA : shape (20, 20)
# tap skim: WLK_HVY_DRV_FAR__EV : shape (20, 20)
# tap skim: WLK_HVY_DRV_FAR__MD : shape (20, 20)
# tap skim: WLK_HVY_DRV_FAR__PM : shape (20, 20)
# tap skim: WLK_HVY_DRV_IWAIT__AM : shape (20, 20)
# tap skim: WLK_HVY_DRV_IWAIT__EA : shape (20, 20)
# tap skim: WLK_HVY_DRV_IWAIT__EV : shape (20, 20)
# tap skim: WLK_HVY_DRV_IWAIT__MD : shape (20, 20)
# tap skim: WLK_HVY_DRV_IWAIT__PM : shape (20, 20)
# tap skim: WLK_HVY_DRV_KEYIVT__AM : shape (20, 20)
# tap skim: WLK_HVY_DRV_KEYIVT__EA : shape (20, 20)
# tap skim: WLK_HVY_DRV_KEYIVT__EV : shape (20, 20)
# tap skim: WLK_HVY_DRV_KEYIVT__MD : shape (20, 20)
# tap skim: WLK_HVY_DRV_KEYIVT__PM : shape (20, 20)
# tap skim: WLK_HVY_DRV_TOTIVT__AM : shape (20, 20)
# tap skim: WLK_HVY_DRV_TOTIVT__EA : shape (20, 20)
# tap skim: WLK_HVY_DRV_TOTIVT__EV : shape (20, 20)
# tap skim: WLK_HVY_DRV_TOTIVT__MD : shape (20, 20)
# tap skim: WLK_HVY_DRV_TOTIVT__PM : shape (20, 20)
# tap skim: WLK_HVY_DRV_WAIT__AM : shape (20, 20)
# tap skim: WLK_HVY_DRV_WAIT__EA : shape (20, 20)
# tap skim: WLK_HVY_DRV_WAIT__EV : shape (20, 20)
# tap skim: WLK_HVY_DRV_WAIT__MD : shape (20, 20)
# tap skim: WLK_HVY_DRV_WAIT__PM : shape (20, 20)
# tap skim: WLK_HVY_DRV_WAUX__AM : shape (20, 20)
# tap skim: WLK_HVY_DRV_WAUX__EA : shape (20, 20)
# tap skim: WLK_HVY_DRV_WAUX__EV : shape (20, 20)
# tap skim: WLK_HVY_DRV_WAUX__MD : shape (20, 20)
# tap skim: WLK_HVY_DRV_WAUX__PM : shape (20, 20)
# tap skim: WLK_HVY_DRV_XWAIT__AM : shape (20, 20)
# tap skim: WLK_HVY_DRV_XWAIT__EA : shape (20, 20)
# tap skim: WLK_HVY_DRV_XWAIT__EV : shape (20, 20)
# tap skim: WLK_HVY_DRV_XWAIT__MD : shape (20, 20)
# tap skim: WLK_HVY_DRV_XWAIT__PM : shape (20, 20)
# tap skim: WLK_HVY_WLK_BOARDS__AM : shape (20, 20)
# tap skim: WLK_HVY_WLK_BOARDS__EA : shape (20, 20)
# tap skim: WLK_HVY_WLK_BOARDS__EV : shape (20, 20)
# tap skim: WLK_HVY_WLK_BOARDS__MD : shape (20, 20)
# tap skim: WLK_HVY_WLK_BOARDS__PM : shape (20, 20)
# tap skim: WLK_HVY_WLK_FAR__AM : shape (20, 20)
# tap skim: WLK_HVY_WLK_FAR__EA : shape (20, 20)
# tap skim: WLK_HVY_WLK_FAR__EV : shape (20, 20)
# tap skim: WLK_HVY_WLK_FAR__MD : shape (20, 20)
# tap skim: WLK_HVY_WLK_FAR__PM : shape (20, 20)
# tap skim: WLK_HVY_WLK_IWAIT__AM : shape (20, 20)
# tap skim: WLK_HVY_WLK_IWAIT__EA : shape (20, 20)
# tap skim: WLK_HVY_WLK_IWAIT__EV : shape (20, 20)
# tap skim: WLK_HVY_WLK_IWAIT__MD : shape (20, 20)
# tap skim: WLK_HVY_WLK_IWAIT__PM : shape (20, 20)
# tap skim: WLK_HVY_WLK_KEYIVT__AM : shape (20, 20)
# tap skim: WLK_HVY_WLK_KEYIVT__EA : shape (20, 20)
# tap skim: WLK_HVY_WLK_KEYIVT__EV : shape (20, 20)
# tap skim: WLK_HVY_WLK_KEYIVT__MD : shape (20, 20)
# tap skim: WLK_HVY_WLK_KEYIVT__PM : shape (20, 20)
# tap skim: WLK_HVY_WLK_TOTIVT__AM : shape (20, 20)
# tap skim: WLK_HVY_WLK_TOTIVT__EA : shape (20, 20)
# tap skim: WLK_HVY_WLK_TOTIVT__EV : shape (20, 20)
# tap skim: WLK_HVY_WLK_TOTIVT__MD : shape (20, 20)
# tap skim: WLK_HVY_WLK_TOTIVT__PM : shape (20, 20)
# tap skim: WLK_HVY_WLK_WAIT__AM : shape (20, 20)
# tap skim: WLK_HVY_WLK_WAIT__EA : shape (20, 20)
# tap skim: WLK_HVY_WLK_WAIT__EV : shape (20, 20)
# tap skim: WLK_HVY_WLK_WAIT__MD : shape (20, 20)
# tap skim: WLK_HVY_WLK_WAIT__PM : shape (20, 20)
# tap skim: WLK_HVY_WLK_WAUX__AM : shape (20, 20)
# tap skim: WLK_HVY_WLK_WAUX__EA : shape (20, 20)
# tap skim: WLK_HVY_WLK_WAUX__EV : shape (20, 20)
# tap skim: WLK_HVY_WLK_WAUX__MD : shape (20, 20)
# tap skim: WLK_HVY_WLK_WAUX__PM : shape (20, 20)
# tap skim: WLK_HVY_WLK_XWAIT__AM : shape (20, 20)
# tap skim: WLK_HVY_WLK_XWAIT__EA : shape (20, 20)
# tap skim: WLK_HVY_WLK_XWAIT__EV : shape (20, 20)
# tap skim: WLK_HVY_WLK_XWAIT__MD : shape (20, 20)
# tap skim: WLK_HVY_WLK_XWAIT__PM : shape (20, 20)
# tap skim: WLK_LOC_DRV_BOARDS__AM : shape (20, 20)
# tap skim: WLK_LOC_DRV_BOARDS__EA : shape (20, 20)
# tap skim: WLK_LOC_DRV_BOARDS__EV : shape (20, 20)
# tap skim: WLK_LOC_DRV_BOARDS__MD : shape (20, 20)
# tap skim: WLK_LOC_DRV_BOARDS__PM : shape (20, 20)
# tap skim: WLK_LOC_DRV_DDIST__AM : shape (20, 20)
# tap skim: WLK_LOC_DRV_DDIST__EA : shape (20, 20)
# tap skim: WLK_LOC_DRV_DDIST__EV : shape (20, 20)
# tap skim: WLK_LOC_DRV_DDIST__MD : shape (20, 20)
# tap skim: WLK_LOC_DRV_DDIST__PM : shape (20, 20)
# tap skim: WLK_LOC_DRV_DTIM__AM : shape (20, 20)
# tap skim: WLK_LOC_DRV_DTIM__EA : shape (20, 20)
# tap skim: WLK_LOC_DRV_DTIM__EV : shape (20, 20)
# tap skim: WLK_LOC_DRV_DTIM__MD : shape (20, 20)
# tap skim: WLK_LOC_DRV_DTIM__PM : shape (20, 20)
# tap skim: WLK_LOC_DRV_FAR__AM : shape (20, 20)
# tap skim: WLK_LOC_DRV_FAR__EA : shape (20, 20)
# tap skim: WLK_LOC_DRV_FAR__EV : shape (20, 20)
# tap skim: WLK_LOC_DRV_FAR__MD : shape (20, 20)
# tap skim: WLK_LOC_DRV_FAR__PM : shape (20, 20)
# tap skim: WLK_LOC_DRV_IWAIT__AM : shape (20, 20)
# tap skim: WLK_LOC_DRV_IWAIT__EA : shape (20, 20)
# tap skim: WLK_LOC_DRV_IWAIT__EV : shape (20, 20)
# tap skim: WLK_LOC_DRV_IWAIT__MD : shape (20, 20)
# tap skim: WLK_LOC_DRV_IWAIT__PM : shape (20, 20)
# tap skim: WLK_LOC_DRV_TOTIVT__AM : shape (20, 20)
# tap skim: WLK_LOC_DRV_TOTIVT__EA : shape (20, 20)
# tap skim: WLK_LOC_DRV_TOTIVT__EV : shape (20, 20)
# tap skim: WLK_LOC_DRV_TOTIVT__MD : shape (20, 20)
# tap skim: WLK_LOC_DRV_TOTIVT__PM : shape (20, 20)
# tap skim: WLK_LOC_DRV_WAIT__AM : shape (20, 20)
# tap skim: WLK_LOC_DRV_WAIT__EA : shape (20, 20)
# tap skim: WLK_LOC_DRV_WAIT__EV : shape (20, 20)
# tap skim: WLK_LOC_DRV_WAIT__MD : shape (20, 20)
# tap skim: WLK_LOC_DRV_WAIT__PM : shape (20, 20)
# tap skim: WLK_LOC_DRV_WAUX__AM : shape (20, 20)
# tap skim: WLK_LOC_DRV_WAUX__EA : shape (20, 20)
# tap skim: WLK_LOC_DRV_WAUX__EV : shape (20, 20)
# tap skim: WLK_LOC_DRV_WAUX__MD : shape (20, 20)
# tap skim: WLK_LOC_DRV_WAUX__PM : shape (20, 20)
# tap skim: WLK_LOC_DRV_XWAIT__AM : shape (20, 20)
# tap skim: WLK_LOC_DRV_XWAIT__EA : shape (20, 20)
# tap skim: WLK_LOC_DRV_XWAIT__EV : shape (20, 20)
# tap skim: WLK_LOC_DRV_XWAIT__MD : shape (20, 20)
# tap skim: WLK_LOC_DRV_XWAIT__PM : shape (20, 20)
# tap skim: WLK_LOC_WLK_BOARDS__AM : shape (20, 20)
# tap skim: WLK_LOC_WLK_BOARDS__EA : shape (20, 20)
# tap skim: WLK_LOC_WLK_BOARDS__EV : shape (20, 20)
# tap skim: WLK_LOC_WLK_BOARDS__MD : shape (20, 20)
# tap skim: WLK_LOC_WLK_BOARDS__PM : shape (20, 20)
# tap skim: WLK_LOC_WLK_FAR__AM : shape (20, 20)
# tap skim: WLK_LOC_WLK_FAR__EA : shape (20, 20)
# tap skim: WLK_LOC_WLK_FAR__EV : shape (20, 20)
# tap skim: WLK_LOC_WLK_FAR__MD : shape (20, 20)
# tap skim: WLK_LOC_WLK_FAR__PM : shape (20, 20)
# tap skim: WLK_LOC_WLK_IWAIT__AM : shape (20, 20)
# tap skim: WLK_LOC_WLK_IWAIT__EA : shape (20, 20)
# tap skim: WLK_LOC_WLK_IWAIT__EV : shape (20, 20)
# tap skim: WLK_LOC_WLK_IWAIT__MD : shape (20, 20)
# tap skim: WLK_LOC_WLK_IWAIT__PM : shape (20, 20)
# tap skim: WLK_LOC_WLK_TOTIVT__AM : shape (20, 20)
# tap skim: WLK_LOC_WLK_TOTIVT__EA : shape (20, 20)
# tap skim: WLK_LOC_WLK_TOTIVT__EV : shape (20, 20)
# tap skim: WLK_LOC_WLK_TOTIVT__MD : shape (20, 20)
# tap skim: WLK_LOC_WLK_TOTIVT__PM : shape (20, 20)
# tap skim: WLK_LOC_WLK_WAIT__AM : shape (20, 20)
# tap skim: WLK_LOC_WLK_WAIT__EA : shape (20, 20)
# tap skim: WLK_LOC_WLK_WAIT__EV : shape (20, 20)
# tap skim: WLK_LOC_WLK_WAIT__MD : shape (20, 20)
# tap skim: WLK_LOC_WLK_WAIT__PM : shape (20, 20)
# tap skim: WLK_LOC_WLK_WAUX__AM : shape (20, 20)
# tap skim: WLK_LOC_WLK_WAUX__EA : shape (20, 20)
# tap skim: WLK_LOC_WLK_WAUX__EV : shape (20, 20)
# tap skim: WLK_LOC_WLK_WAUX__MD : shape (20, 20)
# tap skim: WLK_LOC_WLK_WAUX__PM : shape (20, 20)
# tap skim: WLK_LOC_WLK_XWAIT__AM : shape (20, 20)
# tap skim: WLK_LOC_WLK_XWAIT__EA : shape (20, 20)
# tap skim: WLK_LOC_WLK_XWAIT__EV : shape (20, 20)
# tap skim: WLK_LOC_WLK_XWAIT__MD : shape (20, 20)
# tap skim: WLK_LOC_WLK_XWAIT__PM : shape (20, 20)
# tap skim: WLK_LRF_DRV_BOARDS__AM : shape (20, 20)
# tap skim: WLK_LRF_DRV_BOARDS__EA : shape (20, 20)
# tap skim: WLK_LRF_DRV_BOARDS__EV : shape (20, 20)
# tap skim: WLK_LRF_DRV_BOARDS__MD : shape (20, 20)
# tap skim: WLK_LRF_DRV_BOARDS__PM : shape (20, 20)
# tap skim: WLK_LRF_DRV_DDIST__AM : shape (20, 20)
# tap skim: WLK_LRF_DRV_DDIST__EA : shape (20, 20)
# tap skim: WLK_LRF_DRV_DDIST__EV : shape (20, 20)
# tap skim: WLK_LRF_DRV_DDIST__MD : shape (20, 20)
# tap skim: WLK_LRF_DRV_DDIST__PM : shape (20, 20)
# tap skim: WLK_LRF_DRV_DTIM__AM : shape (20, 20)
# tap skim: WLK_LRF_DRV_DTIM__EA : shape (20, 20)
# tap skim: WLK_LRF_DRV_DTIM__EV : shape (20, 20)
# tap skim: WLK_LRF_DRV_DTIM__MD : shape (20, 20)
# tap skim: WLK_LRF_DRV_DTIM__PM : shape (20, 20)
# tap skim: WLK_LRF_DRV_FAR__AM : shape (20, 20)
# tap skim: WLK_LRF_DRV_FAR__EA : shape (20, 20)
# tap skim: WLK_LRF_DRV_FAR__EV : shape (20, 20)
# tap skim: WLK_LRF_DRV_FAR__MD : shape (20, 20)
# tap skim: WLK_LRF_DRV_FAR__PM : shape (20, 20)
# tap skim: WLK_LRF_DRV_FERRYIVT__AM : shape (20, 20)
# tap skim: WLK_LRF_DRV_FERRYIVT__EA : shape (20, 20)
# tap skim: WLK_LRF_DRV_FERRYIVT__EV : shape (20, 20)
# tap skim: WLK_LRF_DRV_FERRYIVT__MD : shape (20, 20)
# tap skim: WLK_LRF_DRV_FERRYIVT__PM : shape (20, 20)
# tap skim: WLK_LRF_DRV_IWAIT__AM : shape (20, 20)
# tap skim: WLK_LRF_DRV_IWAIT__EA : shape (20, 20)
# tap skim: WLK_LRF_DRV_IWAIT__EV : shape (20, 20)
# tap skim: WLK_LRF_DRV_IWAIT__MD : shape (20, 20)
# tap skim: WLK_LRF_DRV_IWAIT__PM : shape (20, 20)
# tap skim: WLK_LRF_DRV_KEYIVT__AM : shape (20, 20)
# tap skim: WLK_LRF_DRV_KEYIVT__EA : shape (20, 20)
# tap skim: WLK_LRF_DRV_KEYIVT__EV : shape (20, 20)
# tap skim: WLK_LRF_DRV_KEYIVT__MD : shape (20, 20)
# tap skim: WLK_LRF_DRV_KEYIVT__PM : shape (20, 20)
# tap skim: WLK_LRF_DRV_TOTIVT__AM : shape (20, 20)
# tap skim: WLK_LRF_DRV_TOTIVT__EA : shape (20, 20)
# tap skim: WLK_LRF_DRV_TOTIVT__EV : shape (20, 20)
# tap skim: WLK_LRF_DRV_TOTIVT__MD : shape (20, 20)
# tap skim: WLK_LRF_DRV_TOTIVT__PM : shape (20, 20)
# tap skim: WLK_LRF_DRV_WAIT__AM : shape (20, 20)
# tap skim: WLK_LRF_DRV_WAIT__EA : shape (20, 20)
# tap skim: WLK_LRF_DRV_WAIT__EV : shape (20, 20)
# tap skim: WLK_LRF_DRV_WAIT__MD : shape (20, 20)
# tap skim: WLK_LRF_DRV_WAIT__PM : shape (20, 20)
# tap skim: WLK_LRF_DRV_WAUX__AM : shape (20, 20)
# tap skim: WLK_LRF_DRV_WAUX__EA : shape (20, 20)
# tap skim: WLK_LRF_DRV_WAUX__EV : shape (20, 20)
# tap skim: WLK_LRF_DRV_WAUX__MD : shape (20, 20)
# tap skim: WLK_LRF_DRV_WAUX__PM : shape (20, 20)
# tap skim: WLK_LRF_DRV_XWAIT__AM : shape (20, 20)
# tap skim: WLK_LRF_DRV_XWAIT__EA : shape (20, 20)
# tap skim: WLK_LRF_DRV_XWAIT__EV : shape (20, 20)
# tap skim: WLK_LRF_DRV_XWAIT__MD : shape (20, 20)
# tap skim: WLK_LRF_DRV_XWAIT__PM : shape (20, 20)
# tap skim: WLK_LRF_WLK_BOARDS__AM : shape (20, 20)
# tap skim: WLK_LRF_WLK_BOARDS__EA : shape (20, 20)
# tap skim: WLK_LRF_WLK_BOARDS__EV : shape (20, 20)
# tap skim: WLK_LRF_WLK_BOARDS__MD : shape (20, 20)
# tap skim: WLK_LRF_WLK_BOARDS__PM : shape (20, 20)
# tap skim: WLK_LRF_WLK_FAR__AM : shape (20, 20)
# tap skim: WLK_LRF_WLK_FAR__EA : shape (20, 20)
# tap skim: WLK_LRF_WLK_FAR__EV : shape (20, 20)
# tap skim: WLK_LRF_WLK_FAR__MD : shape (20, 20)
# tap skim: WLK_LRF_WLK_FAR__PM : shape (20, 20)
# tap skim: WLK_LRF_WLK_FERRYIVT__AM : shape (20, 20)
# tap skim: WLK_LRF_WLK_FERRYIVT__EA : shape (20, 20)
# tap skim: WLK_LRF_WLK_FERRYIVT__EV : shape (20, 20)
# tap skim: WLK_LRF_WLK_FERRYIVT__MD : shape (20, 20)
# tap skim: WLK_LRF_WLK_FERRYIVT__PM : shape (20, 20)
# tap skim: WLK_LRF_WLK_IWAIT__AM : shape (20, 20)
# tap skim: WLK_LRF_WLK_IWAIT__EA : shape (20, 20)
# tap skim: WLK_LRF_WLK_IWAIT__EV : shape (20, 20)
# tap skim: WLK_LRF_WLK_IWAIT__MD : shape (20, 20)
# tap skim: WLK_LRF_WLK_IWAIT__PM : shape (20, 20)
# tap skim: WLK_LRF_WLK_KEYIVT__AM : shape (20, 20)
# tap skim: WLK_LRF_WLK_KEYIVT__EA : shape (20, 20)
# tap skim: WLK_LRF_WLK_KEYIVT__EV : shape (20, 20)
# tap skim: WLK_LRF_WLK_KEYIVT__MD : shape (20, 20)
# tap skim: WLK_LRF_WLK_KEYIVT__PM : shape (20, 20)
# tap skim: WLK_LRF_WLK_TOTIVT__AM : shape (20, 20)
# tap skim: WLK_LRF_WLK_TOTIVT__EA : shape (20, 20)
# tap skim: WLK_LRF_WLK_TOTIVT__EV : shape (20, 20)
# tap skim: WLK_LRF_WLK_TOTIVT__MD : shape (20, 20)
# tap skim: WLK_LRF_WLK_TOTIVT__PM : shape (20, 20)
# tap skim: WLK_LRF_WLK_WAIT__AM : shape (20, 20)
# tap skim: WLK_LRF_WLK_WAIT__EA : shape (20, 20)
# tap skim: WLK_LRF_WLK_WAIT__EV : shape (20, 20)
# tap skim: WLK_LRF_WLK_WAIT__MD : shape (20, 20)
# tap skim: WLK_LRF_WLK_WAIT__PM : shape (20, 20)
# tap skim: WLK_LRF_WLK_WAUX__AM : shape (20, 20)
# tap skim: WLK_LRF_WLK_WAUX__EA : shape (20, 20)
# tap skim: WLK_LRF_WLK_WAUX__EV : shape (20, 20)
# tap skim: WLK_LRF_WLK_WAUX__MD : shape (20, 20)
# tap skim: WLK_LRF_WLK_WAUX__PM : shape (20, 20)
# tap skim: WLK_LRF_WLK_XWAIT__AM : shape (20, 20)
# tap skim: WLK_LRF_WLK_XWAIT__EA : shape (20, 20)
# tap skim: WLK_LRF_WLK_XWAIT__EV : shape (20, 20)
# tap skim: WLK_LRF_WLK_XWAIT__MD : shape (20, 20)
# tap skim: WLK_LRF_WLK_XWAIT__PM : shape (20, 20)
# tap skim: WLK_TRN_WLK_IVT__AM : shape (20, 20)
# tap skim: WLK_TRN_WLK_IVT__MD : shape (20, 20)
# tap skim: WLK_TRN_WLK_IVT__PM : shape (20, 20)
# tap skim: WLK_TRN_WLK_IWAIT__AM : shape (20, 20)
# tap skim: WLK_TRN_WLK_IWAIT__MD : shape (20, 20)
# tap skim: WLK_TRN_WLK_IWAIT__PM : shape (20, 20)
# tap skim: WLK_TRN_WLK_WACC__AM : shape (20, 20)
# tap skim: WLK_TRN_WLK_WACC__MD : shape (20, 20)
# tap skim: WLK_TRN_WLK_WACC__PM : shape (20, 20)
# tap skim: WLK_TRN_WLK_WAUX__AM : shape (20, 20)
# tap skim: WLK_TRN_WLK_WAUX__MD : shape (20, 20)
# tap skim: WLK_TRN_WLK_WAUX__PM : shape (20, 20)
# tap skim: WLK_TRN_WLK_WEGR__AM : shape (20, 20)
# tap skim: WLK_TRN_WLK_WEGR__MD : shape (20, 20)
# tap skim: WLK_TRN_WLK_WEGR__PM : shape (20, 20)
# tap skim: WLK_TRN_WLK_XWAIT__AM : shape (20, 20)
# tap skim: WLK_TRN_WLK_XWAIT__MD : shape (20, 20)
# tap skim: WLK_TRN_WLK_XWAIT__PM : shape (20, 20)

# %% [markdown]
# ### Create maz to maz distance files by mode

# %%
with omx.open_file(os.path.join(output_data, 'skims.omx')) as skims_file:
    distance_table = pd.DataFrame(skims_file['DIST']).unstack()

walk_speed = 3
bike_speed = 10
max_distance_for_nearby_mazs_walk = 1.0
max_distance_for_nearby_mazs_bike = 5.0

distance_table = distance_table.reset_index()

distance_table.columns = ["OMAZ","DMAZ","DIST"]
distance_table["OMAZ"] = distance_table["OMAZ"] + 1 #seq from 1 to X
distance_table["DMAZ"] = distance_table["DMAZ"] + 1 #seq from 1 to X


maz_to_maz_dist_walk = distance_table[distance_table["DIST"] <= max_distance_for_nearby_mazs_walk].copy()
maz_to_maz_dist_walk["TIME"] = distance_table["DIST"] * (60 / walk_speed)
maz_to_maz_dist_walk.to_csv(os.path.join(output_data, 'maz_to_maz_dist_walk.csv'), index=False)
print("maz_to_maz_dist_walk\n%s" % (maz_to_maz_dist_walk.head(10), ) )

maz_to_maz_dist_bike = distance_table[distance_table["DIST"] <= max_distance_for_nearby_mazs_bike].copy()
maz_to_maz_dist_bike["TIME"] = distance_table["DIST"] * (60 / bike_speed)
maz_to_maz_dist_bike.to_csv(os.path.join(output_data, 'maz_to_maz_dist_bike.csv'), index=False)

print("maz_to_maz_dist_bike\n%s" % (maz_to_maz_dist_bike.head(10), ) )
# Out:
# maz_to_maz_dist_walk
#     OMAZ  DMAZ  DIST  TIME
# 0      1     1  0.12   2.4
# 1      1     2  0.37   7.4
# 2      1     3  0.57  11.4
# 3      1     4  0.34   6.8
# 4      1     5  0.70  14.0
# 5      1     6  0.97  19.4
# 11     1    12  0.62  12.4
# 12     1    13  0.40   8.0
# 13     1    14  0.27   5.4
# 14     1    15  0.36   7.2
# maz_to_maz_dist_bike
#    OMAZ  DMAZ  DIST  TIME
# 0     1     1  0.12  0.72
# 1     1     2  0.37  2.22
# 2     1     3  0.57  3.42
# 3     1     4  0.34  2.04
# 4     1     5  0.70  4.20
# 5     1     6  0.97  5.82
# 6     1     7  1.02  6.12
# 7     1     8  1.05  6.30
# 8     1     9  1.49  8.94
# 9     1    10  1.57  9.42
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-91890c303196> in <module>
#      25 print("maz_to_maz_dist_bike\n%s" % (maz_to_maz_dist_bike.head(10), ) )
#      26
# ---> 27 bolrt
#
# NameError: name 'bolrt' is not defined

# %% [markdown]
# ### Remove other files not needed

# %%
"success"
