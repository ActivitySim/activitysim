# %% [markdown]
# # Getting Started with ActivitySim
#
# This getting started guide is a [Jupyter notebook](https://jupyter.org/). It is an interactive Python 3 environment that describes how to set up, run, and begin to analyze the results of ActivitySim modeling scenarios. It is assumed users of ActivitySim are familiar with the basic concepts of activity-based modeling.  This tutorial covers:
#
# *   Installation and setup
# *   Setting up and running a base model
# *   Inputs and outputs
# *   Setting up and running an alternative scenario
# *   Comparing results
# *   Next steps and further reading
#
# This notebook depends on [Anaconda Python 3 64bit](https://www.anaconda.com/distribution/).

# %% [markdown]
# # Install ActivitySim
#
# The first step is to install activitysim from [conda forge](https://anaconda.org/conda-forge/activitysim).  This also installs dependent packages such as [tables](https://pypi.org/project/tables/) for reading/writing HDF5, [openmatrix](https://pypi.org/project/OpenMatrix/) for reading/writing OMX matrix, and [pyyaml](https://pypi.org/project/PyYAML/) for yaml settings files.  The command below also creates an asim [conda environment](https://conda.io/projects/conda/en/latest/user-guide/concepts/environments.html) just for activitysim.

# %%
# !conda create -n asim python=3.10 activitysim -c conda-forge --override-channels

# %% [markdown]
# # Activate the Environment

# %%
# !conda activate asim

# %% [markdown]
# # Creating an Example Setup
#
# The example is included in the package and can be copied to a user defined location using the package's command line interface.  The example includes all model steps.  The command below copies the prototype_mtc example to a new example folder.  It also changes into the new example folder so we can run the model from there.

# %%
# !activitysim create -e prototype_mtc -d example
# %cd example
# Out:
# copying data ...
# copying configs ...
# copying configs_mp ...
# copying output ...
# copying README.MD ...
# copied! new project files are in C:\projects\development\activitysim\activitysim\examples\prototype_mtc\notebooks\example
# C:\projects\development\activitysim\activitysim\examples\prototype_mtc\notebooks\example

# %% [markdown]
# # Run the Example
#
# The code below runs the example, which runs in a few minutes.  The example consists of 100 synthetic households and the first 25 zones in the example model region.  The full example (**prototype_mtc_full**) can be created and downloaded from the [activitysim resources](https://github.com/ActivitySim/activitysim_resources) repository using activitysim's create command above.  As the model runs, it logs information to the screen.
#
# To run the example, use activitysim's built-in run command.  As shown in the script help, the default settings assume a configs, data, and output folder in the current directory.

# %%
# !activitysim run -c configs -d data -o output
# Out:
# Configured logging using basicConfig
# INFO:activitysim:Configured logging using basicConfig
# INFO - Read logging configuration from: configs\logging.yaml
# INFO - SETTING configs_dir: ['configs']
# INFO - SETTING settings_file_name: settings.yaml
# INFO - SETTING data_dir: ['data']
# INFO - SETTING output_dir: output
# INFO - SETTING households_sample_size: 100
# INFO - SETTING chunk_size: 0
# INFO - SETTING chunk_method: hybrid_uss
# INFO - SETTING chunk_training_mode: training
# INFO - SETTING multiprocess: None
# INFO - SETTING num_processes: None
# INFO - SETTING resume_after: None
# INFO - SETTING trace_hh_id: 982875
# INFO - ENV MKL_NUM_THREADS: None
# INFO - ENV OMP_NUM_THREADS: None
# INFO - ENV OPENBLAS_NUM_THREADS: None
# INFO - NUMPY blas_info libraries: ['cblas', 'blas', 'cblas', 'blas', 'cblas', 'blas']
# INFO - NUMPY blas_opt_info libraries: ['cblas', 'blas', 'cblas', 'blas', 'cblas', 'blas']
# INFO - NUMPY lapack_info libraries: ['lapack', 'blas', 'lapack', 'blas']
# INFO - NUMPY lapack_opt_info libraries: ['lapack', 'blas', 'lapack', 'blas', 'cblas', 'blas', 'cblas', 'blas', 'cblas', 'blas']
# INFO - run single process simulation
# INFO - Time to execute open_pipeline : 0.038 seconds (0.0 minutes)
# INFO - preload_injectables
# INFO - Time to execute preload_injectables : 0.016 seconds (0.0 minutes)
# INFO - #run_model running step initialize_landuse
# INFO - Reading CSV file data\land_use.csv
# INFO - loaded land_use (25, 24)
# INFO - initialize_landuse.annotate_tables - annotating land_use SPEC annotate_landuse
# INFO - Network_LOS using skim_dict_factory: NumpyArraySkimFactory
# INFO - allocate_skim_buffer shared False taz shape (826, 25, 25) total size: 2_065_000 (2.1 MB)
# INFO - _read_skims_from_omx data\skims.omx
# INFO - _read_skims_from_omx loaded 826 skims from data\skims.omx
# INFO - writing skim cache taz (826, 25, 25) to output\cache\cached_taz.mmap
# INFO - load_skims_to_buffer taz shape (826, 25, 25)
# INFO - get_skim_data taz SkimData shape (826, 25, 25)
# INFO - SkimDict init taz
# INFO - SkimDict.build_3d_skim_block_offset_table registered 167 3d keys
# INFO - #run_model running step initialize_households
# INFO - Reading CSV file data\households.csv
# INFO - full household list contains 5000 households
# INFO - sampling 100 of 5000 households
# INFO - loaded households (100, 7)
# INFO - tracing household id 982875 in 100 households
# INFO - Reading CSV file data\persons.csv
# INFO - loaded persons (167, 7)
# INFO - initialize_households.annotate_tables - annotating persons SPEC annotate_persons
# INFO - initialize_households.annotate_tables - annotating households SPEC annotate_households
# INFO - initialize_households.annotate_tables - annotating persons SPEC annotate_persons_after_hh
# INFO - #run_model running step compute_accessibility
# INFO - Running compute_accessibility with 25 orig zones 25 dest zones
# INFO - compute_accessibility Running adaptive_chunked_choosers with 25 choosers
# INFO - Running chunk 1 of 1 with 25 of 25 choosers
# INFO - Running compute_accessibility with 25 orig zones 25 dest zones
# INFO - compute_accessibility computed accessibilities (25, 10)
# INFO - #run_model running step school_location
# INFO - Running school_location.i1.sample.university with 17 persons
# INFO - school_location.i1.sample.university.interaction_sample Running adaptive_chunked_choosers with 17 choosers
# INFO - Running chunk 1 of 1 with 17 of 17 choosers
# INFO - Running eval_interaction_utilities on 102 rows
# INFO - Running school_location.i1.logsums.university with 44 rows
# INFO - school_location.i1.logsums.university.compute_logsums Running adaptive_chunked_choosers with 44 choosers
# INFO - Running chunk 1 of 1 with 44 of 44 choosers
# INFO - Running school_location.i1.simulate.university with 17 persons
# INFO - school_location.i1.simulate.university.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 17 choosers and 44 alternatives
# INFO - Running chunk 1 of 1 with 17 of 17 choosers
# INFO - Running eval_interaction_utilities on 44 rows
# INFO - Running school_location.i1.sample.highschool with 5 persons
# INFO - school_location.i1.sample.highschool.interaction_sample Running adaptive_chunked_choosers with 5 choosers
# INFO - Running chunk 1 of 1 with 5 of 5 choosers
# INFO - Running eval_interaction_utilities on 10 rows
# INFO - Running school_location.i1.logsums.highschool with 5 rows
# INFO - school_location.i1.logsums.highschool.compute_logsums Running adaptive_chunked_choosers with 5 choosers
# INFO - Running chunk 1 of 1 with 5 of 5 choosers
# INFO - Running school_location.i1.simulate.highschool with 5 persons
# INFO - school_location.i1.simulate.highschool.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 5 choosers and 5 alternatives
# INFO - Running chunk 1 of 1 with 5 of 5 choosers
# INFO - Running eval_interaction_utilities on 5 rows
# INFO - Running school_location.i1.sample.gradeschool with 17 persons
# INFO - school_location.i1.sample.gradeschool.interaction_sample Running adaptive_chunked_choosers with 17 choosers
# INFO - Running chunk 1 of 1 with 17 of 17 choosers
# INFO - Running eval_interaction_utilities on 425 rows
# INFO - Running school_location.i1.logsums.gradeschool with 168 rows
# INFO - school_location.i1.logsums.gradeschool.compute_logsums Running adaptive_chunked_choosers with 168 choosers
# INFO - Running chunk 1 of 1 with 168 of 168 choosers
# INFO - Running school_location.i1.simulate.gradeschool with 17 persons
# INFO - school_location.i1.simulate.gradeschool.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 17 choosers and 168 alternatives
# INFO - Running chunk 1 of 1 with 17 of 17 choosers
# INFO - Running eval_interaction_utilities on 168 rows
# INFO - write_trace_files iteration 1
# INFO - school_location_logsum top 10 value counts:
# 7.716620     1
# 8.243127     1
# 10.231078    1
# 12.256776    1
# 20.139937    1
# 12.125021    1
# 11.786408    1
# 16.124778    1
# 8.537372     1
# 10.997809    1
# Name: logsum, dtype: int64
# INFO - #run_model running step workplace_location
# INFO - Running workplace_location.i1.sample.work_low with 37 persons
# INFO - workplace_location.i1.sample.work_low.interaction_sample Running adaptive_chunked_choosers with 37 choosers
# INFO - Running chunk 1 of 1 with 37 of 37 choosers
# INFO - Running eval_interaction_utilities on 925 rows
# INFO - Running workplace_location.i1.logsums.work_low with 504 rows
# INFO - workplace_location.i1.logsums.work_low.compute_logsums Running adaptive_chunked_choosers with 504 choosers
# INFO - Running chunk 1 of 1 with 504 of 504 choosers
# INFO - Running workplace_location.i1.simulate.work_low with 37 persons
# INFO - workplace_location.i1.simulate.work_low.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 37 choosers and 504 alternatives
# INFO - Running chunk 1 of 1 with 37 of 37 choosers
# INFO - Running eval_interaction_utilities on 504 rows
# INFO - Running workplace_location.i1.sample.work_med with 26 persons
# INFO - workplace_location.i1.sample.work_med.interaction_sample Running adaptive_chunked_choosers with 26 choosers
# INFO - Running chunk 1 of 1 with 26 of 26 choosers
# INFO - Running eval_interaction_utilities on 650 rows
# INFO - Running workplace_location.i1.logsums.work_med with 367 rows
# INFO - workplace_location.i1.logsums.work_med.compute_logsums Running adaptive_chunked_choosers with 367 choosers
# INFO - Running chunk 1 of 1 with 367 of 367 choosers
# INFO - Running workplace_location.i1.simulate.work_med with 26 persons
# INFO - workplace_location.i1.simulate.work_med.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 26 choosers and 367 alternatives
# INFO - Running chunk 1 of 1 with 26 of 26 choosers
# INFO - Running eval_interaction_utilities on 367 rows
# INFO - Running workplace_location.i1.sample.work_high with 16 persons
# INFO - workplace_location.i1.sample.work_high.interaction_sample Running adaptive_chunked_choosers with 16 choosers
# INFO - Running chunk 1 of 1 with 16 of 16 choosers
# INFO - Running eval_interaction_utilities on 400 rows
# INFO - Running workplace_location.i1.logsums.work_high with 226 rows
# INFO - workplace_location.i1.logsums.work_high.compute_logsums Running adaptive_chunked_choosers with 226 choosers
# INFO - Running chunk 1 of 1 with 226 of 226 choosers
# INFO - Running workplace_location.i1.simulate.work_high with 16 persons
# INFO - workplace_location.i1.simulate.work_high.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 16 choosers and 226 alternatives
# INFO - Running chunk 1 of 1 with 16 of 16 choosers
# INFO - Running eval_interaction_utilities on 226 rows
# INFO - Running workplace_location.i1.sample.work_veryhigh with 18 persons
# INFO - workplace_location.i1.sample.work_veryhigh.interaction_sample Running adaptive_chunked_choosers with 18 choosers
# INFO - Running chunk 1 of 1 with 18 of 18 choosers
# INFO - Running eval_interaction_utilities on 450 rows
# INFO - Running workplace_location.i1.logsums.work_veryhigh with 253 rows
# INFO - workplace_location.i1.logsums.work_veryhigh.compute_logsums Running adaptive_chunked_choosers with 253 choosers
# INFO - Running chunk 1 of 1 with 253 of 253 choosers
# INFO - Running workplace_location.i1.simulate.work_veryhigh with 18 persons
# INFO - workplace_location.i1.simulate.work_veryhigh.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 18 choosers and 253 alternatives
# INFO - Running chunk 1 of 1 with 18 of 18 choosers
# INFO - Running eval_interaction_utilities on 253 rows
# INFO - write_trace_files iteration 1
# INFO - workplace_location_logsum top 10 value counts:
# 15.316797    1
# 15.641096    1
# 13.574187    1
# 15.586471    1
# 15.430079    1
# 15.412180    1
# 14.011234    1
# 15.522393    1
# 15.725096    1
# 13.564067    1
# Name: logsum, dtype: int64
# INFO - #run_model running step auto_ownership_simulate
# INFO - Running auto_ownership_simulate with 100 households
# INFO - auto_ownership_simulate.simple_simulate Running adaptive_chunked_choosers with 100 choosers
# INFO - Running chunk 1 of 1 with 100 of 100 choosers
# INFO - auto_ownership top 10 value counts:
# 0    60
# 1    40
# Name: auto_ownership, dtype: int64
# INFO - #run_model running step free_parking
# INFO - Running free_parking with 97 persons
# INFO - free_parking.simple_simulate Running adaptive_chunked_choosers with 97 choosers
# INFO - Running chunk 1 of 1 with 97 of 97 choosers
# INFO - free_parking top 10 value counts:
# False    163
# True       4
# Name: free_parking_at_work, dtype: int64
# INFO - #run_model running step cdap_simulate
# INFO - Pre-building cdap specs
# INFO - Time to execute build_cdap_spec hh_size 2 : 0.314 seconds (0.0 minutes)
# INFO - Time to execute build_cdap_spec hh_size 3 : 0.645 seconds (0.0 minutes)
# INFO - Time to execute build_cdap_spec hh_size 4 : 1.403 seconds (0.0 minutes)
# INFO - Time to execute build_cdap_spec hh_size 5 : 2.92 seconds (0.0 minutes)
# INFO - Running cdap_simulate with 167 persons
# INFO - cdap.cdap Running chunk 1 of 1 with 100 of 100 choosers
# INFO - cdap_activity top 10 value counts:
# M    89
# N    48
# H    30
# Name: cdap_activity, dtype: int64
# INFO - cdap crosstabs:
# cdap_activity   H   M   N  All
# ptype
# 1               4  42   6   52
# 2               8  19   7   34
# 3               1  11   5   17
# 4               4   0  17   21
# 5               9   0  12   21
# 6               4   1   0    5
# 7               0  10   1   11
# 8               0   6   0    6
# All            30  89  48  167
# INFO - #run_model running step mandatory_tour_frequency
# INFO - Running mandatory_tour_frequency with 89 persons
# INFO - mandatory_tour_frequency.simple_simulate Running adaptive_chunked_choosers with 89 choosers
# INFO - Running chunk 1 of 1 with 89 of 89 choosers
# INFO - mandatory_tour_frequency top 10 value counts:
#                    78
# work1              61
# school1            22
# work_and_school     4
# work2               2
# Name: mandatory_tour_frequency, dtype: int64
# INFO - #run_model running step mandatory_tour_scheduling
# DEBUG - @inject timetable
# INFO - Running mandatory_tour_scheduling with 95 tours
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work schedule_tours running 67 tour choices
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work Running adaptive_chunked_choosers with 67 choosers
# INFO - Running chunk 1 of 1 with 67 of 67 choosers
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work schedule_tours running 67 tour choices
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums compute_logsums deduped_alt_tdds reduced number of rows by 92.11% from 12730 to 1005 compared to USE_BRUTE_FORCE_TO_COMPUTE_LOGSUMS
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums compute_logsums for 1005 choosers 1005 alts
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums Running adaptive_chunked_choosers with 1005 choosers
# INFO - Running chunk 1 of 1 with 1005 of 1005 choosers
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 67 choosers and 12730 alternatives
# INFO - Running chunk 1 of 1 with 67 of 67 choosers
# INFO - Running eval_interaction_utilities on 12730 rows
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.school schedule_tours running 17 tour choices
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.school Running adaptive_chunked_choosers with 17 choosers
# INFO - Running chunk 1 of 1 with 17 of 17 choosers
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.school schedule_tours running 17 tour choices
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.school.compute_logsums compute_logsums deduped_alt_tdds reduced number of rows by 92.11% from 3230 to 255 compared to USE_BRUTE_FORCE_TO_COMPUTE_LOGSUMS
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.school.compute_logsums.logsums compute_logsums for 255 choosers 255 alts
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.school.compute_logsums.logsums Running adaptive_chunked_choosers with 255 choosers
# INFO - Running chunk 1 of 1 with 255 of 255 choosers
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.school.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 17 choosers and 3230 alternatives
# INFO - Running chunk 1 of 1 with 17 of 17 choosers
# INFO - Running eval_interaction_utilities on 3230 rows
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.univ schedule_tours running 5 tour choices
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.univ Running adaptive_chunked_choosers with 5 choosers
# INFO - Running chunk 1 of 1 with 5 of 5 choosers
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.univ schedule_tours running 5 tour choices
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.univ.compute_logsums compute_logsums deduped_alt_tdds reduced number of rows by 92.11% from 950 to 75 compared to USE_BRUTE_FORCE_TO_COMPUTE_LOGSUMS
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.univ.compute_logsums.logsums compute_logsums for 75 choosers 75 alts
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.univ.compute_logsums.logsums Running adaptive_chunked_choosers with 75 choosers
# INFO - Running chunk 1 of 1 with 75 of 75 choosers
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.univ.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 5 choosers and 950 alternatives
# INFO - Running chunk 1 of 1 with 5 of 5 choosers
# INFO - Running eval_interaction_utilities on 950 rows
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.work schedule_tours running 2 tour choices
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.work Running adaptive_chunked_choosers with 2 choosers
# INFO - Running chunk 1 of 1 with 2 of 2 choosers
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.work schedule_tours running 2 tour choices
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.work.compute_logsums compute_logsums deduped_alt_tdds reduced number of rows by 89.71% from 175 to 18 compared to USE_BRUTE_FORCE_TO_COMPUTE_LOGSUMS
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.work.compute_logsums.logsums compute_logsums for 18 choosers 18 alts
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.work.compute_logsums.logsums Running adaptive_chunked_choosers with 18 choosers
# INFO - Running chunk 1 of 1 with 18 of 18 choosers
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.work.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 2 choosers and 175 alternatives
# INFO - Running chunk 1 of 1 with 2 of 2 choosers
# INFO - Running eval_interaction_utilities on 175 rows
# INFO - skipping empty segment school
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.univ schedule_tours running 4 tour choices
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.univ Running adaptive_chunked_choosers with 4 choosers
# INFO - Running chunk 1 of 1 with 4 of 4 choosers
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.univ schedule_tours running 4 tour choices
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.univ.compute_logsums compute_logsums deduped_alt_tdds reduced number of rows by 90.16% from 366 to 36 compared to USE_BRUTE_FORCE_TO_COMPUTE_LOGSUMS
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.univ.compute_logsums.logsums compute_logsums for 36 choosers 36 alts
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.univ.compute_logsums.logsums Running adaptive_chunked_choosers with 36 choosers
# INFO - Running chunk 1 of 1 with 36 of 36 choosers
# INFO - mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.univ.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 4 choosers and 366 alternatives
# INFO - Running chunk 1 of 1 with 4 of 4 choosers
# INFO - Running eval_interaction_utilities on 366 rows
# INFO - #run_model running step joint_tour_frequency
# INFO - Running joint_tour_frequency with 36 multi-person households
# DEBUG - @inject timetable
# INFO - joint_tour_frequency.simple_simulate Running adaptive_chunked_choosers with 36 choosers
# INFO - Running chunk 1 of 1 with 36 of 36 choosers
# WARNING - register tours: no rows with household_id in [982875].
# INFO - joint_tour_frequency top 10 value counts:
# 0_tours    97
# 1_Disc      1
# 1_Eat       1
# 1_Shop      1
# Name: joint_tour_frequency, dtype: int64
# INFO - #run_model running step joint_tour_composition
# INFO - Running joint_tour_composition with 3 joint tours
# DEBUG - @inject timetable
# INFO - joint_tour_composition.simple_simulate Running adaptive_chunked_choosers with 3 choosers
# INFO - Running chunk 1 of 1 with 3 of 3 choosers
# INFO - joint_tour_composition top 10 value counts:
# adults      2
# children    1
# Name: composition, dtype: int64
# INFO - #run_model running step joint_tour_participation
# WARNING - register joint_tour_participants: no rows with household_id in [982875].
# INFO - Running joint_tours_participation with 8 potential participants (candidates)
# DEBUG - @inject timetable
# INFO - joint_tour_participation Running chunk 1 of 1 with 3 of 3 choosers
# INFO - joint_tour_participation.eval_mnl.participants_chooser 3 joint tours to satisfy.
# INFO - joint_tour_participation.eval_mnl.participants_chooser 1 iterations to satisfy all joint tours.
# INFO - #run_model running step joint_tour_destination
# INFO - running joint_tour_destination.shopping.sample with 1 tours
# INFO - joint_tour_destination.shopping.sample.interaction_sample Running adaptive_chunked_choosers with 1 choosers
# INFO - Running chunk 1 of 1 with 1 of 1 choosers
# INFO - Running eval_interaction_utilities on 25 rows
# INFO - Running joint_tour_destination.shopping.logsums with 11 rows
# INFO - joint_tour_destination.shopping.logsums.compute_logsums Running adaptive_chunked_choosers with 11 choosers
# INFO - Running chunk 1 of 1 with 11 of 11 choosers
# INFO - Running tour_destination_simulate with 1 persons
# INFO - joint_tour_destination.shopping.simulate.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 1 choosers and 11 alternatives
# INFO - Running chunk 1 of 1 with 1 of 1 choosers
# INFO - Running eval_interaction_utilities on 11 rows
# INFO - joint_tour_destination skipping segment othmaint: no choosers
# INFO - running joint_tour_destination.othdiscr.sample with 1 tours
# INFO - joint_tour_destination.othdiscr.sample.interaction_sample Running adaptive_chunked_choosers with 1 choosers
# INFO - Running chunk 1 of 1 with 1 of 1 choosers
# INFO - Running eval_interaction_utilities on 25 rows
# INFO - Running joint_tour_destination.othdiscr.logsums with 15 rows
# INFO - joint_tour_destination.othdiscr.logsums.compute_logsums Running adaptive_chunked_choosers with 15 choosers
# INFO - Running chunk 1 of 1 with 15 of 15 choosers
# INFO - Running tour_destination_simulate with 1 persons
# INFO - joint_tour_destination.othdiscr.simulate.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 1 choosers and 15 alternatives
# INFO - Running chunk 1 of 1 with 1 of 1 choosers
# INFO - Running eval_interaction_utilities on 15 rows
# INFO - running joint_tour_destination.eatout.sample with 1 tours
# INFO - joint_tour_destination.eatout.sample.interaction_sample Running adaptive_chunked_choosers with 1 choosers
# INFO - Running chunk 1 of 1 with 1 of 1 choosers
# INFO - Running eval_interaction_utilities on 25 rows
# INFO - Running joint_tour_destination.eatout.logsums with 16 rows
# INFO - joint_tour_destination.eatout.logsums.compute_logsums Running adaptive_chunked_choosers with 16 choosers
# INFO - Running chunk 1 of 1 with 16 of 16 choosers
# INFO - Running tour_destination_simulate with 1 persons
# INFO - joint_tour_destination.eatout.simulate.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 1 choosers and 16 alternatives
# INFO - Running chunk 1 of 1 with 1 of 1 choosers
# INFO - Running eval_interaction_utilities on 16 rows
# INFO - joint_tour_destination skipping segment social: no choosers
# INFO - joint_tour_destination skipping segment escort: no choosers
# INFO - destination summary:
# count     3.000000
# mean     14.000000
# std       9.539392
# min       5.000000
# 25%       9.000000
# 50%      13.000000
# 75%      18.500000
# max      24.000000
# Name: destination, dtype: float64
# INFO - #run_model running step joint_tour_scheduling
# INFO - Running joint_tour_scheduling with 3 joint tours
# DEBUG - @inject timetable
# INFO - schedule_tours %s tours not monotonic_increasing - sorting df
# INFO - joint_tour_scheduling.vectorize_joint_tour_scheduling.tour_1 schedule_tours running 3 tour choices
# INFO - joint_tour_scheduling.vectorize_joint_tour_scheduling.tour_1 Running adaptive_chunked_choosers with 3 choosers
# INFO - Running chunk 1 of 1 with 3 of 3 choosers
# INFO - joint_tour_scheduling.vectorize_joint_tour_scheduling.tour_1 schedule_tours running 3 tour choices
# INFO - joint_tour_scheduling.vectorize_joint_tour_scheduling.tour_1.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 3 choosers and 65 alternatives
# INFO - Running chunk 1 of 1 with 3 of 3 choosers
# INFO - Running eval_interaction_utilities on 65 rows
# INFO - #run_model running step non_mandatory_tour_frequency
# DEBUG - @inject timetable
# INFO - Running non_mandatory_tour_frequency with 137 persons
# INFO - Running segment 'PTYPE_FULL' of size 48
# INFO - non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate Running adaptive_chunked_choosers with 48 choosers
# INFO - Running chunk 1 of 1 with 48 of 48 choosers
# INFO - Running eval_interaction_utilities on 4608 rows
# INFO - Running segment 'PTYPE_PART' of size 26
# INFO - non_mandatory_tour_frequency.PTYPE_PART.interaction_simulate Running adaptive_chunked_choosers with 26 choosers
# INFO - Running chunk 1 of 1 with 26 of 26 choosers
# INFO - Running eval_interaction_utilities on 2496 rows
# INFO - Running segment 'PTYPE_UNIVERSITY' of size 16
# INFO - non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate Running adaptive_chunked_choosers with 16 choosers
# INFO - Running chunk 1 of 1 with 16 of 16 choosers
# INFO - Running eval_interaction_utilities on 1536 rows
# INFO - Running segment 'PTYPE_NONWORK' of size 17
# INFO - non_mandatory_tour_frequency.PTYPE_NONWORK.interaction_simulate Running adaptive_chunked_choosers with 17 choosers
# INFO - Running chunk 1 of 1 with 17 of 17 choosers
# INFO - Running eval_interaction_utilities on 1632 rows
# INFO - Running segment 'PTYPE_RETIRED' of size 12
# INFO - non_mandatory_tour_frequency.PTYPE_RETIRED.interaction_simulate Running adaptive_chunked_choosers with 12 choosers
# INFO - Running chunk 1 of 1 with 12 of 12 choosers
# INFO - Running eval_interaction_utilities on 1152 rows
# INFO - Running segment 'PTYPE_DRIVING' of size 1
# INFO - non_mandatory_tour_frequency.PTYPE_DRIVING.interaction_simulate Running adaptive_chunked_choosers with 1 choosers
# INFO - Running chunk 1 of 1 with 1 of 1 choosers
# INFO - Running eval_interaction_utilities on 96 rows
# INFO - Running segment 'PTYPE_SCHOOL' of size 11
# INFO - non_mandatory_tour_frequency.PTYPE_SCHOOL.interaction_simulate Running adaptive_chunked_choosers with 11 choosers
# INFO - Running chunk 1 of 1 with 11 of 11 choosers
# INFO - Running eval_interaction_utilities on 1056 rows
# INFO - Running segment 'PTYPE_PRESCHOOL' of size 6
# INFO - non_mandatory_tour_frequency.PTYPE_PRESCHOOL.interaction_simulate Running adaptive_chunked_choosers with 6 choosers
# INFO - Running chunk 1 of 1 with 6 of 6 choosers
# INFO - Running eval_interaction_utilities on 576 rows
# INFO - extend_tour_counts increased tour count by 5 from 90 to 95
# INFO - non_mandatory_tour_frequency top 10 value counts:
# 0     102
# 16     17
# 8       8
# 1       8
# 4       7
# 9       4
# 2       3
# 20      3
# 17      3
# 24      2
# Name: non_mandatory_tour_frequency, dtype: int64
# INFO - #run_model running step non_mandatory_tour_destination
# INFO - running non_mandatory_tour_destination.shopping.sample with 30 tours
# INFO - non_mandatory_tour_destination.shopping.sample.interaction_sample Running adaptive_chunked_choosers with 30 choosers
# INFO - Running chunk 1 of 1 with 30 of 30 choosers
# INFO - Running eval_interaction_utilities on 750 rows
# INFO - Running non_mandatory_tour_destination.shopping.logsums with 366 rows
# INFO - non_mandatory_tour_destination.shopping.logsums.compute_logsums Running adaptive_chunked_choosers with 366 choosers
# INFO - Running chunk 1 of 1 with 366 of 366 choosers
# INFO - Running tour_destination_simulate with 30 persons
# INFO - non_mandatory_tour_destination.shopping.simulate.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 30 choosers and 366 alternatives
# INFO - Running chunk 1 of 1 with 30 of 30 choosers
# INFO - Running eval_interaction_utilities on 366 rows
# INFO - running non_mandatory_tour_destination.othmaint.sample with 20 tours
# INFO - non_mandatory_tour_destination.othmaint.sample.interaction_sample Running adaptive_chunked_choosers with 20 choosers
# INFO - Running chunk 1 of 1 with 20 of 20 choosers
# INFO - Running eval_interaction_utilities on 500 rows
# INFO - Running non_mandatory_tour_destination.othmaint.logsums with 286 rows
# INFO - non_mandatory_tour_destination.othmaint.logsums.compute_logsums Running adaptive_chunked_choosers with 286 choosers
# INFO - Running chunk 1 of 1 with 286 of 286 choosers
# INFO - Running tour_destination_simulate with 20 persons
# INFO - non_mandatory_tour_destination.othmaint.simulate.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 20 choosers and 286 alternatives
# INFO - Running chunk 1 of 1 with 20 of 20 choosers
# INFO - Running eval_interaction_utilities on 286 rows
# INFO - running non_mandatory_tour_destination.othdiscr.sample with 20 tours
# INFO - non_mandatory_tour_destination.othdiscr.sample.interaction_sample Running adaptive_chunked_choosers with 20 choosers
# INFO - Running chunk 1 of 1 with 20 of 20 choosers
# INFO - Running eval_interaction_utilities on 500 rows
# INFO - Running non_mandatory_tour_destination.othdiscr.logsums with 291 rows
# INFO - non_mandatory_tour_destination.othdiscr.logsums.compute_logsums Running adaptive_chunked_choosers with 291 choosers
# INFO - Running chunk 1 of 1 with 291 of 291 choosers
# INFO - Running tour_destination_simulate with 20 persons
# INFO - non_mandatory_tour_destination.othdiscr.simulate.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 20 choosers and 291 alternatives
# INFO - Running chunk 1 of 1 with 20 of 20 choosers
# INFO - Running eval_interaction_utilities on 291 rows
# INFO - running non_mandatory_tour_destination.eatout.sample with 15 tours
# INFO - non_mandatory_tour_destination.eatout.sample.interaction_sample Running adaptive_chunked_choosers with 15 choosers
# INFO - Running chunk 1 of 1 with 15 of 15 choosers
# INFO - Running eval_interaction_utilities on 375 rows
# INFO - Running non_mandatory_tour_destination.eatout.logsums with 203 rows
# INFO - non_mandatory_tour_destination.eatout.logsums.compute_logsums Running adaptive_chunked_choosers with 203 choosers
# INFO - Running chunk 1 of 1 with 203 of 203 choosers
# INFO - Running tour_destination_simulate with 15 persons
# INFO - non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 15 choosers and 203 alternatives
# INFO - Running chunk 1 of 1 with 15 of 15 choosers
# INFO - Running eval_interaction_utilities on 203 rows
# INFO - running non_mandatory_tour_destination.social.sample with 7 tours
# INFO - non_mandatory_tour_destination.social.sample.interaction_sample Running adaptive_chunked_choosers with 7 choosers
# INFO - Running chunk 1 of 1 with 7 of 7 choosers
# INFO - Running eval_interaction_utilities on 175 rows
# INFO - Running non_mandatory_tour_destination.social.logsums with 97 rows
# INFO - non_mandatory_tour_destination.social.logsums.compute_logsums Running adaptive_chunked_choosers with 97 choosers
# INFO - Running chunk 1 of 1 with 97 of 97 choosers
# INFO - Running tour_destination_simulate with 7 persons
# INFO - non_mandatory_tour_destination.social.simulate.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 7 choosers and 97 alternatives
# INFO - Running chunk 1 of 1 with 7 of 7 choosers
# INFO - Running eval_interaction_utilities on 97 rows
# INFO - running non_mandatory_tour_destination.escort.sample with 3 tours
# INFO - non_mandatory_tour_destination.escort.sample.interaction_sample Running adaptive_chunked_choosers with 3 choosers
# INFO - Running chunk 1 of 1 with 3 of 3 choosers
# INFO - Running eval_interaction_utilities on 75 rows
# INFO - Running non_mandatory_tour_destination.escort.logsums with 41 rows
# INFO - non_mandatory_tour_destination.escort.logsums.compute_logsums Running adaptive_chunked_choosers with 41 choosers
# INFO - Running chunk 1 of 1 with 41 of 41 choosers
# INFO - Running tour_destination_simulate with 3 persons
# INFO - non_mandatory_tour_destination.escort.simulate.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 3 choosers and 41 alternatives
# INFO - Running chunk 1 of 1 with 3 of 3 choosers
# INFO - Running eval_interaction_utilities on 41 rows
# INFO - #run_model running step non_mandatory_tour_scheduling
# DEBUG - @inject timetable
# INFO - Running non_mandatory_tour_scheduling with 95 tours
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1 schedule_tours running 65 tour choices
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1 Running adaptive_chunked_choosers with 65 choosers
# INFO - Running chunk 1 of 1 with 65 of 65 choosers
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1 schedule_tours running 65 tour choices
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 65 choosers and 9990 alternatives
# INFO - Running chunk 1 of 1 with 65 of 65 choosers
# INFO - Running eval_interaction_utilities on 9990 rows
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2 schedule_tours running 23 tour choices
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2 Running adaptive_chunked_choosers with 23 choosers
# INFO - Running chunk 1 of 1 with 23 of 23 choosers
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2 schedule_tours running 23 tour choices
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_2.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 23 choosers and 1758 alternatives
# INFO - Running chunk 1 of 1 with 23 of 23 choosers
# INFO - Running eval_interaction_utilities on 1758 rows
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_3 schedule_tours running 6 tour choices
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_3 Running adaptive_chunked_choosers with 6 choosers
# INFO - Running chunk 1 of 1 with 6 of 6 choosers
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_3 schedule_tours running 6 tour choices
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_3.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 6 choosers and 200 alternatives
# INFO - Running chunk 1 of 1 with 6 of 6 choosers
# INFO - Running eval_interaction_utilities on 200 rows
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_4 schedule_tours running 1 tour choices
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_4 Running adaptive_chunked_choosers with 1 choosers
# INFO - Running chunk 1 of 1 with 1 of 1 choosers
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_4 schedule_tours running 1 tour choices
# INFO - non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_4.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 1 choosers and 18 alternatives
# INFO - Running chunk 1 of 1 with 1 of 1 choosers
# INFO - Running eval_interaction_utilities on 18 rows
# INFO - #run_model running step tour_mode_choice_simulate
# INFO - Running tour_mode_choice with 193 tours
# INFO - tour_types top 10 value counts:
# work        69
# shopping    31
# school      26
# othdiscr    21
# othmaint    20
# eatout      16
# social       7
# escort       3
# Name: tour_type, dtype: int64
# INFO - tour_mode_choice_simulate tour_type 'eatout' (16 tours)
# INFO - tour_mode_choice.eatout.simple_simulate Running adaptive_chunked_choosers with 16 choosers
# INFO - Running chunk 1 of 1 with 16 of 16 choosers
# INFO - tour_mode_choice_simulate eatout choices_df top 10 value counts:
# WALK              12
# WALK_LRF           3
# DRIVEALONEFREE     1
# Name: tour_mode, dtype: int64
# INFO - tour_mode_choice_simulate tour_type 'escort' (3 tours)
# INFO - tour_mode_choice.escort.simple_simulate Running adaptive_chunked_choosers with 3 choosers
# INFO - Running chunk 1 of 1 with 3 of 3 choosers
# INFO - tour_mode_choice_simulate escort choices_df top 10 value counts:
# SHARED2FREE    1
# WALK_LOC       1
# TNC_SINGLE     1
# Name: tour_mode, dtype: int64
# INFO - tour_mode_choice_simulate tour_type 'othdiscr' (21 tours)
# INFO - tour_mode_choice.othdiscr.simple_simulate Running adaptive_chunked_choosers with 21 choosers
# INFO - Running chunk 1 of 1 with 21 of 21 choosers
# INFO - tour_mode_choice_simulate othdiscr choices_df top 10 value counts:
# WALK              10
# WALK_LRF           3
# WALK_LOC           2
# TNC_SINGLE         2
# DRIVEALONEFREE     2
# WALK_HVY           1
# SHARED3FREE        1
# Name: tour_mode, dtype: int64
# INFO - tour_mode_choice_simulate tour_type 'othmaint' (20 tours)
# INFO - tour_mode_choice.othmaint.simple_simulate Running adaptive_chunked_choosers with 20 choosers
# INFO - Running chunk 1 of 1 with 20 of 20 choosers
# INFO - tour_mode_choice_simulate othmaint choices_df top 10 value counts:
# WALK              9
# TNC_SINGLE        4
# BIKE              4
# WALK_LOC          1
# DRIVEALONEFREE    1
# TAXI              1
# Name: tour_mode, dtype: int64
# INFO - tour_mode_choice_simulate tour_type 'school' (17 tours)
# INFO - tour_mode_choice.school.simple_simulate Running adaptive_chunked_choosers with 17 choosers
# INFO - Running chunk 1 of 1 with 17 of 17 choosers
# INFO - tour_mode_choice_simulate school choices_df top 10 value counts:
# WALK           7
# WALK_LOC       5
# WALK_LRF       3
# SHARED3FREE    1
# WALK_HVY       1
# Name: tour_mode, dtype: int64
# INFO - tour_mode_choice_simulate tour_type 'shopping' (31 tours)
# INFO - tour_mode_choice.shopping.simple_simulate Running adaptive_chunked_choosers with 31 choosers
# INFO - Running chunk 1 of 1 with 31 of 31 choosers
# INFO - tour_mode_choice_simulate shopping choices_df top 10 value counts:
# WALK              13
# WALK_LRF           7
# WALK_LOC           5
# TAXI               2
# DRIVEALONEFREE     2
# SHARED2FREE        1
# TNC_SINGLE         1
# Name: tour_mode, dtype: int64
# INFO - tour_mode_choice_simulate tour_type 'social' (7 tours)
# INFO - tour_mode_choice.social.simple_simulate Running adaptive_chunked_choosers with 7 choosers
# INFO - Running chunk 1 of 1 with 7 of 7 choosers
# INFO - tour_mode_choice_simulate social choices_df top 10 value counts:
# WALK          2
# WALK_LRF      2
# TNC_SINGLE    1
# WALK_LOC      1
# TAXI          1
# Name: tour_mode, dtype: int64
# INFO - tour_mode_choice_simulate tour_type 'univ' (9 tours)
# INFO - tour_mode_choice.univ.simple_simulate Running adaptive_chunked_choosers with 9 choosers
# INFO - Running chunk 1 of 1 with 9 of 9 choosers
# INFO - tour_mode_choice_simulate univ choices_df top 10 value counts:
# WALK              3
# WALK_LRF          2
# TNC_SHARED        1
# WALK_LOC          1
# TAXI              1
# DRIVEALONEFREE    1
# Name: tour_mode, dtype: int64
# INFO - tour_mode_choice_simulate tour_type 'work' (69 tours)
# INFO - tour_mode_choice.work.simple_simulate Running adaptive_chunked_choosers with 69 choosers
# INFO - Running chunk 1 of 1 with 69 of 69 choosers
# INFO - tour_mode_choice_simulate work choices_df top 10 value counts:
# WALK              24
# WALK_LOC          14
# WALK_LRF          12
# TNC_SINGLE         7
# BIKE               4
# WALK_HVY           3
# DRIVEALONEFREE     3
# SHARED2FREE        1
# SHARED3FREE        1
# Name: tour_mode, dtype: int64
# INFO - tour_mode_choice_simulate all tour type choices top 10 value counts:
# WALK              80
# WALK_LRF          32
# WALK_LOC          30
# TNC_SINGLE        16
# DRIVEALONEFREE    10
# BIKE               8
# WALK_HVY           5
# TAXI               5
# SHARED3FREE        3
# SHARED2FREE        3
# Name: tour_mode, dtype: int64
# INFO - #run_model running step atwork_subtour_frequency
# INFO - Running atwork_subtour_frequency with 69 work tours
# INFO - atwork_subtour_frequency.simple_simulate Running adaptive_chunked_choosers with 69 choosers
# INFO - Running chunk 1 of 1 with 69 of 69 choosers
# WARNING - register tours: no rows with household_id in [982875].
# INFO - atwork_subtour_frequency top 10 value counts:
#                133
# no_subtours     60
# eat              8
# maint            1
# Name: atwork_subtour_frequency, dtype: int64
# INFO - #run_model running step atwork_subtour_destination
# INFO - running atwork_subtour_destination.atwork.sample with 9 tours
# INFO - atwork_subtour_destination.atwork.sample.interaction_sample Running adaptive_chunked_choosers with 9 choosers
# INFO - Running chunk 1 of 1 with 9 of 9 choosers
# INFO - Running eval_interaction_utilities on 225 rows
# INFO - Running atwork_subtour_destination.atwork.logsums with 124 rows
# INFO - atwork_subtour_destination.atwork.logsums.compute_logsums Running adaptive_chunked_choosers with 124 choosers
# INFO - Running chunk 1 of 1 with 124 of 124 choosers
# INFO - Running tour_destination_simulate with 9 persons
# INFO - atwork_subtour_destination.atwork.simulate.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 9 choosers and 124 alternatives
# INFO - Running chunk 1 of 1 with 9 of 9 choosers
# INFO - Running eval_interaction_utilities on 124 rows
# INFO - destination summary:
# count     9.000000
# mean     10.444444
# std       7.333333
# min       2.000000
# 25%       7.000000
# 50%       8.000000
# 75%      15.000000
# max      25.000000
# Name: destination, dtype: float64
# INFO - #run_model running step atwork_subtour_scheduling
# INFO - Running atwork_subtour_scheduling with 9 tours
# INFO - atwork_subtour_scheduling.tour_1 schedule_tours running 9 tour choices
# INFO - atwork_subtour_scheduling.tour_1 Running adaptive_chunked_choosers with 9 choosers
# INFO - Running chunk 1 of 1 with 9 of 9 choosers
# INFO - atwork_subtour_scheduling.tour_1 schedule_tours running 9 tour choices
# INFO - atwork_subtour_scheduling.tour_1.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 9 choosers and 651 alternatives
# INFO - Running chunk 1 of 1 with 9 of 9 choosers
# INFO - Running eval_interaction_utilities on 651 rows
# INFO - #run_model running step atwork_subtour_mode_choice
# INFO - Running atwork_subtour_mode_choice with 9 subtours
# INFO - atwork_subtour_mode_choice tour_type top 10 value counts:
# eat      8
# maint    1
# Name: tour_type, dtype: int64
# INFO - atwork_subtour_mode_choice.simple_simulate Running adaptive_chunked_choosers with 9 choosers
# INFO - Running chunk 1 of 1 with 9 of 9 choosers
# INFO - atwork_subtour_mode_choice choices top 10 value counts:
# WALK    9
# Name: tour_mode, dtype: int64
# INFO - #run_model running step stop_frequency
# INFO - stop_frequency segments top 10 value counts:
# work        69
# shopping    31
# othdiscr    21
# othmaint    20
# school      17
# eatout      16
# univ         9
# atwork       9
# social       7
# escort       3
# Name: primary_purpose, dtype: int64
# INFO - stop_frequency running segment work with 69 chooser rows
# INFO - stop_frequency.work.simple_simulate Running adaptive_chunked_choosers with 69 choosers
# INFO - Running chunk 1 of 1 with 69 of 69 choosers
# INFO - stop_frequency running segment school with 17 chooser rows
# INFO - stop_frequency.school.simple_simulate Running adaptive_chunked_choosers with 17 choosers
# INFO - Running chunk 1 of 1 with 17 of 17 choosers
# INFO - stop_frequency running segment univ with 9 chooser rows
# INFO - stop_frequency.univ.simple_simulate Running adaptive_chunked_choosers with 9 choosers
# INFO - Running chunk 1 of 1 with 9 of 9 choosers
# INFO - stop_frequency running segment social with 7 chooser rows
# INFO - stop_frequency.social.simple_simulate Running adaptive_chunked_choosers with 7 choosers
# INFO - Running chunk 1 of 1 with 7 of 7 choosers
# INFO - stop_frequency running segment shopping with 31 chooser rows
# INFO - stop_frequency.shopping.simple_simulate Running adaptive_chunked_choosers with 31 choosers
# INFO - Running chunk 1 of 1 with 31 of 31 choosers
# INFO - stop_frequency running segment eatout with 16 chooser rows
# INFO - stop_frequency.eatout.simple_simulate Running adaptive_chunked_choosers with 16 choosers
# INFO - Running chunk 1 of 1 with 16 of 16 choosers
# INFO - stop_frequency running segment escort with 3 chooser rows
# INFO - stop_frequency.escort.simple_simulate Running adaptive_chunked_choosers with 3 choosers
# INFO - Running chunk 1 of 1 with 3 of 3 choosers
# INFO - stop_frequency running segment othmaint with 20 chooser rows
# INFO - stop_frequency.othmaint.simple_simulate Running adaptive_chunked_choosers with 20 choosers
# INFO - Running chunk 1 of 1 with 20 of 20 choosers
# INFO - stop_frequency running segment othdiscr with 21 chooser rows
# INFO - stop_frequency.othdiscr.simple_simulate Running adaptive_chunked_choosers with 21 choosers
# INFO - Running chunk 1 of 1 with 21 of 21 choosers
# INFO - stop_frequency running segment atwork with 9 chooser rows
# INFO - stop_frequency.atwork.simple_simulate Running adaptive_chunked_choosers with 9 choosers
# INFO - Running chunk 1 of 1 with 9 of 9 choosers
# INFO - stop_frequency top 10 value counts:
# 0out_0in    157
# 0out_1in     14
# 1out_0in     10
# 0out_2in      8
# 1out_1in      4
# 3out_0in      3
# 1out_3in      2
# 3out_1in      1
# 2out_0in      1
# 2out_2in      1
# dtype: int64
# INFO - #run_model running step trip_purpose
# INFO - assign purpose to 202 last outbound trips
# INFO - assign purpose to 202 last inbound trips
# INFO - assign purpose to 78 intermediate trips
# INFO - trip_purpose Running adaptive_chunked_choosers with 78 choosers
# INFO - Running chunk 1 of 1 with 78 of 78 choosers
# INFO - #run_model running step trip_destination
# INFO - Running trip_destination with 482 trips
# INFO - Running trip_destination.trip_num_1 with 53 trips
# INFO - choose_trip_destination trip_destination.trip_num_1.atwork with 5 trips
# INFO - trip_destination.trip_num_1.atwork.sample.interaction_sample Running adaptive_chunked_choosers with 5 choosers
# INFO - Running chunk 1 of 1 with 5 of 5 choosers
# INFO - Running eval_interaction_utilities on 125 rows
# INFO - Time to execute trip_destination.trip_num_1.atwork.trip_destination_sample : 0.851 seconds (0.0 minutes)
# INFO - Running trip_destination.trip_num_1.atwork.compute_logsums with 68 samples
# INFO - trip_destination.trip_num_1.atwork.compute_logsums.od Running adaptive_chunked_choosers with 68 choosers
# INFO - Running chunk 1 of 1 with 68 of 68 choosers
# INFO - trip_destination.trip_num_1.atwork.compute_logsums.dp Running adaptive_chunked_choosers with 68 choosers
# INFO - Running chunk 1 of 1 with 68 of 68 choosers
# INFO - Time to execute trip_destination.trip_num_1.atwork.compute_logsums : 2.526 seconds (0.0 minutes)
# INFO - Running trip_destination_simulate with 5 trips
# INFO - trip_destination.trip_num_1.atwork.trip_dest_simulate.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 5 choosers and 68 alternatives
# INFO - Running chunk 1 of 1 with 5 of 5 choosers
# INFO - Running eval_interaction_utilities on 68 rows
# INFO - Time to execute trip_destination.trip_num_1.atwork.trip_destination_simulate : 0.771 seconds (0.0 minutes)
# INFO - choose_trip_destination trip_destination.trip_num_1.eatout with 1 trips
# INFO - trip_destination.trip_num_1.eatout.sample.interaction_sample Running adaptive_chunked_choosers with 1 choosers
# INFO - Running chunk 1 of 1 with 1 of 1 choosers
# INFO - Running eval_interaction_utilities on 25 rows
# INFO - Time to execute trip_destination.trip_num_1.eatout.trip_destination_sample : 1.016 seconds (0.0 minutes)
# INFO - Running trip_destination.trip_num_1.eatout.compute_logsums with 15 samples
# INFO - trip_destination.trip_num_1.eatout.compute_logsums.od Running adaptive_chunked_choosers with 15 choosers
# INFO - Running chunk 1 of 1 with 15 of 15 choosers
# INFO - trip_destination.trip_num_1.eatout.compute_logsums.dp Running adaptive_chunked_choosers with 15 choosers
# INFO - Running chunk 1 of 1 with 15 of 15 choosers
# INFO - Time to execute trip_destination.trip_num_1.eatout.compute_logsums : 4.679 seconds (0.1 minutes)
# INFO - Running trip_destination_simulate with 1 trips
# INFO - trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate Running adaptive_chunked_choosers_and_alts with 1 choosers and 15 alternatives
# INFO - Running chunk 1 of 1 with 1 of 1 choosers
# INFO - Running eval_interaction_utilities on 15 rows
# INFO - Time to execute trip_destination.trip_num_1.eatout.trip_destination_simulate : 0.94 seconds (0.0 minutes)
# INFO - choose_trip_destination trip_destination.trip_num_1.othdiscr with 1 trips
# INFO - trip_destination.trip_num_1.othdiscr.sample.interaction_sample Running adaptive_chunked_choosers with 1 choosers
# INFO - Running chunk 1 of 1 with 1 of 1 choosers
# INFO - Running eval_interaction_utilities on 25 rows
# INFO - Time to execute trip_destination.trip_num_1.othdiscr.trip_destination_sample : 0.833 seconds (0.0 minutes)
# INFO - Running trip_destination.trip_num_1.othdiscr.compute_logsums with 15 samples
# INFO - trip_destination.trip_num_1.othdiscr.compute_logsums.od Running adaptive_chunked_choosers with 15 choosers
# INFO - Running chunk 1 of 1 with 15 of 15 choosers
# INFO - trip_destination.trip_num_1.othdiscr.compute_logsums.dp Running adaptive_chunked_choosers with 15 choosers
# INFO - Running chunk 1 of 1 with 15 of 15 choosers
# ...
# INFO - trip_scheduling.i33 2 failed
# INFO - trip_scheduling.i34 scheduling 4 trips
# INFO - trip_scheduling.i34 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i34 2 failed
# INFO - trip_scheduling.i35 scheduling 4 trips
# INFO - trip_scheduling.i35 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i35 2 failed
# INFO - trip_scheduling.i36 scheduling 4 trips
# INFO - trip_scheduling.i36 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i36 2 failed
# INFO - trip_scheduling.i37 scheduling 4 trips
# INFO - trip_scheduling.i37 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i37 2 failed
# INFO - trip_scheduling.i38 scheduling 4 trips
# INFO - trip_scheduling.i38 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i38 2 failed
# INFO - trip_scheduling.i39 scheduling 4 trips
# INFO - trip_scheduling.i39 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i39 2 failed
# INFO - trip_scheduling.i40 scheduling 4 trips
# INFO - trip_scheduling.i40 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i40 2 failed
# INFO - trip_scheduling.i41 scheduling 4 trips
# INFO - trip_scheduling.i41 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i41 2 failed
# INFO - trip_scheduling.i42 scheduling 4 trips
# INFO - trip_scheduling.i42 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i42 2 failed
# INFO - trip_scheduling.i43 scheduling 4 trips
# INFO - trip_scheduling.i43 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i43 2 failed
# INFO - trip_scheduling.i44 scheduling 4 trips
# INFO - trip_scheduling.i44 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i44 2 failed
# INFO - trip_scheduling.i45 scheduling 4 trips
# INFO - trip_scheduling.i45 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i45 2 failed
# INFO - trip_scheduling.i46 scheduling 4 trips
# INFO - trip_scheduling.i46 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i46 2 failed
# INFO - trip_scheduling.i47 scheduling 4 trips
# INFO - trip_scheduling.i47 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i47 2 failed
# INFO - trip_scheduling.i48 scheduling 4 trips
# INFO - trip_scheduling.i48 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i48 2 failed
# INFO - trip_scheduling.i49 scheduling 4 trips
# INFO - trip_scheduling.i49 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i49 2 failed
# INFO - trip_scheduling.i50 scheduling 4 trips
# INFO - trip_scheduling.i50 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i50 2 failed
# INFO - trip_scheduling.i51 scheduling 4 trips
# INFO - trip_scheduling.i51 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i51 2 failed
# INFO - trip_scheduling.i52 scheduling 4 trips
# INFO - trip_scheduling.i52 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i52 2 failed
# INFO - trip_scheduling.i53 scheduling 4 trips
# INFO - trip_scheduling.i53 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i53 2 failed
# INFO - trip_scheduling.i54 scheduling 4 trips
# INFO - trip_scheduling.i54 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i54 2 failed
# INFO - trip_scheduling.i55 scheduling 4 trips
# INFO - trip_scheduling.i55 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i55 2 failed
# INFO - trip_scheduling.i56 scheduling 4 trips
# INFO - trip_scheduling.i56 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i56 2 failed
# INFO - trip_scheduling.i57 scheduling 4 trips
# INFO - trip_scheduling.i57 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i57 2 failed
# INFO - trip_scheduling.i58 scheduling 4 trips
# INFO - trip_scheduling.i58 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i58 2 failed
# INFO - trip_scheduling.i59 scheduling 4 trips
# INFO - trip_scheduling.i59 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i59 2 failed
# INFO - trip_scheduling.i60 scheduling 4 trips
# INFO - trip_scheduling.i60 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i60 2 failed
# INFO - trip_scheduling.i61 scheduling 4 trips
# INFO - trip_scheduling.i61 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i61 2 failed
# INFO - trip_scheduling.i62 scheduling 4 trips
# INFO - trip_scheduling.i62 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i62 2 failed
# INFO - trip_scheduling.i63 scheduling 4 trips
# INFO - trip_scheduling.i63 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i63 2 failed
# INFO - trip_scheduling.i64 scheduling 4 trips
# INFO - trip_scheduling.i64 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i64 2 failed
# INFO - trip_scheduling.i65 scheduling 4 trips
# INFO - trip_scheduling.i65 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i65 2 failed
# INFO - trip_scheduling.i66 scheduling 4 trips
# INFO - trip_scheduling.i66 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i66 2 failed
# INFO - trip_scheduling.i67 scheduling 4 trips
# INFO - trip_scheduling.i67 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i67 2 failed
# INFO - trip_scheduling.i68 scheduling 4 trips
# INFO - trip_scheduling.i68 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i68 2 failed
# INFO - trip_scheduling.i69 scheduling 4 trips
# INFO - trip_scheduling.i69 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i69 2 failed
# INFO - trip_scheduling.i70 scheduling 4 trips
# INFO - trip_scheduling.i70 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i70 2 failed
# INFO - trip_scheduling.i71 scheduling 4 trips
# INFO - trip_scheduling.i71 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i71 2 failed
# INFO - trip_scheduling.i72 scheduling 4 trips
# INFO - trip_scheduling.i72 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i72 2 failed
# INFO - trip_scheduling.i73 scheduling 4 trips
# INFO - trip_scheduling.i73 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i73 2 failed
# INFO - trip_scheduling.i74 scheduling 4 trips
# INFO - trip_scheduling.i74 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i74 2 failed
# INFO - trip_scheduling.i75 scheduling 4 trips
# INFO - trip_scheduling.i75 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i75 2 failed
# INFO - trip_scheduling.i76 scheduling 4 trips
# INFO - trip_scheduling.i76 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i76 2 failed
# INFO - trip_scheduling.i77 scheduling 4 trips
# INFO - trip_scheduling.i77 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i77 2 failed
# INFO - trip_scheduling.i78 scheduling 4 trips
# INFO - trip_scheduling.i78 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i78 2 failed
# INFO - trip_scheduling.i79 scheduling 4 trips
# INFO - trip_scheduling.i79 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i79 2 failed
# INFO - trip_scheduling.i80 scheduling 4 trips
# INFO - trip_scheduling.i80 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i80 2 failed
# INFO - trip_scheduling.i81 scheduling 4 trips
# INFO - trip_scheduling.i81 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i81 2 failed
# INFO - trip_scheduling.i82 scheduling 4 trips
# INFO - trip_scheduling.i82 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i82 2 failed
# INFO - trip_scheduling.i83 scheduling 4 trips
# INFO - trip_scheduling.i83 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i83 2 failed
# INFO - trip_scheduling.i84 scheduling 4 trips
# INFO - trip_scheduling.i84 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i84 2 failed
# INFO - trip_scheduling.i85 scheduling 4 trips
# INFO - trip_scheduling.i85 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i85 2 failed
# INFO - trip_scheduling.i86 scheduling 4 trips
# INFO - trip_scheduling.i86 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i86 2 failed
# INFO - trip_scheduling.i87 scheduling 4 trips
# INFO - trip_scheduling.i87 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i87 2 failed
# INFO - trip_scheduling.i88 scheduling 4 trips
# INFO - trip_scheduling.i88 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i88 2 failed
# INFO - trip_scheduling.i89 scheduling 4 trips
# INFO - trip_scheduling.i89 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i89 2 failed
# INFO - trip_scheduling.i90 scheduling 4 trips
# INFO - trip_scheduling.i90 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i90 2 failed
# INFO - trip_scheduling.i91 scheduling 4 trips
# INFO - trip_scheduling.i91 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i91 2 failed
# INFO - trip_scheduling.i92 scheduling 4 trips
# INFO - trip_scheduling.i92 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i92 2 failed
# INFO - trip_scheduling.i93 scheduling 4 trips
# INFO - trip_scheduling.i93 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i93 2 failed
# INFO - trip_scheduling.i94 scheduling 4 trips
# INFO - trip_scheduling.i94 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i94 2 failed
# INFO - trip_scheduling.i95 scheduling 4 trips
# INFO - trip_scheduling.i95 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i95 2 failed
# INFO - trip_scheduling.i96 scheduling 4 trips
# INFO - trip_scheduling.i96 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i96 2 failed
# INFO - trip_scheduling.i97 scheduling 4 trips
# INFO - trip_scheduling.i97 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i97 2 failed
# INFO - trip_scheduling.i98 scheduling 4 trips
# INFO - trip_scheduling.i98 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i98 2 failed
# INFO - trip_scheduling.i99 scheduling 4 trips
# INFO - trip_scheduling.i99 Running chunk 1 of 1 with 28 of 28 choosers
# INFO - trip_scheduling.i99 2 failed
# INFO - trip_scheduling.i100 scheduling 4 trips
# INFO - trip_scheduling.i100 Running chunk 1 of 1 with 28 of 28 choosers
# WARNING - trip_scheduling.i100.outbound.num_2 coercing 0 depart choices to most initial
# INFO - dumping trip_scheduling.i100.outbound.num_3.failed_choosers
# WARNING - trip_scheduling.i100.outbound.num_3 coercing 1 depart choices to most initial
# INFO - dumping trip_scheduling.i100.outbound.num_4.failed_choosers
# WARNING - trip_scheduling.i100.outbound.num_4 coercing 1 depart choices to most initial
# INFO - trip_scheduling.i100 0 failed
# INFO - #run_model running step trip_mode_choice
# INFO - Running trip_mode_choice with 482 trips
# INFO - primary_purpose top 10 value counts:
# work        168
# shopping     77
# othmaint     46
# othdiscr     43
# school       37
# eatout       33
# atwork       27
# univ         26
# social       19
# escort        6
# Name: primary_purpose, dtype: int64
# INFO - trip_mode_choice tour_type 'atwork' (27 trips)
# INFO - trip_mode_choice.atwork.simple_simulate Running adaptive_chunked_choosers with 27 choosers
# INFO - Running chunk 1 of 1 with 27 of 27 choosers
# WARNING - slice_canonically: no rows in trip_mode_choice.atwork.trip_mode with household_id == [982875]
# INFO - trip_mode_choice tour_type 'eatout' (33 trips)
# INFO - trip_mode_choice.eatout.simple_simulate Running adaptive_chunked_choosers with 33 choosers
# INFO - Running chunk 1 of 1 with 33 of 33 choosers
# INFO - trip_mode_choice tour_type 'escort' (6 trips)
# INFO - trip_mode_choice.escort.simple_simulate Running adaptive_chunked_choosers with 6 choosers
# INFO - Running chunk 1 of 1 with 6 of 6 choosers
# WARNING - slice_canonically: no rows in trip_mode_choice.escort.trip_mode with household_id == [982875]
# INFO - trip_mode_choice tour_type 'othdiscr' (43 trips)
# INFO - trip_mode_choice.othdiscr.simple_simulate Running adaptive_chunked_choosers with 43 choosers
# INFO - Running chunk 1 of 1 with 43 of 43 choosers
# WARNING - slice_canonically: no rows in trip_mode_choice.othdiscr.trip_mode with household_id == [982875]
# INFO - trip_mode_choice tour_type 'othmaint' (46 trips)
# INFO - trip_mode_choice.othmaint.simple_simulate Running adaptive_chunked_choosers with 46 choosers
# INFO - Running chunk 1 of 1 with 46 of 46 choosers
# WARNING - slice_canonically: no rows in trip_mode_choice.othmaint.trip_mode with household_id == [982875]
# INFO - trip_mode_choice tour_type 'school' (37 trips)
# INFO - trip_mode_choice.school.simple_simulate Running adaptive_chunked_choosers with 37 choosers
# INFO - Running chunk 1 of 1 with 37 of 37 choosers
# WARNING - slice_canonically: no rows in trip_mode_choice.school.trip_mode with household_id == [982875]
# INFO - trip_mode_choice tour_type 'shopping' (77 trips)
# INFO - trip_mode_choice.shopping.simple_simulate Running adaptive_chunked_choosers with 77 choosers
# INFO - Running chunk 1 of 1 with 77 of 77 choosers
# WARNING - slice_canonically: no rows in trip_mode_choice.shopping.trip_mode with household_id == [982875]
# INFO - trip_mode_choice tour_type 'social' (19 trips)
# INFO - trip_mode_choice.social.simple_simulate Running adaptive_chunked_choosers with 19 choosers
# INFO - Running chunk 1 of 1 with 19 of 19 choosers
# WARNING - slice_canonically: no rows in trip_mode_choice.social.trip_mode with household_id == [982875]
# INFO - trip_mode_choice tour_type 'univ' (26 trips)
# INFO - trip_mode_choice.univ.simple_simulate Running adaptive_chunked_choosers with 26 choosers
# INFO - Running chunk 1 of 1 with 26 of 26 choosers
# WARNING - slice_canonically: no rows in trip_mode_choice.univ.trip_mode with household_id == [982875]
# INFO - trip_mode_choice tour_type 'work' (168 trips)
# INFO - trip_mode_choice.work.simple_simulate Running adaptive_chunked_choosers with 168 choosers
# INFO - Running chunk 1 of 1 with 168 of 168 choosers
# INFO - trip_modes top 10 value counts:
# WALK              211
# WALK_LRF           80
# WALK_LOC           64
# TNC_SINGLE         38
# DRIVEALONEFREE     27
# BIKE               18
# TAXI               15
# WALK_HVY           14
# SHARED3FREE         6
# SHARED2FREE         6
# Name: tour_mode, dtype: int64
# INFO - trip_mode_choice choices top 10 value counts:
# WALK              304
# WALK_LOC           85
# WALK_LRF           53
# BIKE               17
# TNC_SHARED          4
# DRIVEALONEFREE      4
# WALK_HVY            4
# TNC_SINGLE          4
# SHARED2FREE         4
# TAXI                2
# Name: trip_mode, dtype: int64
# INFO - #run_model running step write_data_dictionary
# INFO - #run_model running step track_skim_usage
# INFO - #run_model running step write_trip_matrices
# INFO - adding 'sample_rate' from households to trips table
# INFO - aggregating trips one zone...
# INFO - opening output\trips_ea.omx
# INFO - adding zone_id mapping for 25 zones to trips_ea.omx
# INFO - closing output\trips_ea.omx
# INFO - opening output\trips_am.omx
# INFO - adding zone_id mapping for 25 zones to trips_am.omx
# INFO - closing output\trips_am.omx
# INFO - opening output\trips_md.omx
# INFO - adding zone_id mapping for 25 zones to trips_md.omx
# INFO - closing output\trips_md.omx
# INFO - opening output\trips_pm.omx
# INFO - adding zone_id mapping for 25 zones to trips_pm.omx
# INFO - closing output\trips_pm.omx
# INFO - opening output\trips_ev.omx
# INFO - adding zone_id mapping for 25 zones to trips_ev.omx
# INFO - closing output\trips_ev.omx
# INFO - #run_model running step write_tables
# INFO - Time to execute run_model (33 models) : 382.13 seconds (6.4 minutes)
# INFO - MainProcess high water mark rss: 166_891_520 (166.9 MB) timestamp: 03/06/2021 06:51:56 label:tt.adjacent_window_run_length.add.mask
# INFO - MainProcess high water mark uss: 150_724_608 (150.7 MB) timestamp: 03/06/2021 06:51:56 label:tt.adjacent_window_run_length.add.mask
# INFO - MainProcess high water mark bytes: 7_475_552 (7.5 MB) timestamp: 03/06/2021 06:51:56 label:tt.adjacent_window_run_length.add.available_run_length
# INFO - Time to execute all models : 382.256 seconds (6.4 minutes)

# %% [markdown]
# # Inputs and Outputs Overview
#
# An ActivitySim model requires:
#
# *  Configs: settings, model step expressions files, etc.​
#   * settings.yaml - main settings file for running the model
#   * network_los.yaml - network level-of-service (skims) settings file
#   * [model].yaml - configuration file for the model step (such as auto ownership)
#   * [model].csv - expressions file for the model step
# *  Data: input data - input data tables and skims​
#   * land_use.csv - zone data file
#   * households.csv - synthethic households
#   * persons.csv - synthethic persons
#   * skims.omx - all skims in one open matrix file
# *  Output: output data - output data, tables, tracing info, etc.
#   * pipeline.h5 - data pipeline database file (all tables at each model step)
#   * final_[table].csv - final household, person, tour, trip CSV tables
#   * activitysim.log - console log file
#   * trace.[model].csv - trace calculations for select households
# *  simulation.py: main script to run the model
#
# Run the command below to list the example folder contents.

# %%
import os
for root, dirs, files in os.walk(".", topdown=False):
   for name in files:
      print(os.path.join(root, name))
   for name in dirs:
      print(os.path.join(root, name))
# Out:
# .\configs\accessibility.csv
# .\configs\accessibility.yaml
# .\configs\annotate_households.csv
# .\configs\annotate_households_cdap.csv
# .\configs\annotate_households_workplace.csv
# .\configs\annotate_landuse.csv
# .\configs\annotate_persons.csv
# .\configs\annotate_persons_after_hh.csv
# .\configs\annotate_persons_cdap.csv
# .\configs\annotate_persons_jtp.csv
# .\configs\annotate_persons_mtf.csv
# .\configs\annotate_persons_nmtf.csv
# .\configs\annotate_persons_school.csv
# .\configs\annotate_persons_workplace.csv
# .\configs\atwork_subtour_destination.csv
# .\configs\atwork_subtour_destination.yaml
# .\configs\atwork_subtour_destination_coefficients.csv
# .\configs\atwork_subtour_destination_sample.csv
# .\configs\atwork_subtour_frequency.csv
# .\configs\atwork_subtour_frequency.yaml
# .\configs\atwork_subtour_frequency_alternatives.csv
# .\configs\atwork_subtour_frequency_annotate_tours_preprocessor.csv
# .\configs\atwork_subtour_frequency_coefficients.csv
# .\configs\auto_ownership.csv
# .\configs\auto_ownership.yaml
# .\configs\auto_ownership_coefficients.csv
# .\configs\cdap.yaml
# .\configs\cdap_coefficients.csv
# .\configs\cdap_fixed_relative_proportions.csv
# .\configs\cdap_indiv_and_hhsize1.csv
# .\configs\cdap_interaction_coefficients.csv
# .\configs\constants.yaml
# .\configs\destination_choice_size_terms.csv
# .\configs\free_parking.csv
# .\configs\free_parking.yaml
# .\configs\free_parking_annotate_persons_preprocessor.csv
# .\configs\free_parking_coefficients.csv
# .\configs\initialize_households.yaml
# .\configs\initialize_landuse.yaml
# .\configs\joint_tour_composition.csv
# .\configs\joint_tour_composition.yaml
# .\configs\joint_tour_composition_annotate_households_preprocessor.csv
# .\configs\joint_tour_composition_coefficients.csv
# .\configs\joint_tour_destination.yaml
# .\configs\joint_tour_frequency.csv
# .\configs\joint_tour_frequency.yaml
# .\configs\joint_tour_frequency_alternatives.csv
# .\configs\joint_tour_frequency_annotate_households_preprocessor.csv
# .\configs\joint_tour_frequency_coefficients.csv
# .\configs\joint_tour_participation.csv
# .\configs\joint_tour_participation.yaml
# .\configs\joint_tour_participation_annotate_participants_preprocessor.csv
# .\configs\joint_tour_participation_coefficients.csv
# .\configs\joint_tour_scheduling.yaml
# .\configs\joint_tour_scheduling_annotate_tours_preprocessor.csv
# .\configs\logging.yaml
# .\configs\mandatory_tour_frequency.csv
# .\configs\mandatory_tour_frequency.yaml
# .\configs\mandatory_tour_frequency_alternatives.csv
# .\configs\mandatory_tour_frequency_coefficients.csv
# .\configs\mandatory_tour_scheduling.yaml
# .\configs\network_los.yaml
# .\configs\non_mandatory_tour_destination.csv
# .\configs\non_mandatory_tour_destination.yaml
# .\configs\non_mandatory_tour_destination_coefficients.csv
# .\configs\non_mandatory_tour_destination_sample.csv
# .\configs\non_mandatory_tour_frequency.csv
# .\configs\non_mandatory_tour_frequency.yaml
# .\configs\non_mandatory_tour_frequency_alternatives.csv
# .\configs\non_mandatory_tour_frequency_annotate_persons_preprocessor.csv
# .\configs\non_mandatory_tour_frequency_coefficients_PTYPE_DRIVING.csv
# .\configs\non_mandatory_tour_frequency_coefficients_PTYPE_FULL.csv
# .\configs\non_mandatory_tour_frequency_coefficients_PTYPE_NONWORK.csv
# .\configs\non_mandatory_tour_frequency_coefficients_PTYPE_PART.csv
# .\configs\non_mandatory_tour_frequency_coefficients_PTYPE_PRESCHOOL.csv
# .\configs\non_mandatory_tour_frequency_coefficients_PTYPE_RETIRED.csv
# .\configs\non_mandatory_tour_frequency_coefficients_PTYPE_SCHOOL.csv
# .\configs\non_mandatory_tour_frequency_coefficients_PTYPE_UNIVERSITY.csv
# .\configs\non_mandatory_tour_frequency_extension_probs.csv
# .\configs\non_mandatory_tour_scheduling.yaml
# .\configs\non_mandatory_tour_scheduling_annotate_tours_preprocessor.csv
# .\configs\school_location.csv
# .\configs\school_location.yaml
# .\configs\school_location_coefficients.csv
# .\configs\school_location_sample.csv
# .\configs\settings.yaml
# .\configs\shadow_pricing.yaml
# .\configs\stop_frequency.yaml
# .\configs\stop_frequency_alternatives.csv
# .\configs\stop_frequency_annotate_tours_preprocessor.csv
# .\configs\stop_frequency_atwork.csv
# .\configs\stop_frequency_coefficients_atwork.csv
# .\configs\stop_frequency_coefficients_eatout.csv
# .\configs\stop_frequency_coefficients_escort.csv
# .\configs\stop_frequency_coefficients_othdiscr.csv
# .\configs\stop_frequency_coefficients_othmaint.csv
# .\configs\stop_frequency_coefficients_school.csv
# .\configs\stop_frequency_coefficients_shopping.csv
# .\configs\stop_frequency_coefficients_social.csv
# .\configs\stop_frequency_coefficients_univ.csv
# .\configs\stop_frequency_coefficients_work.csv
# .\configs\stop_frequency_eatout.csv
# .\configs\stop_frequency_escort.csv
# .\configs\stop_frequency_othdiscr.csv
# .\configs\stop_frequency_othmaint.csv
# .\configs\stop_frequency_school.csv
# .\configs\stop_frequency_shopping.csv
# .\configs\stop_frequency_social.csv
# .\configs\stop_frequency_univ.csv
# .\configs\stop_frequency_work.csv
# .\configs\tour_departure_and_duration_alternatives.csv
# .\configs\tour_departure_and_duration_segments.csv
# .\configs\tour_mode_choice.csv
# .\configs\tour_mode_choice.yaml
# .\configs\tour_mode_choice_annotate_choosers_preprocessor.csv
# .\configs\tour_mode_choice_coefficients.csv
# .\configs\tour_mode_choice_coefficients_template.csv
# .\configs\tour_scheduling_atwork.csv
# .\configs\tour_scheduling_atwork.yaml
# .\configs\tour_scheduling_atwork_coefficients.csv
# .\configs\tour_scheduling_atwork_preprocessor.csv
# .\configs\tour_scheduling_joint.csv
# .\configs\tour_scheduling_joint_coefficients.csv
# .\configs\tour_scheduling_nonmandatory.csv
# .\configs\tour_scheduling_nonmandatory_coefficients.csv
# .\configs\tour_scheduling_school.csv
# .\configs\tour_scheduling_school_coefficients.csv
# .\configs\tour_scheduling_work.csv
# .\configs\tour_scheduling_work_coefficients.csv
# .\configs\trip_destination.csv
# .\configs\trip_destination.yaml
# .\configs\trip_destination_annotate_trips_preprocessor.csv
# .\configs\trip_destination_coefficients.csv
# .\configs\trip_destination_sample.csv
# .\configs\trip_mode_choice.csv
# .\configs\trip_mode_choice.yaml
# .\configs\trip_mode_choice_annotate_trips_preprocessor.csv
# .\configs\trip_mode_choice_coefficients.csv
# .\configs\trip_mode_choice_coefficients_template.csv
# .\configs\trip_purpose.yaml
# .\configs\trip_purpose_and_destination.yaml
# .\configs\trip_purpose_annotate_trips_preprocessor.csv
# .\configs\trip_purpose_probs.csv
# .\configs\trip_scheduling.yaml
# .\configs\trip_scheduling_probs.csv
# .\configs\workplace_location.csv
# .\configs\workplace_location.yaml
# .\configs\workplace_location_coefficients.csv
# .\configs\workplace_location_sample.csv
# .\configs\write_data_dictionary.yaml
# .\configs\write_trip_matrices.yaml
# .\configs\write_trip_matrices_annotate_trips_preprocessor.csv
# .\configs_mp\logging.yaml
# .\configs_mp\settings.yaml
# .\data\.gitignore
# .\data\households.csv
# .\data\land_use.csv
# .\data\mtc_asim.h5
# .\data\override_hh_ids.csv
# .\data\persons.csv
# .\data\skims.omx
# .\output\cache\.gitignore
# .\output\cache\cached_taz.mmap
# .\output\cache\chunk_cache.csv
# .\output\log\.gitignore
# .\output\log\activitysim.log
# .\output\log\chunk_cache.csv
# .\output\log\chunk_history.csv
# .\output\log\mem.csv
# .\output\log\omnibus_chunk_history.csv
# .\output\log\timing_log.csv
# .\output\trace\.gitignore
# .\output\trace\atwork_subtour_destination.csv
# .\output\trace\atwork_subtour_frequency.atwork_subtour_frequency_annotate_tours_preprocessor.csv
# .\output\trace\atwork_subtour_frequency.atwork_subtour_frequency_annotate_tours_preprocessor_locals.csv
# .\output\trace\atwork_subtour_frequency.simple_simulate.eval_mnl.choices.csv
# .\output\trace\atwork_subtour_frequency.simple_simulate.eval_mnl.choosers.csv
# .\output\trace\atwork_subtour_frequency.simple_simulate.eval_mnl.eval_utils.expression_values.csv
# .\output\trace\atwork_subtour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_business1.csv
# .\output\trace\atwork_subtour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_business2.csv
# .\output\trace\atwork_subtour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_eat.csv
# .\output\trace\atwork_subtour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_eat_business.csv
# .\output\trace\atwork_subtour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_maint.csv
# .\output\trace\atwork_subtour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_no_subtours.csv
# .\output\trace\atwork_subtour_frequency.simple_simulate.eval_mnl.probs.csv
# .\output\trace\atwork_subtour_frequency.simple_simulate.eval_mnl.rands.csv
# .\output\trace\atwork_subtour_frequency.simple_simulate.eval_mnl.utilities.csv
# .\output\trace\atwork_subtour_frequency.tours.csv
# .\output\trace\auto_ownership.csv
# .\output\trace\auto_ownership_simulate.simple_simulate.eval_mnl.choices.csv
# .\output\trace\auto_ownership_simulate.simple_simulate.eval_mnl.choosers.csv
# .\output\trace\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_values.csv
# .\output\trace\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars0.csv
# .\output\trace\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars1.csv
# .\output\trace\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars2.csv
# .\output\trace\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars3.csv
# .\output\trace\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars4.csv
# .\output\trace\auto_ownership_simulate.simple_simulate.eval_mnl.probs.csv
# .\output\trace\auto_ownership_simulate.simple_simulate.eval_mnl.rands.csv
# .\output\trace\auto_ownership_simulate.simple_simulate.eval_mnl.utilities.csv
# .\output\trace\cdap.annotate_households.annotate_households_cdap.csv
# .\output\trace\cdap.annotate_persons.annotate_persons_cdap.csv
# .\output\trace\cdap.cdap.cdap_rank.csv
# .\output\trace\cdap.cdap.hhsize2_activity_choices.csv
# .\output\trace\cdap.cdap.hhsize2_choosers.csv
# .\output\trace\cdap.cdap.hhsize2_probs.csv
# .\output\trace\cdap.cdap.hhsize2_rands.csv
# .\output\trace\cdap.cdap.hhsize2_utils.csv
# .\output\trace\cdap.cdap.indiv_utils.csv
# .\output\trace\cdap.csv
# .\output\trace\free_parking.csv
# .\output\trace\free_parking.free_parking_annotate_persons_preprocessor.csv
# .\output\trace\free_parking.simple_simulate.eval_mnl.choices.csv
# .\output\trace\free_parking.simple_simulate.eval_mnl.choosers.csv
# .\output\trace\free_parking.simple_simulate.eval_mnl.eval_utils.expression_values.csv
# .\output\trace\free_parking.simple_simulate.eval_mnl.eval_utils.expression_value_free.csv
# .\output\trace\free_parking.simple_simulate.eval_mnl.eval_utils.expression_value_pay.csv
# .\output\trace\free_parking.simple_simulate.eval_mnl.probs.csv
# .\output\trace\free_parking.simple_simulate.eval_mnl.rands.csv
# .\output\trace\free_parking.simple_simulate.eval_mnl.utilities.csv
# .\output\trace\initialize_households.annotate_tables.annotate_households.csv
# .\output\trace\initialize_households.annotate_tables.annotate_households_locals.csv
# .\output\trace\initialize_households.annotate_tables.annotate_persons.csv
# .\output\trace\initialize_households.annotate_tables.annotate_persons_after_hh.csv
# .\output\trace\joint_tour_frequency.households.csv
# .\output\trace\joint_tour_frequency.joint_tour_frequency_annotate_households_preprocessor.csv
# .\output\trace\joint_tour_frequency.joint_tour_frequency_annotate_households_preprocessor_locals.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.choices.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.choosers.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_values.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_0_tours.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_1_Disc.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_1_Eat.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_1_Main.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_1_Shop.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_1_Visit.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_DD.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_ED.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_EE.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_EV.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_MD.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_ME.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_MM.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_MV.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_SD.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_SE.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_SM.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_SS.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_SV.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_VD.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_VV.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.probs.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.rands.csv
# .\output\trace\joint_tour_frequency.simple_simulate.eval_mnl.utilities.csv
# .\output\trace\joint_tour_participation.annotate_persons.annotate_persons_jtp.csv
# .\output\trace\mandatory_tour_frequency.annotate_persons.annotate_persons_mtf.csv
# .\output\trace\mandatory_tour_frequency.annotate_persons.annotate_persons_mtf_locals.csv
# .\output\trace\mandatory_tour_frequency.mandatory_tours.csv
# .\output\trace\mandatory_tour_frequency.persons.csv
# .\output\trace\mandatory_tour_frequency.simple_simulate.eval_mnl.choices.csv
# .\output\trace\mandatory_tour_frequency.simple_simulate.eval_mnl.choosers.csv
# .\output\trace\mandatory_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_values.csv
# .\output\trace\mandatory_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_school1.csv
# .\output\trace\mandatory_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_school2.csv
# .\output\trace\mandatory_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_work1.csv
# .\output\trace\mandatory_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_work2.csv
# .\output\trace\mandatory_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_work_and_school.csv
# .\output\trace\mandatory_tour_frequency.simple_simulate.eval_mnl.probs.csv
# .\output\trace\mandatory_tour_frequency.simple_simulate.eval_mnl.rands.csv
# .\output\trace\mandatory_tour_frequency.simple_simulate.eval_mnl.utilities.csv
# .\output\trace\mandatory_tour_scheduling.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.choosers.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_values.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_BIKE.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEFREE.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEPAY.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_COM.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_EXP.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_HVY.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LOC.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LRF.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2FREE.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2PAY.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3FREE.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3PAY.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_TAXI.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SHARED.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SINGLE.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_WALK.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_WALK_COM.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_WALK_EXP.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_WALK_HVY.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LOC.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LRF.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.logsums.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.nested_exp_utilities.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.raw_utilities.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.tour_mode_choice_annotate_choosers_preprocessor.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.tour_mode_choice_annotate_choosers_preprocessor_locals.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.alternatives.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.choices.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.choosers.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.eval.household_id.982875.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.eval.raw.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.interaction_df.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.interaction_utilities.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.probs.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.rands.csv
# .\output\trace\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.utilities.csv
# .\output\trace\non_mandatory_tour_destination.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.choosers.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_values.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_BIKE.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEFREE.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEPAY.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_COM.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_EXP.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_HVY.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LOC.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LRF.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2FREE.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2PAY.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3FREE.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3PAY.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TAXI.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SHARED.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SINGLE.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_COM.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_EXP.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_HVY.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LOC.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LRF.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.logsums.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.nested_exp_utilities.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.raw_utilities.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.tour_mode_choice_annotate_choosers_preprocessor.csv
# .\output\trace\non_mandatory_tour_destination.eatout.logsums.compute_logsums.tour_mode_choice_annotate_choosers_preprocessor_locals.csv
# .\output\trace\non_mandatory_tour_destination.eatout.sample.interaction_sample.alternatives.csv
# .\output\trace\non_mandatory_tour_destination.eatout.sample.interaction_sample.choosers.csv
# .\output\trace\non_mandatory_tour_destination.eatout.sample.interaction_sample.eval.person_id.1875722.csv
# .\output\trace\non_mandatory_tour_destination.eatout.sample.interaction_sample.eval.raw.csv
# .\output\trace\non_mandatory_tour_destination.eatout.sample.interaction_sample.interaction_df.csv
# .\output\trace\non_mandatory_tour_destination.eatout.sample.interaction_sample.interaction_utilities.csv
# .\output\trace\non_mandatory_tour_destination.eatout.sample.interaction_sample.probs.csv
# .\output\trace\non_mandatory_tour_destination.eatout.sample.interaction_sample.sampled_alternatives.csv
# .\output\trace\non_mandatory_tour_destination.eatout.sample.interaction_sample.utils.csv
# .\output\trace\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.alternatives.csv
# .\output\trace\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.choices.csv
# .\output\trace\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.choosers.csv
# .\output\trace\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.eval.person_id.1875722.csv
# .\output\trace\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.eval.raw.csv
# .\output\trace\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.interaction_df.csv
# .\output\trace\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.interaction_utilities.csv
# .\output\trace\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.logsum.csv
# .\output\trace\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.probs.csv
# .\output\trace\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.rands.csv
# .\output\trace\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.utilities.csv
# .\output\trace\non_mandatory_tour_frequency.annotated_persons.csv
# .\output\trace\non_mandatory_tour_frequency.annotate_persons_nmtf.csv
# .\output\trace\non_mandatory_tour_frequency.choosers.csv
# .\output\trace\non_mandatory_tour_frequency.extend_tour_counts.eatout.choices.csv
# .\output\trace\non_mandatory_tour_frequency.extend_tour_counts.eatout.rands.csv
# .\output\trace\non_mandatory_tour_frequency.non_mandatory_tours.csv
# .\output\trace\non_mandatory_tour_frequency.non_mandatory_tour_frequency_annotate_persons_preprocessor.csv
# .\output\trace\non_mandatory_tour_frequency.non_mandatory_tour_frequency_annotate_persons_preprocessor_locals.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.alternatives.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.choices.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.choosers.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.eval.person_id.1875721.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.eval.raw.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.interaction_df.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.interaction_utils.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.probs.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.rands.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.utils.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.alternatives.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.choices.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.choosers.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.eval.person_id.1875722.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.eval.raw.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.interaction_df.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.interaction_utils.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.probs.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.rands.csv
# .\output\trace\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.utils.csv
# .\output\trace\non_mandatory_tour_scheduling.csv
# .\output\trace\non_mandatory_tour_scheduling.non_mandatory_tour_scheduling_annotate_tours_preprocessor.csv
# .\output\trace\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.alternatives.csv
# .\output\trace\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.choices.csv
# .\output\trace\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.choosers.csv
# .\output\trace\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.eval.household_id.982875.csv
# .\output\trace\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.eval.raw.csv
# .\output\trace\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.interaction_df.csv
# .\output\trace\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.interaction_utilities.csv
# .\output\trace\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.probs.csv
# .\output\trace\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.rands.csv
# .\output\trace\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.utilities.csv
# .\output\trace\raw.households.csv
# .\output\trace\raw.persons.csv
# .\output\trace\school_location.annotate_persons.annotate_persons_school.csv
# .\output\trace\school_location.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.choosers.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_values.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_BIKE.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEFREE.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEPAY.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_COM.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_EXP.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_HVY.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LOC.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LRF.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2FREE.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2PAY.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3FREE.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3PAY.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TAXI.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SHARED.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SINGLE.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_COM.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_EXP.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_HVY.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LOC.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LRF.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.logsums.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.nested_exp_utilities.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.raw_utilities.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.tour_mode_choice_annotate_choosers_preprocessor.csv
# .\output\trace\school_location.i1.logsums.university.compute_logsums.tour_mode_choice_annotate_choosers_preprocessor_locals.csv
# .\output\trace\school_location.i1.sample.university.interaction_sample.alternatives.csv
# .\output\trace\school_location.i1.sample.university.interaction_sample.choosers.csv
# .\output\trace\school_location.i1.sample.university.interaction_sample.eval.person_id.1875722.csv
# .\output\trace\school_location.i1.sample.university.interaction_sample.eval.raw.csv
# .\output\trace\school_location.i1.sample.university.interaction_sample.interaction_df.csv
# .\output\trace\school_location.i1.sample.university.interaction_sample.interaction_utilities.csv
# .\output\trace\school_location.i1.sample.university.interaction_sample.probs.csv
# .\output\trace\school_location.i1.sample.university.interaction_sample.sampled_alternatives.csv
# .\output\trace\school_location.i1.sample.university.interaction_sample.utils.csv
# .\output\trace\school_location.i1.simulate.university.interaction_sample_simulate.alternatives.csv
# .\output\trace\school_location.i1.simulate.university.interaction_sample_simulate.choices.csv
# .\output\trace\school_location.i1.simulate.university.interaction_sample_simulate.choosers.csv
# .\output\trace\school_location.i1.simulate.university.interaction_sample_simulate.eval.person_id.1875722.csv
# .\output\trace\school_location.i1.simulate.university.interaction_sample_simulate.eval.raw.csv
# .\output\trace\school_location.i1.simulate.university.interaction_sample_simulate.interaction_df.csv
# .\output\trace\school_location.i1.simulate.university.interaction_sample_simulate.interaction_utilities.csv
# .\output\trace\school_location.i1.simulate.university.interaction_sample_simulate.logsum.csv
# .\output\trace\school_location.i1.simulate.university.interaction_sample_simulate.probs.csv
# .\output\trace\school_location.i1.simulate.university.interaction_sample_simulate.rands.csv
# .\output\trace\school_location.i1.simulate.university.interaction_sample_simulate.utilities.csv
# .\output\trace\shadow_price_school_desired_size.csv
# .\output\trace\shadow_price_school_modeled_size_1.csv
# .\output\trace\shadow_price_workplace_desired_size.csv
# .\output\trace\shadow_price_workplace_modeled_size_1.csv
# .\output\trace\stop_frequency.annotations.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.choices.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.choosers.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_values.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_0out_0in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_0out_1in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_0out_2in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_0out_3in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_1out_0in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_1out_1in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_1out_2in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_1out_3in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_2out_0in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_2out_1in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_2out_2in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_2out_3in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_3out_0in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_3out_1in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_3out_2in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_3out_3in.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.probs.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.rands.csv
# .\output\trace\stop_frequency.eatout.simple_simulate.eval_mnl.utilities.csv
# .\output\trace\stop_frequency.stop_frequency_annotate_tours_preprocessor.csv
# .\output\trace\stop_frequency.stop_frequency_annotate_tours_preprocessor_locals.csv
# .\output\trace\stop_frequency.tours.csv
# .\output\trace\stop_frequency.tours_merged.csv
# .\output\trace\stop_frequency.trips.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.choices.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.choosers.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_values.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_0out_0in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_0out_1in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_0out_2in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_0out_3in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_1out_0in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_1out_1in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_1out_2in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_1out_3in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_2out_0in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_2out_1in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_2out_2in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_2out_3in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_3out_0in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_3out_1in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_3out_2in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_3out_3in.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.probs.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.rands.csv
# .\output\trace\stop_frequency.work.simple_simulate.eval_mnl.utilities.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.base_probabilities.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.choices.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.choosers.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_values.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_BIKE.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEFREE.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEPAY.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_COM.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_EXP.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_HVY.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LOC.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LRF.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2FREE.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2PAY.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3FREE.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3PAY.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_TAXI.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SHARED.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SINGLE.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_COM.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_EXP.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_HVY.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LOC.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LRF.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.logsums.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.nested_exp_utilities.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.nested_probabilities.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.rands.csv
# .\output\trace\tour_mode_choice.eatout.simple_simulate.eval_nl.raw_utilities.csv
# .\output\trace\tour_mode_choice.eatout.tour_mode_choice_annotate_choosers_preprocessor.csv
# .\output\trace\tour_mode_choice.eatout.tour_mode_choice_annotate_choosers_preprocessor_locals.csv
# .\output\trace\tour_mode_choice.tour_mode.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.base_probabilities.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.choices.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.choosers.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_values.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_BIKE.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEFREE.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEPAY.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_COM.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_EXP.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_HVY.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LOC.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LRF.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2FREE.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2PAY.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3FREE.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3PAY.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_TAXI.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SHARED.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SINGLE.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_COM.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_EXP.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_HVY.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LOC.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LRF.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.logsums.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.nested_exp_utilities.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.nested_probabilities.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.rands.csv
# .\output\trace\tour_mode_choice.work.simple_simulate.eval_nl.raw_utilities.csv
# .\output\trace\tour_mode_choice.work.tour_mode_choice_annotate_choosers_preprocessor.csv
# .\output\trace\tour_mode_choice.work.tour_mode_choice_annotate_choosers_preprocessor_locals.csv
# .\output\trace\trip_destination.csv
# .\output\trace\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.choosers.csv
# .\output\trace\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_values.csv
# .\output\trace\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_BIKE.csv
# .\output\trace\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEFREE.csv
# ...
# .\output\trace\trip_destination.trip_num_1.eatout.sample.interaction_sample.choosers.csv
# .\output\trace\trip_destination.trip_num_1.eatout.sample.interaction_sample.eval.household_id.982875.csv
# .\output\trace\trip_destination.trip_num_1.eatout.sample.interaction_sample.eval.raw.csv
# .\output\trace\trip_destination.trip_num_1.eatout.sample.interaction_sample.interaction_df.csv
# .\output\trace\trip_destination.trip_num_1.eatout.sample.interaction_sample.interaction_utilities.csv
# .\output\trace\trip_destination.trip_num_1.eatout.sample.interaction_sample.probs.csv
# .\output\trace\trip_destination.trip_num_1.eatout.sample.interaction_sample.sampled_alternatives.csv
# .\output\trace\trip_destination.trip_num_1.eatout.sample.interaction_sample.utils.csv
# .\output\trace\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.alternatives.csv
# .\output\trace\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.choices.csv
# .\output\trace\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.choosers.csv
# .\output\trace\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.eval.household_id.982875.csv
# .\output\trace\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.eval.raw.csv
# .\output\trace\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.interaction_df.csv
# .\output\trace\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.interaction_utilities.csv
# .\output\trace\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.logsum.csv
# .\output\trace\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.probs.csv
# .\output\trace\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.rands.csv
# .\output\trace\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.utilities.csv
# .\output\trace\trip_destination.trip_num_1.trip_destination_annotate_trips_preprocessor.csv
# .\output\trace\trip_matrices.write_trip_matrices_annotate_trips_preprocessor.csv
# .\output\trace\trip_mode_choice.atwork.constants.csv
# .\output\trace\trip_mode_choice.eatout.constants.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.base_probabilities.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.choices.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.choosers.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_values.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_BIKE.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEFREE.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEPAY.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_COM.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_EXP.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_HVY.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LOC.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LRF.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2FREE.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2PAY.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3FREE.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3PAY.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_TAXI.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SHARED.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SINGLE.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_COM.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_EXP.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_HVY.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LOC.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LRF.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.logsums.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.nested_exp_utilities.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.nested_probabilities.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.rands.csv
# .\output\trace\trip_mode_choice.eatout.simple_simulate.eval_nl.raw_utilities.csv
# .\output\trace\trip_mode_choice.eatout.trip_mode.csv
# .\output\trace\trip_mode_choice.eatout.trip_mode_choice_annotate_trips_preprocessor.csv
# .\output\trace\trip_mode_choice.escort.constants.csv
# .\output\trace\trip_mode_choice.othdiscr.constants.csv
# .\output\trace\trip_mode_choice.othmaint.constants.csv
# .\output\trace\trip_mode_choice.school.constants.csv
# .\output\trace\trip_mode_choice.shopping.constants.csv
# .\output\trace\trip_mode_choice.social.constants.csv
# .\output\trace\trip_mode_choice.trip_mode.csv
# .\output\trace\trip_mode_choice.univ.constants.csv
# .\output\trace\trip_mode_choice.work.constants.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.base_probabilities.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.choices.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.choosers.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_values.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_BIKE.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEFREE.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEPAY.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_COM.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_EXP.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_HVY.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LOC.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LRF.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2FREE.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2PAY.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3FREE.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3PAY.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_TAXI.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SHARED.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SINGLE.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_COM.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_EXP.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_HVY.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LOC.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LRF.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.logsums.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.nested_exp_utilities.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.nested_probabilities.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.rands.csv
# .\output\trace\trip_mode_choice.work.simple_simulate.eval_nl.raw_utilities.csv
# .\output\trace\trip_mode_choice.work.trip_mode.csv
# .\output\trace\trip_mode_choice.work.trip_mode_choice_annotate_trips_preprocessor.csv
# .\output\trace\trip_purpose.choices.csv
# .\output\trace\trip_purpose.csv
# .\output\trace\trip_purpose.rands.csv
# .\output\trace\trip_purpose.trip_purpose_annotate_trips_preprocessor.csv
# .\output\trace\trip_scheduling.i1.outbound.num_2.choices.csv
# .\output\trace\trip_scheduling.i1.outbound.num_2.choosers.csv
# .\output\trace\trip_scheduling.i1.outbound.num_2.chooser_probs.csv
# .\output\trace\trip_scheduling.i1.outbound.num_2.rands.csv
# .\output\trace\trip_scheduling.i100.outbound.num_3.failed_choosers.csv
# .\output\trace\trip_scheduling.i100.outbound.num_4.failed_choosers.csv
# .\output\trace\workplace_location.annotate_households.annotate_households_workplace.csv
# .\output\trace\workplace_location.annotate_persons.annotate_persons_workplace.csv
# .\output\trace\workplace_location.annotate_persons.annotate_persons_workplace_locals.csv
# .\output\trace\workplace_location.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.choosers.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_values.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_BIKE.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEFREE.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEPAY.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_COM.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_EXP.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_HVY.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LOC.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LRF.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2FREE.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2PAY.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3FREE.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3PAY.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TAXI.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SHARED.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SINGLE.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_COM.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_EXP.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_HVY.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LOC.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LRF.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.logsums.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.nested_exp_utilities.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.raw_utilities.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.tour_mode_choice_annotate_choosers_preprocessor.csv
# .\output\trace\workplace_location.i1.logsums.work_med.compute_logsums.tour_mode_choice_annotate_choosers_preprocessor_locals.csv
# .\output\trace\workplace_location.i1.sample.work_med.interaction_sample.alternatives.csv
# .\output\trace\workplace_location.i1.sample.work_med.interaction_sample.choosers.csv
# .\output\trace\workplace_location.i1.sample.work_med.interaction_sample.eval.person_id.1875721.csv
# .\output\trace\workplace_location.i1.sample.work_med.interaction_sample.eval.person_id.1875722.csv
# .\output\trace\workplace_location.i1.sample.work_med.interaction_sample.eval.raw.csv
# .\output\trace\workplace_location.i1.sample.work_med.interaction_sample.interaction_df.csv
# .\output\trace\workplace_location.i1.sample.work_med.interaction_sample.interaction_utilities.csv
# .\output\trace\workplace_location.i1.sample.work_med.interaction_sample.probs.csv
# .\output\trace\workplace_location.i1.sample.work_med.interaction_sample.sampled_alternatives.csv
# .\output\trace\workplace_location.i1.sample.work_med.interaction_sample.utils.csv
# .\output\trace\workplace_location.i1.simulate.work_med.interaction_sample_simulate.alternatives.csv
# .\output\trace\workplace_location.i1.simulate.work_med.interaction_sample_simulate.choices.csv
# .\output\trace\workplace_location.i1.simulate.work_med.interaction_sample_simulate.choosers.csv
# .\output\trace\workplace_location.i1.simulate.work_med.interaction_sample_simulate.eval.person_id.1875721.csv
# .\output\trace\workplace_location.i1.simulate.work_med.interaction_sample_simulate.eval.person_id.1875722.csv
# .\output\trace\workplace_location.i1.simulate.work_med.interaction_sample_simulate.eval.raw.csv
# .\output\trace\workplace_location.i1.simulate.work_med.interaction_sample_simulate.interaction_df.csv
# .\output\trace\workplace_location.i1.simulate.work_med.interaction_sample_simulate.interaction_utilities.csv
# .\output\trace\workplace_location.i1.simulate.work_med.interaction_sample_simulate.logsum.csv
# .\output\trace\workplace_location.i1.simulate.work_med.interaction_sample_simulate.probs.csv
# .\output\trace\workplace_location.i1.simulate.work_med.interaction_sample_simulate.rands.csv
# .\output\trace\workplace_location.i1.simulate.work_med.interaction_sample_simulate.utilities.csv
# .\output\.gitignore
# .\output\cdap_spec_2.csv
# .\output\cdap_spec_3.csv
# .\output\cdap_spec_4.csv
# .\output\cdap_spec_5.csv
# .\output\data_dict.csv
# .\output\data_dict.txt
# .\output\final_accessibility.csv
# .\output\final_checkpoints.csv
# .\output\final_households.csv
# .\output\final_joint_tour_participants.csv
# .\output\final_land_use.csv
# .\output\final_persons.csv
# .\output\final_tours.csv
# .\output\final_trips.csv
# .\output\pipeline.h5
# .\output\skim_usage.txt
# .\output\trips_am.omx
# .\output\trips_ea.omx
# .\output\trips_ev.omx
# .\output\trips_md.omx
# .\output\trips_pm.omx
# .\output\cache
# .\output\log
# .\output\trace
# .\README.MD
# .\configs
# .\configs_mp
# .\data
# .\output

# %% [markdown]
# # Inputs
#
# Run the commands below to:
# * Load required Python libraries for reading data
# * Display the settings.yaml, including the list of `models` to run
# * Display the land_use, households, and persons tables
# * Display the skims

# %%
print("Load libraries.")
import pandas as pd
import openmatrix as omx
import yaml
import glob
# Out:
# Load libraries.

# %%
print("Display the settings file.\n")

with open(r'configs/settings.yaml') as file:
    file_contents = yaml.load(file, Loader=yaml.FullLoader)
    print(yaml.dump(file_contents))
# Out:
# Display the settings file.
#
# cbd_threshold: 2
# check_for_variability: false
# checkpoints: true
# chunk_method: hybrid_uss
# chunk_size: 0
# chunk_training_mode: training
# default_initial_rows_per_chunk: 500
# distributed_vot_mu: 0.684
# distributed_vot_sigma: 0.85
# household_median_value_of_time:
#   1: 6.01
#   2: 8.81
#   3: 10.44
#   4: 12.86
# households_sample_size: 100
# input_table_list:
# - filename: households.csv
#   index_col: household_id
#   keep_columns:
#   - home_zone_id
#   - income
#   - hhsize
#   - HHT
#   - auto_ownership
#   - num_workers
#   rename_columns:
#     HHID: household_id
#     PERSONS: hhsize
#     TAZ: home_zone_id
#     VEHICL: auto_ownership
#     workers: num_workers
#   tablename: households
# - filename: persons.csv
#   index_col: person_id
#   keep_columns:
#   - household_id
#   - age
#   - PNUM
#   - sex
#   - pemploy
#   - pstudent
#   - ptype
#   rename_columns:
#     PERID: person_id
#   tablename: persons
# - filename: land_use.csv
#   index_col: zone_id
#   keep_columns:
#   - DISTRICT
#   - SD
#   - county_id
#   - TOTHH
#   - TOTPOP
#   - TOTACRE
#   - RESACRE
#   - CIACRE
#   - TOTEMP
#   - AGE0519
#   - RETEMPN
#   - FPSEMPN
#   - HEREMPN
#   - OTHEMPN
#   - AGREMPN
#   - MWTEMPN
#   - PRKCST
#   - OPRKCST
#   - area_type
#   - HSENROLL
#   - COLLFTE
#   - COLLPTE
#   - TOPOLOGY
#   - TERMINAL
#   rename_columns:
#     COUNTY: county_id
#     TAZ: zone_id
#   tablename: land_use
# keep_chunk_logs: true
# keep_mem_logs: true
# max_value_of_time: 50
# min_available_chunk_ratio: 0.05
# min_value_of_time: 1
# models:
# - initialize_landuse
# - initialize_households
# - compute_accessibility
# - school_location
# - workplace_location
# - auto_ownership_simulate
# - free_parking
# - cdap_simulate
# - mandatory_tour_frequency
# - mandatory_tour_scheduling
# - joint_tour_frequency
# - joint_tour_composition
# - joint_tour_participation
# - joint_tour_destination
# - joint_tour_scheduling
# - non_mandatory_tour_frequency
# - non_mandatory_tour_destination
# - non_mandatory_tour_scheduling
# - tour_mode_choice_simulate
# - atwork_subtour_frequency
# - atwork_subtour_destination
# - atwork_subtour_scheduling
# - atwork_subtour_mode_choice
# - stop_frequency
# - trip_purpose
# - trip_destination
# - trip_purpose_and_destination
# - trip_scheduling
# - trip_mode_choice
# - write_data_dictionary
# - track_skim_usage
# - write_trip_matrices
# - write_tables
# output_tables:
#   action: include
#   h5_store: false
#   prefix: final_
#   tables:
#   - checkpoints
#   - accessibility
#   - land_use
#   - households
#   - persons
#   - tours
#   - trips
#   - joint_tour_participants
# resume_after: null
# rural_threshold: 6
# trace_hh_id: 982875
# trace_od: null
# urban_threshold: 4
# use_shadow_pricing: false
# want_dest_choice_sample_tables: false

# %%
print("Display the network_los file.\n")

with open(r'configs/network_los.yaml') as file:
    file_contents = yaml.load(file, Loader=yaml.FullLoader)
    print(yaml.dump(file_contents))
# Out:
# Display the network_los file.
#
# read_skim_cache: false
# skim_time_periods:
#   labels:
#   - EA
#   - EA
#   - AM
#   - MD
#   - PM
#   - EV
#   period_minutes: 60
#   periods:
#   - 0
#   - 3
#   - 5
#   - 9
#   - 14
#   - 18
#   - 24
#   time_window: 1440
# taz_skims: skims.omx
# write_skim_cache: true
# zone_system: 1

# %%
print("Input land_use.  Primary key: TAZ.  Required additional fields depend on the downstream submodels (and expression files).")
pd.read_csv("data/land_use.csv")
# Out:
# Input land_use.  Primary key: TAZ.  Required additional fields depend on the downstream submodels (and expression files).
#     TAZ  DISTRICT  SD  COUNTY  TOTHH  HHPOP  TOTPOP  EMPRES  SFDU  MFDU  ...  \
# 0     1         1   1       1     46     74      82      37     1    60  ...
# 1     2         1   1       1    134    214     240     107     5   147  ...
# 2     3         1   1       1    267    427     476     214     9   285  ...
# 3     4         1   1       1    151    239     253     117     6   210  ...
# 4     5         1   1       1    611    974    1069     476    22   671  ...
# 5     6         1   1       1   2240   3311    3963    2052     0  2406  ...
# 6     7         1   1       1   3762   5561    6032    3375     0  4174  ...
# 7     8         1   1       1   4582   7565    9907    3594    19  4898  ...
# 8     9         1   1       1   5545   9494   10171    4672    35  6032  ...
# 9    10         1   1       1   5344   9205    9308    5137     5  5663  ...
# 10   11         1   1       1   2902   4998    5163    2865    10  2923  ...
# 11   12         1   1       1    793   1197    1207     897     0   984  ...
# 12   13         1   1       1    102    156     166      60     0   119  ...
# 13   14         1   1       1    476    722     728     523     0   552  ...
# 14   15         1   1       1    279    422     470     330     0   319  ...
# 15   16         1   1       1   6164  10143   10272    8094    15  6720  ...
# 16   17         1   1       1   4075   6702    7119    5422    25  4532  ...
# 17   18         1   1       1   1034   1705    2069    1266    56  1087  ...
# 18   19         1   1       1    843   1387    1608    1023    22   863  ...
# 19   20         1   1       1   2006   3346    3691    1668    97  2019  ...
# 20   21         1   1       1   3472   5793    6203    2782   117  3520  ...
# 21   22         1   1       1   1195   1906    1925    1137    98  1291  ...
# 22   23         1   1       1    565    900     906     543    43   628  ...
# 23   24         1   1       1    604    972     979     355     0   669  ...
# 24   25         1   1       1   1551   3410    3416    1239   131  1553  ...
#
#     area_type   HSENROLL     COLLFTE     COLLPTE  TOPOLOGY  TERMINAL  ZERO  \
# 0           0    0.00000     0.00000     0.00000         3   5.89564     0
# 1           0    0.00000     0.00000     0.00000         1   5.84871     0
# 2           0    0.00000     0.00000     0.00000         1   5.53231     0
# 3           0    0.00000     0.00000     0.00000         2   5.64330     0
# 4           0    0.00000    72.14684     0.00000         1   5.52555     0
# 5           0    0.00000     0.00000     0.00000         1   5.00004     0
# 6           0    0.00000     0.00000     0.00000         1   5.35435     0
# 7           0    0.00000     0.00000     0.00000         2   4.64648     0
# 8           0   26.92893  2035.58118    20.60887         2   5.22542     0
# 9           0    0.00000   690.54974     0.00000         3   4.73802     0
# 10          0    0.00000     0.00000     0.00000         3   4.64739     0
# 11          0    0.00000  3434.21460  2376.73853         3   5.46202     0
# 12          0  348.71741  1719.16077  3824.83545         3   5.51319     0
# 13          0    0.00000   851.33472   251.48717         3   5.52147     0
# 14          0    0.00000     0.00000     0.00000         3   5.59024     0
# 15          0    0.00000     0.00000     0.00000         2   4.75017     0
# 16          1    0.00000     0.00000     0.00000         1   4.58156     0
# 17          1    0.00000     0.00000     0.00000         3   4.17010     0
# 18          1    0.00000     0.00000     0.00000         3   4.18480     0
# 19          1    0.00000     0.00000     0.00000         3   3.99027     0
# 20          1    0.00000     0.00000     0.00000         3   4.29617     0
# 21          0    0.00000     0.00000     0.00000         3   4.93813     0
# 22          1    0.00000     0.00000     0.00000         1   5.11702     0
# 23          0    0.00000     0.00000     0.00000         1   5.35851     0
# 24          0    0.00000     0.00000     0.00000         1   4.89113     0
#
#     hhlds  sftaz  gqpop
# 0      46      1      8
# 1     134      2     26
# 2     267      3     49
# 3     151      4     14
# 4     611      5     95
# 5    2240      6    652
# 6    3762      7    471
# 7    4582      8   2342
# 8    5545      9    677
# 9    5344     10    103
# 10   2902     11    165
# 11    793     12     10
# 12    102     13     10
# 13    476     14      6
# 14    279     15     48
# 15   6164     16    129
# 16   4075     17    417
# 17   1034     18    364
# 18    843     19    221
# 19   2006     20    345
# 20   3472     21    410
# 21   1195     22     19
# 22    565     23      6
# 23    604     24      7
# 24   1551     25      6
#
# [25 rows x 42 columns]

# %%
print("Input households.  Primary key: HHID.  Foreign key: TAZ.  Required additional fields depend on the downstream submodels (and expression files).")
pd.read_csv("data/households.csv")
# Out:
# Input households.  Primary key: HHID.  Foreign key: TAZ.  Required additional fields depend on the downstream submodels (and expression files).
#          HHID  TAZ  SERIALNO  PUMA5  income  PERSONS  HHT  UNITTYPE  NOC  \
# 0     2717868   25   2715386   2202  361000        2    1         0    0
# 1      763899    6   5360279   2203   59220        1    4         0    0
# 2     2222791    9     77132   2203  197000        2    2         0    0
# 3      112477   17   3286812   2203    2200        1    6         0    0
# 4      370491   21   6887183   2203   16500        3    1         0    1
# ...       ...  ...       ...    ...     ...      ...  ...       ...  ...
# 4995   109218   10   3592966   2203   15000        1    4         0    0
# 4996   570708   23   2418140   2202   13100        1    6         0    0
# 4997  2762199   21   4016973   2203       0        1    0         2    0
# 4998  2049372   18    965334   2203  103000        1    4         0    0
# 4999   702559   13   1415973   2203   14800        2    1         0    0
#
#       BLDGSZ  ...  hschpred  hschdriv  htypdwel  hownrent  hadnwst  hadwpst  \
# 0          9  ...         0         0         2         1        0        0
# 1          9  ...         0         0         2         2        0        0
# 2          9  ...         0         0         2         1        0        0
# 3          8  ...         0         0         2         2        0        0
# 4          8  ...         1         0         2         2        0        0
# ...      ...  ...       ...       ...       ...       ...      ...      ...
# 4995       8  ...         0         0         2         2        0        0
# 4996       9  ...         0         0         2         2        0        0
# 4997       0  ...         0         0         2         2        0        0
# 4998       9  ...         0         0         2         2        0        0
# 4999       9  ...         0         0         2         2        0        0
#
#       hadkids  bucketBin  originalPUMA  hmultiunit
# 0           0          3          2202           1
# 1           0          4          2203           1
# 2           1          5          2203           1
# 3           0          7          2203           1
# 4           0          7          2203           1
# ...       ...        ...           ...         ...
# 4995        0          7          2203           1
# 4996        0          6          2202           1
# 4997        0          2          2203           1
# 4998        0          9          2203           1
# 4999        0          3          2203           1
#
# [5000 rows x 47 columns]

# %%
print("Input persons.  Primary key: PERID.  Foreign key: household_id.  Required additional fields depend on the downstream submodels (and expression files).")
pd.read_csv("data/persons.csv")
# Out:
# Input persons.  Primary key: PERID.  Foreign key: household_id.  Required additional fields depend on the downstream submodels (and expression files).
#         PERID  household_id  age  RELATE  ESR  GRADE  PNUM  PAUG  DDP  sex  \
# 0       25671         25671   47       1    6      0     1     0    0    1
# 1       25675         25675   27       1    6      7     1     0    0    2
# 2       25678         25678   30       1    6      0     1     0    0    2
# 3       25683         25683   23       1    6      0     1     0    0    1
# 4       25684         25684   52       1    6      0     1     0    0    1
# ...       ...           ...  ...     ...  ...    ...   ...   ...  ...  ...
# 8207  7554848       2863513   68      22    6      0     1     0    0    1
# 8208  7554855       2863520   68      22    6      0     1     0    0    1
# 8209  7554859       2863524   93      22    6      0     1     0    0    2
# 8210  7554887       2863552   76      22    6      0     1     0    0    2
# 8211  7554903       2863568   82      22    6      0     1     0    0    2
#
#       WEEKS  HOURS  MSP  POVERTY  EARNS  pagecat  pemploy  pstudent  ptype  \
# 0         0      0    6       39      0        6        3         3      4
# 1        52     40    2       84   7200        5        3         2      3
# 2         0      0    6       84      0        5        3         3      4
# 3         0      0    6        1      0        4        3         3      4
# 4         0      0    6       94      0        7        3         3      4
# ...     ...    ...  ...      ...    ...      ...      ...       ...    ...
# 8207      0      0    4        0      0        8        3         3      5
# 8208      0      0    4        0      0        8        3         3      5
# 8209      0      0    2        0      0        9        3         3      5
# 8210      0      0    2        0      0        8        3         3      5
# 8211      0      0    2        0      0        9        3         3      5
#
#       padkid
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2
# ...      ...
# 8207       2
# 8208       2
# 8209       2
# 8210       2
# 8211       2
#
# [8212 rows x 20 columns]

# %%
print("Skims.  All skims are input via one OMX file.  Required skims depend on the downstream submodels (and expression files).\n")
print(omx.open_file("data/skims.omx"))
# Out:
# Skims.  All skims are input via one OMX file.  Required skims depend on the downstream submodels (and expression files).
#
# data/skims.omx (File) ''
# Last modif.: 'Thu Apr 22 08:35:45 2021'
# Object Tree:
# / (RootGroup) ''
# /data (Group) ''
# /data/DIST (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DISTBIKE (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DISTWALK (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_DDIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_DDIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_DDIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_DDIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_DDIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_DTIM__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_DTIM__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_DTIM__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_DTIM__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_DTIM__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_KEYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_KEYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_KEYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_KEYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_KEYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_COM_WLK_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_DDIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_DDIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_DDIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_DDIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_DDIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_DTIM__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_DTIM__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_DTIM__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_DTIM__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_DTIM__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_KEYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_KEYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_KEYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_KEYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_KEYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_EXP_WLK_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_DDIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_DDIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_DDIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_DDIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_DDIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_DTIM__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_DTIM__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_DTIM__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_DTIM__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_DTIM__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_KEYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_KEYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_KEYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_KEYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_KEYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_HVY_WLK_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_DDIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_DDIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_DDIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_DDIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_DDIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_DTIM__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_DTIM__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_DTIM__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_DTIM__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_DTIM__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LOC_WLK_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_DDIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_DDIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_DDIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_DDIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_DDIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_DTIM__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_DTIM__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_DTIM__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_DTIM__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_DTIM__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_FERRYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_FERRYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_FERRYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_FERRYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_FERRYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_KEYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_KEYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_KEYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_KEYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_KEYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/DRV_LRF_WLK_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_BTOLL__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_BTOLL__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_BTOLL__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_BTOLL__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_BTOLL__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_DIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_DIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_DIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_DIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_DIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_TIME__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_TIME__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_TIME__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_TIME__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_TIME__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_VTOLL__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_VTOLL__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_VTOLL__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_VTOLL__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2TOLL_VTOLL__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_BTOLL__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_BTOLL__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_BTOLL__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_BTOLL__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_BTOLL__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_DIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_DIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_DIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_DIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_DIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_TIME__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_TIME__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_TIME__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_TIME__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV2_TIME__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_BTOLL__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_BTOLL__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_BTOLL__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_BTOLL__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_BTOLL__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_DIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_DIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_DIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_DIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_DIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_TIME__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_TIME__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_TIME__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_TIME__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_TIME__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_VTOLL__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_VTOLL__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_VTOLL__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_VTOLL__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3TOLL_VTOLL__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_BTOLL__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_BTOLL__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_BTOLL__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_BTOLL__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_BTOLL__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_DIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_DIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_DIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_DIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_DIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_TIME__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_TIME__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_TIME__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_TIME__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/HOV3_TIME__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_BTOLL__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_BTOLL__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_BTOLL__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_BTOLL__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_BTOLL__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_DIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_DIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_DIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_DIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_DIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_TIME__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_TIME__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_TIME__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_TIME__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_TIME__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_VTOLL__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_VTOLL__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_VTOLL__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_VTOLL__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOVTOLL_VTOLL__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_BTOLL__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_BTOLL__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_BTOLL__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_BTOLL__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_BTOLL__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_DIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_DIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_DIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_DIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_DIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_TIME__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_TIME__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_TIME__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_TIME__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/SOV_TIME__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_DDIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_DDIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_DDIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_DDIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_DDIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_DTIM__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_DTIM__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_DTIM__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_DTIM__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_DTIM__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_KEYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_KEYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_KEYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_KEYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_KEYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_DRV_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_KEYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_KEYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_KEYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_KEYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_KEYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_COM_WLK_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_DDIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_DDIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_DDIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_DDIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_DDIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_DTIM__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_DTIM__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_DTIM__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_DTIM__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_DTIM__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_KEYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_KEYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_KEYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_KEYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_KEYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_DRV_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_KEYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_KEYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_KEYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_KEYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_KEYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_EXP_WLK_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_DDIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_DDIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_DDIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_DDIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_DDIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_DTIM__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_DTIM__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_DTIM__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_DTIM__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_DTIM__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_KEYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_KEYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_KEYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_KEYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_KEYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_DRV_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_KEYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_KEYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_KEYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_KEYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_KEYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_HVY_WLK_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_DDIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_DDIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_DDIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_DDIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_DDIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_DTIM__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_DTIM__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_DTIM__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_DTIM__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_DTIM__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_DRV_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LOC_WLK_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_DDIST__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_DDIST__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_DDIST__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_DDIST__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_DDIST__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_DTIM__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_DTIM__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_DTIM__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_DTIM__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_DTIM__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_FERRYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_FERRYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_FERRYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_FERRYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_FERRYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_KEYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_KEYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_KEYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_KEYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_KEYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_DRV_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_BOARDS__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_BOARDS__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_BOARDS__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_BOARDS__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_BOARDS__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_FAR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_FAR__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_FAR__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_FAR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_FAR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_FERRYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_FERRYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_FERRYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_FERRYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_FERRYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_IWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_IWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_KEYIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_KEYIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_KEYIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_KEYIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_KEYIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_TOTIVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_TOTIVT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_TOTIVT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_TOTIVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_TOTIVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_WAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_WAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_WAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_WAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_WAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_WAUX__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_WAUX__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_XWAIT__EA (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_XWAIT__EV (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_LRF_WLK_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_IVT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_IVT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_IVT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_IWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_IWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_IWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_WACC__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_WACC__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_WACC__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_WAUX__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_WAUX__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_WAUX__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_WEGR__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_WEGR__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_WEGR__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_XWAIT__AM (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_XWAIT__MD (CArray(25, 25), shuffle, zlib(1)) ''
# /data/WLK_TRN_WLK_XWAIT__PM (CArray(25, 25), shuffle, zlib(1)) ''
# /lookup (Group) ''

# %% [markdown]
# # Outputs
#
# Run the commands below to:
# * Display the output household and person tables
# * Display the output tour and trip tables

# %%
print("The output pipeline contains the state of each table after each model step.")
pipeline = pd.io.pytables.HDFStore('output/pipeline.h5')
pipeline.keys()
# Out:
# The output pipeline contains the state of each table after each model step.
# ['/checkpoints',
#  '/workplace_modeled_size/workplace_location',
#  '/workplace_destination_size/initialize_households',
#  '/trips/stop_frequency',
#  '/trips/trip_destination',
#  '/trips/trip_mode_choice',
#  '/trips/trip_purpose',
#  '/trips/trip_purpose_and_destination',
#  '/trips/trip_scheduling',
#  '/tours/atwork_subtour_destination',
#  '/tours/atwork_subtour_frequency',
#  '/tours/atwork_subtour_mode_choice',
#  '/tours/atwork_subtour_scheduling',
#  '/tours/joint_tour_composition',
#  '/tours/joint_tour_destination',
#  '/tours/joint_tour_frequency',
#  '/tours/joint_tour_participation',
#  '/tours/joint_tour_scheduling',
#  '/tours/mandatory_tour_frequency',
#  '/tours/mandatory_tour_scheduling',
#  '/tours/non_mandatory_tour_destination',
#  '/tours/non_mandatory_tour_frequency',
#  '/tours/non_mandatory_tour_scheduling',
#  '/tours/stop_frequency',
#  '/tours/tour_mode_choice_simulate',
#  '/school_modeled_size/school_location',
#  '/school_destination_size/initialize_households',
#  '/persons/cdap_simulate',
#  '/persons/free_parking',
#  '/persons/initialize_households',
#  '/persons/joint_tour_participation',
#  '/persons/mandatory_tour_frequency',
#  '/persons/non_mandatory_tour_frequency',
#  '/persons/school_location',
#  '/persons/workplace_location',
#  '/person_windows/initialize_households',
#  '/person_windows/joint_tour_scheduling',
#  '/person_windows/mandatory_tour_scheduling',
#  '/person_windows/non_mandatory_tour_scheduling',
#  '/land_use/initialize_landuse',
#  '/joint_tour_participants/joint_tour_participation',
#  '/households/auto_ownership_simulate',
#  '/households/cdap_simulate',
#  '/households/initialize_households',
#  '/households/joint_tour_frequency',
#  '/households/workplace_location',
#  '/accessibility/compute_accessibility',
#  '/accessibility/initialize_landuse']

# %%
print("Households table after trip mode choice, which contains several calculated fields.")
pipeline['/households/joint_tour_frequency'] #watch out for key changes if not running all models
# Out:
# Households table after trip mode choice, which contains several calculated fields.
#               home_zone_id  income  hhsize  HHT  auto_ownership  num_workers  \
# household_id
# 982875                  16   30900       2    5               1            2
# 1810015                 16   99700       9    2               1            4
# 1099626                 20   58160       3    1               1            1
# 763879                   6   59220       1    4               1            0
# 824207                  18   51000       1    4               0            1
# ...                    ...     ...     ...  ...             ...          ...
# 287819                   9    6500       2    3               1            0
# 2832313                 10       0       1    0               0            0
# 2222549                  7  112500       2    5               0            2
# 2048809                 11  145450       1    4               1            1
# 566633                   8    8400       1    4               0            0
#
#               sample_rate  income_in_thousands  income_segment  \
# household_id
# 982875               0.02                30.90               2
# 1810015              0.02                99.70               3
# 1099626              0.02                58.16               2
# 763879               0.02                59.22               2
# 824207               0.02                51.00               2
# ...                   ...                  ...             ...
# 287819               0.02                 6.50               1
# 2832313              0.02                 0.00               1
# 2222549              0.02               112.50               4
# 2048809              0.02               145.45               4
# 566633               0.02                 8.40               1
#
#               median_value_of_time  ...  hh_work_auto_savings_ratio  \
# household_id                        ...
# 982875                        8.81  ...                    0.399721
# 1810015                      10.44  ...                    0.711955
# 1099626                       8.81  ...                    0.264600
# 763879                        8.81  ...                    0.000000
# 824207                        8.81  ...                    0.187061
# ...                            ...  ...                         ...
# 287819                        6.01  ...                    0.000000
# 2832313                       6.01  ...                    0.000000
# 2222549                      12.86  ...                    0.243357
# 2048809                      12.86  ...                    0.138205
# 566633                        6.01  ...                    0.000000
#
#               num_under16_not_at_school  num_travel_active  \
# household_id
# 982875                                0                  2
# 1810015                               0                  7
# 1099626                               0                  3
# 763879                                0                  1
# 824207                                0                  1
# ...                                 ...                ...
# 287819                                0                  2
# 2832313                               0                  1
# 2222549                               0                  2
# 2048809                               0                  1
# 566633                                0                  1
#
#               num_travel_active_adults  num_travel_active_preschoolers  \
# household_id
# 982875                               2                               0
# 1810015                              6                               1
# 1099626                              2                               1
# 763879                               1                               0
# 824207                               1                               0
# ...                                ...                             ...
# 287819                               1                               0
# 2832313                              1                               0
# 2222549                              2                               0
# 2048809                              1                               0
# 566633                               1                               0
#
#               num_travel_active_children  num_travel_active_non_preschoolers  \
# household_id
# 982875                                 0                                   2
# 1810015                                1                                   6
# 1099626                                1                                   2
# 763879                                 0                                   1
# 824207                                 0                                   1
# ...                                  ...                                 ...
# 287819                                 1                                   2
# 2832313                                0                                   1
# 2222549                                0                                   2
# 2048809                                0                                   1
# 566633                                 0                                   1
#
#               participates_in_jtf_model  joint_tour_frequency  \
# household_id
# 982875                             True               0_tours
# 1810015                            True               0_tours
# 1099626                            True               0_tours
# 763879                            False               0_tours
# 824207                            False               0_tours
# ...                                 ...                   ...
# 287819                             True               0_tours
# 2832313                           False               0_tours
# 2222549                            True               0_tours
# 2048809                           False               0_tours
# 566633                            False               0_tours
#
#               num_hh_joint_tours
# household_id
# 982875                         0
# 1810015                        0
# 1099626                        0
# 763879                         0
# 824207                         0
# ...                          ...
# 287819                         0
# 2832313                        0
# 2222549                        0
# 2048809                        0
# 566633                         0
#
# [100 rows x 34 columns]

# %%
print("Final output households table to written to CSV, which is the same as the table in the pipeline.")
pd.read_csv("output/final_households.csv")
# Out:
# Final output households table to written to CSV, which is the same as the table in the pipeline.
#     household_id  home_zone_id  income  hhsize  HHT  auto_ownership  \
# 0         982875            16   30900       2    5               1
# 1        1810015            16   99700       9    2               1
# 2        1099626            20   58160       3    1               1
# 3         763879             6   59220       1    4               1
# 4         824207            18   51000       1    4               0
# ..           ...           ...     ...     ...  ...             ...
# 95        287819             9    6500       2    3               1
# 96       2832313            10       0       1    0               0
# 97       2222549             7  112500       2    5               0
# 98       2048809            11  145450       1    4               1
# 99        566633             8    8400       1    4               0
#
#     num_workers  sample_rate  income_in_thousands  income_segment  ...  \
# 0             2         0.02                30.90               2  ...
# 1             4         0.02                99.70               3  ...
# 2             1         0.02                58.16               2  ...
# 3             0         0.02                59.22               2  ...
# 4             1         0.02                51.00               2  ...
# ..          ...          ...                  ...             ...  ...
# 95            0         0.02                 6.50               1  ...
# 96            0         0.02                 0.00               1  ...
# 97            2         0.02               112.50               4  ...
# 98            1         0.02               145.45               4  ...
# 99            0         0.02                 8.40               1  ...
#
#     hh_work_auto_savings_ratio  num_under16_not_at_school  num_travel_active  \
# 0                     0.399721                          0                  2
# 1                     0.711955                          0                  7
# 2                     0.264600                          0                  3
# 3                     0.000000                          0                  1
# 4                     0.187061                          0                  1
# ..                         ...                        ...                ...
# 95                    0.000000                          0                  2
# 96                    0.000000                          0                  1
# 97                    0.243358                          0                  2
# 98                    0.138205                          0                  1
# 99                    0.000000                          0                  1
#
#     num_travel_active_adults  num_travel_active_preschoolers  \
# 0                          2                               0
# 1                          6                               1
# 2                          2                               1
# 3                          1                               0
# 4                          1                               0
# ..                       ...                             ...
# 95                         1                               0
# 96                         1                               0
# 97                         2                               0
# 98                         1                               0
# 99                         1                               0
#
#     num_travel_active_children  num_travel_active_non_preschoolers  \
# 0                            0                                   2
# 1                            1                                   6
# 2                            1                                   2
# 3                            0                                   1
# 4                            0                                   1
# ..                         ...                                 ...
# 95                           1                                   2
# 96                           0                                   1
# 97                           0                                   2
# 98                           0                                   1
# 99                           0                                   1
#
#     participates_in_jtf_model  joint_tour_frequency  num_hh_joint_tours
# 0                        True               0_tours                   0
# 1                        True               0_tours                   0
# 2                        True               0_tours                   0
# 3                       False               0_tours                   0
# 4                       False               0_tours                   0
# ..                        ...                   ...                 ...
# 95                       True               0_tours                   0
# 96                      False               0_tours                   0
# 97                       True               0_tours                   0
# 98                      False               0_tours                   0
# 99                      False               0_tours                   0
#
# [100 rows x 35 columns]

# %%
print("Final output persons table to written to CSV, which is the same as the table in the pipeline.")
pd.read_csv("output/final_persons.csv")
# Out:
# Final output persons table to written to CSV, which is the same as the table in the pipeline.
#      person_id  household_id  age  PNUM  sex  pemploy  pstudent  ptype  \
# 0        26478         26478   46     1    1        3         3      4
# 1        26686         26686   39     1    1        3         3      4
# 2        26844         26844   51     1    1        3         3      4
# 3        27726         27726   52     1    1        3         3      4
# 4        27748         27748   57     1    2        3         3      4
# ..         ...           ...  ...   ...  ...      ...       ...    ...
# 162    7523517       2832182   87     1    2        3         3      5
# 163    7523648       2832313   78     1    2        3         3      5
# 164    7523764       2832429   93     1    2        3         3      5
# 165    7539466       2848131   38     1    2        3         2      3
# 166    7539708       2848373   21     1    1        3         2      3
#
#      age_16_to_19  age_16_p  ...  num_joint_tours  \
# 0           False      True  ...                0
# 1           False      True  ...                0
# 2           False      True  ...                0
# 3           False      True  ...                0
# 4           False      True  ...                0
# ..            ...       ...  ...              ...
# 162         False      True  ...                0
# 163         False      True  ...                0
# 164         False      True  ...                0
# 165         False      True  ...                0
# 166         False      True  ...                0
#
#      non_mandatory_tour_frequency  num_non_mand  num_escort_tours  \
# 0                              12             2                 0
# 1                              12             2                 0
# 2                               2             1                 0
# 3                               1             1                 0
# 4                               0             0                 0
# ..                            ...           ...               ...
# 162                             1             1                 0
# 163                             1             1                 0
# 164                             0             0                 0
# 165                            16             1                 0
# 166                             0             0                 0
#
#      num_eatout_tours  num_shop_tours  num_maint_tours  num_discr_tours  \
# 0                   1               0                1                0
# 1                   1               0                1                0
# 2                   0               0                0                0
# 3                   0               0                0                1
# 4                   0               0                0                0
# ..                ...             ...              ...              ...
# 162                 0               0                0                1
# 163                 0               0                0                1
# 164                 0               0                0                0
# 165                 0               1                0                0
# 166                 0               0                0                0
#
#      num_social_tours  num_non_escort_tours
# 0                   0                     2
# 1                   0                     2
# 2                   1                     1
# 3                   0                     1
# 4                   0                     0
# ..                ...                   ...
# 162                 0                     1
# 163                 0                     1
# 164                 0                     0
# 165                 0                     1
# 166                 0                     0
#
# [167 rows x 64 columns]

# %%
print("Final output tours table to written to CSV, which is the same as the table in the pipeline.  Joint tours are stored as one record.")
pd.read_csv("output/final_tours.csv")
# Out:
# Final output tours table to written to CSV, which is the same as the table in the pipeline.  Joint tours are stored as one record.
#        tour_id  person_id tour_type  tour_type_count  tour_type_num  tour_num  \
# 0     10828426     264107      work                1              1         1
# 1     10834207     264248      work                1              1         1
# 2     13271288     323689      work                1              1         1
# 3     13286130     324051      work                1              1         1
# 4     13286171     324052      work                1              1         1
# ..         ...        ...       ...              ...            ...       ...
# 197  143309067    3495343       eat                1              1         1
# 198  171036547    4171623       eat                1              1         1
# 199  220897896    5387753     maint                1              1         1
# 200  220958270    5389226       eat                1              1         1
# 201  307996473    7512109       eat                1              1         1
#
#      tour_count tour_category  number_of_participants  destination  ...   end  \
# 0             1     mandatory                       1         24.0  ...  19.0
# 1             1     mandatory                       1         22.0  ...  19.0
# 2             1     mandatory                       1          1.0  ...  18.0
# 3             1     mandatory                       1         13.0  ...  18.0
# 4             1     mandatory                       1          2.0  ...  17.0
# ..          ...           ...                     ...          ...  ...   ...
# 197           1        atwork                       1         16.0  ...  14.0
# 198           1        atwork                       1          7.0  ...  10.0
# 199           1        atwork                       1         15.0  ...  14.0
# 200           1        atwork                       1          2.0  ...  13.0
# 201           1        atwork                       1          8.0  ...  10.0
#
#      duration  composition  destination_logsum  tour_mode  mode_choice_logsum  \
# 0        12.0          NaN                 NaN   WALK_LRF            5.706465
# 1        12.0          NaN                 NaN   WALK_LRF            5.740181
# 2         7.0          NaN                 NaN   WALK_LRF            5.762750
# 3        12.0          NaN                 NaN       WALK            1.894204
# 4        10.0          NaN                 NaN   WALK_LOC            2.055649
# ..        ...          ...                 ...        ...                 ...
# 197       0.0          NaN           15.544104       WALK            4.189554
# 198       0.0          NaN           12.963491       WALK           -0.212087
# 199       1.0          NaN           15.821604       WALK            5.934528
# 200       0.0          NaN           15.712982       WALK            6.339068
# 201       0.0          NaN           20.633673       WALK           -0.471238
#
#     atwork_subtour_frequency  parent_tour_id stop_frequency  primary_purpose
# 0                no_subtours             NaN       0out_0in             work
# 1                no_subtours             NaN       3out_0in             work
# 2                no_subtours             NaN       0out_0in             work
# 3                no_subtours             NaN       0out_0in             work
# 4                        eat             NaN       0out_0in             work
# ..                       ...             ...            ...              ...
# 197                      NaN     143309102.0       3out_0in           atwork
# 198                      NaN     171036582.0       0out_1in           atwork
# 199                      NaN     220897912.0       0out_0in           atwork
# 200                      NaN     220958305.0       0out_0in           atwork
# 201                      NaN     307996508.0       0out_1in           atwork
#
# [202 rows x 24 columns]

# %%
print("Final output trips table to written to CSV, which is the same as the table in the pipeline.  Joint trips are stored as one record")
pd.read_csv("output/final_trips.csv")
# Out:
# Final output trips table to written to CSV, which is the same as the table in the pipeline.  Joint trips are stored as one record
#         trip_id  person_id  household_id    tour_id primary_purpose  trip_num  \
# 0       8684833      26478         26478    1085604          eatout         1
# 1       8684837      26478         26478    1085604          eatout         1
# 2       8685009      26478         26478    1085626        othmaint         1
# 3       8685013      26478         26478    1085626        othmaint         1
# 4       8753057      26686         26686    1094132          eatout         1
# ..          ...        ...           ...        ...             ...       ...
# 477  2472945113    7539466       2848131  309118139        shopping         1
# 478  2472945117    7539466       2848131  309118139        shopping         1
# 479  2472945118    7539466       2848131  309118139        shopping         2
# 480  2473024473    7539708       2848373  309128059            univ         1
# 481  2473024477    7539708       2848373  309128059            univ         1
#
#      outbound  trip_count   purpose  destination  origin  destination_logsum  \
# 0        True           1    eatout           13       8                 NaN
# 1       False           1      Home            8      13                 NaN
# 2        True           1  othmaint           10       8                 NaN
# 3       False           1      Home            8      10                 NaN
# 4        True           1    eatout            5       8                 NaN
# ..        ...         ...       ...          ...     ...                 ...
# 477      True           1  shopping            8       3                 NaN
# 478     False           2  shopping           25       8           56.842247
# 479     False           2      Home            3      25                 NaN
# 480      True           1      univ           13      18                 NaN
# 481     False           1      Home           18      13                 NaN
#
#      depart trip_mode  mode_choice_logsum
# 0      11.0      WALK           -1.171760
# 1      11.0      WALK           -1.238719
# 2      12.0      BIKE            6.198626
# 3      13.0      BIKE            6.175681
# 4      19.0      WALK            4.457539
# ..      ...       ...                 ...
# 477    18.0  WALK_LOC           12.537675
# 478    21.0  WALK_LOC           11.880804
# 479    22.0      WALK           13.710030
# 480    16.0  WALK_LOC           -0.530696
# 481    23.0  WALK_LRF            0.624304
#
# [482 rows x 15 columns]

# %% [markdown]
# # Other notable outputs

# %%
print("Final output accessibility table to written to CSV.")
pd.read_csv("output/final_accessibility.csv")
# Out:
# Final output accessibility table to written to CSV.
#     zone_id  auPkRetail  auPkTotal  auOpRetail  auOpTotal  trPkRetail  \
# 0         1    9.316494  12.615176    9.307437  12.607849    7.764264
# 1         2    9.316898  12.613461    9.304627  12.604209    7.511301
# 2         3    9.293217  12.580014    9.286242  12.574902    7.340975
# 3         4    9.357349  12.630894    9.348249  12.623586    7.873327
# 4         5    9.343551  12.585069    9.333262  12.574554    7.589356
# 5         6    9.271350  12.523449    9.265762  12.519698    7.313872
# 6         7    9.293194  12.528401    9.286373  12.520416    7.641910
# 7         8    9.267844  12.497146    9.262133  12.489886    7.546934
# 8         9    9.189503  12.426036    9.184035  12.415460    7.188751
# 9        10    9.186004  12.403890    9.180762  12.396344    7.379336
# 10       11    9.320093  12.519242    9.315095  12.511758    7.455702
# 11       12    9.351591  12.600777    9.340287  12.590073    7.945965
# 12       13    9.347596  12.610940    9.337329  12.601590    7.767894
# 13       14    9.327288  12.612722    9.319522  12.605843    7.982914
# 14       15    9.284935  12.581337    9.277798  12.575463    7.656614
# 15       16    9.312159  12.554715    9.309852  12.554250    7.016154
# 16       17    9.252513  12.480891    9.251513  12.479315    6.661200
# 17       18    9.249360  12.438991    9.248962  12.440035    7.085930
# 18       19    9.169029  12.357455    9.169914  12.359584    6.088623
# 19       20    9.221743  12.420066    9.218863  12.415977    6.636653
# 20       21    9.321916  12.515867    9.325176  12.518961    7.428997
# 21       22    9.229652  12.543187    9.219600  12.535205    7.150924
# 22       23    9.116150  12.433018    9.107848  12.426055    6.211645
# 23       24    9.243797  12.550974    9.230086  12.541350    7.322742
# 24       25    9.198262  12.494596    9.191437  12.490872    7.296646
#
#     trPkTotal  trOpRetail  trOpTotal  nmRetail    nmTotal
# 0   11.145248    7.693086  11.037286  8.137361  11.726242
# 1   10.950046    7.427060  10.763102  8.142717  11.724186
# 2   10.787608    7.252678  10.574954  8.050369  11.478913
# 3   11.224171    7.814365  11.135416  8.371197  11.775231
# 4   11.082550    7.549557  11.027965  8.318059  11.431764
# 5   10.504311    7.068341  10.251790  7.838241  11.023738
# 6   10.805003    7.607878  10.752510  8.016915  11.108805
# 7   10.834136    7.501424  10.779320  7.981951  11.052153
# 8   10.303186    7.149057  10.260610  7.415630  10.758663
# 9   10.548675    7.306522  10.495922  7.567826  10.694411
# 10  10.875601    7.348368  10.762778  8.228287  11.171157
# 11  11.204375    7.846326  11.074534  8.420518  11.618973
# 12  11.121006    7.691842  11.012477  8.422746  11.742390
# 13  11.205704    7.914738  11.096305  8.293606  11.736593
# 14  10.997076    7.574397  10.914272  8.000487  11.541814
# 15  10.534221    6.945206  10.442447  8.247303  11.373742
# 16   9.844753    6.562684   9.735318  7.667142  10.785216
# 17  10.252688    6.997756  10.137302  7.596636  10.414585
# 18   9.295992    5.907469   9.101217  7.088693   9.865001
# 19   9.801904    6.590820   9.753201  7.494197  10.367678
# 20  10.580038    7.342734  10.454321  8.108436  11.011608
# 21  10.713898    6.941084  10.463985  7.637908  11.319587
# 22   9.770781    6.118223   9.687799  6.887640  10.656700
# 23  10.850764    7.115121  10.577147  7.713628  11.346711
# 24  10.729605    7.180366  10.549489  7.616518  11.016223

# %%
print("Joint tour participants table, which contains the person ids of joint tour participants.")
pipeline['joint_tour_participants/joint_tour_participation']
# Out:
# Joint tour participants table, which contains the person ids of joint tour participants.
#                   tour_id  household_id  person_id  participant_num
# participant_id
# 22095827901     220958279       2223759    5389226                1
# 22095827902     220958279       2223759    5389227                2
# 10079851903     100798519       1173905    2458502                1
# 10079851904     100798519       1173905    2458503                2
# 13072777702     130727777       1402945    3188483                1
# 13072777703     130727777       1402945    3188484                2
# 13072777704     130727777       1402945    3188485                3

# %%
print("Destination choice sample logsums table for school location if want_dest_choice_sample_tables=True.")
if '/school_location_sample/school_location' in pipeline:
    pipeline['/school_location_sample/school_location']
# Out:
# Destination choice sample logsums table for school location if want_dest_choice_sample_tables=True.

# %% [markdown]
# # Trip matrices
#
# A **write_trip_matrices** step at the end of the model adds boolean indicator columns to the trip table in order to assign each trip into a trip matrix and then aggregates the trip counts and writes OD matrices to OMX (open matrix) files.  The coding of trips into trip matrices is done via annotation expressions.

# %%
print("trip matrices by time of day for assignment")
output_files = os.listdir("output")
for output_file in output_files:
    if "omx" in output_file:
        print(output_file)
# Out:
# trip matrices by time of day for assignment
# trips_am.omx
# trips_ea.omx
# trips_ev.omx
# trips_md.omx
# trips_pm.omx

# %% [markdown]
# # Tracing calculations
#
# Tracing calculations is an important part of model setup and debugging.  Often times data issues, such as missing values in input data and/or incorrect submodel expression files, do not reveal themselves until a downstream submodels fails.  There are two types of tracing in ActivtiySim: household and origin-destination (OD) pair. If a household trace ID is specified via `trace_hh_id`, then ActivitySim will output a comprehensive set of trace files for all calculations for all household members.  These trace files are listed below and explained.

# %%
print("All trace files.\n")
glob.glob("output/trace/*.csv")
# Out:
# All trace files.
# ['output/trace\\atwork_subtour_destination.csv',
#  'output/trace\\atwork_subtour_frequency.atwork_subtour_frequency_annotate_tours_preprocessor.csv',
#  'output/trace\\atwork_subtour_frequency.atwork_subtour_frequency_annotate_tours_preprocessor_locals.csv',
#  'output/trace\\atwork_subtour_frequency.simple_simulate.eval_mnl.choices.csv',
#  'output/trace\\atwork_subtour_frequency.simple_simulate.eval_mnl.choosers.csv',
#  'output/trace\\atwork_subtour_frequency.simple_simulate.eval_mnl.eval_utils.expression_values.csv',
#  'output/trace\\atwork_subtour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_business1.csv',
#  'output/trace\\atwork_subtour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_business2.csv',
#  'output/trace\\atwork_subtour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_eat.csv',
#  'output/trace\\atwork_subtour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_eat_business.csv',
#  'output/trace\\atwork_subtour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_maint.csv',
#  'output/trace\\atwork_subtour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_no_subtours.csv',
#  'output/trace\\atwork_subtour_frequency.simple_simulate.eval_mnl.probs.csv',
#  'output/trace\\atwork_subtour_frequency.simple_simulate.eval_mnl.rands.csv',
#  'output/trace\\atwork_subtour_frequency.simple_simulate.eval_mnl.utilities.csv',
#  'output/trace\\atwork_subtour_frequency.tours.csv',
#  'output/trace\\auto_ownership.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.choices.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.choosers.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_values.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars0.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars1.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars2.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars3.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars4.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.probs.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.rands.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.utilities.csv',
#  'output/trace\\cdap.annotate_households.annotate_households_cdap.csv',
#  'output/trace\\cdap.annotate_persons.annotate_persons_cdap.csv',
#  'output/trace\\cdap.cdap.cdap_rank.csv',
#  'output/trace\\cdap.cdap.hhsize2_activity_choices.csv',
#  'output/trace\\cdap.cdap.hhsize2_choosers.csv',
#  'output/trace\\cdap.cdap.hhsize2_probs.csv',
#  'output/trace\\cdap.cdap.hhsize2_rands.csv',
#  'output/trace\\cdap.cdap.hhsize2_utils.csv',
#  'output/trace\\cdap.cdap.indiv_utils.csv',
#  'output/trace\\cdap.csv',
#  'output/trace\\free_parking.csv',
#  'output/trace\\free_parking.free_parking_annotate_persons_preprocessor.csv',
#  'output/trace\\free_parking.simple_simulate.eval_mnl.choices.csv',
#  'output/trace\\free_parking.simple_simulate.eval_mnl.choosers.csv',
#  'output/trace\\free_parking.simple_simulate.eval_mnl.eval_utils.expression_values.csv',
#  'output/trace\\free_parking.simple_simulate.eval_mnl.eval_utils.expression_value_free.csv',
#  'output/trace\\free_parking.simple_simulate.eval_mnl.eval_utils.expression_value_pay.csv',
#  'output/trace\\free_parking.simple_simulate.eval_mnl.probs.csv',
#  'output/trace\\free_parking.simple_simulate.eval_mnl.rands.csv',
#  'output/trace\\free_parking.simple_simulate.eval_mnl.utilities.csv',
#  'output/trace\\initialize_households.annotate_tables.annotate_households.csv',
#  'output/trace\\initialize_households.annotate_tables.annotate_households_locals.csv',
#  'output/trace\\initialize_households.annotate_tables.annotate_persons.csv',
#  'output/trace\\initialize_households.annotate_tables.annotate_persons_after_hh.csv',
#  'output/trace\\joint_tour_frequency.households.csv',
#  'output/trace\\joint_tour_frequency.joint_tour_frequency_annotate_households_preprocessor.csv',
#  'output/trace\\joint_tour_frequency.joint_tour_frequency_annotate_households_preprocessor_locals.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.choices.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.choosers.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_values.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_0_tours.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_1_Disc.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_1_Eat.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_1_Main.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_1_Shop.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_1_Visit.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_DD.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_ED.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_EE.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_EV.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_MD.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_ME.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_MM.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_MV.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_SD.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_SE.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_SM.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_SS.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_SV.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_VD.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_2_VV.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.probs.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.rands.csv',
#  'output/trace\\joint_tour_frequency.simple_simulate.eval_mnl.utilities.csv',
#  'output/trace\\joint_tour_participation.annotate_persons.annotate_persons_jtp.csv',
#  'output/trace\\mandatory_tour_frequency.annotate_persons.annotate_persons_mtf.csv',
#  'output/trace\\mandatory_tour_frequency.annotate_persons.annotate_persons_mtf_locals.csv',
#  'output/trace\\mandatory_tour_frequency.mandatory_tours.csv',
#  'output/trace\\mandatory_tour_frequency.persons.csv',
#  'output/trace\\mandatory_tour_frequency.simple_simulate.eval_mnl.choices.csv',
#  'output/trace\\mandatory_tour_frequency.simple_simulate.eval_mnl.choosers.csv',
#  'output/trace\\mandatory_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_values.csv',
#  'output/trace\\mandatory_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_school1.csv',
#  'output/trace\\mandatory_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_school2.csv',
#  'output/trace\\mandatory_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_work1.csv',
#  'output/trace\\mandatory_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_work2.csv',
#  'output/trace\\mandatory_tour_frequency.simple_simulate.eval_mnl.eval_utils.expression_value_work_and_school.csv',
#  'output/trace\\mandatory_tour_frequency.simple_simulate.eval_mnl.probs.csv',
#  'output/trace\\mandatory_tour_frequency.simple_simulate.eval_mnl.rands.csv',
#  'output/trace\\mandatory_tour_frequency.simple_simulate.eval_mnl.utilities.csv',
#  'output/trace\\mandatory_tour_scheduling.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.choosers.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_values.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_BIKE.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEFREE.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEPAY.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_COM.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_EXP.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_HVY.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LOC.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LRF.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2FREE.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2PAY.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3FREE.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3PAY.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_TAXI.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SHARED.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SINGLE.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_WALK.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_WALK_COM.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_WALK_EXP.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_WALK_HVY.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LOC.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LRF.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.logsums.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.nested_exp_utilities.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.eval_nl_logsums.raw_utilities.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.tour_mode_choice_annotate_choosers_preprocessor.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.compute_logsums.logsums.tour_mode_choice_annotate_choosers_preprocessor_locals.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.alternatives.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.choices.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.choosers.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.eval.household_id.982875.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.eval.raw.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.interaction_df.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.interaction_utilities.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.probs.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.rands.csv',
#  'output/trace\\mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.work.interaction_sample_simulate.utilities.csv',
#  'output/trace\\non_mandatory_tour_destination.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.choosers.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_values.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_BIKE.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEFREE.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEPAY.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_COM.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_EXP.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_HVY.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LOC.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LRF.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2FREE.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2PAY.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3FREE.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3PAY.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TAXI.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SHARED.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SINGLE.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_COM.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_EXP.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_HVY.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LOC.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LRF.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.logsums.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.nested_exp_utilities.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.eval_nl_logsums.raw_utilities.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.tour_mode_choice_annotate_choosers_preprocessor.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.logsums.compute_logsums.tour_mode_choice_annotate_choosers_preprocessor_locals.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.sample.interaction_sample.alternatives.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.sample.interaction_sample.choosers.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.sample.interaction_sample.eval.person_id.1875722.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.sample.interaction_sample.eval.raw.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.sample.interaction_sample.interaction_df.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.sample.interaction_sample.interaction_utilities.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.sample.interaction_sample.probs.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.sample.interaction_sample.sampled_alternatives.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.sample.interaction_sample.utils.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.alternatives.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.choices.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.choosers.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.eval.person_id.1875722.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.eval.raw.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.interaction_df.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.interaction_utilities.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.logsum.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.probs.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.rands.csv',
#  'output/trace\\non_mandatory_tour_destination.eatout.simulate.interaction_sample_simulate.utilities.csv',
#  'output/trace\\non_mandatory_tour_frequency.annotated_persons.csv',
#  'output/trace\\non_mandatory_tour_frequency.annotate_persons_nmtf.csv',
#  'output/trace\\non_mandatory_tour_frequency.choosers.csv',
#  'output/trace\\non_mandatory_tour_frequency.extend_tour_counts.eatout.choices.csv',
#  'output/trace\\non_mandatory_tour_frequency.extend_tour_counts.eatout.rands.csv',
#  'output/trace\\non_mandatory_tour_frequency.non_mandatory_tours.csv',
#  'output/trace\\non_mandatory_tour_frequency.non_mandatory_tour_frequency_annotate_persons_preprocessor.csv',
#  'output/trace\\non_mandatory_tour_frequency.non_mandatory_tour_frequency_annotate_persons_preprocessor_locals.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.alternatives.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.choices.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.choosers.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.eval.person_id.1875721.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.eval.raw.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.interaction_df.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.interaction_utils.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.probs.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.rands.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_FULL.interaction_simulate.interaction_simulate.utils.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.alternatives.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.choices.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.choosers.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.eval.person_id.1875722.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.eval.raw.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.interaction_df.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.interaction_utils.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.probs.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.rands.csv',
#  'output/trace\\non_mandatory_tour_frequency.PTYPE_UNIVERSITY.interaction_simulate.interaction_simulate.utils.csv',
#  'output/trace\\non_mandatory_tour_scheduling.csv',
#  'output/trace\\non_mandatory_tour_scheduling.non_mandatory_tour_scheduling_annotate_tours_preprocessor.csv',
#  'output/trace\\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.alternatives.csv',
#  'output/trace\\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.choices.csv',
#  'output/trace\\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.choosers.csv',
#  'output/trace\\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.eval.household_id.982875.csv',
#  'output/trace\\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.eval.raw.csv',
#  'output/trace\\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.interaction_df.csv',
#  'output/trace\\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.interaction_utilities.csv',
#  'output/trace\\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.probs.csv',
#  'output/trace\\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.rands.csv',
#  'output/trace\\non_mandatory_tour_scheduling.vectorize_tour_scheduling.tour_1.interaction_sample_simulate.utilities.csv',
#  'output/trace\\raw.households.csv',
#  'output/trace\\raw.persons.csv',
#  'output/trace\\school_location.annotate_persons.annotate_persons_school.csv',
#  'output/trace\\school_location.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.choosers.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_values.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_BIKE.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEFREE.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEPAY.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_COM.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_EXP.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_HVY.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LOC.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LRF.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2FREE.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2PAY.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3FREE.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3PAY.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TAXI.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SHARED.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SINGLE.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_COM.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_EXP.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_HVY.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LOC.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LRF.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.logsums.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.nested_exp_utilities.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.eval_nl_logsums.raw_utilities.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.tour_mode_choice_annotate_choosers_preprocessor.csv',
#  'output/trace\\school_location.i1.logsums.university.compute_logsums.tour_mode_choice_annotate_choosers_preprocessor_locals.csv',
#  'output/trace\\school_location.i1.sample.university.interaction_sample.alternatives.csv',
#  'output/trace\\school_location.i1.sample.university.interaction_sample.choosers.csv',
#  'output/trace\\school_location.i1.sample.university.interaction_sample.eval.person_id.1875722.csv',
#  'output/trace\\school_location.i1.sample.university.interaction_sample.eval.raw.csv',
#  'output/trace\\school_location.i1.sample.university.interaction_sample.interaction_df.csv',
#  'output/trace\\school_location.i1.sample.university.interaction_sample.interaction_utilities.csv',
#  'output/trace\\school_location.i1.sample.university.interaction_sample.probs.csv',
#  'output/trace\\school_location.i1.sample.university.interaction_sample.sampled_alternatives.csv',
#  'output/trace\\school_location.i1.sample.university.interaction_sample.utils.csv',
#  'output/trace\\school_location.i1.simulate.university.interaction_sample_simulate.alternatives.csv',
#  'output/trace\\school_location.i1.simulate.university.interaction_sample_simulate.choices.csv',
#  'output/trace\\school_location.i1.simulate.university.interaction_sample_simulate.choosers.csv',
#  'output/trace\\school_location.i1.simulate.university.interaction_sample_simulate.eval.person_id.1875722.csv',
#  'output/trace\\school_location.i1.simulate.university.interaction_sample_simulate.eval.raw.csv',
#  'output/trace\\school_location.i1.simulate.university.interaction_sample_simulate.interaction_df.csv',
#  'output/trace\\school_location.i1.simulate.university.interaction_sample_simulate.interaction_utilities.csv',
#  'output/trace\\school_location.i1.simulate.university.interaction_sample_simulate.logsum.csv',
#  'output/trace\\school_location.i1.simulate.university.interaction_sample_simulate.probs.csv',
#  'output/trace\\school_location.i1.simulate.university.interaction_sample_simulate.rands.csv',
#  'output/trace\\school_location.i1.simulate.university.interaction_sample_simulate.utilities.csv',
#  'output/trace\\shadow_price_school_desired_size.csv',
#  'output/trace\\shadow_price_school_modeled_size_1.csv',
#  'output/trace\\shadow_price_workplace_desired_size.csv',
#  'output/trace\\shadow_price_workplace_modeled_size_1.csv',
#  'output/trace\\stop_frequency.annotations.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.choices.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.choosers.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_values.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_0out_0in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_0out_1in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_0out_2in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_0out_3in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_1out_0in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_1out_1in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_1out_2in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_1out_3in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_2out_0in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_2out_1in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_2out_2in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_2out_3in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_3out_0in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_3out_1in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_3out_2in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.eval_utils.expression_value_3out_3in.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.probs.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.rands.csv',
#  'output/trace\\stop_frequency.eatout.simple_simulate.eval_mnl.utilities.csv',
#  'output/trace\\stop_frequency.stop_frequency_annotate_tours_preprocessor.csv',
#  'output/trace\\stop_frequency.stop_frequency_annotate_tours_preprocessor_locals.csv',
#  'output/trace\\stop_frequency.tours.csv',
#  'output/trace\\stop_frequency.tours_merged.csv',
#  'output/trace\\stop_frequency.trips.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.choices.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.choosers.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_values.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_0out_0in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_0out_1in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_0out_2in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_0out_3in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_1out_0in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_1out_1in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_1out_2in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_1out_3in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_2out_0in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_2out_1in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_2out_2in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_2out_3in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_3out_0in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_3out_1in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_3out_2in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.eval_utils.expression_value_3out_3in.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.probs.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.rands.csv',
#  'output/trace\\stop_frequency.work.simple_simulate.eval_mnl.utilities.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.base_probabilities.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.choices.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.choosers.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_values.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_BIKE.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEFREE.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEPAY.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_COM.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_EXP.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_HVY.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LOC.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LRF.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2FREE.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2PAY.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3FREE.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3PAY.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_TAXI.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SHARED.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SINGLE.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_COM.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_EXP.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_HVY.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LOC.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LRF.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.logsums.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.nested_exp_utilities.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.nested_probabilities.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.rands.csv',
#  'output/trace\\tour_mode_choice.eatout.simple_simulate.eval_nl.raw_utilities.csv',
#  'output/trace\\tour_mode_choice.eatout.tour_mode_choice_annotate_choosers_preprocessor.csv',
#  'output/trace\\tour_mode_choice.eatout.tour_mode_choice_annotate_choosers_preprocessor_locals.csv',
#  'output/trace\\tour_mode_choice.tour_mode.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.base_probabilities.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.choices.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.choosers.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_values.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_BIKE.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEFREE.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEPAY.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_COM.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_EXP.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_HVY.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LOC.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LRF.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2FREE.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2PAY.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3FREE.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3PAY.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_TAXI.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SHARED.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SINGLE.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_COM.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_EXP.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_HVY.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LOC.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LRF.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.logsums.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.nested_exp_utilities.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.nested_probabilities.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.rands.csv',
#  'output/trace\\tour_mode_choice.work.simple_simulate.eval_nl.raw_utilities.csv',
#  'output/trace\\tour_mode_choice.work.tour_mode_choice_annotate_choosers_preprocessor.csv',
#  'output/trace\\tour_mode_choice.work.tour_mode_choice_annotate_choosers_preprocessor_locals.csv',
#  'output/trace\\trip_destination.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.choosers.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_values.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_BIKE.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEFREE.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEPAY.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_DRIVE_COM.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_DRIVE_EXP.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_DRIVE_HVY.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_DRIVE_LOC.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_DRIVE_LRF.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_SHARED2FREE.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_SHARED2PAY.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_SHARED3FREE.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_SHARED3PAY.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_TAXI.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_TNC_SHARED.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_TNC_SINGLE.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_WALK.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_WALK_COM.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_WALK_EXP.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_WALK_HVY.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_WALK_LOC.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.eval_utils.expression_value_WALK_LRF.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.logsums.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.nested_exp_utilities.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.eval_nl_logsums.raw_utilities.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.dp.trip_mode_choice_annotate_trips_preprocessor.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.choosers.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_values.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_BIKE.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEFREE.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEPAY.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_DRIVE_COM.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_DRIVE_EXP.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_DRIVE_HVY.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_DRIVE_LOC.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_DRIVE_LRF.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_SHARED2FREE.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_SHARED2PAY.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_SHARED3FREE.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_SHARED3PAY.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_TAXI.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_TNC_SHARED.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_TNC_SINGLE.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_WALK.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_WALK_COM.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_WALK_EXP.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_WALK_HVY.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_WALK_LOC.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.eval_utils.expression_value_WALK_LRF.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.eval_nl_logsums.logsums.csv',
# ...
#  'output/trace\\trip_destination.trip_num_1.eatout.compute_logsums.od.trip_mode_choice_annotate_trips_preprocessor.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.sample.interaction_sample.alternatives.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.sample.interaction_sample.choosers.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.sample.interaction_sample.eval.household_id.982875.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.sample.interaction_sample.eval.raw.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.sample.interaction_sample.interaction_df.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.sample.interaction_sample.interaction_utilities.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.sample.interaction_sample.probs.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.sample.interaction_sample.sampled_alternatives.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.sample.interaction_sample.utils.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.alternatives.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.choices.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.choosers.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.eval.household_id.982875.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.eval.raw.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.interaction_df.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.interaction_utilities.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.logsum.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.probs.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.rands.csv',
#  'output/trace\\trip_destination.trip_num_1.eatout.trip_dest_simulate.interaction_sample_simulate.utilities.csv',
#  'output/trace\\trip_destination.trip_num_1.trip_destination_annotate_trips_preprocessor.csv',
#  'output/trace\\trip_matrices.write_trip_matrices_annotate_trips_preprocessor.csv',
#  'output/trace\\trip_mode_choice.atwork.constants.csv',
#  'output/trace\\trip_mode_choice.eatout.constants.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.base_probabilities.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.choices.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.choosers.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_values.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_BIKE.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEFREE.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEPAY.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_COM.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_EXP.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_HVY.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LOC.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LRF.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2FREE.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2PAY.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3FREE.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3PAY.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_TAXI.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SHARED.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SINGLE.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_COM.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_EXP.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_HVY.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LOC.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LRF.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.logsums.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.nested_exp_utilities.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.nested_probabilities.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.rands.csv',
#  'output/trace\\trip_mode_choice.eatout.simple_simulate.eval_nl.raw_utilities.csv',
#  'output/trace\\trip_mode_choice.eatout.trip_mode.csv',
#  'output/trace\\trip_mode_choice.eatout.trip_mode_choice_annotate_trips_preprocessor.csv',
#  'output/trace\\trip_mode_choice.escort.constants.csv',
#  'output/trace\\trip_mode_choice.othdiscr.constants.csv',
#  'output/trace\\trip_mode_choice.othmaint.constants.csv',
#  'output/trace\\trip_mode_choice.school.constants.csv',
#  'output/trace\\trip_mode_choice.shopping.constants.csv',
#  'output/trace\\trip_mode_choice.social.constants.csv',
#  'output/trace\\trip_mode_choice.trip_mode.csv',
#  'output/trace\\trip_mode_choice.univ.constants.csv',
#  'output/trace\\trip_mode_choice.work.constants.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.base_probabilities.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.choices.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.choosers.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_values.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_BIKE.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEFREE.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVEALONEPAY.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_COM.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_EXP.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_HVY.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LOC.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_DRIVE_LRF.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2FREE.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED2PAY.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3FREE.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_SHARED3PAY.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_TAXI.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SHARED.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_TNC_SINGLE.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_COM.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_EXP.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_HVY.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LOC.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.eval_utils.expression_value_WALK_LRF.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.logsums.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.nested_exp_utilities.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.nested_probabilities.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.rands.csv',
#  'output/trace\\trip_mode_choice.work.simple_simulate.eval_nl.raw_utilities.csv',
#  'output/trace\\trip_mode_choice.work.trip_mode.csv',
#  'output/trace\\trip_mode_choice.work.trip_mode_choice_annotate_trips_preprocessor.csv',
#  'output/trace\\trip_purpose.choices.csv',
#  'output/trace\\trip_purpose.csv',
#  'output/trace\\trip_purpose.rands.csv',
#  'output/trace\\trip_purpose.trip_purpose_annotate_trips_preprocessor.csv',
#  'output/trace\\trip_scheduling.i1.outbound.num_2.choices.csv',
#  'output/trace\\trip_scheduling.i1.outbound.num_2.choosers.csv',
#  'output/trace\\trip_scheduling.i1.outbound.num_2.chooser_probs.csv',
#  'output/trace\\trip_scheduling.i1.outbound.num_2.rands.csv',
#  'output/trace\\trip_scheduling.i100.outbound.num_3.failed_choosers.csv',
#  'output/trace\\trip_scheduling.i100.outbound.num_4.failed_choosers.csv',
#  'output/trace\\workplace_location.annotate_households.annotate_households_workplace.csv',
#  'output/trace\\workplace_location.annotate_persons.annotate_persons_workplace.csv',
#  'output/trace\\workplace_location.annotate_persons.annotate_persons_workplace_locals.csv',
#  'output/trace\\workplace_location.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.choosers.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_values.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_BIKE.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEFREE.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVEALONEPAY.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_COM.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_EXP.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_HVY.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LOC.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_DRIVE_LRF.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2FREE.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED2PAY.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3FREE.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_SHARED3PAY.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TAXI.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SHARED.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_TNC_SINGLE.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_COM.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_EXP.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_HVY.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LOC.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.eval_utils.expression_value_WALK_LRF.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.logsums.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.nested_exp_utilities.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.eval_nl_logsums.raw_utilities.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.tour_mode_choice_annotate_choosers_preprocessor.csv',
#  'output/trace\\workplace_location.i1.logsums.work_med.compute_logsums.tour_mode_choice_annotate_choosers_preprocessor_locals.csv',
#  'output/trace\\workplace_location.i1.sample.work_med.interaction_sample.alternatives.csv',
#  'output/trace\\workplace_location.i1.sample.work_med.interaction_sample.choosers.csv',
#  'output/trace\\workplace_location.i1.sample.work_med.interaction_sample.eval.person_id.1875721.csv',
#  'output/trace\\workplace_location.i1.sample.work_med.interaction_sample.eval.person_id.1875722.csv',
#  'output/trace\\workplace_location.i1.sample.work_med.interaction_sample.eval.raw.csv',
#  'output/trace\\workplace_location.i1.sample.work_med.interaction_sample.interaction_df.csv',
#  'output/trace\\workplace_location.i1.sample.work_med.interaction_sample.interaction_utilities.csv',
#  'output/trace\\workplace_location.i1.sample.work_med.interaction_sample.probs.csv',
#  'output/trace\\workplace_location.i1.sample.work_med.interaction_sample.sampled_alternatives.csv',
#  'output/trace\\workplace_location.i1.sample.work_med.interaction_sample.utils.csv',
#  'output/trace\\workplace_location.i1.simulate.work_med.interaction_sample_simulate.alternatives.csv',
#  'output/trace\\workplace_location.i1.simulate.work_med.interaction_sample_simulate.choices.csv',
#  'output/trace\\workplace_location.i1.simulate.work_med.interaction_sample_simulate.choosers.csv',
#  'output/trace\\workplace_location.i1.simulate.work_med.interaction_sample_simulate.eval.person_id.1875721.csv',
#  'output/trace\\workplace_location.i1.simulate.work_med.interaction_sample_simulate.eval.person_id.1875722.csv',
#  'output/trace\\workplace_location.i1.simulate.work_med.interaction_sample_simulate.eval.raw.csv',
#  'output/trace\\workplace_location.i1.simulate.work_med.interaction_sample_simulate.interaction_df.csv',
#  'output/trace\\workplace_location.i1.simulate.work_med.interaction_sample_simulate.interaction_utilities.csv',
#  'output/trace\\workplace_location.i1.simulate.work_med.interaction_sample_simulate.logsum.csv',
#  'output/trace\\workplace_location.i1.simulate.work_med.interaction_sample_simulate.probs.csv',
#  'output/trace\\workplace_location.i1.simulate.work_med.interaction_sample_simulate.rands.csv',
#  'output/trace\\workplace_location.i1.simulate.work_med.interaction_sample_simulate.utilities.csv']

# %%
print("Trace files for auto ownership.\n")
glob.glob("output/trace/auto_ownership*.csv")
# Out:
# Trace files for auto ownership.
# ['output/trace\\auto_ownership.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.choices.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.choosers.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_values.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars0.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars1.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars2.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars3.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_value_cars4.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.probs.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.rands.csv',
#  'output/trace\\auto_ownership_simulate.simple_simulate.eval_mnl.utilities.csv']

# %%
print("Trace chooser data for auto ownership.\n")
pd.read_csv("output\\trace\\auto_ownership_simulate.simple_simulate.eval_mnl.choosers.csv")
# Out:
# Trace chooser data for auto ownership.
#                  label               value
# 0         household_id              982875
# 1         home_zone_id                  16
# 2               income               30900
# 3               hhsize                   2
# 4                  HHT                   5
# ..                 ...                 ...
# 59            TERMINAL             4.75017
# 60   household_density    71.8980801556283
# 61  employment_density  273.02374467923295
# 62       density_index   56.91110757846511
# 63              is_cbd               False
#
# [64 rows x 2 columns]

# %%
print("Trace utility expression values for auto ownership.\n")
pd.read_csv("output\\trace\\auto_ownership_simulate.simple_simulate.eval_mnl.eval_utils.expression_values.csv")
# Out:
# Trace utility expression values for auto ownership.
#                                            Expression  \
# 0                                      num_drivers==2
# 1                                      num_drivers==3
# 2                                       num_drivers>3
# 3                               num_children_16_to_17
# 4                                     num_college_age
# 5                                    num_young_adults
# 6                                num_young_children>0
# 7      (num_children_5_to_15+num_children_16_to_17)>0
# 8                       @df.num_workers.clip(upper=3)
# 9                 @df.income_in_thousands.clip(0, 30)
# 10           @(df.income_in_thousands-30).clip(0, 45)
# 11           @(df.income_in_thousands-75).clip(0, 50)
# 12  @(df.num_workers==0)*df.density_index.clip(0, 10)
# 13  @(df.num_workers==0)*(df.density_index-10).cli...
# 14   @(df.num_workers>0)*df.density_index.clip(0, 10)
# 15  @(df.num_workers>0)*(df.density_index-10).clip(0)
# 16                                                  1
# 17                  @df.county_id == ID_SAN_FRANCISCO
# 18                         @df.county_id == ID_SOLANO
# 19                           @df.county_id == ID_NAPA
# 20                         @df.county_id == ID_SONOMA
# 21                          @df.county_id == ID_MARIN
# 22  (num_workers==0)*(0.66*auPkRetail+0.34*auOpRet...
# 23  (num_workers>0)*(0.66*auPkRetail+0.34*auOpRetail)
# 24  (num_workers==0)*(0.66*trPkRetail+0.34*trOpRet...
# 25  (num_workers>0)*(0.66*trPkRetail+0.34*trOpRetail)
# 26                          (num_workers==0)*nmRetail
# 27                           (num_workers>0)*nmRetail
# 28  @np.where(df.num_workers > 0, df.hh_work_auto_...
#
#                                Label          0
# 0                     util_drivers_2   1.000000
# 1                     util_drivers_3   0.000000
# 2                  util_drivers_4_up   0.000000
# 3                 util_persons_16_17   0.000000
# 4                 util_persons_18_24   0.000000
# 5                 util_persons_25_34   2.000000
# 6         util_presence_children_0_4   0.000000
# 7        util_presence_children_5_17   0.000000
# 8            util_num_workers_clip_3   2.000000
# 9               util_hh_income_0_30k  30.000000
# 10             util_hh_income_30_75k   0.900000
# 11             util_hh_income_75k_up   0.000000
# 12      util_density_0_10_no_workers   0.000000
# 13     util_density_10_up_no_workers   0.000000
# 14         util_density_0_10_workers  10.000000
# 15        util_density_10_up_workers  46.911108
# 16                          util_asc   1.000000
# 17            util_asc_san_francisco   1.000000
# 18                   util_asc_solano   0.000000
# 19                     util_asc_napa   0.000000
# 20                   util_asc_sonoma   0.000000
# 21                    util_asc_marin   0.000000
# 22       util_retail_auto_no_workers   0.000000
# 23          util_retail_auto_workers   9.311374
# 24    util_retail_transit_no_workers   0.000000
# 25       util_retail_transit_workers   6.992032
# 26  util_retail_non_motor_no_workers   0.000000
# 27     util_retail_non_motor_workers   8.247303
# 28  util_auto_time_saving_per_worker   0.199860

# %%
print("Trace alternative total utilities for auto ownership.\n")
pd.read_csv("output\\trace\\auto_ownership_simulate.simple_simulate.eval_mnl.utilities.csv")
# Out:
# Trace alternative total utilities for auto ownership.
#     alternative        utility
# 0  household_id  982875.000000
# 1         cars0       0.000000
# 2         cars1      -0.150164
# 3         cars2      -5.680333
# 4         cars3     -12.779770
# 5         cars4     -14.672508

# %%
print("Trace alternative probabilities for auto ownership.\n")
pd.read_csv("output\\trace\\auto_ownership_simulate.simple_simulate.eval_mnl.probs.csv")
# Out:
# Trace alternative probabilities for auto ownership.
#     alternative   probability
# 0  household_id  9.828750e+05
# 1         cars0  5.364857e-01
# 2         cars1  4.616819e-01
# 3         cars2  1.830715e-03
# 4         cars3  1.511383e-06
# 5         cars4  2.277031e-07

# %%
print("Trace random number for auto ownership.\n")
pd.read_csv("output\\trace\\auto_ownership_simulate.simple_simulate.eval_mnl.rands.csv")
# Out:
# Trace random number for auto ownership.
#    household_id      rand
# 0        982875  0.746306

# %%
print("Trace choice for auto ownership.\n")
pd.read_csv("output\\trace\\auto_ownership_simulate.simple_simulate.eval_mnl.choices.csv")
# Out:
# Trace choice for auto ownership.
#    household_id  auto_ownership
# 0        982875               1

# %% [markdown]
# # Run the Multiprocessor Example
#
# The command below runs the multiprocessor example, which runs in a few minutes.  It uses settings inheritance to override setings in the configs folder with settings in the configs_mp folder.  This allows for re-using expression files and settings files in the single and multiprocessed setups.  The multiprocessed example uses the following additional settings:
#
# ```
# num_processes: 2
# chunk_size: 0
# chunk_training_mode: disabled
#
# multiprocess_steps:
#   - name: mp_initialize
#     begin: initialize_landuse
#   - name: mp_households
#     begin: school_location
#     slice:
#       tables:
#         - households
#         - persons
#   - name: mp_summarize
#     begin: write_data_dictionary
#
# ```
#
# In brief, `num_processes` specifies the number of processors to use and a `chunk_size` of `0` plus a `chunk_training_mode` of `disabled` means ActivitySim is free to use all the available RAM if needed.  The `multiprocess_steps` specifies the beginning, middle, and end steps in multiprocessing.  The `mp_initialize` step is single processed because there is no `slice` setting.  It starts with the `initialize_landuse` submodel and runs until the submodel identified by the next multiprocess submodel starting point, `school_location`.  The `mp_households` step is multiprocessed and the households and persons tables are sliced and allocated to processes using the chunking settings.  The rest of the submodels are run multiprocessed until the final multiprocess step.  The `mp_summarize` step is single processed because there is no `slice` setting and it writes outputs.  See [multiprocessing](https://activitysim.github.io/activitysim/core.html#multiprocessing) and [chunk_size](https://activitysim.github.io/activitysim/core.html#chunk) for more information.

# %%
# !activitysim run -c configs_mp -c configs -d data -o output
# Out:
# Configured logging using basicConfig
# INFO:activitysim:Configured logging using basicConfig
# [WinError 32] The process cannot access the file because it is being used by another process: 'output\\pipeline.h5'
# INFO - activitysim - Read logging configuration from: configs_mp\logging.yaml
# INFO - activitysim.cli.run - SETTING configs_dir: ['configs_mp', 'configs']
# INFO - activitysim.cli.run - SETTING settings_file_name: settings.yaml
# INFO - activitysim.cli.run - SETTING data_dir: ['data']
# INFO - activitysim.cli.run - SETTING output_dir: output
# INFO - activitysim.cli.run - SETTING households_sample_size: 100
# INFO - activitysim.cli.run - SETTING chunk_size: 0
# INFO - activitysim.cli.run - SETTING chunk_method: hybrid_uss
# INFO - activitysim.cli.run - SETTING chunk_training_mode: training
# INFO - activitysim.cli.run - SETTING multiprocess: True
# INFO - activitysim.cli.run - SETTING num_processes: 2
# INFO - activitysim.cli.run - SETTING resume_after: None
# INFO - activitysim.cli.run - SETTING trace_hh_id: 982875
# INFO - activitysim.cli.run - ENV MKL_NUM_THREADS: None
# INFO - activitysim.cli.run - ENV OMP_NUM_THREADS: None
# INFO - activitysim.cli.run - ENV OPENBLAS_NUM_THREADS: None
# INFO - activitysim.cli.run - NUMPY blas_info libraries: ['cblas', 'blas', 'cblas', 'blas', 'cblas', 'blas']
# INFO - activitysim.cli.run - NUMPY blas_opt_info libraries: ['cblas', 'blas', 'cblas', 'blas', 'cblas', 'blas']
# INFO - activitysim.cli.run - NUMPY lapack_info libraries: ['lapack', 'blas', 'lapack', 'blas']
# INFO - activitysim.cli.run - NUMPY lapack_opt_info libraries: ['lapack', 'blas', 'lapack', 'blas', 'cblas', 'blas', 'cblas', 'blas', 'cblas', 'blas']
# INFO - activitysim.cli.run - run multiprocess simulation
# INFO - activitysim.core.mp_tasks - Setting num_processes = 0 for step mp_households
# INFO - activitysim.core.mp_tasks - run_multiprocess fail_fast: True
# INFO - activitysim.core.mp_tasks - allocate_shared_skim_buffer
# DEBUG - activitysim.abm.tables.skims - loading network_los_without_data_loaded injectable
# INFO - activitysim.core.los - Network_LOS using skim_dict_factory: NumpyArraySkimFactory
# DEBUG - activitysim.core.skim_dict_factory - load_skim_info taz reading data\skims.omx
# INFO - activitysim.core.skim_dict_factory - allocate_skim_buffer shared True taz shape (826, 25, 25) total size: 2_065_000 (2.1 MB)
# INFO - activitysim.core.tracing - Time to execute allocate shared skim buffer : 0.544 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - allocate_shared_shadow_pricing_buffers
# DEBUG - activitysim.abm.tables.shadow_pricing - loading shadow_pricing_info injectable
# INFO - activitysim.core.input - Reading CSV file data\land_use.csv
# DEBUG - activitysim.core.input - raw land_use table size: (25, 42) 8.5 KB
# DEBUG - activitysim.core.input - renaming columns: {'TAZ': 'zone_id', 'COUNTY': 'county_id'}
# DEBUG - activitysim.core.input - keeping columns: ['DISTRICT', 'SD', 'county_id', 'TOTHH', 'TOTPOP', 'TOTACRE', 'RESACRE', 'CIACRE', 'TOTEMP', 'AGE0519', 'RETEMPN', 'FPSEMPN', 'HEREMPN', 'OTHEMPN', 'AGREMPN', 'MWTEMPN', 'PRKCST', 'OPRKCST', 'area_type', 'HSENROLL', 'COLLFTE', 'COLLPTE', 'TOPOLOGY', 'TERMINAL']
# DEBUG - activitysim.core.input - land_use table columns: ['DISTRICT' 'SD' 'county_id' 'TOTHH' 'TOTPOP' 'TOTACRE' 'RESACRE' 'CIACRE'
#  'TOTEMP' 'AGE0519' 'RETEMPN' 'FPSEMPN' 'HEREMPN' 'OTHEMPN' 'AGREMPN'
#  'MWTEMPN' 'PRKCST' 'OPRKCST' 'area_type' 'HSENROLL' 'COLLFTE' 'COLLPTE'
#  'TOPOLOGY' 'TERMINAL']
# DEBUG - activitysim.core.input - land_use table size: (25, 24) 5.0 KB
# DEBUG - activitysim.core.input - land_use index name: zone_id
# INFO - activitysim.abm.tables.landuse - loaded land_use (25, 24)
# DEBUG - activitysim.abm.tables.shadow_pricing - shadow_pricing_info dtype: <class 'numpy.int64'>
# DEBUG - activitysim.abm.tables.shadow_pricing - shadow_pricing_info block_shapes: OrderedDict([('school', (25, 4)), ('workplace', (25, 5))])
# INFO - activitysim.abm.tables.shadow_pricing - allocating shared shadow pricing buffer school 100 buffer_size (25, 4) bytes 800 (800 B)
# INFO - activitysim.abm.tables.shadow_pricing - buffer_for_shadow_pricing added block school
# INFO - activitysim.abm.tables.shadow_pricing - allocating shared shadow pricing buffer workplace 125 buffer_size (25, 5) bytes 1000 (1000 B)
# INFO - activitysim.abm.tables.shadow_pricing - buffer_for_shadow_pricing added block workplace
# INFO - activitysim.core.tracing - Time to execute allocate shared shadow_pricing buffer : 0.057 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - #run_model running sub_process mp_setup_skims
# INFO - activitysim.core.tracing - Time to execute #run_model sub_process mp_setup_skims : 4.031 seconds (0.1 minutes)
# INFO - activitysim.core.tracing - Time to execute setup shared_data_buffers : 4.085 seconds (0.1 minutes)
# INFO - activitysim.core.mp_tasks - run_sub_simulations step mp_initialize models resume_after None
# INFO - activitysim.core.mp_tasks - start process mp_initialize
# [WinError 32] The process cannot access the file because it is being used by another process: 'output\\pipeline.h5'
# mp_initialize WARNING - activitysim.core.pipeline - Error removing output\pipeline.h5: [WinError 32] The process cannot access the file because it is being used by another process: 'output\\pipeline.h5'
# INFO - activitysim.core.mp_tasks - mp_initialize initialize_landuse : 0.668 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_initialize initialize_households : 1.047 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - process mp_initialize completed
# INFO - activitysim.core.mp_tasks - Process mp_initialize completed with exitcode 0
# INFO - activitysim.core.tracing - Time to execute run_sub_simulations step mp_initialize : 4.118 seconds (0.1 minutes)
# INFO - activitysim.core.mp_tasks - #run_model running sub_process mp_accessibility_apportion
# INFO - activitysim.core.tracing - Time to execute #run_model sub_process mp_accessibility_apportion : 3.041 seconds (0.1 minutes)
# INFO - activitysim.core.mp_tasks - run_sub_simulations step mp_accessibility models resume_after None
# INFO - activitysim.core.mp_tasks - start process mp_accessibility_0
# INFO - activitysim.core.mp_tasks - start process mp_accessibility_1
# INFO - activitysim.core.mp_tasks - mp_accessibility_0 compute_accessibility : 0.951 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - process mp_accessibility_0 completed
# INFO - activitysim.core.mp_tasks - mp_accessibility_1 compute_accessibility : 0.725 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - process mp_accessibility_1 completed
# INFO - activitysim.core.mp_tasks - Process mp_accessibility_0 completed with exitcode 0
# INFO - activitysim.core.mp_tasks - Process mp_accessibility_1 completed with exitcode 0
# INFO - activitysim.core.tracing - Time to execute run_sub_simulations step mp_accessibility : 5.188 seconds (0.1 minutes)
# INFO - activitysim.core.mp_tasks - #run_model running sub_process mp_accessibility_coalesce
# INFO - activitysim.core.tracing - Time to execute #run_model sub_process mp_accessibility_coalesce : 3.027 seconds (0.1 minutes)
# INFO - activitysim.core.mp_tasks - #run_model running sub_process mp_households_apportion
# INFO - activitysim.core.tracing - Time to execute #run_model sub_process mp_households_apportion : 3.036 seconds (0.1 minutes)
# INFO - activitysim.core.mp_tasks - run_sub_simulations step mp_households models resume_after None
# INFO - activitysim.core.mp_tasks - start process mp_households_0
# INFO - activitysim.core.mp_tasks - start process mp_households_1
# mp_households_1 WARNING - activitysim.core.tracing - trace_hh_id 982875 not in dataframe
# mp_households_1 WARNING - activitysim.core.tracing - register persons: no rows with household_id in [].
# INFO - activitysim.core.mp_tasks - mp_households_0 school_location : 14.739 seconds (0.2 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 school_location : 12.82 seconds (0.2 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 workplace_location : 18.423 seconds (0.3 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 auto_ownership_simulate : 0.622 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 free_parking : 0.716 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 workplace_location : 20.1 seconds (0.3 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 auto_ownership_simulate : 0.734 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 free_parking : 0.612 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 cdap_simulate : 14.964 seconds (0.2 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 cdap_simulate : 14.713 seconds (0.2 minutes)
# mp_households_1 WARNING - activitysim.core.tracing - register tours: no rows with household_id in [].
# INFO - activitysim.core.mp_tasks - mp_households_0 mandatory_tour_frequency : 1.996 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 mandatory_tour_frequency : 1.908 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 mandatory_tour_scheduling : 22.935 seconds (0.4 minutes)
# mp_households_1 WARNING - activitysim.core.tracing - register tours: no rows with household_id in [].
# INFO - activitysim.core.mp_tasks - mp_households_1 joint_tour_frequency : 1.399 seconds (0.0 minutes)
# mp_households_1 WARNING - activitysim.core.tracing - register joint_tour_participants: no rows with household_id in [].
# INFO - activitysim.core.mp_tasks - mp_households_1 joint_tour_composition : 0.816 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 joint_tour_participation : 1.57 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 mandatory_tour_scheduling : 29.011 seconds (0.5 minutes)
# mp_households_0 WARNING - activitysim.core.tracing - register tours: no rows with household_id in [982875].
# INFO - activitysim.core.mp_tasks - mp_households_0 joint_tour_frequency : 1.845 seconds (0.0 minutes)
# mp_households_0 WARNING - activitysim.core.tracing - register joint_tour_participants: no rows with household_id in [982875].
# INFO - activitysim.core.mp_tasks - mp_households_0 joint_tour_composition : 1.016 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 joint_tour_participation : 1.752 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 joint_tour_destination : 9.291 seconds (0.2 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 joint_tour_destination : 4.38 seconds (0.1 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 joint_tour_scheduling : 3.463 seconds (0.1 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 joint_tour_scheduling : 3.254 seconds (0.1 minutes)
# mp_households_1 WARNING - activitysim.core.tracing - register tours: no rows with household_id in [].
# INFO - activitysim.core.mp_tasks - mp_households_1 non_mandatory_tour_frequency : 13.382 seconds (0.2 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 non_mandatory_tour_frequency : 12.86 seconds (0.2 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 non_mandatory_tour_destination : 21.47 seconds (0.4 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 non_mandatory_tour_destination : 25.443 seconds (0.4 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 non_mandatory_tour_scheduling : 8.882 seconds (0.1 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 non_mandatory_tour_scheduling : 11.293 seconds (0.2 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 tour_mode_choice_simulate : 23.113 seconds (0.4 minutes)
# mp_households_0 WARNING - activitysim.core.tracing - register tours: no rows with household_id in [982875].
# INFO - activitysim.core.mp_tasks - mp_households_0 atwork_subtour_frequency : 1.668 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 atwork_subtour_destination : 4.636 seconds (0.1 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 atwork_subtour_scheduling : 2.997 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 tour_mode_choice_simulate : 26.624 seconds (0.4 minutes)
# mp_households_1 WARNING - activitysim.core.tracing - register tours: no rows with household_id in [].
# INFO - activitysim.core.mp_tasks - mp_households_1 atwork_subtour_frequency : 0.942 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 atwork_subtour_mode_choice : 2.667 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 atwork_subtour_destination : 4.881 seconds (0.1 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 atwork_subtour_scheduling : 2.383 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 stop_frequency : 7.157 seconds (0.1 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 trip_purpose : 0.457 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 atwork_subtour_mode_choice : 2.593 seconds (0.0 minutes)
# mp_households_1 WARNING - activitysim.core.tracing - register trips: no rows with household_id in [].
# INFO - activitysim.core.mp_tasks - mp_households_1 stop_frequency : 6.83 seconds (0.1 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 trip_purpose : 0.396 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 trip_destination : 49.096 seconds (0.8 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 trip_purpose_and_destination : 0.172 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_0 trip_scheduling : 2.471 seconds (0.0 minutes)
# mp_households_0 WARNING - activitysim.core.tracing - slice_canonically: no rows in trip_mode_choice.atwork.trip_mode with household_id == [982875]
# mp_households_0 WARNING - activitysim.core.tracing - slice_canonically: no rows in trip_mode_choice.othdiscr.trip_mode with household_id == [982875]
# mp_households_0 WARNING - activitysim.core.tracing - slice_canonically: no rows in trip_mode_choice.othmaint.trip_mode with household_id == [982875]
# mp_households_0 WARNING - activitysim.core.tracing - slice_canonically: no rows in trip_mode_choice.school.trip_mode with household_id == [982875]
# mp_households_0 WARNING - activitysim.core.tracing - slice_canonically: no rows in trip_mode_choice.shopping.trip_mode with household_id == [982875]
# mp_households_0 WARNING - activitysim.core.tracing - slice_canonically: no rows in trip_mode_choice.social.trip_mode with household_id == [982875]
# mp_households_0 WARNING - activitysim.core.tracing - slice_canonically: no rows in trip_mode_choice.univ.trip_mode with household_id == [982875]
# INFO - activitysim.core.mp_tasks - mp_households_0 trip_mode_choice : 19.328 seconds (0.3 minutes)
# INFO - activitysim.core.mp_tasks - process mp_households_0 completed
# INFO - activitysim.core.mp_tasks - mp_households_1 trip_destination : 99.634 seconds (1.7 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 trip_purpose_and_destination : 0.127 seconds (0.0 minutes)
# mp_households_1 WARNING - activitysim.abm.models.trip_scheduling - trip_scheduling.i100.outbound.num_2 coercing 0 depart choices to most initial
# mp_households_1 WARNING - activitysim.abm.models.trip_scheduling - trip_scheduling.i100.outbound.num_3 coercing 1 depart choices to most initial
# mp_households_1 WARNING - activitysim.abm.models.trip_scheduling - trip_scheduling.i100.outbound.num_4 coercing 1 depart choices to most initial
# INFO - activitysim.core.mp_tasks - mp_households_1 trip_scheduling : 141.396 seconds (2.4 minutes)
# INFO - activitysim.core.mp_tasks - mp_households_1 trip_mode_choice : 14.998 seconds (0.2 minutes)
# INFO - activitysim.core.mp_tasks - process mp_households_1 completed
# INFO - activitysim.core.mp_tasks - Process mp_households_0 completed with exitcode 0
# INFO - activitysim.core.mp_tasks - Process mp_households_1 completed with exitcode 0
# INFO - activitysim.core.tracing - Time to execute run_sub_simulations step mp_households : 446.378 seconds (7.4 minutes)
# INFO - activitysim.core.mp_tasks - #run_model running sub_process mp_households_coalesce
# INFO - activitysim.core.tracing - Time to execute #run_model sub_process mp_households_coalesce : 3.006 seconds (0.1 minutes)
# INFO - activitysim.core.mp_tasks - run_sub_simulations step mp_summarize models resume_after None
# INFO - activitysim.core.mp_tasks - start process mp_summarize
# mp_summarize WARNING - activitysim.core.tracing - register joint_tour_participants: no rows with household_id in [982875].
# INFO - activitysim.core.mp_tasks - mp_summarize write_data_dictionary : 0.27 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_summarize write_trip_matrices : 1.249 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - mp_summarize write_tables : 0.2 seconds (0.0 minutes)
# INFO - activitysim.core.mp_tasks - process mp_summarize completed
# INFO - activitysim.core.mp_tasks - Process mp_summarize completed with exitcode 0
# INFO - activitysim.core.tracing - Time to execute run_sub_simulations step mp_summarize : 4.107 seconds (0.1 minutes)
# INFO - activitysim.core.mem - MainProcess high water mark rss: 434_630_656 (434.6 MB) timestamp: 03/06/2021 07:09:09 label:mp_households_0.mandatory_tour_frequency.completed
# INFO - activitysim.core.mem - MainProcess high water mark uss: 108_953_600 (109.0 MB) timestamp: 03/06/2021 07:08:13 label:run_model mp_households_apportion completed
# DEBUG - activitysim.core.chunk - chunk.consolidate_logs reading glob output\log\*chunk_history.csv
# DEBUG - activitysim.core.chunk - chunk.consolidate_logs writing omnibus log to output\log\omnibus_chunk_history.csv
# DEBUG - activitysim.core.chunk - consolidate_logs dropping 2 rows where num_rows == 0
# DEBUG - activitysim.core.chunk - chunk.consolidate_logs writing omnibus chunk cache to output\log\chunk_cache.csv
# DEBUG - activitysim.core.chunk - chunk.consolidate_logs writing chunk cache to output\cache\chunk_cache.csv
# DEBUG - activitysim.core.mem - mem.consolidate_logs for step mp_initialize
# DEBUG - activitysim.core.mem - mem.consolidate_logs consolidating 1 logs for mp_initialize
# DEBUG - activitysim.core.mem - chunk.consolidate_logs writing step summary log for step mp_initialize to output\log\mem_mp_initialize.csv
# DEBUG - activitysim.core.mem - mem.consolidate_logs for step mp_accessibility
# DEBUG - activitysim.core.mem - mem.consolidate_logs consolidating 2 logs for mp_accessibility
# DEBUG - activitysim.core.mem - chunk.consolidate_logs writing step summary log for step mp_accessibility to output\log\mem_mp_accessibility.csv
# DEBUG - activitysim.core.mem - mem.consolidate_logs for step mp_households
# DEBUG - activitysim.core.mem - mem.consolidate_logs consolidating 2 logs for mp_households
# DEBUG - activitysim.core.mem - chunk.consolidate_logs writing step summary log for step mp_households to output\log\mem_mp_households.csv
# DEBUG - activitysim.core.mem - mem.consolidate_logs for step mp_summarize
# DEBUG - activitysim.core.mem - mem.consolidate_logs consolidating 1 logs for mp_summarize
# DEBUG - activitysim.core.mem - chunk.consolidate_logs writing step summary log for step mp_summarize to output\log\mem_mp_summarize.csv
# DEBUG - activitysim.core.mem - chunk.consolidate_logs writing omnibus log to output\log\omnibus_mem.csv
# INFO - activitysim.core.tracing - Time to execute all models : 477.186 seconds (8.0 minutes)

# %% [markdown]
# # Next Steps and Further Reading
#
# For futher information on the software, management consortium, and activity-based models in general, see the resources below.
#
# * ActivitySim
#   * [User Documentation](https://activitysim.github.io/activitysim/)
#   * [GitHub Repository](https://github.com/ActivitySim/activitysim)
#   * [Project Wiki](https://github.com/ActivitySim/activitysim/wiki)
# * [Activity-Based Travel Demand Models: A Primer](http://www.trb.org/Publications/Blurbs/170963.aspx)
